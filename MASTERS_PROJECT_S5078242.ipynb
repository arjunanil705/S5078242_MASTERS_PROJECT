# %% [markdown]
# # STEP 1: IMPORTING THE REQUIRED LIBRARIES FOR ANALYSIS:

# %% [markdown]
# The librares to be imported are divided into 4 parts-
# 1- The libraries which are required for inputing , modifying and plotting the data in the Jupyter environment
# 2- The libraries which are required for running the algorithms that are Random Forest Regressor, Support Vector Regressor and Neural networks
# 3- The libraries that are required to help the user to measure the efficiency of the algorithms and also to help the data preprocessing steps
# 4- The libraries that are required to install the Hyper parameter tuning algorithms onto the Jupyter environment

# %%
#importing Libraries which are required for inputing,modifying and plotting the data.
import numpy as np  #IMPORTING NUMPY
import pandas as pd #IMPORTING PANDAS
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
from scipy import stats #IMPORTING SCIPY
from scipy.stats import norm, skew #for some statistics
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points

# %%
#Importing the algorithm libraries:
from sklearn.ensemble import RandomForestRegressor #IMPORTING THE RANDOM FOREST REGRESSOR
from sklearn.svm import LinearSVR #IMPORTING THE SUPPORT VECTOR REGRESSOR
#Importing the neural network algorithm:
from keras.callbacks import ModelCheckpoint

from keras.models import Sequential

from keras.layers import Dense, Activation, Flatten
from keras.wrappers.scikit_learn import KerasRegressor
# Out:
# Using TensorFlow backend.

# %%
#IMPORTING THE DATA PRE-PROCESSING LIBRARIES:
from sklearn.preprocessing import StandardScaler      #IMPORTING THE LIBRARY FOR SCALING THE FEATURES
from sklearn.model_selection import train_test_split  #IMPORTING THE LIBRARY FOR SPLITTING THE DATA INTO TRAINING AND TESTING
from sklearn.preprocessing import LabelEncoder        #IMPORTING THE LIBRARY FOR ENCDOING CATEGORICAL VARIABLES
from sklearn.model_selection import cross_val_score   #IMPORTING THE LIBRARY TO DO CROSS VALIDATION ON TESTING DATA
from sklearn.model_selection import KFold             #IMPORTING THE LIBRARY WHICH DOES CROSS VALIDATION FOR NEURAL NETWORK MODELS
from sklearn.model_selection import StratifiedKFold   #IMPORTING THE STRTIFIED CROSS VALIDATION TECHNIQUE FOR NEURAL NETWORKS

# %%
#IMPORTING THE PERFORMANCE EVALUATION METRIC LIBRARIES:
from sklearn.metrics import mean_absolute_error #IMPORTING THE LIBRARY TO CALCULATE THE MEAN ABOSLUTE ERROR
from scipy.stats import normaltest              #IMPORTING THE LIBRARY TO CALCULATE THE NORMALITY OF THE MEAN DISTRIBUTIONS OF RESULTS
from scipy.stats import ttest_rel               #IMPORTING THE STUDENTS T-TEST LIBRARY
from scipy.stats import wilcoxon                #IMPORTING THE WILCOXON SIGNED RANK TEST LIBRARY
import time                                     #IMPORTING THE LIBRARY REQUIRED TO CALCULATE THE COMPUTATIONAL TIME:

# %%
# IMPORTING THE HYPER PARAMETER TUNING LIBRARIES:
from sklearn.model_selection import GridSearchCV       #IMPORTING THE GRID SEARCH TUNING METHOD LIBRARY
from sklearn.model_selection import RandomizedSearchCV #IMPORTING THE RANDOM SEARCH TUNING METHOD LIBRARY
from skopt import BayesSearchCV                        #IMPORTING THE BAYESIAN SEARCH TUNING LIBRARY

# %% [markdown]
# #  STEP 2: IMPORTING THE DATA FILE INTO THE JUPYTER ENVIRONMENT

# %%
# load dataset
data = pd.read_csv('s5078242_dataset.csv')

# %%
#CHECKING THE SHAPE OF THE DATA:
data.shape
# Out:
# (5789, 31)

# %% [markdown]
# FROM THE ABOVE CODE WE CAN SEE THAT THE TOTAL NUMBER OF READINGS IN THE DATA SET IS 5789 AND THE TOTAL NUMBER OF FEATURES IN THE DATASET IS 31 WHICH IS INCLUDING THE TARGET VARIABLE SYSTOLIC BLOOD PRESSURE

# %%
# BASIC STATISTICS OF THE FEATURES IN THE DATASET:

# %%
data.describe()
# Out:
#            Age  HeartRate  No of maximas in the first derivative  \
# count 5708.000   5775.000                               5789.000
# mean    50.054     73.186                                  4.695
# std     17.118     13.021                                  0.956
# min     18.000      6.000                                  2.136
# 25%     36.000     65.000                                  4.067
# 50%     51.000     72.000                                  4.615
# 75%     62.000     81.000                                  5.273
# max    117.000    183.000                                 10.000
#
#        No of minimas in the first derivative  Systolic peak amplitude  \
# count                               5789.000                 5789.000
# mean                                   4.711                    3.007
# std                                    0.961                    0.285
# min                                    2.136                    1.651
# 25%                                    4.067                    2.849
# 50%                                    4.643                    3.055
# 75%                                    5.308                    3.196
# max                                   10.000                    4.075
#
#        Pulse interval  Systolic time   DBW 75   DBW 66   DBW 50  ...  \
# count        5789.000       5789.000 5789.000 5789.000 5789.000  ...
# mean            0.804          0.258    0.111    0.142    0.201  ...
# std             0.137          0.077    0.050    0.064    0.080  ...
# min             0.425          0.114    0.046    0.054    0.069  ...
# 25%             0.709          0.192    0.074    0.089    0.135  ...
# 50%             0.788          0.247    0.092    0.124    0.193  ...
# 75%             0.883          0.311    0.137    0.184    0.251  ...
# max             1.956          0.511    0.334    0.402    0.513  ...
#
#        Location of first maxima index  Ta1/Tpi  Tb1/Tpi   F_base    Sbase  \
# count                        5789.000 5789.000 5789.000 5789.000 5789.000
# mean                            0.225    0.092    0.295    2.520    0.288
# std                             0.032    0.021    0.054    0.471    0.101
# min                             0.143    0.020    0.128    0.930    0.069
# 25%                             0.202    0.078    0.258    2.184    0.213
# 50%                             0.222    0.092    0.292    2.486    0.262
# 75%                             0.244    0.106    0.329    2.817    0.343
# max                             0.392    0.185    0.606    4.843    0.869
#
#          F 2nd    S 2nd    F 3rd    S 3rd  BPSystolic
# count 5789.000 5789.000 5789.000 5789.000    5789.000
# mean     4.481    0.129    6.310    0.054     127.289
# std      0.872    0.050    1.016    0.027      18.398
# min      1.846    0.019    2.747    0.007      71.000
# 25%      3.857    0.094    5.678    0.034     114.000
# 50%      4.449    0.122    6.345    0.050     124.000
# 75%      5.089    0.156    6.981    0.068     137.000
# max      8.268    0.393   10.711    0.286     197.000
#
# [8 rows x 30 columns]

# %% [markdown]
# As you can see from the above statistics , the different feature values are having different value ranges which would have a negative impact on some of the algorithms therefore the features should be subjected to normalization/scaling

# %% [markdown]
# # STEP 3: DATA PREPROCESSING:

# %%
#CHECKING FOR NULL VALUES IN THE DATASET:

# %%
data.isnull().any().any()
# Out:
# True

# %% [markdown]
# The above statement tells us that there is missing values in the dataset, so the missing value rows would be deleted

# %%
#deleting missing value rows in the dataset

# %%
data.dropna(axis=0,inplace=True)

# %%
#rechecking again if there are any null values in the dataset

# %%
data.isnull().any().any()
# Out:
# False

# %%
#SPLITTING THE DATA INTO TRAIN AND TEST SPLIT:

# %% [markdown]
# The total data would be split into 75% for training and 25% for testing and the total data would be split into X and Y variables with X_train and X_test specifying the feature values for training and testing while Y_train and Y_test speciying the Systolic BP (Target) values for training and testing

# %%
# separate train and test sets
X_train, X_test, Y_train, Y_test = train_test_split(
    data.drop(labels=['BPSystolic'], axis=1),
    data['BPSystolic'],
    test_size=0.25,
    random_state=3,shuffle=True)

# %%
#CHECKING THE NUMBER OF DATAPOINTS FOR TRAINING AND TESTING:
X_train.shape,X_test.shape
# Out:
# ((4257, 30), (1419, 30))

# %% [markdown]
# After splitting the data into training and testing we end up with 4257 datapoints for training and 1419 for testing with 30 features which include the PPG and the Biometric Features:

# %%
# BINARIZING THE 'SEX' VARIABLE FOR TRAINING AND TESTING DATA:

# %% [markdown]
# The Label Encoding process helps to convert the categorical feature of 'Sex' vaiable into binary values so that the Machine Learning algorithm can analyze the feature in predicting the Sytolic Blood Pressure

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

X_train['Sex'] = le.fit_transform(X_train['Sex'])
X_test['Sex']=le.fit_transform(X_test['Sex'])

# %%
# NORMALIZING THE VALUES IN TRAIN AND TESTING DATA : USING THE STANDARDSCALER LIBRARY

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()

# %% [markdown]
# The Standard Scalaer object helps in getting all features in the same range of values which will help to improve the algorithm prediction accuracy

# %%
X_train= pd.DataFrame(sc.fit_transform(X_train.values),columns=X_train.columns,index=X_train.index)
X_test= pd.DataFrame(sc.transform(X_test.values),columns=X_test.columns,index=X_test.index)

# %%
#FINDING THE BEST FEATURES THROUGH INFORMATION GAIN:

# %% [markdown]
# Information gain method is a process in univariate feature selection which helps to determine how much each individual feature contributes to the variance in the Target object, which in the case of the project is SystolicBP

# %%
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import SelectKBest, SelectPercentile
# determine the mutual information
mi = mutual_info_regression(X_train.fillna(0), Y_train,random_state=3)
mi = pd.Series(mi)
mi.index = X_train.columns
mi.sort_values(ascending=False)
# Out:
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# Age                                     0.133
# Sex                                     0.051
# Sbase                                   0.040
# DBW 66                                  0.033
# RBW 50                                  0.030
# RBW 75                                  0.020
# DBW 33                                  0.019
# Systolic time                           0.018
# DBW 50                                  0.017
# Systolic peak amplitude                 0.016
# RBW 25                                  0.014
# F_base                                  0.014
# DBW 25                                  0.013
# RBW 33                                  0.013
# RBW 66                                  0.012
# Location of first maxima index          0.011
# S 2nd                                   0.011
# Ta1/Tpi                                 0.011
# No of maximas in the first derivative   0.010
# DBW 75                                  0.010
# S 3rd                                   0.005
# Tb1/Tpi                                 0.004
# RBW 10                                  0.002
# F 2nd                                   0.002
# DBW 10                                  0.000
# Pulse interval                          0.000
# F 3rd                                   0.000
# No of minimas in the first derivative   0.000
# HeartRate                               0.000
# Location of first minima index          0.000
# dtype: float64

# %% [markdown]
# From the above analysis we can see that there are 24 features which can help in analyzing the vairance of the Target variable, so the next step is to make seperate dataframes for training and testing data with just those selected features

# %%
#TRANSFERRING THE IMPORTANT FEATURES INTO NEW DATAFRAMES FOR TRAINING AND TESTING DATA:

# %%
X_train_new= X_train[['Age','Sex','Sbase','DBW 66','RBW 50','RBW 75','DBW 33','Systolic time',
 'DBW 50','Systolic peak amplitude','RBW 25','F_base','DBW 25','RBW 33','RBW 66',
'Location of first maxima index','S 2nd','Ta1/Tpi','No of maximas in the first derivative','DBW 75','S 3rd','Tb1/Tpi','RBW 10','F 2nd']]

# %%
X_test_new= X_test[['Age','Sex','Sbase','DBW 66','RBW 50','RBW 75','DBW 33','Systolic time',
 'DBW 50','Systolic peak amplitude','RBW 25','F_base','DBW 25','RBW 33','RBW 66',
'Location of first maxima index','S 2nd','Ta1/Tpi','No of maximas in the first derivative','DBW 75','S 3rd','Tb1/Tpi','RBW 10','F 2nd']]

# %% [markdown]
# # STEP 3: RUNNING THE 3  ALGORITHMS ON THE DATASET:

# %% [markdown]
# This step involves taking the 3 algorithms which are Random Forest Regressor, Support Vector Regressor and Neural Networks and applying them on the dataset without any hyper parameter tuning

# %%
#RANDOM FOREST BASE ALGORITHM

# %% [markdown]
# Initialziang the Random Forest Regressors with the base Hyper parameters:

# %%
random_forest = RandomForestRegressor(max_depth=5,min_samples_split=2,min_samples_leaf=10,n_estimators=10,random_state=3)

# %%
#APPLYING THE 5 FOLD CROSS VALIDATION TECHNIQUE TO GET THE ALGORITHM EFFICIENCY ON THE TRAINING SET

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(X_train_new)
    rmse= cross_val_score(model, X_train_new, Y_train, scoring="neg_mean_absolute_error", cv = kf)
    return(rmse)

# %%
score = rmsle_cv(random_forest)
print("\nThe MAE and Standard Deviation for Random Forest Regressor on the Training data is: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# The MAE and Standard Deviation for Random Forest Regressor on the Training data is: -12.6664 (0.3259)

# %%
t0= time.clock() #START TIME FOR TESTING DATA COMPUTATION
random_forest.fit(X_train_new, Y_train)
rforest_train_pred = random_forest.predict(X_test_new)
print("\nThe MAE for Random Forest Regressor on the Testing data is: {:.4f} \n".format(mean_absolute_error(Y_test, rforest_train_pred)))
t1 = time.clock() - t0 # END TIME FOR COMPUTATION 
print("Total Computational time for the Random Forest Regressor is: ", t1 ) # CPU seconds elapsed (floating point)
# Out:
# The MAE for Random Forest Regressor on the Testing data is: 12.7452
#
# Total Computational time for the Random Forest Regressor is:  0.2331682

# %%
#CHECKING FOR NORMALITY:

# %% [markdown]
# The next step is to run the Algorithm over 30 times since it is probabilistic in nature and to determine whether the results follow a Gaussian distribution or not.

# %%
L_randomforest=[] #THE ARRAY TO STORE ALL THE RANDOM FOREST RESULTS OVER DIFFERENT SEEDS

# %%
for i in range(0,30):
    model_rf = RandomForestRegressor(max_depth=5,min_samples_split=2,min_samples_leaf=10,n_estimators=10,random_state=i)
    model_rf.fit(X_train_new, Y_train)
    model_rf_test_pred = model_rf.predict(X_test_new)
    Q=abs(model_rf_test_pred-Y_test)
    M= mean_absolute_error(Y_test, model_rf_test_pred)
    L_randomforest.append(mean_absolute_error(Y_test, model_rf_test_pred))

# %%
# Checking the normality of the Random Forest results:
stat, p = normaltest(L_randomforest)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the Random Forest Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the Random Forest Regressor follow a non Gaussian distribution (reject H0)')
# Out:
# Statistics=1.813, p=0.404
# The Samples from the Random Forest Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#SUPPORT VECTOR REGRESSOR BASE ALGORITHM:

# %% [markdown]
# INITIATING THE SUPPORT VECTOR REGRESSOR OBJECT WITH THE BASE HYPER PARAMETERS:

# %%
svr_linear = LinearSVR(C=1.0,epsilon=0.1,tol=0.001,random_state=3)

# %%
score = rmsle_cv(svr_linear)
print("\nThe MAE and Standard Deviation for Support Vector Regressor on the Training data is: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# The MAE and Standard Deviation for Support Vector Regressor on the Training data is: -12.8011 (0.2102)

# %%
t2= time.clock() #START TIME OF TESTING DATA COMPUTATION FOR SUPPORT VECTOR REGRESSOR
svr_linear.fit(X_train_new, Y_train)
svr_linear_test_pred = svr_linear.predict(X_test_new)
print("\nThe MAE for Support Vector Regressor on the Testing data is: {:.4f} \n".format(mean_absolute_error(Y_test, svr_linear_test_pred)))
t3 = time.clock() - t2 # END TIME FOR COMPUTATION 
print("Total computational time for the Support Vector Regressor is: ", t3 ) # CPU seconds elapsed (floating point)
# Out:
# The MAE for Support Vector Regressor on the Testing data is: 12.7715
#
# Total computational time for the Support Vector Regressor is:  0.015454599999998209

# %% [markdown]
# THE NEXT STEP IS TO RUN THE SUPPORT VECTOR REGRESSOR OVER 30 DIFFERENT SEEDS AND FIND WHETHER THE RESULTS FOLLOW A GAUSSIAN DISTRIBUTION OR NOT

# %%
L_svr=[] #THE ARRAY TO STORE THE 3O RESULTS OF THE SUPPORT VECTOR REGRESSOR OVER DIFFERENT SEEDS

# %%
for i in range(0,30):
    model_svr = LinearSVR(C=1.0,epsilon=0.1,tol=0.001,random_state=i)
    model_svr.fit(X_train_new, Y_train) 
    model_svr_test_pred = model_svr.predict(X_test_new)
    Q=abs(model_svr_test_pred-Y_test)
    M= mean_absolute_error(Y_test, model_svr_test_pred)
    L_svr.append(mean_absolute_error(Y_test, model_svr_test_pred))

# %%
# compare samples
stat, p = normaltest(L_svr) #DOING THE NORMALITY CHECK
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The samples from the Support Vector Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the Support Vector Regressor follow a non Gaussian distribution (reject H0)')
# Out:
# Statistics=0.058, p=0.972
# The samples from the Support Vector Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#NEURAL NETWORKSBASE ALGORITHM

# %% [markdown]
# The first step is to configure the Keras environment so that reproducible results can be obtained in neural networks

# %%
# Seed value (can actually be different for each attribution step)
seed_value= 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
from keras import backend as K
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# %% [markdown]
# Initializing the Neural Networks with 2 Hidden Layers and 100 neurons in each hidden layer

# %%
def build_regressor():
    regressor = Sequential()
    regressor.add(Dense(units=100,kernel_initializer='normal', input_dim=24,activation='relu'))#FIRST HIDDEN LAYER
    regressor.add(Dense(units=100,kernel_initializer='normal',activation='relu'))#THIRD HIDDEN LAYER
    regressor.add(Dense(units=1))#OUTPUT LAYER
    regressor.compile(optimizer='adam', loss='mean_absolute_error',  metrics=['mae'])# ASSIGNING THE LOSS METRIC OF MAE
    return regressor

# %%
seed=3 #fixing a seed
np.random.seed(seed)
# evaluate model with Training dataset
estimator = KerasRegressor(build_fn=build_regressor, epochs=100, batch_size=50)
# evaluate using 5-fold cross validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
results = cross_val_score(estimator, X_train_new, Y_train, cv=kfold)
print("\nThe MAE for Neural Networks on the Training data is: {:.4f} \n".format(results.mean()))
# Out:
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:652: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# Epoch 1/100
# 3382/3382 [==============================] - 0s 123us/step - loss: 111.8812 - mean_absolute_error: 111.8812
# Epoch 2/100
# 3382/3382 [==============================] - 0s 26us/step - loss: 52.9310 - mean_absolute_error: 52.9310
# Epoch 3/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 35.7808 - mean_absolute_error: 35.7808
# Epoch 4/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 27.0333 - mean_absolute_error: 27.0333
# Epoch 5/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 21.9397 - mean_absolute_error: 21.9397
# Epoch 6/100
# 3382/3382 [==============================] - 0s 26us/step - loss: 18.6589 - mean_absolute_error: 18.6589
# Epoch 7/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 16.3175 - mean_absolute_error: 16.3175
# Epoch 8/100
# 3382/3382 [==============================] - 0s 27us/step - loss: 14.7692 - mean_absolute_error: 14.7692
# Epoch 9/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 13.8140 - mean_absolute_error: 13.8140
# Epoch 10/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 13.3460 - mean_absolute_error: 13.3460
# Epoch 11/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 13.0767 - mean_absolute_error: 13.0767
# Epoch 12/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.9003 - mean_absolute_error: 12.9003
# Epoch 13/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.7537 - mean_absolute_error: 12.7537
# Epoch 14/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.6880 - mean_absolute_error: 12.6880
# Epoch 15/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.6552 - mean_absolute_error: 12.6552
# Epoch 16/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.5053 - mean_absolute_error: 12.5053
# Epoch 17/100
# 3382/3382 [==============================] - 0s 23us/step - loss: 12.4632 - mean_absolute_error: 12.4632
# Epoch 18/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.4969 - mean_absolute_error: 12.4969
# Epoch 19/100
# 3382/3382 [==============================] - 0s 24us/step - loss: 12.4733 - mean_absolute_error: 12.4733
# Epoch 20/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.3956 - mean_absolute_error: 12.3956
# Epoch 21/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.3773 - mean_absolute_error: 12.3773
# Epoch 22/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.3957 - mean_absolute_error: 12.3957
# Epoch 23/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.4407 - mean_absolute_error: 12.4407
# Epoch 24/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.3672 - mean_absolute_error: 12.3672
# Epoch 25/100
# 3382/3382 [==============================] - 0s 31us/step - loss: 12.3171 - mean_absolute_error: 12.3171
# Epoch 26/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.4610 - mean_absolute_error: 12.4610
# Epoch 27/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.2549 - mean_absolute_error: 12.2549
# Epoch 28/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.2472 - mean_absolute_error: 12.2472
# Epoch 29/100
# 3382/3382 [==============================] - 0s 23us/step - loss: 12.2750 - mean_absolute_error: 12.2750
# Epoch 30/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.3197 - mean_absolute_error: 12.3197
# Epoch 31/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.3093 - mean_absolute_error: 12.3093
# Epoch 32/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.2224 - mean_absolute_error: 12.2224
# Epoch 33/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.3099 - mean_absolute_error: 12.3099
# Epoch 34/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.2978 - mean_absolute_error: 12.2978
# Epoch 35/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.2275 - mean_absolute_error: 12.2275
# Epoch 36/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.2201 - mean_absolute_error: 12.2201
# Epoch 37/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.2112 - mean_absolute_error: 12.2112
# Epoch 38/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.2215 - mean_absolute_error: 12.2215
# Epoch 39/100
# 3382/3382 [==============================] - 0s 23us/step - loss: 12.2417 - mean_absolute_error: 12.2417
# Epoch 40/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.2617 - mean_absolute_error: 12.2617
# Epoch 41/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.2031 - mean_absolute_error: 12.2031
# Epoch 42/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.2870 - mean_absolute_error: 12.2870
# Epoch 43/100
# 3382/3382 [==============================] - 0s 26us/step - loss: 12.1713 - mean_absolute_error: 12.1713
# Epoch 44/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.1473 - mean_absolute_error: 12.1473
# Epoch 45/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.1768 - mean_absolute_error: 12.1768
# Epoch 46/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1910 - mean_absolute_error: 12.1910
# Epoch 47/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1797 - mean_absolute_error: 12.1797
# Epoch 48/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1552 - mean_absolute_error: 12.1552
# Epoch 49/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.1016 - mean_absolute_error: 12.1016
# Epoch 50/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.1781 - mean_absolute_error: 12.1781
# Epoch 51/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.1513 - mean_absolute_error: 12.1513
# Epoch 52/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1019 - mean_absolute_error: 12.1019
# Epoch 53/100
# 3382/3382 [==============================] - 0s 25us/step - loss: 12.1551 - mean_absolute_error: 12.1551
# Epoch 54/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.1857 - mean_absolute_error: 12.1857
# Epoch 55/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.0930 - mean_absolute_error: 12.0930
# Epoch 56/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1574 - mean_absolute_error: 12.1574
# Epoch 57/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.1043 - mean_absolute_error: 12.1043
# Epoch 58/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1719 - mean_absolute_error: 12.1719
# Epoch 59/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.1909 - mean_absolute_error: 12.1909
# Epoch 60/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0961 - mean_absolute_error: 12.0961
# Epoch 61/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.1576 - mean_absolute_error: 12.1576
# Epoch 62/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1638 - mean_absolute_error: 12.1638
# Epoch 63/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.1657 - mean_absolute_error: 12.1657
# Epoch 64/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0698 - mean_absolute_error: 12.0698
# Epoch 65/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.0825 - mean_absolute_error: 12.0825
# Epoch 66/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1594 - mean_absolute_error: 12.1594
# Epoch 67/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.0469 - mean_absolute_error: 12.0469
# Epoch 68/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0546 - mean_absolute_error: 12.0546
# Epoch 69/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.0300 - mean_absolute_error: 12.0300
# Epoch 70/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1410 - mean_absolute_error: 12.1410
# Epoch 71/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.1366 - mean_absolute_error: 12.1366
# Epoch 72/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.1428 - mean_absolute_error: 12.1428
# Epoch 73/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 11.9859 - mean_absolute_error: 11.9859
# Epoch 74/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0338 - mean_absolute_error: 12.0338
# Epoch 75/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.0657 - mean_absolute_error: 12.0657
# Epoch 76/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.1235 - mean_absolute_error: 12.1235
# Epoch 77/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.1738 - mean_absolute_error: 12.1738
# Epoch 78/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0385 - mean_absolute_error: 12.0385
# Epoch 79/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.0585 - mean_absolute_error: 12.0585
# Epoch 80/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.0790 - mean_absolute_error: 12.0790
# Epoch 81/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0978 - mean_absolute_error: 12.0978
# Epoch 82/100
# 3382/3382 [==============================] - 0s 18us/step - loss: 12.0203 - mean_absolute_error: 12.0203
# Epoch 83/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.0736 - mean_absolute_error: 12.0736
# Epoch 84/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.0283 - mean_absolute_error: 12.0283
# Epoch 85/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 11.9977 - mean_absolute_error: 11.9977
# Epoch 86/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 12.0483 - mean_absolute_error: 12.0483
# Epoch 87/100
# 3382/3382 [==============================] - 0s 21us/step - loss: 12.0181 - mean_absolute_error: 12.0181
# Epoch 88/100
# 3382/3382 [==============================] - 0s 20us/step - loss: 11.9452 - mean_absolute_error: 11.9452
# Epoch 89/100
# 3382/3382 [==============================] - 0s 24us/step - loss: 11.9708 - mean_absolute_error: 11.9708
# Epoch 90/100
# 3382/3382 [==============================] - 0s 26us/step - loss: 12.0804 - mean_absolute_error: 12.0804
# Epoch 91/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.0040 - mean_absolute_error: 12.0040
# Epoch 92/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 11.9537 - mean_absolute_error: 11.9537
# Epoch 93/100
# 3382/3382 [==============================] - 0s 28us/step - loss: 12.0343 - mean_absolute_error: 12.0343
# Epoch 94/100
# 3382/3382 [==============================] - 0s 23us/step - loss: 11.9657 - mean_absolute_error: 11.9657
# Epoch 95/100
# 3382/3382 [==============================] - 0s 22us/step - loss: 12.0476 - mean_absolute_error: 12.0476
# Epoch 96/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 11.9173 - mean_absolute_error: 11.9173
# Epoch 97/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 12.0050 - mean_absolute_error: 12.0050
# Epoch 98/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 11.9225 - mean_absolute_error: 11.9225
# Epoch 99/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 11.9136 - mean_absolute_error: 11.9136
# Epoch 100/100
# 3382/3382 [==============================] - 0s 19us/step - loss: 11.9715 - mean_absolute_error: 11.9715
# 875/875 [==============================] - 0s 59us/step
# Epoch 1/100
# 3397/3397 [==============================] - 0s 131us/step - loss: 115.0170 - mean_absolute_error: 115.0170
# Epoch 2/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 53.9190 - mean_absolute_error: 53.9190
# Epoch 3/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 36.1437 - mean_absolute_error: 36.1437
# Epoch 4/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 27.4768 - mean_absolute_error: 27.4768
# Epoch 5/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 22.1881 - mean_absolute_error: 22.1881
# Epoch 6/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 18.8035 - mean_absolute_error: 18.8035
# Epoch 7/100
# 3397/3397 [==============================] - 0s 22us/step - loss: 16.6502 - mean_absolute_error: 16.6502
# Epoch 8/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 15.2191 - mean_absolute_error: 15.2191
# Epoch 9/100
# 3397/3397 [==============================] - 0s 26us/step - loss: 14.3436 - mean_absolute_error: 14.3436
# Epoch 10/100
# 3397/3397 [==============================] - 0s 24us/step - loss: 13.6536 - mean_absolute_error: 13.6536
# Epoch 11/100
# 3397/3397 [==============================] - 0s 22us/step - loss: 13.2595 - mean_absolute_error: 13.2595
# Epoch 12/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 13.0904 - mean_absolute_error: 13.0904
# Epoch 13/100
# 3397/3397 [==============================] - 0s 25us/step - loss: 12.9959 - mean_absolute_error: 12.9959
# Epoch 14/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 12.8996 - mean_absolute_error: 12.8996
# Epoch 15/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 12.7310 - mean_absolute_error: 12.7310
# Epoch 16/100
# 3397/3397 [==============================] - 0s 24us/step - loss: 12.7573 - mean_absolute_error: 12.7573
# Epoch 17/100
# 3397/3397 [==============================] - 0s 32us/step - loss: 12.6852 - mean_absolute_error: 12.6852
# Epoch 18/100
# 3397/3397 [==============================] - 0s 22us/step - loss: 12.6474 - mean_absolute_error: 12.6474
# Epoch 19/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.5755 - mean_absolute_error: 12.5755
# Epoch 20/100
# 3397/3397 [==============================] - 0s 27us/step - loss: 12.5340 - mean_absolute_error: 12.5340
# Epoch 21/100
# 3397/3397 [==============================] - 0s 27us/step - loss: 12.5594 - mean_absolute_error: 12.5594
# Epoch 22/100
# 3397/3397 [==============================] - 0s 28us/step - loss: 12.5090 - mean_absolute_error: 12.5090
# Epoch 23/100
# 3397/3397 [==============================] - 0s 22us/step - loss: 12.4619 - mean_absolute_error: 12.4619
# Epoch 24/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.5293 - mean_absolute_error: 12.5293
# Epoch 25/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.4245 - mean_absolute_error: 12.4245
# Epoch 26/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.5500 - mean_absolute_error: 12.5500
# Epoch 27/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.4425 - mean_absolute_error: 12.4425
# Epoch 28/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.3638 - mean_absolute_error: 12.3638
# Epoch 29/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.4412 - mean_absolute_error: 12.4412
# Epoch 30/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.4330 - mean_absolute_error: 12.4330
# Epoch 31/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.3833 - mean_absolute_error: 12.3833
# Epoch 32/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.3975 - mean_absolute_error: 12.3975
# Epoch 33/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.3279 - mean_absolute_error: 12.3279
# Epoch 34/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 12.3187 - mean_absolute_error: 12.3187
# Epoch 35/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.2900 - mean_absolute_error: 12.2900
# Epoch 36/100
# 3397/3397 [==============================] - 0s 18us/step - loss: 12.2599 - mean_absolute_error: 12.2599
# Epoch 37/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.3308 - mean_absolute_error: 12.3308
# Epoch 38/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.3489 - mean_absolute_error: 12.3489
# Epoch 39/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.2776 - mean_absolute_error: 12.2776
# Epoch 40/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.2484 - mean_absolute_error: 12.2484
# Epoch 41/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.2824 - mean_absolute_error: 12.2824
# Epoch 42/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.3022 - mean_absolute_error: 12.3022
# Epoch 43/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1968 - mean_absolute_error: 12.1968
# Epoch 44/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.2521 - mean_absolute_error: 12.2521
# Epoch 45/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.2794 - mean_absolute_error: 12.2794
# Epoch 46/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.2549 - mean_absolute_error: 12.2549
# Epoch 47/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1788 - mean_absolute_error: 12.1788
# Epoch 48/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.2033 - mean_absolute_error: 12.2033
# Epoch 49/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.2410 - mean_absolute_error: 12.2410
# Epoch 50/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.2294 - mean_absolute_error: 12.2294
# Epoch 51/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1970 - mean_absolute_error: 12.1970
# Epoch 52/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1797 - mean_absolute_error: 12.1797
# Epoch 53/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1963 - mean_absolute_error: 12.1963
# Epoch 54/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 12.1674 - mean_absolute_error: 12.1674
# Epoch 55/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1770 - mean_absolute_error: 12.1770
# Epoch 56/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0820 - mean_absolute_error: 12.0820
# Epoch 57/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1932 - mean_absolute_error: 12.1932
# Epoch 58/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1200 - mean_absolute_error: 12.1200
# Epoch 59/100
# 3397/3397 [==============================] - 0s 18us/step - loss: 12.1844 - mean_absolute_error: 12.1844
# Epoch 60/100
# 3397/3397 [==============================] - 0s 18us/step - loss: 12.1631 - mean_absolute_error: 12.1631
# Epoch 61/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1495 - mean_absolute_error: 12.1495
# Epoch 62/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1413 - mean_absolute_error: 12.1413
# Epoch 63/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0913 - mean_absolute_error: 12.0913
# Epoch 64/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.0699 - mean_absolute_error: 12.0699
# Epoch 65/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1040 - mean_absolute_error: 12.1040
# Epoch 66/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.1127 - mean_absolute_error: 12.1127
# Epoch 67/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0928 - mean_absolute_error: 12.0928
# Epoch 68/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0962 - mean_absolute_error: 12.0962
# Epoch 69/100
# 3397/3397 [==============================] - 0s 18us/step - loss: 12.0847 - mean_absolute_error: 12.0847
# Epoch 70/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0847 - mean_absolute_error: 12.0847
# Epoch 71/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1470 - mean_absolute_error: 12.1470
# Epoch 72/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0550 - mean_absolute_error: 12.0550
# Epoch 73/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0399 - mean_absolute_error: 12.0399
# Epoch 74/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.1164 - mean_absolute_error: 12.1164
# Epoch 75/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1191 - mean_absolute_error: 12.1191
# Epoch 76/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0909 - mean_absolute_error: 12.0909
# Epoch 77/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 12.0271 - mean_absolute_error: 12.0271
# Epoch 78/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0924 - mean_absolute_error: 12.0924
# Epoch 79/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0486 - mean_absolute_error: 12.0486
# Epoch 80/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0554 - mean_absolute_error: 12.0554
# Epoch 81/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0164 - mean_absolute_error: 12.0164
# Epoch 82/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0439 - mean_absolute_error: 12.0439
# Epoch 83/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1152 - mean_absolute_error: 12.1152
# Epoch 84/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.1155 - mean_absolute_error: 12.1155
# Epoch 85/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0063 - mean_absolute_error: 12.0063
# Epoch 86/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0269 - mean_absolute_error: 12.0269
# Epoch 87/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0104 - mean_absolute_error: 12.0104
# Epoch 88/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 11.9918 - mean_absolute_error: 11.9918
# Epoch 89/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0386 - mean_absolute_error: 12.0386
# Epoch 90/100
# 3397/3397 [==============================] - 0s 23us/step - loss: 12.2490 - mean_absolute_error: 12.2490
# Epoch 91/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 11.9971 - mean_absolute_error: 11.9971
# Epoch 92/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 11.9717 - mean_absolute_error: 11.9717
# Epoch 93/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 11.9194 - mean_absolute_error: 11.9194
# Epoch 94/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 12.0249 - mean_absolute_error: 12.0249
# Epoch 95/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 12.0850 - mean_absolute_error: 12.0850
# Epoch 96/100
# 3397/3397 [==============================] - 0s 20us/step - loss: 11.8903 - mean_absolute_error: 11.8903
# Epoch 97/100
# 3397/3397 [==============================] - 0s 22us/step - loss: 11.9821 - mean_absolute_error: 11.9821
# Epoch 98/100
# 3397/3397 [==============================] - 0s 19us/step - loss: 11.9101 - mean_absolute_error: 11.9101
# Epoch 99/100
# 3397/3397 [==============================] - 0s 21us/step - loss: 11.9445 - mean_absolute_error: 11.9445
# Epoch 100/100
# 3397/3397 [==============================] - 0s 26us/step - loss: 11.9753 - mean_absolute_error: 11.9753
# 860/860 [==============================] - 0s 92us/step
# Epoch 1/100
# 3404/3404 [==============================] - 0s 134us/step - loss: 115.3085 - mean_absolute_error: 115.3085
# Epoch 2/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 55.9183 - mean_absolute_error: 55.9183
# Epoch 3/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 37.5360 - mean_absolute_error: 37.5360
# Epoch 4/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 28.6658 - mean_absolute_error: 28.6658
# Epoch 5/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 23.6298 - mean_absolute_error: 23.6298
# Epoch 6/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 19.8023 - mean_absolute_error: 19.8023
# Epoch 7/100
# 3404/3404 [==============================] - 0s 26us/step - loss: 17.3035 - mean_absolute_error: 17.3035
# Epoch 8/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 15.6144 - mean_absolute_error: 15.6144
# Epoch 9/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 14.5740 - mean_absolute_error: 14.5740
# Epoch 10/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 14.0261 - mean_absolute_error: 14.0261
# Epoch 11/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 13.5394 - mean_absolute_error: 13.5394
# Epoch 12/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 13.1922 - mean_absolute_error: 13.1922
# Epoch 13/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 13.1499 - mean_absolute_error: 13.1499
# Epoch 14/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.8723 - mean_absolute_error: 12.8723
# Epoch 15/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.8212 - mean_absolute_error: 12.8212
# Epoch 16/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.8257 - mean_absolute_error: 12.8257
# Epoch 17/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.7325 - mean_absolute_error: 12.7325
# Epoch 18/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.6008 - mean_absolute_error: 12.6008
# Epoch 19/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.6203 - mean_absolute_error: 12.6203
# Epoch 20/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.6177 - mean_absolute_error: 12.6177
# Epoch 21/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.5664 - mean_absolute_error: 12.5664
# Epoch 22/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.6675 - mean_absolute_error: 12.6675
# Epoch 23/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.5871 - mean_absolute_error: 12.5871
# Epoch 24/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.5308 - mean_absolute_error: 12.5308
# Epoch 25/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.4859 - mean_absolute_error: 12.4859
# Epoch 26/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.4797 - mean_absolute_error: 12.4797
# Epoch 27/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.5077 - mean_absolute_error: 12.5077
# Epoch 28/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.4282 - mean_absolute_error: 12.4282
# Epoch 29/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.4563 - mean_absolute_error: 12.4563
# Epoch 30/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.4420 - mean_absolute_error: 12.4420
# Epoch 31/100
# 3404/3404 [==============================] - 0s 23us/step - loss: 12.4883 - mean_absolute_error: 12.4883
# Epoch 32/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.4579 - mean_absolute_error: 12.4579
# Epoch 33/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.4898 - mean_absolute_error: 12.4898
# Epoch 34/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.3717 - mean_absolute_error: 12.3717
# Epoch 35/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.4403 - mean_absolute_error: 12.4403
# Epoch 36/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3961 - mean_absolute_error: 12.3961
# Epoch 37/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.4225 - mean_absolute_error: 12.4225
# Epoch 38/100
# 3404/3404 [==============================] - 0s 26us/step - loss: 12.4336 - mean_absolute_error: 12.4336
# Epoch 39/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.5397 - mean_absolute_error: 12.5397
# Epoch 40/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.4523 - mean_absolute_error: 12.4523
# Epoch 41/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.5075 - mean_absolute_error: 12.5075
# Epoch 42/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3711 - mean_absolute_error: 12.3711
# Epoch 43/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3347 - mean_absolute_error: 12.3347
# Epoch 44/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3111 - mean_absolute_error: 12.3111
# Epoch 45/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.4903 - mean_absolute_error: 12.4903
# Epoch 46/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.3286 - mean_absolute_error: 12.3286
# Epoch 47/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3273 - mean_absolute_error: 12.3273
# Epoch 48/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.4853 - mean_absolute_error: 12.4853
# Epoch 49/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.3526 - mean_absolute_error: 12.3526
# Epoch 50/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.2479 - mean_absolute_error: 12.2479
# Epoch 51/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3394 - mean_absolute_error: 12.3394
# Epoch 52/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.2890 - mean_absolute_error: 12.2890
# Epoch 53/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.3394 - mean_absolute_error: 12.3394
# Epoch 54/100
# 3404/3404 [==============================] - 0s 24us/step - loss: 12.2039 - mean_absolute_error: 12.2039
# Epoch 55/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1919 - mean_absolute_error: 12.1919
# Epoch 56/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2307 - mean_absolute_error: 12.2307
# Epoch 57/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2796 - mean_absolute_error: 12.2796
# Epoch 58/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1762 - mean_absolute_error: 12.1762
# Epoch 59/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.3496 - mean_absolute_error: 12.3496
# Epoch 60/100
# 3404/3404 [==============================] - 0s 23us/step - loss: 12.3084 - mean_absolute_error: 12.3084
# Epoch 61/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.1771 - mean_absolute_error: 12.1771
# Epoch 62/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2674 - mean_absolute_error: 12.2674
# Epoch 63/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2808 - mean_absolute_error: 12.2808
# Epoch 64/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2934 - mean_absolute_error: 12.2934
# Epoch 65/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2021 - mean_absolute_error: 12.2021
# Epoch 66/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1782 - mean_absolute_error: 12.1782
# Epoch 67/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.2278 - mean_absolute_error: 12.2278
# Epoch 68/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2284 - mean_absolute_error: 12.2284
# Epoch 69/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.2092 - mean_absolute_error: 12.2092
# Epoch 70/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.2262 - mean_absolute_error: 12.2262
# Epoch 71/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.1764 - mean_absolute_error: 12.1764
# Epoch 72/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1835 - mean_absolute_error: 12.1835
# Epoch 73/100
# 3404/3404 [==============================] - 0s 23us/step - loss: 12.2004 - mean_absolute_error: 12.2004
# Epoch 74/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.2470 - mean_absolute_error: 12.2470
# Epoch 75/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.1675 - mean_absolute_error: 12.1675
# Epoch 76/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1640 - mean_absolute_error: 12.1640
# Epoch 77/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1741 - mean_absolute_error: 12.1741
# Epoch 78/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1570 - mean_absolute_error: 12.1570
# Epoch 79/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1864 - mean_absolute_error: 12.1864
# Epoch 80/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.2127 - mean_absolute_error: 12.2127
# Epoch 81/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1538 - mean_absolute_error: 12.1538
# Epoch 82/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.0962 - mean_absolute_error: 12.0962
# Epoch 83/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.1575 - mean_absolute_error: 12.1575
# Epoch 84/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1836 - mean_absolute_error: 12.1836
# Epoch 85/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1472 - mean_absolute_error: 12.1472
# Epoch 86/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1088 - mean_absolute_error: 12.1088
# Epoch 87/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.1953 - mean_absolute_error: 12.1953
# Epoch 88/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.0922 - mean_absolute_error: 12.0922
# Epoch 89/100
# 3404/3404 [==============================] - 0s 25us/step - loss: 12.1533 - mean_absolute_error: 12.1533
# Epoch 90/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1751 - mean_absolute_error: 12.1751
# Epoch 91/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.0757 - mean_absolute_error: 12.0757
# Epoch 92/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.0618 - mean_absolute_error: 12.0618
# Epoch 93/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.0738 - mean_absolute_error: 12.0738: 0s - loss: 12.2154 - mean_absolute_error: 12.215
# Epoch 94/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.0536 - mean_absolute_error: 12.0536
# Epoch 95/100
# 3404/3404 [==============================] - 0s 19us/step - loss: 12.0745 - mean_absolute_error: 12.0745
# Epoch 96/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1713 - mean_absolute_error: 12.1713
# Epoch 97/100
# 3404/3404 [==============================] - 0s 20us/step - loss: 12.1891 - mean_absolute_error: 12.1891
# Epoch 98/100
# 3404/3404 [==============================] - 0s 21us/step - loss: 12.0629 - mean_absolute_error: 12.0629
# Epoch 99/100
# 3404/3404 [==============================] - 0s 23us/step - loss: 12.1597 - mean_absolute_error: 12.1597
# Epoch 100/100
# 3404/3404 [==============================] - 0s 22us/step - loss: 12.0962 - mean_absolute_error: 12.0962
# 853/853 [==============================] - 0s 95us/step
# Epoch 1/100
# 3403/3403 [==============================] - 0s 145us/step - loss: 118.3563 - mean_absolute_error: 118.3563
# Epoch 2/100
# 3403/3403 [==============================] - 0s 33us/step - loss: 59.5460 - mean_absolute_error: 59.5460
# Epoch 3/100
# 3403/3403 [==============================] - 0s 71us/step - loss: 39.1707 - mean_absolute_error: 39.1707
# Epoch 4/100
# 3403/3403 [==============================] - 0s 47us/step - loss: 29.6131 - mean_absolute_error: 29.6131
# Epoch 5/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 24.2440 - mean_absolute_error: 24.2440
# Epoch 6/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 20.3218 - mean_absolute_error: 20.3218
# Epoch 7/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 17.5909 - mean_absolute_error: 17.5909
# Epoch 8/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 15.6859 - mean_absolute_error: 15.6859
# Epoch 9/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 14.6065 - mean_absolute_error: 14.6065
# Epoch 10/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 13.8677 - mean_absolute_error: 13.8677
# Epoch 11/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 13.3302 - mean_absolute_error: 13.3302
# Epoch 12/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 13.0332 - mean_absolute_error: 13.0332
# Epoch 13/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.8084 - mean_absolute_error: 12.8084
# Epoch 14/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.7313 - mean_absolute_error: 12.7313
# Epoch 15/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 12.6518 - mean_absolute_error: 12.6518
# Epoch 16/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.5382 - mean_absolute_error: 12.5382
# Epoch 17/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.6194 - mean_absolute_error: 12.6194
# Epoch 18/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.5936 - mean_absolute_error: 12.5936
# Epoch 19/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.6512 - mean_absolute_error: 12.6512
# Epoch 20/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.3149 - mean_absolute_error: 12.3149
# Epoch 21/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 12.3732 - mean_absolute_error: 12.3732
# Epoch 22/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 12.3627 - mean_absolute_error: 12.3627
# Epoch 23/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 12.6138 - mean_absolute_error: 12.6138
# Epoch 24/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.3203 - mean_absolute_error: 12.3203
# Epoch 25/100
# 3403/3403 [==============================] - 0s 38us/step - loss: 12.3200 - mean_absolute_error: 12.3200
# Epoch 26/100
# 3403/3403 [==============================] - 0s 26us/step - loss: 12.3165 - mean_absolute_error: 12.3165
# Epoch 27/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.2337 - mean_absolute_error: 12.2337
# Epoch 28/100
# 3403/3403 [==============================] - 0s 23us/step - loss: 12.2478 - mean_absolute_error: 12.2478
# Epoch 29/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 12.1927 - mean_absolute_error: 12.1927
# Epoch 30/100
# 3403/3403 [==============================] - 0s 23us/step - loss: 12.2260 - mean_absolute_error: 12.2260
# Epoch 31/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1724 - mean_absolute_error: 12.1724
# Epoch 32/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 12.2713 - mean_absolute_error: 12.2713
# Epoch 33/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1214 - mean_absolute_error: 12.1214
# Epoch 34/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.2152 - mean_absolute_error: 12.2152
# Epoch 35/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1576 - mean_absolute_error: 12.1576
# Epoch 36/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.1471 - mean_absolute_error: 12.1471
# Epoch 37/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.1571 - mean_absolute_error: 12.1571
# Epoch 38/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.1472 - mean_absolute_error: 12.1472
# Epoch 39/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 12.1585 - mean_absolute_error: 12.1585
# Epoch 40/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.0936 - mean_absolute_error: 12.0936
# Epoch 41/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1220 - mean_absolute_error: 12.1220
# Epoch 42/100
# 3403/3403 [==============================] - 0s 24us/step - loss: 12.0590 - mean_absolute_error: 12.0590
# Epoch 43/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.0845 - mean_absolute_error: 12.0845
# Epoch 44/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 12.2121 - mean_absolute_error: 12.2121
# Epoch 45/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 12.1677 - mean_absolute_error: 12.1677
# Epoch 46/100
# 3403/3403 [==============================] - 0s 19us/step - loss: 12.0467 - mean_absolute_error: 12.0467
# Epoch 47/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.1755 - mean_absolute_error: 12.1755
# Epoch 48/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.0618 - mean_absolute_error: 12.0618
# Epoch 49/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.0878 - mean_absolute_error: 12.0878
# Epoch 50/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1690 - mean_absolute_error: 12.1690
# Epoch 51/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1206 - mean_absolute_error: 12.1206
# Epoch 52/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.0815 - mean_absolute_error: 12.0815
# Epoch 53/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9834 - mean_absolute_error: 11.9834
# Epoch 54/100
# 3403/3403 [==============================] - 0s 23us/step - loss: 12.0802 - mean_absolute_error: 12.0802
# Epoch 55/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.1069 - mean_absolute_error: 12.1069
# Epoch 56/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9904 - mean_absolute_error: 11.9904
# Epoch 57/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9708 - mean_absolute_error: 11.9708
# Epoch 58/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9697 - mean_absolute_error: 11.9697
# Epoch 59/100
# 3403/3403 [==============================] - 0s 23us/step - loss: 12.0014 - mean_absolute_error: 12.0014
# Epoch 60/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.1591 - mean_absolute_error: 12.1591
# Epoch 61/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 12.0262 - mean_absolute_error: 12.0262
# Epoch 62/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 12.0383 - mean_absolute_error: 12.0383
# Epoch 63/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.9861 - mean_absolute_error: 11.9861
# Epoch 64/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9967 - mean_absolute_error: 11.9967
# Epoch 65/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 11.9692 - mean_absolute_error: 11.9692
# Epoch 66/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.9582 - mean_absolute_error: 11.9582
# Epoch 67/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8780 - mean_absolute_error: 11.8780
# Epoch 68/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9951 - mean_absolute_error: 11.9951
# Epoch 69/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.0397 - mean_absolute_error: 12.0397
# Epoch 70/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.9069 - mean_absolute_error: 11.9069
# Epoch 71/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9510 - mean_absolute_error: 11.9510
# Epoch 72/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9739 - mean_absolute_error: 11.9739
# Epoch 73/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.9798 - mean_absolute_error: 11.9798
# Epoch 74/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.9733 - mean_absolute_error: 11.9733
# Epoch 75/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.8875 - mean_absolute_error: 11.8875
# Epoch 76/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8965 - mean_absolute_error: 11.8965
# Epoch 77/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9269 - mean_absolute_error: 11.9269
# Epoch 78/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8846 - mean_absolute_error: 11.8846
# Epoch 79/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9473 - mean_absolute_error: 11.9473
# Epoch 80/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9542 - mean_absolute_error: 11.9542
# Epoch 81/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.8562 - mean_absolute_error: 11.8562
# Epoch 82/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8964 - mean_absolute_error: 11.8964
# Epoch 83/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.0034 - mean_absolute_error: 12.0034
# Epoch 84/100
# 3403/3403 [==============================] - 0s 22us/step - loss: 12.0070 - mean_absolute_error: 12.0070
# Epoch 85/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9742 - mean_absolute_error: 11.9742
# Epoch 86/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8265 - mean_absolute_error: 11.8265
# Epoch 87/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9006 - mean_absolute_error: 11.9006
# Epoch 88/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8976 - mean_absolute_error: 11.8976
# Epoch 89/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8235 - mean_absolute_error: 11.8235
# Epoch 90/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9304 - mean_absolute_error: 11.9304
# Epoch 91/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9099 - mean_absolute_error: 11.9099
# Epoch 92/100
# 3403/3403 [==============================] - 0s 26us/step - loss: 11.8192 - mean_absolute_error: 11.8192
# Epoch 93/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.8665 - mean_absolute_error: 11.8665
# Epoch 94/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8166 - mean_absolute_error: 11.8166
# Epoch 95/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8761 - mean_absolute_error: 11.8761
# Epoch 96/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.9276 - mean_absolute_error: 11.9276
# Epoch 97/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 12.0194 - mean_absolute_error: 12.0194
# Epoch 98/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8413 - mean_absolute_error: 11.8413
# Epoch 99/100
# 3403/3403 [==============================] - 0s 20us/step - loss: 11.8221 - mean_absolute_error: 11.8221
# Epoch 100/100
# 3403/3403 [==============================] - 0s 21us/step - loss: 11.8020 - mean_absolute_error: 11.8020
# 854/854 [==============================] - 0s 109us/step
# Epoch 1/100
# 3442/3442 [==============================] - 1s 147us/step - loss: 112.2562 - mean_absolute_error: 112.2562
# Epoch 2/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 53.0640 - mean_absolute_error: 53.0640
# Epoch 3/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 35.8524 - mean_absolute_error: 35.8524
# Epoch 4/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 27.2163 - mean_absolute_error: 27.2163
# Epoch 5/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 21.8813 - mean_absolute_error: 21.8813
# Epoch 6/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 18.5069 - mean_absolute_error: 18.5069
# Epoch 7/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 16.2167 - mean_absolute_error: 16.2167
# Epoch 8/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 14.9262 - mean_absolute_error: 14.9262
# Epoch 9/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 14.0175 - mean_absolute_error: 14.0175
# Epoch 10/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 13.5346 - mean_absolute_error: 13.5346
# Epoch 11/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 13.2902 - mean_absolute_error: 13.2902
# Epoch 12/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 13.1312 - mean_absolute_error: 13.1312
# Epoch 13/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.9527 - mean_absolute_error: 12.9527
# Epoch 14/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 13.0341 - mean_absolute_error: 13.0341
# Epoch 15/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.7853 - mean_absolute_error: 12.7853
# Epoch 16/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.7801 - mean_absolute_error: 12.7801
# Epoch 17/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.6143 - mean_absolute_error: 12.6143
# Epoch 18/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.6790 - mean_absolute_error: 12.6790
# Epoch 19/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.5928 - mean_absolute_error: 12.5928
# Epoch 20/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.5509 - mean_absolute_error: 12.5509
# Epoch 21/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.5073 - mean_absolute_error: 12.5073
# Epoch 22/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.4613 - mean_absolute_error: 12.4613
# Epoch 23/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.5296 - mean_absolute_error: 12.5296
# Epoch 24/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.4263 - mean_absolute_error: 12.4263
# Epoch 25/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.4291 - mean_absolute_error: 12.4291
# Epoch 26/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.4168 - mean_absolute_error: 12.4168
# Epoch 27/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.4538 - mean_absolute_error: 12.4538
# Epoch 28/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.3600 - mean_absolute_error: 12.3600
# Epoch 29/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.4072 - mean_absolute_error: 12.4072
# Epoch 30/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.4922 - mean_absolute_error: 12.4922
# Epoch 31/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.3311 - mean_absolute_error: 12.3311
# Epoch 32/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.4172 - mean_absolute_error: 12.4172
# Epoch 33/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.3656 - mean_absolute_error: 12.3656
# Epoch 34/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.3415 - mean_absolute_error: 12.3415
# Epoch 35/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.3820 - mean_absolute_error: 12.3820
# Epoch 36/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.3091 - mean_absolute_error: 12.3091
# Epoch 37/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.3134 - mean_absolute_error: 12.3134
# Epoch 38/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.3779 - mean_absolute_error: 12.3779
# Epoch 39/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.3255 - mean_absolute_error: 12.3255
# Epoch 40/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.2633 - mean_absolute_error: 12.2633
# Epoch 41/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.2747 - mean_absolute_error: 12.2747
# Epoch 42/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2198 - mean_absolute_error: 12.2198
# Epoch 43/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1982 - mean_absolute_error: 12.1982
# Epoch 44/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.3120 - mean_absolute_error: 12.3120
# Epoch 45/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.2452 - mean_absolute_error: 12.2452
# Epoch 46/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.2604 - mean_absolute_error: 12.2604
# Epoch 47/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.2250 - mean_absolute_error: 12.2250
# Epoch 48/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2439 - mean_absolute_error: 12.2439
# Epoch 49/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1794 - mean_absolute_error: 12.1794
# Epoch 50/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2167 - mean_absolute_error: 12.2167
# Epoch 51/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.2481 - mean_absolute_error: 12.2481
# Epoch 52/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.2790 - mean_absolute_error: 12.2790
# Epoch 53/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2126 - mean_absolute_error: 12.2126
# Epoch 54/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1672 - mean_absolute_error: 12.1672
# Epoch 55/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2985 - mean_absolute_error: 12.2985
# Epoch 56/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1923 - mean_absolute_error: 12.1923
# Epoch 57/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1611 - mean_absolute_error: 12.1611
# Epoch 58/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1744 - mean_absolute_error: 12.1744
# Epoch 59/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2062 - mean_absolute_error: 12.2062
# Epoch 60/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1620 - mean_absolute_error: 12.1620
# Epoch 61/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2616 - mean_absolute_error: 12.2616
# Epoch 62/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1834 - mean_absolute_error: 12.1834
# Epoch 63/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2100 - mean_absolute_error: 12.2100
# Epoch 64/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1845 - mean_absolute_error: 12.1845
# Epoch 65/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1842 - mean_absolute_error: 12.1842
# Epoch 66/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1104 - mean_absolute_error: 12.1104
# Epoch 67/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1712 - mean_absolute_error: 12.1712
# Epoch 68/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1926 - mean_absolute_error: 12.1926
# Epoch 69/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.2221 - mean_absolute_error: 12.2221
# Epoch 70/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1799 - mean_absolute_error: 12.1799
# Epoch 71/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1183 - mean_absolute_error: 12.1183
# Epoch 72/100
# 3442/3442 [==============================] - 0s 24us/step - loss: 12.1045 - mean_absolute_error: 12.1045
# Epoch 73/100
# 3442/3442 [==============================] - 0s 19us/step - loss: 12.1380 - mean_absolute_error: 12.1380
# Epoch 74/100
# 3442/3442 [==============================] - 0s 19us/step - loss: 12.2187 - mean_absolute_error: 12.2187
# Epoch 75/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1148 - mean_absolute_error: 12.1148
# Epoch 76/100
# 3442/3442 [==============================] - 0s 19us/step - loss: 12.2091 - mean_absolute_error: 12.2091
# Epoch 77/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1620 - mean_absolute_error: 12.1620
# Epoch 78/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0924 - mean_absolute_error: 12.0924
# Epoch 79/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1755 - mean_absolute_error: 12.1755
# Epoch 80/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.0630 - mean_absolute_error: 12.0630
# Epoch 81/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1287 - mean_absolute_error: 12.1287
# Epoch 82/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.3078 - mean_absolute_error: 12.3078
# Epoch 83/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1038 - mean_absolute_error: 12.1038
# Epoch 84/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0967 - mean_absolute_error: 12.0967
# Epoch 85/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.1212 - mean_absolute_error: 12.1212
# Epoch 86/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1104 - mean_absolute_error: 12.1104
# Epoch 87/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.0297 - mean_absolute_error: 12.0297
# Epoch 88/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.0290 - mean_absolute_error: 12.0290
# Epoch 89/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0972 - mean_absolute_error: 12.0972
# Epoch 90/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1230 - mean_absolute_error: 12.1230
# Epoch 91/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.1126 - mean_absolute_error: 12.1126
# Epoch 92/100
# 3442/3442 [==============================] - 0s 22us/step - loss: 12.1346 - mean_absolute_error: 12.1346
# Epoch 93/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0420 - mean_absolute_error: 12.0420
# Epoch 94/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0566 - mean_absolute_error: 12.0566
# Epoch 95/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.0872 - mean_absolute_error: 12.0872
# Epoch 96/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.0654 - mean_absolute_error: 12.0654
# Epoch 97/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0351 - mean_absolute_error: 12.0351
# Epoch 98/100
# 3442/3442 [==============================] - 0s 20us/step - loss: 12.0472 - mean_absolute_error: 12.0472
# Epoch 99/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.0714 - mean_absolute_error: 12.0714
# Epoch 100/100
# 3442/3442 [==============================] - 0s 21us/step - loss: 12.1674 - mean_absolute_error: 12.1674
# 815/815 [==============================] - 0s 117us/step
#
# The MAE for Neural Networks on the Training data is: -12.7987

# %%
t4= time.clock() #START TIME OF TESTING DATA COMPUTATION FOR NEURAL NETWORK REGRESSOR
estimator.fit(X_train_new, Y_train)
estimator_test_pred = estimator.predict(X_test_new)
print("\nThe MAE for Neural Network Regressor on the Testing data is: {:.4f} \n".format(mean_absolute_error(Y_test, estimator_test_pred)))
t5 = time.clock() - t4 # END TIME FOR COMPUTATION OF NEURAL NETWORK REGRESSOR
print("Total Computational time for the Neural Network Regressor on the testing Data is: ", t5 ) # CPU seconds elapsed (floating point)
# Out:
# Epoch 1/100
# 4257/4257 [==============================] - 1s 130us/step - loss: 101.8520 - mean_absolute_error: 101.8520
# Epoch 2/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 44.9363 - mean_absolute_error: 44.9363
# Epoch 3/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 29.8846 - mean_absolute_error: 29.8846
# Epoch 4/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 22.4005 - mean_absolute_error: 22.4005
# Epoch 5/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 18.0674 - mean_absolute_error: 18.0674
# Epoch 6/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 15.8102 - mean_absolute_error: 15.8102
# Epoch 7/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 14.4297 - mean_absolute_error: 14.4297
# Epoch 8/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.5836 - mean_absolute_error: 13.5836
# Epoch 9/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.2875 - mean_absolute_error: 13.2875
# Epoch 10/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 13.0313 - mean_absolute_error: 13.0313
# Epoch 11/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.9018 - mean_absolute_error: 12.9018
# Epoch 12/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.7512 - mean_absolute_error: 12.7512
# Epoch 13/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.6226 - mean_absolute_error: 12.6226
# Epoch 14/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.6324 - mean_absolute_error: 12.6324
# Epoch 15/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.6635 - mean_absolute_error: 12.6635
# Epoch 16/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.6390 - mean_absolute_error: 12.6390
# Epoch 17/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4733 - mean_absolute_error: 12.4733
# Epoch 18/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4846 - mean_absolute_error: 12.4846
# Epoch 19/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.5274 - mean_absolute_error: 12.5274
# Epoch 20/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4338 - mean_absolute_error: 12.4338
# Epoch 21/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.5110 - mean_absolute_error: 12.5110
# Epoch 22/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4375 - mean_absolute_error: 12.4375
# Epoch 23/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4875 - mean_absolute_error: 12.4875
# Epoch 24/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4955 - mean_absolute_error: 12.4955
# Epoch 25/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3616 - mean_absolute_error: 12.3616
# Epoch 26/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3582 - mean_absolute_error: 12.3582
# Epoch 27/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3497 - mean_absolute_error: 12.3497
# Epoch 28/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.4131 - mean_absolute_error: 12.4131
# Epoch 29/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3579 - mean_absolute_error: 12.3579
# Epoch 30/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3457 - mean_absolute_error: 12.3457
# Epoch 31/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.4184 - mean_absolute_error: 12.4184
# Epoch 32/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3708 - mean_absolute_error: 12.3708
# Epoch 33/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.3732 - mean_absolute_error: 12.3732
# Epoch 34/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2724 - mean_absolute_error: 12.2724
# Epoch 35/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2752 - mean_absolute_error: 12.2752
# Epoch 36/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2866 - mean_absolute_error: 12.2866
# Epoch 37/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2531 - mean_absolute_error: 12.2531
# Epoch 38/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2833 - mean_absolute_error: 12.2833
# Epoch 39/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.2516 - mean_absolute_error: 12.2516
# Epoch 40/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.2525 - mean_absolute_error: 12.2525
# Epoch 41/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.2284 - mean_absolute_error: 12.2284
# Epoch 42/100
# 4257/4257 [==============================] - 0s 51us/step - loss: 12.2323 - mean_absolute_error: 12.2323
# Epoch 43/100
# 4257/4257 [==============================] - 0s 35us/step - loss: 12.3686 - mean_absolute_error: 12.3686
# Epoch 44/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.2443 - mean_absolute_error: 12.2443
# Epoch 45/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.2917 - mean_absolute_error: 12.2917
# Epoch 46/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.2126 - mean_absolute_error: 12.2126
# Epoch 47/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.2808 - mean_absolute_error: 12.2808
# Epoch 48/100
# 4257/4257 [==============================] - 0s 34us/step - loss: 12.3052 - mean_absolute_error: 12.3052
# Epoch 49/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.2278 - mean_absolute_error: 12.2278
# Epoch 50/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.1684 - mean_absolute_error: 12.1684
# Epoch 51/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.2160 - mean_absolute_error: 12.2160
# Epoch 52/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1334 - mean_absolute_error: 12.1334
# Epoch 53/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2481 - mean_absolute_error: 12.2481
# Epoch 54/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2518 - mean_absolute_error: 12.2518
# Epoch 55/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2362 - mean_absolute_error: 12.2362
# Epoch 56/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.1337 - mean_absolute_error: 12.1337
# Epoch 57/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.0890 - mean_absolute_error: 12.0890
# Epoch 58/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1437 - mean_absolute_error: 12.1437
# Epoch 59/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1874 - mean_absolute_error: 12.1874
# Epoch 60/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2669 - mean_absolute_error: 12.2669
# Epoch 61/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1706 - mean_absolute_error: 12.1706
# Epoch 62/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1390 - mean_absolute_error: 12.1390
# Epoch 63/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2217 - mean_absolute_error: 12.2217
# Epoch 64/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1168 - mean_absolute_error: 12.1168
# Epoch 65/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1866 - mean_absolute_error: 12.1866
# Epoch 66/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1652 - mean_absolute_error: 12.1652
# Epoch 67/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1240 - mean_absolute_error: 12.1240
# Epoch 68/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.1564 - mean_absolute_error: 12.1564
# Epoch 69/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.1017 - mean_absolute_error: 12.1017
# Epoch 70/100
# 4257/4257 [==============================] - 0s 40us/step - loss: 12.1497 - mean_absolute_error: 12.1497
# Epoch 71/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.1532 - mean_absolute_error: 12.1532
# Epoch 72/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2001 - mean_absolute_error: 12.2001
# Epoch 73/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1485 - mean_absolute_error: 12.1485
# Epoch 74/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2067 - mean_absolute_error: 12.2067
# Epoch 75/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.1749 - mean_absolute_error: 12.1749
# Epoch 76/100
# 4257/4257 [==============================] - 0s 36us/step - loss: 12.1622 - mean_absolute_error: 12.1622
# Epoch 77/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.1624 - mean_absolute_error: 12.1624
# Epoch 78/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.1404 - mean_absolute_error: 12.1404
# Epoch 79/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1351 - mean_absolute_error: 12.1351
# Epoch 80/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0705 - mean_absolute_error: 12.0705
# Epoch 81/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1301 - mean_absolute_error: 12.1301
# Epoch 82/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.1007 - mean_absolute_error: 12.1007
# Epoch 83/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1527 - mean_absolute_error: 12.1527
# Epoch 84/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1885 - mean_absolute_error: 12.1885
# Epoch 85/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.1319 - mean_absolute_error: 12.1319
# Epoch 86/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0722 - mean_absolute_error: 12.0722
# Epoch 87/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0579 - mean_absolute_error: 12.0579
# Epoch 88/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 11.9850 - mean_absolute_error: 11.9850
# Epoch 89/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.0911 - mean_absolute_error: 12.0911
# Epoch 90/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2011 - mean_absolute_error: 12.2011
# Epoch 91/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.0654 - mean_absolute_error: 12.0654
# Epoch 92/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0782 - mean_absolute_error: 12.0782
# Epoch 93/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0781 - mean_absolute_error: 12.0781
# Epoch 94/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.0305 - mean_absolute_error: 12.0305
# Epoch 95/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1306 - mean_absolute_error: 12.1306
# Epoch 96/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0006 - mean_absolute_error: 12.0006
# Epoch 97/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1148 - mean_absolute_error: 12.1148
# Epoch 98/100
# 4257/4257 [==============================] - 0s 35us/step - loss: 12.0408 - mean_absolute_error: 12.0408
# Epoch 99/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1411 - mean_absolute_error: 12.1411
# Epoch 100/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0592 - mean_absolute_error: 12.0592
#
# The MAE for Neural Network Regressor on the Testing data is: 12.9830
#
# Total Computational time for the Neural Network Regressor on the testing Data is:  11.718570600000021

# %% [markdown]
# THE NEXT STEP IS TO RUN THE NEURAL NETWORK ALGORITHM OVER 30 SEEDS AND STORE THE RESULTS TO CHECK WHETHER THE RESULTS FOLLOW A GAUSSIAN DISTRIBUTION OR NOT

# %%
L_nn=[]

# %%
for i in range(0,30):
    estimator.fit(X_train_new, Y_train)
    regressor_test_pred = estimator.predict(X_test_new)
    M= mean_absolute_error(Y_test, regressor_test_pred)
    L_nn.append(M)
# Out:
# Epoch 1/100
# 4257/4257 [==============================] - 1s 140us/step - loss: 104.4667 - mean_absolute_error: 104.4667
# Epoch 2/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 46.8273 - mean_absolute_error: 46.8273
# Epoch 3/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 30.4767 - mean_absolute_error: 30.4767
# Epoch 4/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 22.9364 - mean_absolute_error: 22.9364
# Epoch 5/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 18.7298 - mean_absolute_error: 18.7298
# Epoch 6/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 16.2468 - mean_absolute_error: 16.2468
# Epoch 7/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 14.6897 - mean_absolute_error: 14.6897
# Epoch 8/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 13.9542 - mean_absolute_error: 13.9542
# Epoch 9/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.4276 - mean_absolute_error: 13.4276
# Epoch 10/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.1175 - mean_absolute_error: 13.1175
# Epoch 11/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.8456 - mean_absolute_error: 12.8456
# Epoch 12/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.8767 - mean_absolute_error: 12.8767
# Epoch 13/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.6793 - mean_absolute_error: 12.6793
# Epoch 14/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.6833 - mean_absolute_error: 12.6833
# Epoch 15/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.5845 - mean_absolute_error: 12.5845
# Epoch 16/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.5863 - mean_absolute_error: 12.5863
# Epoch 17/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.5429 - mean_absolute_error: 12.5429
# Epoch 18/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4880 - mean_absolute_error: 12.4880
# Epoch 19/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.5143 - mean_absolute_error: 12.5143
# Epoch 20/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.5223 - mean_absolute_error: 12.5223
# Epoch 21/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4255 - mean_absolute_error: 12.4255
# Epoch 22/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4660 - mean_absolute_error: 12.4660
# Epoch 23/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.5125 - mean_absolute_error: 12.5125
# Epoch 24/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.5228 - mean_absolute_error: 12.5228
# Epoch 25/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.4746 - mean_absolute_error: 12.4746
# Epoch 26/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4118 - mean_absolute_error: 12.4118
# Epoch 27/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4453 - mean_absolute_error: 12.4453
# Epoch 28/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3633 - mean_absolute_error: 12.3633
# Epoch 29/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4107 - mean_absolute_error: 12.4107
# Epoch 30/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3124 - mean_absolute_error: 12.3124
# Epoch 31/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.3172 - mean_absolute_error: 12.3172
# Epoch 32/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.3433 - mean_absolute_error: 12.3433
# Epoch 33/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3206 - mean_absolute_error: 12.3206
# Epoch 34/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.3229 - mean_absolute_error: 12.3229
# Epoch 35/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2905 - mean_absolute_error: 12.2905
# Epoch 36/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.2864 - mean_absolute_error: 12.2864
# Epoch 37/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3528 - mean_absolute_error: 12.3528
# Epoch 38/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3280 - mean_absolute_error: 12.3280
# Epoch 39/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.3635 - mean_absolute_error: 12.3635
# Epoch 40/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3460 - mean_absolute_error: 12.3460
# Epoch 41/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3529 - mean_absolute_error: 12.3529
# Epoch 42/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2533 - mean_absolute_error: 12.2533
# Epoch 43/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2628 - mean_absolute_error: 12.2628
# Epoch 44/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2644 - mean_absolute_error: 12.2644
# Epoch 45/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3063 - mean_absolute_error: 12.3063
# Epoch 46/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2300 - mean_absolute_error: 12.2300
# Epoch 47/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2650 - mean_absolute_error: 12.2650
# Epoch 48/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2143 - mean_absolute_error: 12.2143
# Epoch 49/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.2789 - mean_absolute_error: 12.2789
# Epoch 50/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1815 - mean_absolute_error: 12.1815
# Epoch 51/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.2955 - mean_absolute_error: 12.2955
# Epoch 52/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.2652 - mean_absolute_error: 12.2652
# Epoch 53/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1963 - mean_absolute_error: 12.1963
# Epoch 54/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1893 - mean_absolute_error: 12.1893
# Epoch 55/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2627 - mean_absolute_error: 12.2627
# Epoch 56/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2110 - mean_absolute_error: 12.2110
# Epoch 57/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2564 - mean_absolute_error: 12.2564
# Epoch 58/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2885 - mean_absolute_error: 12.2885
# Epoch 59/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3267 - mean_absolute_error: 12.3267
# Epoch 60/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2144 - mean_absolute_error: 12.2144
# Epoch 61/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1874 - mean_absolute_error: 12.1874
# Epoch 62/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1526 - mean_absolute_error: 12.1526
# Epoch 63/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2529 - mean_absolute_error: 12.2529
# Epoch 64/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.1566 - mean_absolute_error: 12.1566
# Epoch 65/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1450 - mean_absolute_error: 12.1450
# Epoch 66/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2299 - mean_absolute_error: 12.2299
# Epoch 67/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.2974 - mean_absolute_error: 12.2974
# Epoch 68/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1740 - mean_absolute_error: 12.1740
# Epoch 69/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.0905 - mean_absolute_error: 12.0905
# Epoch 70/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1184 - mean_absolute_error: 12.1184
# Epoch 71/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1097 - mean_absolute_error: 12.1097
# Epoch 72/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.1340 - mean_absolute_error: 12.1340
# Epoch 73/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1133 - mean_absolute_error: 12.1133
# Epoch 74/100
# 4257/4257 [==============================] - ETA: 0s - loss: 12.3289 - mean_absolute_error: 12.328 - 0s 20us/step - loss: 12.1735 - mean_absolute_error: 12.1735
# Epoch 75/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1375 - mean_absolute_error: 12.1375
# Epoch 76/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1224 - mean_absolute_error: 12.1224
# Epoch 77/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1754 - mean_absolute_error: 12.1754
# Epoch 78/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1218 - mean_absolute_error: 12.1218
# Epoch 79/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1335 - mean_absolute_error: 12.1335
# Epoch 80/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1644 - mean_absolute_error: 12.1644
# Epoch 81/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1572 - mean_absolute_error: 12.1572
# Epoch 82/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1423 - mean_absolute_error: 12.1423
# Epoch 83/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0863 - mean_absolute_error: 12.0863
# Epoch 84/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1368 - mean_absolute_error: 12.1368
# Epoch 85/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1875 - mean_absolute_error: 12.1875
# Epoch 86/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1158 - mean_absolute_error: 12.1158
# Epoch 87/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0860 - mean_absolute_error: 12.0860
# Epoch 88/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2160 - mean_absolute_error: 12.2160
# Epoch 89/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1413 - mean_absolute_error: 12.1413
# Epoch 90/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1618 - mean_absolute_error: 12.1618
# Epoch 91/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0463 - mean_absolute_error: 12.0463
# Epoch 92/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2502 - mean_absolute_error: 12.2502
# Epoch 93/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1438 - mean_absolute_error: 12.1438
# Epoch 94/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.0851 - mean_absolute_error: 12.0851
# Epoch 95/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1509 - mean_absolute_error: 12.1509
# Epoch 96/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.0780 - mean_absolute_error: 12.0780
# Epoch 97/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0808 - mean_absolute_error: 12.0808
# Epoch 98/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0704 - mean_absolute_error: 12.0704
# Epoch 99/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0176 - mean_absolute_error: 12.0176
# Epoch 100/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.0910 - mean_absolute_error: 12.0910
# Epoch 1/100
# 4257/4257 [==============================] - 1s 161us/step - loss: 101.3857 - mean_absolute_error: 101.3857
# Epoch 2/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 44.9349 - mean_absolute_error: 44.9349
# Epoch 3/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 29.2324 - mean_absolute_error: 29.2324
# Epoch 4/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 22.2449 - mean_absolute_error: 22.2449
# Epoch 5/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 18.1855 - mean_absolute_error: 18.1855
# Epoch 6/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 15.6894 - mean_absolute_error: 15.6894
# Epoch 7/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 14.3038 - mean_absolute_error: 14.3038
# Epoch 8/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.5817 - mean_absolute_error: 13.5817
# Epoch 9/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.2072 - mean_absolute_error: 13.2072
# Epoch 10/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 13.0236 - mean_absolute_error: 13.0236: 0s - loss: 12.9467 - mean_absolute_error: 12.946
# Epoch 11/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.8106 - mean_absolute_error: 12.8106
# Epoch 12/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.7569 - mean_absolute_error: 12.7569
# Epoch 13/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.7485 - mean_absolute_error: 12.7485
# Epoch 14/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.6473 - mean_absolute_error: 12.6473
# Epoch 15/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.6498 - mean_absolute_error: 12.6498
# Epoch 16/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.6506 - mean_absolute_error: 12.6506
# Epoch 17/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.6369 - mean_absolute_error: 12.6369
# Epoch 18/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.5262 - mean_absolute_error: 12.5262
# Epoch 19/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4714 - mean_absolute_error: 12.4714
# Epoch 20/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4120 - mean_absolute_error: 12.4120
# Epoch 21/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4167 - mean_absolute_error: 12.4167
# Epoch 22/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.4664 - mean_absolute_error: 12.4664
# Epoch 23/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4678 - mean_absolute_error: 12.4678
# Epoch 24/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4076 - mean_absolute_error: 12.4076
# Epoch 25/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4221 - mean_absolute_error: 12.4221
# Epoch 26/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3261 - mean_absolute_error: 12.3261
# Epoch 27/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3786 - mean_absolute_error: 12.3786
# Epoch 28/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3986 - mean_absolute_error: 12.3986
# Epoch 29/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.5099 - mean_absolute_error: 12.5099
# Epoch 30/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3716 - mean_absolute_error: 12.3716
# Epoch 31/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.4850 - mean_absolute_error: 12.4850
# Epoch 32/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3100 - mean_absolute_error: 12.3100
# Epoch 33/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3886 - mean_absolute_error: 12.3886
# Epoch 34/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3688 - mean_absolute_error: 12.3688
# Epoch 35/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2783 - mean_absolute_error: 12.2783
# Epoch 36/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2543 - mean_absolute_error: 12.2543
# Epoch 37/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3474 - mean_absolute_error: 12.3474
# Epoch 38/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3597 - mean_absolute_error: 12.3597
# Epoch 39/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2864 - mean_absolute_error: 12.2864
# Epoch 40/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2575 - mean_absolute_error: 12.2575
# Epoch 41/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3032 - mean_absolute_error: 12.3032
# Epoch 42/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3315 - mean_absolute_error: 12.3315
# Epoch 43/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2677 - mean_absolute_error: 12.2677
# Epoch 44/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3293 - mean_absolute_error: 12.3293
# Epoch 45/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3604 - mean_absolute_error: 12.3604
# Epoch 46/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2314 - mean_absolute_error: 12.2314
# Epoch 47/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2338 - mean_absolute_error: 12.2338
# Epoch 48/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2195 - mean_absolute_error: 12.2195
# Epoch 49/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2406 - mean_absolute_error: 12.2406
# Epoch 50/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2902 - mean_absolute_error: 12.2902
# Epoch 51/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2974 - mean_absolute_error: 12.2974
# Epoch 52/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2346 - mean_absolute_error: 12.2346
# Epoch 53/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2204 - mean_absolute_error: 12.2204
# Epoch 54/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1832 - mean_absolute_error: 12.1832
# Epoch 55/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1550 - mean_absolute_error: 12.1550
# Epoch 56/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2706 - mean_absolute_error: 12.2706
# Epoch 57/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1809 - mean_absolute_error: 12.1809
# Epoch 58/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1797 - mean_absolute_error: 12.1797
# Epoch 59/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1687 - mean_absolute_error: 12.1687
# Epoch 60/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1856 - mean_absolute_error: 12.1856
# Epoch 61/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1475 - mean_absolute_error: 12.1475
# Epoch 62/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1157 - mean_absolute_error: 12.1157
# Epoch 63/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2085 - mean_absolute_error: 12.2085
# Epoch 64/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1101 - mean_absolute_error: 12.1101
# Epoch 65/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1830 - mean_absolute_error: 12.1830
# Epoch 66/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2493 - mean_absolute_error: 12.2493
# Epoch 67/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2445 - mean_absolute_error: 12.2445
# Epoch 68/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1800 - mean_absolute_error: 12.1800
# Epoch 69/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2447 - mean_absolute_error: 12.2447
# Epoch 70/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2332 - mean_absolute_error: 12.2332
# Epoch 71/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1666 - mean_absolute_error: 12.1666
# Epoch 72/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1526 - mean_absolute_error: 12.1526
# Epoch 73/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1551 - mean_absolute_error: 12.1551
# Epoch 74/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2030 - mean_absolute_error: 12.2030
# Epoch 75/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1624 - mean_absolute_error: 12.1624
# Epoch 76/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0784 - mean_absolute_error: 12.0784
# Epoch 77/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1320 - mean_absolute_error: 12.1320
# Epoch 78/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1529 - mean_absolute_error: 12.1529
# Epoch 79/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2070 - mean_absolute_error: 12.2070
# Epoch 80/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1654 - mean_absolute_error: 12.1654
# Epoch 81/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2698 - mean_absolute_error: 12.2698
# Epoch 82/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0871 - mean_absolute_error: 12.0871
# Epoch 83/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0473 - mean_absolute_error: 12.0473
# Epoch 84/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.1039 - mean_absolute_error: 12.1039
# Epoch 85/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1374 - mean_absolute_error: 12.1374
# Epoch 86/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1209 - mean_absolute_error: 12.1209
# Epoch 87/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.1592 - mean_absolute_error: 12.1592
# Epoch 88/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1148 - mean_absolute_error: 12.1148
# Epoch 89/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0990 - mean_absolute_error: 12.0990
# Epoch 90/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2003 - mean_absolute_error: 12.2003
# Epoch 91/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.0790 - mean_absolute_error: 12.0790
# Epoch 92/100
# 4257/4257 [==============================] - 0s 40us/step - loss: 12.1147 - mean_absolute_error: 12.1147
# Epoch 93/100
# 4257/4257 [==============================] - 0s 39us/step - loss: 12.0098 - mean_absolute_error: 12.0098
# Epoch 94/100
# 4257/4257 [==============================] - 0s 49us/step - loss: 12.1080 - mean_absolute_error: 12.1080
# Epoch 95/100
# 4257/4257 [==============================] - 0s 43us/step - loss: 12.0509 - mean_absolute_error: 12.0509
# Epoch 96/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.1550 - mean_absolute_error: 12.1550
# Epoch 97/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.0209 - mean_absolute_error: 12.0209
# Epoch 98/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1618 - mean_absolute_error: 12.1618
# Epoch 99/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0979 - mean_absolute_error: 12.0979
# Epoch 100/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.0952 - mean_absolute_error: 12.0952
# Epoch 1/100
# 4257/4257 [==============================] - 1s 158us/step - loss: 101.4497 - mean_absolute_error: 101.4497
# Epoch 2/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 45.0689 - mean_absolute_error: 45.0689
# Epoch 3/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 29.5717 - mean_absolute_error: 29.5717
# Epoch 4/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 21.7426 - mean_absolute_error: 21.7426
# Epoch 5/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 17.7068 - mean_absolute_error: 17.7068
# Epoch 6/100
# 4257/4257 [==============================] - 0s 34us/step - loss: 15.4952 - mean_absolute_error: 15.4952
# Epoch 7/100
# 4257/4257 [==============================] - 0s 34us/step - loss: 14.1098 - mean_absolute_error: 14.1098
# Epoch 8/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 13.5490 - mean_absolute_error: 13.5490
# Epoch 9/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 13.0939 - mean_absolute_error: 13.0939
# Epoch 10/100
# 4257/4257 [==============================] - 0s 34us/step - loss: 12.9605 - mean_absolute_error: 12.9605
# Epoch 11/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.7898 - mean_absolute_error: 12.7898
# Epoch 12/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.7961 - mean_absolute_error: 12.7961
# Epoch 13/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.6677 - mean_absolute_error: 12.6677
# Epoch 14/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.5075 - mean_absolute_error: 12.5075
# Epoch 15/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.5544 - mean_absolute_error: 12.5544
# Epoch 16/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.5841 - mean_absolute_error: 12.5841
# Epoch 17/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.5571 - mean_absolute_error: 12.5571
# Epoch 18/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.4624 - mean_absolute_error: 12.4624
# Epoch 19/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.4460 - mean_absolute_error: 12.4460
# Epoch 20/100
# 4257/4257 [==============================] - 0s 44us/step - loss: 12.4727 - mean_absolute_error: 12.4727
# Epoch 21/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.5470 - mean_absolute_error: 12.5470
# Epoch 22/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.5233 - mean_absolute_error: 12.5233
# Epoch 23/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.3668 - mean_absolute_error: 12.3668
# Epoch 24/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.4462 - mean_absolute_error: 12.4462
# Epoch 25/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.4368 - mean_absolute_error: 12.4368
# Epoch 26/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.4388 - mean_absolute_error: 12.4388
# Epoch 27/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.3956 - mean_absolute_error: 12.3956
# Epoch 28/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.3794 - mean_absolute_error: 12.3794
# Epoch 29/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.3210 - mean_absolute_error: 12.3210
# Epoch 30/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.3598 - mean_absolute_error: 12.3598
# Epoch 31/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3320 - mean_absolute_error: 12.3320
# Epoch 32/100
# 4257/4257 [==============================] - 0s 47us/step - loss: 12.2857 - mean_absolute_error: 12.2857
# Epoch 33/100
# 4257/4257 [==============================] - 0s 42us/step - loss: 12.3563 - mean_absolute_error: 12.3563
# Epoch 34/100
# 4257/4257 [==============================] - 0s 45us/step - loss: 12.3159 - mean_absolute_error: 12.3159
# Epoch 35/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.2651 - mean_absolute_error: 12.2651
# Epoch 36/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.3216 - mean_absolute_error: 12.3216
# Epoch 37/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.2715 - mean_absolute_error: 12.2715
# Epoch 38/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.2797 - mean_absolute_error: 12.2797
# Epoch 39/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2114 - mean_absolute_error: 12.2114
# Epoch 40/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.3285 - mean_absolute_error: 12.3285
# Epoch 41/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.2676 - mean_absolute_error: 12.2676
# Epoch 42/100
# 4257/4257 [==============================] - 0s 35us/step - loss: 12.2154 - mean_absolute_error: 12.2154
# Epoch 43/100
# 4257/4257 [==============================] - 0s 36us/step - loss: 12.2510 - mean_absolute_error: 12.2510
# Epoch 44/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.2697 - mean_absolute_error: 12.2697
# Epoch 45/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.2438 - mean_absolute_error: 12.2438
# Epoch 46/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.2592 - mean_absolute_error: 12.2592
# Epoch 47/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2426 - mean_absolute_error: 12.2426
# Epoch 48/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2212 - mean_absolute_error: 12.2212
# Epoch 49/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2656 - mean_absolute_error: 12.2656
# Epoch 50/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2117 - mean_absolute_error: 12.2117
# Epoch 51/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1682 - mean_absolute_error: 12.1682
# Epoch 52/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2326 - mean_absolute_error: 12.2326
# Epoch 53/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2457 - mean_absolute_error: 12.2457
# Epoch 54/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.2535 - mean_absolute_error: 12.2535
# Epoch 55/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2678 - mean_absolute_error: 12.2678
# Epoch 56/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2113 - mean_absolute_error: 12.2113
# Epoch 57/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1928 - mean_absolute_error: 12.1928
# Epoch 58/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2898 - mean_absolute_error: 12.2898
# Epoch 59/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2159 - mean_absolute_error: 12.2159
# Epoch 60/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1951 - mean_absolute_error: 12.1951
# Epoch 61/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1728 - mean_absolute_error: 12.1728
# Epoch 62/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.2129 - mean_absolute_error: 12.2129
# Epoch 63/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2257 - mean_absolute_error: 12.2257
# Epoch 64/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1756 - mean_absolute_error: 12.1756
# Epoch 65/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1749 - mean_absolute_error: 12.1749
# Epoch 66/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.1149 - mean_absolute_error: 12.1149
# Epoch 67/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1762 - mean_absolute_error: 12.1762
# Epoch 68/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.0998 - mean_absolute_error: 12.0998
# Epoch 69/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1434 - mean_absolute_error: 12.1434
# Epoch 70/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1254 - mean_absolute_error: 12.1254
# Epoch 71/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2103 - mean_absolute_error: 12.2103
# Epoch 72/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.0697 - mean_absolute_error: 12.0697
# Epoch 73/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2213 - mean_absolute_error: 12.2213
# Epoch 74/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1691 - mean_absolute_error: 12.1691
# Epoch 75/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1463 - mean_absolute_error: 12.1463
# Epoch 76/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0718 - mean_absolute_error: 12.0718
# Epoch 77/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1600 - mean_absolute_error: 12.1600
# Epoch 78/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1114 - mean_absolute_error: 12.1114
# Epoch 79/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1518 - mean_absolute_error: 12.1518
# Epoch 80/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1530 - mean_absolute_error: 12.1530
# Epoch 81/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1264 - mean_absolute_error: 12.1264
# Epoch 82/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0564 - mean_absolute_error: 12.0564
# Epoch 83/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1135 - mean_absolute_error: 12.1135
# Epoch 84/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0966 - mean_absolute_error: 12.0966
# Epoch 85/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1322 - mean_absolute_error: 12.1322
# Epoch 86/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0977 - mean_absolute_error: 12.0977
# Epoch 87/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0556 - mean_absolute_error: 12.0556
# Epoch 88/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0860 - mean_absolute_error: 12.0860
# Epoch 89/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1417 - mean_absolute_error: 12.1417
# Epoch 90/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0824 - mean_absolute_error: 12.0824
# Epoch 91/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1976 - mean_absolute_error: 12.1976
# Epoch 92/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0667 - mean_absolute_error: 12.0667
# Epoch 93/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1053 - mean_absolute_error: 12.1053
# Epoch 94/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0653 - mean_absolute_error: 12.0653
# Epoch 95/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.0872 - mean_absolute_error: 12.0872
# Epoch 96/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1998 - mean_absolute_error: 12.1998
# Epoch 97/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.0614 - mean_absolute_error: 12.0614
# Epoch 98/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.0608 - mean_absolute_error: 12.0608
# Epoch 99/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.0806 - mean_absolute_error: 12.0806
# Epoch 100/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0504 - mean_absolute_error: 12.0504
# Epoch 1/100
# 4257/4257 [==============================] - 1s 172us/step - loss: 104.7876 - mean_absolute_error: 104.7876
# Epoch 2/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 47.9918 - mean_absolute_error: 47.9918
# Epoch 3/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 31.5060 - mean_absolute_error: 31.5060
# Epoch 4/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 23.1723 - mean_absolute_error: 23.1723
# Epoch 5/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 18.8362 - mean_absolute_error: 18.8362
# Epoch 6/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 16.1135 - mean_absolute_error: 16.1135
# Epoch 7/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 14.5598 - mean_absolute_error: 14.5598
# Epoch 8/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 13.8049 - mean_absolute_error: 13.8049
# Epoch 9/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 13.2232 - mean_absolute_error: 13.2232
# Epoch 10/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.9918 - mean_absolute_error: 12.9918
# Epoch 11/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.8719 - mean_absolute_error: 12.8719
# Epoch 12/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.7489 - mean_absolute_error: 12.7489
# Epoch 13/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.8017 - mean_absolute_error: 12.8017
# Epoch 14/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.6398 - mean_absolute_error: 12.6398
# Epoch 15/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.6977 - mean_absolute_error: 12.6977
# Epoch 16/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.7257 - mean_absolute_error: 12.7257
# Epoch 17/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.6641 - mean_absolute_error: 12.6641
# Epoch 18/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.5673 - mean_absolute_error: 12.5673
# Epoch 19/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.6069 - mean_absolute_error: 12.6069
# Epoch 20/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4792 - mean_absolute_error: 12.4792
# Epoch 21/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.4763 - mean_absolute_error: 12.4763
# Epoch 22/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.5055 - mean_absolute_error: 12.5055
# Epoch 23/100
# 4257/4257 [==============================] - 0s 34us/step - loss: 12.4461 - mean_absolute_error: 12.4461
# Epoch 24/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.5147 - mean_absolute_error: 12.5147
# Epoch 25/100
# 4257/4257 [==============================] - 0s 28us/step - loss: 12.4457 - mean_absolute_error: 12.4457
# Epoch 26/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3931 - mean_absolute_error: 12.3931
# Epoch 27/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.3424 - mean_absolute_error: 12.3424
# Epoch 28/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.4602 - mean_absolute_error: 12.4602
# Epoch 29/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3976 - mean_absolute_error: 12.3976
# Epoch 30/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.3935 - mean_absolute_error: 12.3935
# Epoch 31/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3436 - mean_absolute_error: 12.3436
# Epoch 32/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.3928 - mean_absolute_error: 12.3928
# Epoch 33/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2806 - mean_absolute_error: 12.2806
# Epoch 34/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.3503 - mean_absolute_error: 12.3503
# Epoch 35/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2735 - mean_absolute_error: 12.2735
# Epoch 36/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.2398 - mean_absolute_error: 12.2398
# Epoch 37/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2894 - mean_absolute_error: 12.2894
# Epoch 38/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.2515 - mean_absolute_error: 12.2515
# Epoch 39/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2290 - mean_absolute_error: 12.2290
# Epoch 40/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2573 - mean_absolute_error: 12.2573
# Epoch 41/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.2226 - mean_absolute_error: 12.2226
# Epoch 42/100
# 4257/4257 [==============================] - 0s 52us/step - loss: 12.3440 - mean_absolute_error: 12.3440
# Epoch 43/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 12.2084 - mean_absolute_error: 12.2084
# Epoch 44/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2421 - mean_absolute_error: 12.2421
# Epoch 45/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3334 - mean_absolute_error: 12.3334
# Epoch 46/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1894 - mean_absolute_error: 12.1894
# Epoch 47/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2606 - mean_absolute_error: 12.2606
# Epoch 48/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.3745 - mean_absolute_error: 12.3745
# Epoch 49/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.2640 - mean_absolute_error: 12.2640
# Epoch 50/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2879 - mean_absolute_error: 12.2879
# Epoch 51/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.3456 - mean_absolute_error: 12.3456
# Epoch 52/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.2127 - mean_absolute_error: 12.2127
# Epoch 53/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1656 - mean_absolute_error: 12.1656
# Epoch 54/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1552 - mean_absolute_error: 12.1552
# Epoch 55/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.2424 - mean_absolute_error: 12.2424
# Epoch 56/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1168 - mean_absolute_error: 12.1168
# Epoch 57/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1657 - mean_absolute_error: 12.1657
# Epoch 58/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1050 - mean_absolute_error: 12.1050
# Epoch 59/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1517 - mean_absolute_error: 12.1517
# Epoch 60/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.1291 - mean_absolute_error: 12.1291
# Epoch 61/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0735 - mean_absolute_error: 12.0735
# Epoch 62/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1303 - mean_absolute_error: 12.1303
# Epoch 63/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.1619 - mean_absolute_error: 12.1619
# Epoch 64/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0743 - mean_absolute_error: 12.0743
# Epoch 65/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0988 - mean_absolute_error: 12.0988
# Epoch 66/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1806 - mean_absolute_error: 12.1806
# Epoch 67/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.0938 - mean_absolute_error: 12.0938
# Epoch 68/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.1052 - mean_absolute_error: 12.1052
# Epoch 69/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 12.1099 - mean_absolute_error: 12.1099
# Epoch 70/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.0675 - mean_absolute_error: 12.0675
# Epoch 71/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.1641 - mean_absolute_error: 12.1641
# Epoch 72/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0966 - mean_absolute_error: 12.0966
# Epoch 73/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1519 - mean_absolute_error: 12.1519
# Epoch 74/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0816 - mean_absolute_error: 12.0816
# Epoch 75/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0844 - mean_absolute_error: 12.0844
# Epoch 76/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0568 - mean_absolute_error: 12.0568
# Epoch 77/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.0522 - mean_absolute_error: 12.0522
# Epoch 78/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0542 - mean_absolute_error: 12.0542
# Epoch 79/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0237 - mean_absolute_error: 12.0237
# Epoch 80/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0476 - mean_absolute_error: 12.0476
# Epoch 81/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 12.0594 - mean_absolute_error: 12.0594
# Epoch 82/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 11.9659 - mean_absolute_error: 11.9659
# Epoch 83/100
# 4257/4257 [==============================] - 0s 20us/step - loss: 12.0781 - mean_absolute_error: 12.0781
# Epoch 84/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0737 - mean_absolute_error: 12.0737
# Epoch 85/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.1145 - mean_absolute_error: 12.1145
# Epoch 86/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 11.9990 - mean_absolute_error: 11.9990
# Epoch 87/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 11.9662 - mean_absolute_error: 11.9662
# Epoch 88/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0451 - mean_absolute_error: 12.0451
# Epoch 89/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 11.9995 - mean_absolute_error: 11.9995
# Epoch 90/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 12.0041 - mean_absolute_error: 12.0041
# Epoch 91/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 12.0518 - mean_absolute_error: 12.0518
# Epoch 92/100
# 4257/4257 [==============================] - 0s 27us/step - loss: 11.9957 - mean_absolute_error: 11.9957
# Epoch 93/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0278 - mean_absolute_error: 12.0278
# Epoch 94/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0322 - mean_absolute_error: 12.0322
# Epoch 95/100
# 4257/4257 [==============================] - 0s 24us/step - loss: 11.9264 - mean_absolute_error: 11.9264
# Epoch 96/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 11.9242 - mean_absolute_error: 11.9242
# Epoch 97/100
# 4257/4257 [==============================] - 0s 26us/step - loss: 12.0002 - mean_absolute_error: 12.0002
# Epoch 98/100
# 4257/4257 [==============================] - 0s 22us/step - loss: 11.9951 - mean_absolute_error: 11.9951
# Epoch 99/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 12.0041 - mean_absolute_error: 12.0041
# Epoch 100/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 11.9899 - mean_absolute_error: 11.9899
# Epoch 1/100
# 4257/4257 [==============================] - 1s 192us/step - loss: 102.3985 - mean_absolute_error: 102.3985
# Epoch 2/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 45.2544 - mean_absolute_error: 45.2544
# Epoch 3/100
# 4257/4257 [==============================] - 0s 21us/step - loss: 29.0388 - mean_absolute_error: 29.0388
# Epoch 4/100
# 4257/4257 [==============================] - 0s 23us/step - loss: 21.8968 - mean_absolute_error: 21.8968
# Epoch 5/100
# 4257/4257 [==============================] - 0s 25us/step - loss: 17.8082 - mean_absolute_error: 17.8082
# Epoch 6/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 15.5353 - mean_absolute_error: 15.5353
# ...
# Epoch 66/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.1255 - mean_absolute_error: 12.1255
# Epoch 67/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1806 - mean_absolute_error: 12.1806
# Epoch 68/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.1222 - mean_absolute_error: 12.1222
# Epoch 69/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1386 - mean_absolute_error: 12.1386
# Epoch 70/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1259 - mean_absolute_error: 12.1259
# Epoch 71/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.0674 - mean_absolute_error: 12.0674
# Epoch 72/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0931 - mean_absolute_error: 12.0931
# Epoch 73/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.2443 - mean_absolute_error: 12.2443
# Epoch 74/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.1359 - mean_absolute_error: 12.1359
# Epoch 75/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.1638 - mean_absolute_error: 12.1638
# Epoch 76/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.1491 - mean_absolute_error: 12.1491
# Epoch 77/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.0868 - mean_absolute_error: 12.0868
# Epoch 78/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1482 - mean_absolute_error: 12.1482
# Epoch 79/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.1348 - mean_absolute_error: 12.1348
# Epoch 80/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1585 - mean_absolute_error: 12.1585
# Epoch 81/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0464 - mean_absolute_error: 12.0464
# Epoch 82/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1422 - mean_absolute_error: 12.1422
# Epoch 83/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1435 - mean_absolute_error: 12.1435
# Epoch 84/100
# 4257/4257 [==============================] - 0s 37us/step - loss: 12.1177 - mean_absolute_error: 12.1177
# Epoch 85/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1142 - mean_absolute_error: 12.1142
# Epoch 86/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 11.9977 - mean_absolute_error: 11.9977
# Epoch 87/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1706 - mean_absolute_error: 12.1706
# Epoch 88/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0660 - mean_absolute_error: 12.0660
# Epoch 89/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0543 - mean_absolute_error: 12.0543
# Epoch 90/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0817 - mean_absolute_error: 12.0817
# Epoch 91/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0112 - mean_absolute_error: 12.0112
# Epoch 92/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.0569 - mean_absolute_error: 12.0569
# Epoch 93/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1151 - mean_absolute_error: 12.1151
# Epoch 94/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1258 - mean_absolute_error: 12.1258
# Epoch 95/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0904 - mean_absolute_error: 12.0904
# Epoch 96/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0127 - mean_absolute_error: 12.0127
# Epoch 97/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.0385 - mean_absolute_error: 12.0385
# Epoch 98/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1087 - mean_absolute_error: 12.1087
# Epoch 99/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.0507 - mean_absolute_error: 12.0507
# Epoch 100/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0382 - mean_absolute_error: 12.0382
# Epoch 1/100
# 4257/4257 [==============================] - 1s 332us/step - loss: 107.7639 - mean_absolute_error: 107.7639
# Epoch 2/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 49.1198 - mean_absolute_error: 49.1198
# Epoch 3/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 32.2218 - mean_absolute_error: 32.2218
# Epoch 4/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 23.6314 - mean_absolute_error: 23.6314
# Epoch 5/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 19.3270 - mean_absolute_error: 19.3270
# Epoch 6/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 16.6243 - mean_absolute_error: 16.6243
# Epoch 7/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 15.0299 - mean_absolute_error: 15.0299
# Epoch 8/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 14.0563 - mean_absolute_error: 14.0563
# Epoch 9/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 13.5150 - mean_absolute_error: 13.5150
# Epoch 10/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 13.1454 - mean_absolute_error: 13.1454
# Epoch 11/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.9433 - mean_absolute_error: 12.9433
# Epoch 12/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.8317 - mean_absolute_error: 12.8317
# Epoch 13/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.7385 - mean_absolute_error: 12.7385
# Epoch 14/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.7373 - mean_absolute_error: 12.7373
# Epoch 15/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.6371 - mean_absolute_error: 12.6371
# Epoch 16/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.6146 - mean_absolute_error: 12.6146
# Epoch 17/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.6204 - mean_absolute_error: 12.6204
# Epoch 18/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.5164 - mean_absolute_error: 12.5164
# Epoch 19/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.5605 - mean_absolute_error: 12.5605
# Epoch 20/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.4493 - mean_absolute_error: 12.4493
# Epoch 21/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.5227 - mean_absolute_error: 12.5227
# Epoch 22/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.4926 - mean_absolute_error: 12.4926
# Epoch 23/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.4644 - mean_absolute_error: 12.4644
# Epoch 24/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3890 - mean_absolute_error: 12.3890
# Epoch 25/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.4795 - mean_absolute_error: 12.4795
# Epoch 26/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.5047 - mean_absolute_error: 12.5047
# Epoch 27/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3913 - mean_absolute_error: 12.3913
# Epoch 28/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.4001 - mean_absolute_error: 12.4001
# Epoch 29/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.3638 - mean_absolute_error: 12.3638
# Epoch 30/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.4051 - mean_absolute_error: 12.4051
# Epoch 31/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.3556 - mean_absolute_error: 12.3556
# Epoch 32/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.2872 - mean_absolute_error: 12.2872
# Epoch 33/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3367 - mean_absolute_error: 12.3367
# Epoch 34/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3023 - mean_absolute_error: 12.3023
# Epoch 35/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.2793 - mean_absolute_error: 12.2793
# Epoch 36/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3157 - mean_absolute_error: 12.3157
# Epoch 37/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2897 - mean_absolute_error: 12.2897
# Epoch 38/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3039 - mean_absolute_error: 12.3039
# Epoch 39/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.3158 - mean_absolute_error: 12.3158
# Epoch 40/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2501 - mean_absolute_error: 12.2501
# Epoch 41/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2436 - mean_absolute_error: 12.2436
# Epoch 42/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2865 - mean_absolute_error: 12.2865
# Epoch 43/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2322 - mean_absolute_error: 12.2322
# Epoch 44/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.2552 - mean_absolute_error: 12.2552
# Epoch 45/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2239 - mean_absolute_error: 12.2239
# Epoch 46/100
# 4257/4257 [==============================] - 0s 29us/step - loss: 12.3096 - mean_absolute_error: 12.3096
# Epoch 47/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2348 - mean_absolute_error: 12.2348
# Epoch 48/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2618 - mean_absolute_error: 12.2618
# Epoch 49/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2496 - mean_absolute_error: 12.2496
# Epoch 50/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1842 - mean_absolute_error: 12.1842
# Epoch 51/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.2146 - mean_absolute_error: 12.2146
# Epoch 52/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.2698 - mean_absolute_error: 12.2698
# Epoch 53/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2158 - mean_absolute_error: 12.2158
# Epoch 54/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2461 - mean_absolute_error: 12.2461
# Epoch 55/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1611 - mean_absolute_error: 12.1611
# Epoch 56/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2016 - mean_absolute_error: 12.2016
# Epoch 57/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1736 - mean_absolute_error: 12.1736
# Epoch 58/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2658 - mean_absolute_error: 12.2658
# Epoch 59/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2152 - mean_absolute_error: 12.2152
# Epoch 60/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2087 - mean_absolute_error: 12.2087
# Epoch 61/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2290 - mean_absolute_error: 12.2290
# Epoch 62/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2254 - mean_absolute_error: 12.2254
# Epoch 63/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1600 - mean_absolute_error: 12.1600
# Epoch 64/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1781 - mean_absolute_error: 12.1781
# Epoch 65/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2330 - mean_absolute_error: 12.2330
# Epoch 66/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1243 - mean_absolute_error: 12.1243
# Epoch 67/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1442 - mean_absolute_error: 12.1442
# Epoch 68/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.1265 - mean_absolute_error: 12.1265
# Epoch 69/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2045 - mean_absolute_error: 12.2045
# Epoch 70/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2023 - mean_absolute_error: 12.2023
# Epoch 71/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2171 - mean_absolute_error: 12.2171
# Epoch 72/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0930 - mean_absolute_error: 12.0930
# Epoch 73/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1204 - mean_absolute_error: 12.1204
# Epoch 74/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1267 - mean_absolute_error: 12.1267
# Epoch 75/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.1819 - mean_absolute_error: 12.1819
# Epoch 76/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0930 - mean_absolute_error: 12.0930
# Epoch 77/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1413 - mean_absolute_error: 12.1413
# Epoch 78/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0652 - mean_absolute_error: 12.0652
# Epoch 79/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1183 - mean_absolute_error: 12.1183
# Epoch 80/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.0892 - mean_absolute_error: 12.0892
# Epoch 81/100
# 4257/4257 [==============================] - 0s 32us/step - loss: 12.1332 - mean_absolute_error: 12.1332
# Epoch 82/100
# 4257/4257 [==============================] - 0s 33us/step - loss: 12.1635 - mean_absolute_error: 12.1635
# Epoch 83/100
# 4257/4257 [==============================] - 0s 34us/step - loss: 12.1305 - mean_absolute_error: 12.1305
# Epoch 84/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.2674 - mean_absolute_error: 12.2674
# Epoch 85/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0924 - mean_absolute_error: 12.0924
# Epoch 86/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0592 - mean_absolute_error: 12.0592
# Epoch 87/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.1155 - mean_absolute_error: 12.1155
# Epoch 88/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1181 - mean_absolute_error: 12.1181
# Epoch 89/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1401 - mean_absolute_error: 12.1401
# Epoch 90/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0819 - mean_absolute_error: 12.0819
# Epoch 91/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1017 - mean_absolute_error: 12.1017
# Epoch 92/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0731 - mean_absolute_error: 12.0731
# Epoch 93/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0135 - mean_absolute_error: 12.0135
# Epoch 94/100
# 4257/4257 [==============================] - 0s 31us/step - loss: 12.0912 - mean_absolute_error: 12.0912
# Epoch 95/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0076 - mean_absolute_error: 12.0076
# Epoch 96/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0487 - mean_absolute_error: 12.0487
# Epoch 97/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0474 - mean_absolute_error: 12.0474
# Epoch 98/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0366 - mean_absolute_error: 12.0366
# Epoch 99/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.1017 - mean_absolute_error: 12.1017
# Epoch 100/100
# 4257/4257 [==============================] - 0s 30us/step - loss: 12.0447 - mean_absolute_error: 12.0447

# %%
#CHECKING FOR NORMALITY:

# %%
# compare samples
stat, p = normaltest(L_nn)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The samples from the  Neural Network Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The samples from the  Neural Network Regressor follow a non Gaussian distribution (reject H0)')
# Out:
# Statistics=6.494, p=0.039
# The samples from the  Neural Network Regressor follow a non Gaussian distribution (reject H0)

# %% [markdown]
# THE NEXT STEP IS TO CHECK FOR THE SIGNIFICANCE OF THE RESULTS WITHIN EACH OTHER:

# %% [markdown]
# ARE THE DISTRIBUTIONS OF SUPPORT VECTOR REGRESSOR AND RANDOM FOREST REGRESSOR SIGNIFICANTLY DIFFERENT?

# %%
#SINCE BOTH THE DISTRIBUTIONS OF SUPPORT VECTOR AND RANDOM FOREST REGRESSOR FOLLOW A GAUSSIAN DISTRIBUTION ,A STUDENTS T-TEST SHOULD BE CONDUCTED

# %%
# compare samples
stat, p = ttest_rel(L_randomforest, L_svr)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('the mean distribution of the  Support Vector and Random Forest Regressor results without Hyper parameter tuning are the same (fail to reject H0)')
else:
	print('The mean distributions of the  Support Vector Regressor and Random Forest Regressor without Hyper parameter tuning are significantly different (reject H0)')
# Out:
# Statistics=0.193, p=0.848
# the mean distribution of the  Support Vector and Random Forest Regressor results without Hyper parameter tuning are the same (fail to reject H0)

# %%
#CHECKING FOR THE SIGNIFICANCE IN RESULTS BETWEEN THE NEURAL NETWORK RESULTS AND THE RANDOM FOREST RESULTS

# %%
## compare samples
stat, p = wilcoxon(L_randomforest, L_nn) #since the Neural Network results dont follow a Gaussian Distribution
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('the mean distribution of the  Neural Network and Random Forest Regressor results without Hyper parameter tuning are the same (fail to reject H0)')
else:
	print('The mean distribtuion of the  Neural Networks and Random Forest Regressor without Hyper parameter tuning are significantly different (reject H0)')
# Out:
# Statistics=0.000, p=0.000
# The mean distribtuion of the  Neural Networks and Random Forest Regressor without Hyper parameter tuning are significantly different (reject H0)

# %%
#CHECKING FOR THE SIGNIFICANCE IN RESULTS BETWEEN THE NEURAL NETWORK AND SUPPORT VECTOR REGRESSORS:

# %%
## compare samples
stat, p = wilcoxon(L_svr, L_nn)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('the mean distribtuion of the  Neural Network and Support Vector Regressor without Hyper parameter tuning are the same (fail to reject H0)')
else:
	print('The mean distribution of the  Neural Networks and Support Vector Regressor without Hyper parameter tuning are significantly different (reject H0)')
# Out:
# Statistics=0.000, p=0.000
# The mean distribution of the  Neural Networks and Support Vector Regressor without Hyper parameter tuning are significantly different (reject H0)

# %% [markdown]
# # STEP 4: HYPER PARAMETER TUNING ON DIFFERENT ALGORITHMS:

# %% [markdown]
# # HYPER PARAMETER TUNING ON SUPPORT VECTOR MACHINES:

# %%
#GRID SEARCH CV

# %%
#ASSIGNING THE HYPER PARAMETER RANGES

# %%
parameters_svr = { 'C':[0.1,0.3,0.6,0.9,1,1.5,2,3,6,9,15],'epsilon':[0.1,0.3,0.6,0.9,1,1.5,2,3,6,9,15],
                  'tol':[0.00001,0.0001,0.1,0.3,0.6,0.9],'max_iter':[1000,2000,3000,4000,5000] } #DEFINING THE HYPER PARAMETER SPACE:
grid_search_svr = GridSearchCV(estimator=svr_linear, param_grid=parameters_svr, cv=10, n_jobs=-1,verbose=2,scoring='neg_mean_absolute_error')
print("parameters:")
grid_search_svr.fit(X_train_new, Y_train) #FITTING THE DEFINED GRID SEARCH ALGORITHM ON TO THE TRAINING SET:
# Out:
# parameters:
# Fitting 10 folds for each of 3630 candidates, totalling 36300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 258 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 1070 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 2202 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 3662 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 5442 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 7550 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 9978 tasks      | elapsed:   34.5s
# [Parallel(n_jobs=-1)]: Done 12734 tasks      | elapsed:   44.0s
# [Parallel(n_jobs=-1)]: Done 15810 tasks      | elapsed:   54.8s
# [Parallel(n_jobs=-1)]: Done 19214 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 22938 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 26990 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 31362 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 36062 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 36300 out of 36300 | elapsed:  3.1min finished
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=LinearSVR(C=1.0, dual=True, epsilon=0.1, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#      random_state=3, tol=0.001, verbose=0),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'C': [0.1, 0.3, 0.6, 0.9, 1, 1.5, 2, 3, 6, 9, 15], 'epsilon': [0.1, 0.3, 0.6, 0.9, 1, 1.5, 2, 3, 6, 9, 15], 'tol': [1e-05, 0.0001, 0.1, 0.3, 0.6, 0.9], 'max_iter': [1000, 2000, 3000, 4000, 5000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=2)

# %%
print("Best MAE score from the Grid Search tuning on training data: %0.3f" % grid_search_svr.best_score_)
print("Best hyepr parameters on Support Vector Regressor using Grid Search:")
grid_search_svr.best_params_
# Out:
# Best MAE score from the Grid Search tuning on training data: -12.769
# Best hyepr parameters on Support Vector Regressor using Grid Search:
# {'C': 1.5, 'epsilon': 6, 'max_iter': 1000, 'tol': 1e-05}

# %% [markdown]
# USING THE NEW TUNED HYPER PARAMETERS ON THE TEST DATA FOR SUPPORT VECTOR REGRESSOR:

# %%
svr_linear_gs= LinearSVR(C= 1.5, epsilon= 6, tol= 0.00001, random_state=3)
svr_linear_gs.fit(X_train_new,Y_train)
svr_linear_gs_pred = svr_linear_gs.predict(X_test_new)
print('The Grid Search Hyper parameter tuned Support Vector Algorithm on the Test Data is giving an MAE of:%0.3f ' %mean_absolute_error(Y_test, svr_linear_gs_pred))
# Out:
# The Grid Search Hyper parameter tuned Support Vector Algorithm on the Test Data is giving an MAE of:12.739

# %%
#RUNNING THE GRID SEARCH TUNED SUPPORT VECTOR REGRESSOR OVER 30 ITERATIONS:

# %%
L_svr_gs=[]

# %%
for i in range(0,30):
    model_svr_gs = LinearSVR(C=1.5,epsilon=6,tol=0.00001,random_state=i)
    model_svr_gs.fit(X_train_new, Y_train) 
    model_svr_test_pred_gs = model_svr_gs.predict(X_test_new)
    M= mean_absolute_error(Y_test, model_svr_test_pred_gs)
    L_svr_gs.append(mean_absolute_error(Y_test, model_svr_test_pred_gs))

# %%
#CHECKING THE NORMALITY OF THE GRID SEARCH TUNED RESULTS FOR OVER 30 ITERATIONS:

# %%
# compare samples
stat, p = normaltest(L_svr_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The sample distribution from the  Grid Search tuned Support Vector Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The sample distribtuion from the  Grid Search tuned Support Vector Regressor  does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=3.778, p=0.151
# The sample distribution from the  Grid Search tuned Support Vector Regressor follow a Gaussian distribution (fail to reject H0)

# %% [raw]
# the next step is to check wether the mean results from the Grid search tuned and non-Hyper parameter tuned Support Vector regressor are significantly different

# %%
# compare samples
stat, p = ttest_rel(L_svr_gs, L_svr)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print(' Results from Support Vector Rgeressor without Hyper parameter tuning and with Grid Search tuning are the same(fail to reject H0)')
else:
	print('Results from Support Vector Regressor with and without  Grid Search tuning  are significantly different (reject H0)')
# Out:
# Statistics=-9.230, p=0.000
# Results from Support Vector Regressor with and without  Grid Search tuning  are significantly different (reject H0)

# %%
#DOING RANDOM SEARCH ON THE SUPPORT VECTOR REGRESSOR

# %%
t6=time.time() #Computing the time 
parameters_svr = { 'C':[0.1,0.3,0.6,0.9,1,1.5,2,3,6,9,15],'epsilon':[0.1,0.3,0.6,0.9,1,1.5,2,3,6,9,15],
                  'tol':[0.00001,0.0001,0.1,0.3,0.6,0.9],'max_iter':[1000,2000,3000,4000,5000] } #Specifying the parameter ranges
random_search_svr = RandomizedSearchCV(estimator=svr_linear, param_distributions=parameters_svr, cv=10, n_jobs=-1,verbose=2,scoring='neg_mean_absolute_error',random_state=3)
random_search_svr.fit(X_train_new, Y_train) #fitting the random search algorithm onto the Training data
t7= time.time() - t6 #Computing the time required
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    3.6s finished
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
print('total time required for computation is: %0.3f' %t7)
print("Best MAE score from the Hyper Parameter tuning on training data: %0.3f" % random_search_svr.best_score_)
print("Best hyepr parameters on Support Vector Regressor using Random Search:")
random_search_svr.best_params_
# Out:
# total time required for computation is: 3.758
# Best MAE score from the Hyper Parameter tuning on training data: -12.781
# Best hyepr parameters on Support Vector Regressor using Random Search:
# {'tol': 1e-05, 'max_iter': 1000, 'epsilon': 0.3, 'C': 9}

# %%
svr_linear_rs= LinearSVR(C= 9, epsilon= 0.3, tol= 0.00001, max_iter=1000,random_state=3)
svr_linear_rs.fit(X_train_new,Y_train)
svr_linear_rs_pred = svr_linear_rs.predict(X_test_new)
print('The Random Search Hyper parameter tuned Support Vector Regessor on the Test Data is giving an MAE of:%0.3f ' %mean_absolute_error(Y_test, svr_linear_rs_pred))
# Out:
# The Random Search Hyper parameter tuned Support Vector Regessor on the Test Data is giving an MAE of:12.724
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
#TRYING TO FIND THE DISTRIBUTION OF RESULTS OVER 30 ITERATIONS FOR RANDOM SEARCH TUNED SUPPORT VECTOR REGRESSOR

# %%
L_svr_rs=[]

# %%
for i in range(0,30):
    model_svr_rs = LinearSVR(C=9,epsilon=0.3,tol=0.00001,random_state=i,max_iter=1000)
    model_svr_rs.fit(X_train_new, Y_train) 
    model_svr_test_pred_rs = model_svr_rs.predict(X_test_new)
    Q=abs(model_svr_test_pred_rs-Y_test)
    M= mean_absolute_error(Y_test, model_svr_test_pred_rs)
    L_svr_rs.append(mean_absolute_error(Y_test, model_svr_test_pred_rs))
# Out:
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
# compare samples
stat, p = normaltest(L_svr_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Random Search tuned Support Vector Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Random Search tuned Support Vector Regressor  does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=0.444, p=0.801
# The Samples from the  Random Search tuned Support Vector Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#Trying to find whether the results from random search tuned Support Vector regressor and non-Hyper parameter tuned support vector regressor are significantly different

# %%
# compare samples
stat, p = ttest_rel(L_svr_rs, L_svr)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print(' The mean results from Support Vector Rgeressor without Hyper parameter tuning and with Random Search tuning are not Significantly different(fail to reject H0)')
else:
	print('The mean results from Support Vector Regressor  without Hyper parameter tuning and with Random Search Hyper paarameter tuning are significantly different (reject H0)')
# Out:
# Statistics=-12.894, p=0.000
# The mean results from Support Vector Regressor  without Hyper parameter tuning and with Random Search Hyper paarameter tuning are significantly different (reject H0)

# %%
#BAYESIAN SEARCH:

# %%
t8= time.time() #TO FIND THE COMPUTATIONAL TIME
searchcv = BayesSearchCV(
    svr_linear,
    search_spaces={'C': (0.01, 15),'epsilon': (0.1,15),'tol':(0.00001,0.9),'max_iter':(1000,5000)},
    n_iter=10,
    cv=10,scoring='neg_mean_absolute_error',random_state=3
) #DEFINING THE PARAMETER RANGES
searchcv.fit(X_train_new,Y_train) #FITTING THE BAYESIAN SEARCH LIBRARY ON TO THE TRAINING DATA
t9= time.time()- t8

# %%
print('total time required for computation is: %0.3f' %t9)
print("Best MAE score from the Bayesian Search tuning on training data is: %0.3f" % searchcv.best_score_)
print("Best hyepr parameters on Support Vector Regressor using Bayesian Search:")
searchcv.best_params_
# Out:
# total time required for computation is: 2.245
# Best MAE score from the Bayesian Search tuning on training data is: -12.806
# Best hyepr parameters on Support Vector Regressor using Bayesian Search:
# {'C': 12.828756840375657,
#  'epsilon': 3.553033776203018,
#  'max_iter': 4214,
#  'tol': 0.007518239179992571}

# %%
svr_linear_bs= LinearSVR(C= 12.828, epsilon= 3.553, tol= 0.007518239179992571,max_iter=4214,random_state=3) #APPLYING THE TUNED HYPER PARAMETERS ONTO THE ALGORITHM
svr_linear_bs.fit(X_train_new,Y_train)
svr_linear_bs_pred = svr_linear_bs.predict(X_test_new)
print('The Bayesian Search Hyper parameter tuned Support Vector Algorithm on the Test Data is giving an MAE of:%0.3f ' %mean_absolute_error(Y_test, svr_linear_bs_pred))
# Out:
# The Bayesian Search Hyper parameter tuned Support Vector Algorithm on the Test Data is giving an MAE of:12.754

# %%
#RUNNING THE BAYESIAN SEARCH TUNED ALGORITHM OVER 30 ITERATIONS:

# %%
L_svr_bs=[]

# %%
for i in range(0,30):
    model_svr_bs = LinearSVR(C= 12.828, epsilon= 3.553, tol= 0.007518239179992571,max_iter=4214,random_state=i)
    model_svr_bs.fit(X_train_new, Y_train) 
    model_svr_test_pred_bs = model_svr_bs.predict(X_test_new)
    M= mean_absolute_error(Y_test, model_svr_test_pred_bs)
    L_svr_bs.append(mean_absolute_error(Y_test, model_svr_test_pred_bs))

# %%
# compare samples
stat, p = normaltest(L_svr_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Bayesian Search tuned Support Vector Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Bayesian Search tuned Support Vector Regressor does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=3.060, p=0.217
# The Samples from the  Bayesian Search tuned Support Vector Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#FINDING THE SIGNIFICANT TESTS FOR THE 3 HYPER PARAMETER TUNED ALGORITHMS WITH BASE ALGORITHM:

# %%
#1 - NON HYPER PARAMETER TUNED SUPPORT VECTOR WITH GRID SEARCH TUNED SUPPORT VECTOR

# %%
# compare samples
stat, p = ttest_rel(L_svr_gs, L_svr)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('the means of the Support Vector without Hyper parameter tuning and Grid Search tuned Support Vector Regressor are not significantly different (fail to reject H0)')
else:
	print('The means of the Support Vector without Hyper parameter tuning and Grid Search tuned Support Vector Regressor are significantly different (reject H0)')
# Out:
# Statistics=-9.230, p=0.000
# The means of the Support Vector without Hyper parameter tuning and Grid Search tuned Support Vector Regressor are significantly different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_svr_rs, L_svr)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('the means of the Support Vector without Hyper parameter tuning and Random Search tuned Support Vector Regressor are not significantly different (fail to reject H0)')
else:
	print('The means of the Support Vector without Hyper parameter tuning and Random Search tuned Support Vector Regressor are significantly different (reject H0)')
# Out:
# Statistics=-12.894, p=0.000
# The means of the Support Vector without Hyper parameter tuning and Random Search tuned Support Vector Regressor are significantly different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_svr_bs, L_svr)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('the means of the Support Vector without Hyper parameter tuning and Byesian Search tuned Support Vector Regressor are not significantly different (fail to reject H0)')
else:
	print('The means of the Support Vector without Hyper parameter tuning and Bayesian Search tuned Support Vector Regressor are significantly different (reject H0)')
# Out:
# Statistics=1.969, p=0.059
# the means of the Support Vector without Hyper parameter tuning and Byesian Search tuned Support Vector Regressor are not significantly different (fail to reject H0)

# %%
#FINDING THE SIGNIFICANCE IN RESULTS BETWEEN RANDOM SEARCH AND GRID SEARCH TUNED SUPPORT VECTOR REGRESSOR RUN OVER 30 ITERATIONS

# %%
# compare samples
stat, p = ttest_rel(L_svr_gs, L_svr_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means of the Random Search tuned and Grid Search tuned Support Vector Regressor are not significantly different (fail to reject H0)')
else:
	print('The means of the Random Search tuned and Grid Search tuned Support Vector Regressor are significantly different (fail to reject H0)')
# Out:
# Statistics=14.714, p=0.000
# The means of the Random Search tuned and Grid Search tuned Support Vector Regressor are significantly different (fail to reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_svr_bs, L_svr_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means of the Random Search tuned and Bayesian Search tuned Support Vector Regressor are not significantly different (fail to reject H0)')
else:
	print('The means of the Random Search tuned and Bayesian Search tuned Support Vector Regressor are significantly different (fail to reject H0)')
# Out:
# Statistics=7.710, p=0.000
# The means of the Random Search tuned and Bayesian Search tuned Support Vector Regressor are significantly different (fail to reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_svr_bs, L_svr_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means of the Bayesian Search tuned and Grid SSearch tuned Support Vector Regressor are not significantly different (fail to reject H0)')
else:
	print('The means of the Bayesian Search tuned and Grid SSearch tuned Support Vector Regressor are significantly different (fail to reject H0)')
# Out:
# Statistics=5.541, p=0.000
# The means of the Bayesian Search tuned and Grid SSearch tuned Support Vector Regressor are significantly different (fail to reject H0)

# %% [markdown]
# # RANDOM FOREST ALGORITHMS:

# %%
#STEP 2: DOING GRID SEARCH CV:

# %%
#RANDOM FOREST:

# %%
parameters = {'max_depth': [2,5,10,20,50,100,200], 'min_samples_split':[5,10,20,30,50],'min_samples_leaf':[5,10,20,30,50],
              'n_estimators':[5,50,100,200,400,600,1000]} # DEFINING THE HYPER PARAMETER SPACE:
grid_search_rf = GridSearchCV(estimator=random_forest, param_grid=parameters, cv=10, n_jobs=-1,verbose=2,scoring='neg_mean_absolute_error')
grid_search_rf.fit(X_train_new, Y_train) #FITTING THE GRID SEARCH ALGORITHM ONTO RANDOM FOREST ALGORITHM:
# Out:
# Fitting 10 folds for each of 1225 candidates, totalling 12250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=-1)]: Done 341 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 624 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 989 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 1434 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done 1961 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 2568 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=-1)]: Done 3257 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=-1)]: Done 4026 tasks      | elapsed: 35.2min
# [Parallel(n_jobs=-1)]: Done 4877 tasks      | elapsed: 47.6min
# [Parallel(n_jobs=-1)]: Done 5808 tasks      | elapsed: 62.4min
# [Parallel(n_jobs=-1)]: Done 6821 tasks      | elapsed: 76.6min
# [Parallel(n_jobs=-1)]: Done 7914 tasks      | elapsed: 94.7min
# [Parallel(n_jobs=-1)]: Done 9089 tasks      | elapsed: 112.2min
# [Parallel(n_jobs=-1)]: Done 10344 tasks      | elapsed: 130.7min
# [Parallel(n_jobs=-1)]: Done 11681 tasks      | elapsed: 152.3min
# [Parallel(n_jobs=-1)]: Done 12250 out of 12250 | elapsed: 159.5min finished
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=10, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=3, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'max_depth': [2, 5, 10, 20, 50, 100, 200], 'min_samples_split': [5, 10, 20, 30, 50], 'min_samples_leaf': [5, 10, 20, 30, 50], 'n_estimators': [5, 50, 100, 200, 400, 600, 1000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=2)

# %%
print("Best MAE score from the Random Search tuning on training data: %0.3f" % grid_search_rf.best_score_)
print("Best hyepr parameters on Random Forest Regressor using Grid Search is:")
grid_search_rf.best_params_
# Out:
# Best MAE score from the Random Search tuning on training data: -12.565
# Best hyepr parameters on Random Forest Regressor using Grid Search is:
# {'max_depth': 10,
#  'min_samples_leaf': 20,
#  'min_samples_split': 50,
#  'n_estimators': 200}

# %%
random_forest_gs= RandomForestRegressor(max_depth=10,min_samples_leaf=20,min_samples_split=50,n_estimators=200,random_state=3)
random_forest_gs.fit(X_train_new, Y_train)
random_forest_gs_test_pred = random_forest_gs.predict(X_test_new)
print("\nThe MAE for Grid search tuned Random Forest Regressor on the Testing data is: {:.4f} \n".format(mean_absolute_error(Y_test, random_forest_gs_test_pred)))
# Out:
# The MAE for Grid search tuned Random Forest Regressor on the Testing data is: 12.6165

# %%
#RUNNING THE GRID SEARCH TUNED RANDOM FOREST OVER 30 ITERATIONS:

# %%
L_randomforest_gs=[]

# %%
for i in range(0,30):
    model_rf_gs = RandomForestRegressor(max_depth=10,min_samples_split=50,min_samples_leaf=20,n_estimators=200,random_state=i)
    model_rf_gs.fit(X_train_new, Y_train)
    model_rf_test_pred_gs = model_rf_gs.predict(X_test_new)
    Q=abs(model_rf_test_pred_gs-Y_test)
    M= mean_absolute_error(Y_test, model_rf_test_pred_gs)
    L_randomforest_gs.append(mean_absolute_error(Y_test, model_rf_test_pred_gs))

# %%
#CHECKING THE NORMALITY OF THE GRID SEARCH TUNED RANDOM FORESTS RESULTS FOR OVER 30 ITERATIONS:

# %%
# compare samples
stat, p = normaltest(L_randomforest_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Grid Search tuned Random Forest Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Grid Search tuned Random Forest Regressor  does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=2.159, p=0.340
# The Samples from the  Grid Search tuned Random Forest Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#DOING RANDOM SEARCH CV ON THE RANDOM FOREST ALGORITHM:

# %%
time9= time.time() #COMPUTATIONAL TIME START
parameters = {'max_depth': [2,5,10,20,50,100,200], 'min_samples_split':[5,10,20,30,50],'min_samples_leaf':[5,10,20,30,50],
              'n_estimators':[5,50,100,200,400,600,1000]} #DEFINING THE PARAMETER SPACE
random_search_rf = RandomizedSearchCV(estimator=random_forest, param_distributions=parameters, n_iter=10, n_jobs=-1,verbose=2,scoring='neg_mean_absolute_error',random_state=3)
random_search_rf.fit(X_train_new, Y_train)
time10=time.time()-time9 #COMPUTATIONAL TIME END
# Out:
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:   10.8s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   17.7s finished

# %%
print("Best MAE score from the Radom Search tuning on training data: %0.3f" % random_search_rf.best_score_)
print("Best Hyper parameters on Random Forest Regressor using Random Search tuning is:")
random_search_rf.best_params_
# Out:
# Best MAE score from the Radom Search tuning on training data: -12.644
# Best Hyper parameters on Random Forest Regressor using Random Search tuning is:
# {'n_estimators': 400,
#  'min_samples_split': 10,
#  'min_samples_leaf': 20,
#  'max_depth': 5}

# %%
random_forest_rf= RandomForestRegressor(max_depth=5,min_samples_leaf=20,min_samples_split=10,n_estimators=400,random_state=3)
random_forest_rf.fit(X_train_new, Y_train)
random_forest_rf_test_pred = random_forest_rf.predict(X_test_new)
print("\nThe MAE for Random Search tuned Random Forest Regressor on the Testing data is: {:.4f} \n".format(mean_absolute_error(Y_test, random_forest_rf_test_pred)))
# Out:
# The MAE for Random Search tuned Random Forest Regressor on the Testing data is: 12.6707

# %%
#ITERATING THE ALGORITHMS OVER 30 RUNS:

# %%
L_randomforest_rs=[]

# %%
for i in range(0,30):
    model_rf_rs = RandomForestRegressor(max_depth=5,min_samples_split=10,min_samples_leaf=20,n_estimators=400,random_state=i)
    model_rf_rs.fit(X_train_new, Y_train)
    model_rf_test_pred_rs = model_rf_rs.predict(X_test_new)
    Q=abs(model_rf_test_pred_rs-Y_test)
    M= mean_absolute_error(Y_test, model_rf_test_pred_rs)
    L_randomforest_rs.append(mean_absolute_error(Y_test, model_rf_test_pred_rs))

# %%
#Checking the normality of the distribution:

# %%
# compare samples
stat, p = normaltest(L_randomforest_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Random Search tuned Random Forest Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Random Search tuned Random Forest Regressor  does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=0.497, p=0.780
# The Samples from the  Random Search tuned Random Forest Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#DOING BAYESIAN SEARCH :

# %%
t10= time.time() #TIME REQUIRED FOR COMPUTATION:
searchcv = BayesSearchCV(
    random_forest,
    search_spaces={'max_depth': (2,200),'min_samples_split': (5,50),'min_samples_leaf':(5,50),'n_estimators':(5,1000)},
    n_iter=10,
    cv=10,scoring='neg_mean_absolute_error',random_state=3,n_jobs=-1
) #INPUTING THE PARAMETER SPACE
searchcv.fit(X_train_new,Y_train)
t11= time.time()- t10 #TIME REQUIRED FOR COMPUTATION:

# %%
print('The total computational time required in seconds is: %0.3f' %t11)
print("Best MAE score from the Hyper Parameter tuning on training data: %0.3f" % searchcv.best_score_)
print("Best hyepr parameters on Support Vector Regressor using Grid Search:")
searchcv.best_params_
# Out:
# The total computational time required in seconds is: 150.640
# Best MAE score from the Hyper Parameter tuning on training data: -12.568
# Best hyepr parameters on Support Vector Regressor using Grid Search:
# {'max_depth': 184,
#  'min_samples_leaf': 41,
#  'min_samples_split': 8,
#  'n_estimators': 871}

# %%
random_forest_bs= RandomForestRegressor(max_depth=184,min_samples_leaf=41,min_samples_split=8,n_estimators=871,random_state=3)
random_forest_bs.fit(X_train_new, Y_train)
random_forest_bs_test_pred = random_forest_bs.predict(X_test_new)
print("\nThe MAE for Bayesian Search tuned Random Forest Regressor on the Testing data is: {:.4f} \n".format(mean_absolute_error(Y_test, random_forest_bs_test_pred)))
# Out:
# The MAE for Bayesian Search tuned Random Forest Regressor on the Testing data is: 12.6105

# %%
#RUNNING THE BAYESIAN TUNED RANDOM FOREST REGRESSOR OVER 30 TIMES:

# %%
L_randomforest_bs=[]

# %%
for i in range(0,30):
    model_rf_bs = RandomForestRegressor(max_depth=184,min_samples_split=8,min_samples_leaf=41,n_estimators=871,random_state=i)
    model_rf_bs.fit(X_train_new, Y_train)
    model_rf_test_pred_bs = model_rf_bs.predict(X_test_new)
    Q=abs(model_rf_test_pred_bs-Y_test)
    M= mean_absolute_error(Y_test, model_rf_test_pred_bs)
    L_randomforest_bs.append(mean_absolute_error(Y_test, model_rf_test_pred_bs))

# %%
#checking the normality of the distribution:

# %%
# compare samples
stat, p = normaltest(L_randomforest_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Bayesian Search tuned Random Forest Regressor follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Bayesian Search tuned Random Forest Regressor  does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=2.530, p=0.282
# The Samples from the  Bayesian Search tuned Random Forest Regressor follow a Gaussian distribution (fail to reject H0)

# %%
#COMPARING THE NON-HYPER PARAMETER TUNED RANDOM FORESTS AND THE HYPER PARAMETER TUNED RANDOM FORESTS:

# %%
# compare samples
stat, p = ttest_rel(L_randomforest, L_randomforest_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The Non-Hyper parameter tuned and Grid Search hyper parameter tuned Random Forests results both have the same distributions (fail to reject H0)')
else:
	print('The Non-Hyper parameter tuned and Grid Search hyper parameter tuned  Random Forests results both have Different distributions (reject H0)')
# Out:
# Statistics=14.888, p=0.000
# The Non-Hyper parameter tuned and Grid Search hyper parameter tuned  Random Forests results both have Different distributions (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_randomforest, L_randomforest_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The Non-Hyper parameter tuned and Random Search hyper parameter tuned Random Forests results both have the same distributions (fail to reject H0)')
else:
	print('The Non-Hyper parameter tuned and  Random Search tuned  Random Forests results both have Different distributions (reject H0)')
# Out:
# Statistics=10.032, p=0.000
# The Non-Hyper parameter tuned and  Random Search tuned  Random Forests results both have Different distributions (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_randomforest, L_randomforest_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The Non-Hyper parameter tuned and Bayesian Search hyper parameter tuned Random Forests results results both have the same distributions (fail to reject H0)')
else:
	print('The Non-Hyper parameter tuned and Bayesian Search hyper parameter tuned Random Forests results both have Different distributions (reject H0)')
# Out:
# Statistics=16.184, p=0.000
# The Non-Hyper parameter tuned and Bayesian Search hyper parameter tuned Random Forests results both have Different distributions (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_randomforest_rs, L_randomforest_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are Same  (fail to reject H0)')
else:
	print('The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are different (reject H0)')
# Out:
# Statistics=19.770, p=0.000
# The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_randomforest_bs, L_randomforest_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The mean distributions of the Bayesian Search and Grid Search tuned Random Forest Regressor are Same  (fail to reject H0)')
else:
	print('The mean distributions of the Bayesian Search and Grid Search tuned Random Forest Regressor are different (reject H0)')
# Out:
# Statistics=-1.801, p=0.082
# The mean distributions of the Bayesian Search and Grid Search tuned Random Forest Regressor are Same  (fail to reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_randomforest_rs, L_randomforest_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are Same  (fail to reject H0)')
else:
	print('The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are different (reject H0)')
# Out:
# Statistics=19.770, p=0.000
# The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_randomforest_rs, L_randomforest_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are Same  (fail to reject H0)')
else:
	print('The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are different (reject H0)')
# Out:
# Statistics=43.273, p=0.000
# The mean distributions of the Random Search and Grid Search tuned Random Forest Regressor are different (reject H0)

# %% [markdown]
# # ALGORITHM 3: NEURAL NETWORKS:

# %%
#NEURAL NETWORKS:

# %%
#GRID SEARCH:

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
def create_model(neurons=256,activation='relu'):
	# create model

    NN_model = Sequential()
    # The Input Layer :
    NN_model.add(Dense(neurons, input_dim=24,kernel_initializer='uniform', activation=activation))
    # The Hidden Layers :
    NN_model.add(Dense(neurons, kernel_initializer='uniform',activation=activation))
    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='uniform'))
    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    #NN_model.summary()
    return NN_model
 
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# create model
model = KerasRegressor(build_fn=create_model, verbose=0)
activation=['relu','tanh','linear']
neurons=[5,10,15,20,50,100,200,300,400]
epochs = [50, 100, 150,200,300]
batches = [5, 10, 20,50,100]
param_grid = dict(neurons=neurons,activation=activation,batch_size=batches,epochs=epochs)
grid_nn = GridSearchCV(estimator=model, param_grid=param_grid,scoring='neg_mean_absolute_error',verbose=2,cv=2)
grid_result = grid_nn.fit(X_train_new, Y_train)
# Out:
# Fitting 2 folds for each of 675 candidates, totalling 1350 fits
# [CV] activation=relu, batch_size=5, epochs=50, neurons=5 .............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=5, total=  45.2s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=5 .............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   45.7s remaining:    0.0s
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=5, total=  43.8s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=10 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=10, total=  44.8s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=10 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=10, total=  45.3s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=15 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=15, total=  44.6s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=15 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=15, total=  46.1s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=20 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=20, total=  45.7s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=20 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=20, total=  45.5s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=50 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=50, total=  46.4s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=50 ............
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=50, total=  46.0s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=100 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=100, total=  48.1s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=100 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=100, total=  48.3s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=200 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=200, total=  57.0s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=200 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=200, total=  56.5s
# [CV] activation=relu, batch_size=5, epochs=50, neurons=300 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=300, total= 1.1min
# [CV] activation=relu, batch_size=5, epochs=50, neurons=300 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=300, total= 1.1min
# [CV] activation=relu, batch_size=5, epochs=50, neurons=400 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=400, total= 1.4min
# [CV] activation=relu, batch_size=5, epochs=50, neurons=400 ...........
# [CV]  activation=relu, batch_size=5, epochs=50, neurons=400, total= 1.4min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=5, total= 1.6min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=5, total= 1.5min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=10, total= 1.5min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=10, total= 1.6min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=15, total= 1.6min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=15, total= 1.6min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=20, total= 1.7min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=20, total= 1.7min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=50, total= 1.6min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=50, total= 1.7min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=100, total= 1.8min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=100, total= 1.8min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=200, total= 2.1min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=200, total= 2.5min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=300, total= 2.9min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=300, total= 3.1min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=400, total= 3.6min
# [CV] activation=relu, batch_size=5, epochs=100, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=100, neurons=400, total= 2.9min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=5, total= 2.4min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=5, total= 2.4min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=10, total= 2.5min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=10, total= 2.5min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=15, total= 2.6min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=15, total= 2.7min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=20, total= 2.5min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=20, total= 2.6min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=50, total= 2.7min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=50, total= 2.8min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=100, total= 2.8min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=100, total= 2.9min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=200, total= 3.7min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=200, total= 3.4min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=300, total= 4.4min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=300, total= 5.4min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=400, total= 6.2min
# [CV] activation=relu, batch_size=5, epochs=150, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=150, neurons=400, total= 5.8min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=5, total= 5.0min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=5, total= 4.6min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=10, total= 5.0min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=10, total= 4.3min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=15, total= 4.7min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=15, total= 5.3min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=20, total= 5.5min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=20, total= 5.9min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=50, total= 5.4min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=50, total= 5.3min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=100, total= 5.4min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=100, total= 5.2min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=200, total= 5.7min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=200, total= 6.9min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=300, total= 6.5min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=300, total= 5.8min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=400, total= 7.0min
# [CV] activation=relu, batch_size=5, epochs=200, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=200, neurons=400, total= 7.3min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=5, total= 6.2min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=5 ............
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=5, total= 6.0min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=10, total= 5.9min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=10 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=10, total= 6.7min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=15, total= 6.5min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=15 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=15, total= 6.3min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=20, total= 6.0min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=20 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=20, total= 6.5min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=50, total= 6.1min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=50 ...........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=50, total= 6.9min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=100, total= 7.8min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=100 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=100, total= 7.1min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=200, total= 7.5min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=200 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=200, total= 7.5min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=300, total= 8.7min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=300 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=300, total= 8.8min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=400, total=10.6min
# [CV] activation=relu, batch_size=5, epochs=300, neurons=400 ..........
# [CV]  activation=relu, batch_size=5, epochs=300, neurons=400, total=10.7min
# [CV] activation=relu, batch_size=10, epochs=50, neurons=5 ............
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=5, total=  41.4s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=5 ............
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=5, total=  41.4s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=10 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=10, total=  41.8s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=10 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=10, total=  41.7s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=15 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=15, total=  42.3s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=15 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=15, total=  42.4s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=20 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=20, total=  42.7s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=20 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=20, total=  43.3s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=50 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=50, total=  43.5s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=50 ...........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=50, total=  43.5s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=100 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=100, total=  44.7s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=100 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=100, total=  45.0s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=200 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=200, total=  51.0s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=200 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=200, total=  50.9s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=300 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=300, total=  58.3s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=300 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=300, total=  58.0s
# [CV] activation=relu, batch_size=10, epochs=50, neurons=400 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=400, total= 1.1min
# [CV] activation=relu, batch_size=10, epochs=50, neurons=400 ..........
# [CV]  activation=relu, batch_size=10, epochs=50, neurons=400, total= 1.2min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=5, total= 1.3min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=5, total= 1.4min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=10, total= 1.4min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=10, total= 1.4min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=15, total= 1.4min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=15, total= 1.5min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=20, total= 1.5min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=20, total= 1.5min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=50, total= 1.5min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=50, total= 1.5min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=100, total= 1.6min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=100, total= 1.6min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=200, total= 1.8min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=200, total= 1.8min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=300, total= 2.0min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=300, total= 2.0min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=400, total= 2.4min
# [CV] activation=relu, batch_size=10, epochs=100, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=100, neurons=400, total= 2.4min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=5, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=5, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=10, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=10, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=15, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=15, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=20, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=20, total= 2.3min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=50, total= 2.4min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=50, total= 2.4min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=100, total= 2.5min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=100, total= 2.5min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=200, total= 2.8min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=200, total= 2.8min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=300, total= 3.2min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=300, total= 3.2min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=400, total= 3.8min
# [CV] activation=relu, batch_size=10, epochs=150, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=150, neurons=400, total= 3.8min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=5, total= 3.2min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=5, total= 3.3min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=10, total= 3.3min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=10, total= 3.2min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=15, total= 3.3min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=15, total= 3.3min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=20, total= 3.4min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=20, total= 3.4min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=50, total= 3.4min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=50, total= 3.4min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=100, total= 3.5min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=100, total= 3.5min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=200, total= 4.0min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=200, total= 4.0min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=300, total= 4.6min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=300, total= 4.6min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=400, total= 5.3min
# [CV] activation=relu, batch_size=10, epochs=200, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=200, neurons=400, total= 5.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=5, total= 5.2min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=5 ...........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=5, total= 5.2min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=10, total= 5.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=10 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=10, total= 5.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=15, total= 5.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=15 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=15, total= 5.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=20, total= 5.5min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=20 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=20, total= 5.4min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=50, total= 5.5min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=50 ..........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=50, total= 5.5min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=100, total= 5.6min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=100 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=100, total= 5.7min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=200, total= 6.4min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=200 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=200, total= 6.4min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=300, total= 7.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=300 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=300, total= 7.3min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=400, total= 8.5min
# [CV] activation=relu, batch_size=10, epochs=300, neurons=400 .........
# [CV]  activation=relu, batch_size=10, epochs=300, neurons=400, total= 8.6min
# [CV] activation=relu, batch_size=20, epochs=50, neurons=5 ............
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=5, total=  40.8s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=5 ............
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=5, total=  41.1s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=10 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=10, total=  40.7s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=10 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=10, total=  40.9s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=15 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=15, total=  41.5s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=15 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=15, total=  41.3s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=20 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=20, total=  42.0s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=20 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=20, total=  42.0s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=50 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=50, total=  42.7s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=50 ...........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=50, total=  42.4s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=100 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=100, total=  44.6s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=100 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=100, total=  44.7s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=200 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=200, total=  47.9s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=200 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=200, total=  48.5s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=300 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=300, total= 1.0min
# [CV] activation=relu, batch_size=20, epochs=50, neurons=300 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=300, total=  53.2s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=400 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=400, total=  58.9s
# [CV] activation=relu, batch_size=20, epochs=50, neurons=400 ..........
# [CV]  activation=relu, batch_size=20, epochs=50, neurons=400, total=  58.9s
# [CV] activation=relu, batch_size=20, epochs=100, neurons=5 ...........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=5, total= 1.2min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=5 ...........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=5, total= 1.2min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=10 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=10, total= 1.2min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=10 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=10, total= 1.2min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=15 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=15, total= 1.3min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=15 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=15, total= 1.2min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=20 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=20, total= 1.3min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=20 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=20, total= 1.3min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=50 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=50, total= 1.3min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=50 ..........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=50, total= 1.3min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=100 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=100, total= 1.4min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=100 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=100, total= 1.4min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=200 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=200, total= 1.5min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=200 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=200, total= 1.5min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=300 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=300, total= 1.6min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=300 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=300, total= 1.6min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=400 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=400, total= 1.8min
# [CV] activation=relu, batch_size=20, epochs=100, neurons=400 .........
# [CV]  activation=relu, batch_size=20, epochs=100, neurons=400, total= 1.8min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=5 ...........
# [CV]  activation=relu, batch_size=20, epochs=150, neurons=5, total= 1.9min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=5 ...........
# [CV]  activation=relu, batch_size=20, epochs=150, neurons=5, total= 1.9min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=10 ..........
# [CV]  activation=relu, batch_size=20, epochs=150, neurons=10, total= 1.9min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=10 ..........
# [CV]  activation=relu, batch_size=20, epochs=150, neurons=10, total= 1.9min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=15 ..........
# [CV]  activation=relu, batch_size=20, epochs=150, neurons=15, total= 1.9min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=15 ..........
# [CV]  activation=relu, batch_size=20, epochs=150, neurons=15, total= 2.2min
# [CV] activation=relu, batch_size=20, epochs=150, neurons=20 ..........

# %%
print("Best MAE score from the Hyper Parameter tuning on training data: %0.3f" % grid_nn.best_score_)
print("Best hyepr parameters on Neural Network Regressor using Grid Search:")
grid_nn.best_params_

# %%
def create_model():
	# create model

    NN_model = Sequential()
    # The Input Layer :
    NN_model.add(Dense(400, input_dim=24,kernel_initializer='uniform', activation='tanh'))
    # The Hidden Layers :
    NN_model.add(Dense(400, kernel_initializer='uniform',activation='tanh'))
    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='uniform'))
    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    #NN_model.summary()
    return NN_model
 
# create model
model_nn_gs = KerasRegressor(build_fn=create_model, verbose=2,batch_size=100,epochs=200)
model_nn_gs.fit(X_train_new,Y_train)
nn_gs_test_pred= model_nn_gs.predict(X_test_new)
print('The MAE for the Neural Networks with Grid Search tuning on the Testing Data is : {:.4f} \n'.format(mean_absolute_error(Y_test,nn_gs_test_pred)))
# Out:
# Epoch 1/200
#  - 0s - loss: 123.8563 - mean_absolute_error: 123.8563
# Epoch 2/200
#  - 0s - loss: 90.2126 - mean_absolute_error: 90.2126
# Epoch 3/200
#  - 0s - loss: 61.5138 - mean_absolute_error: 61.5138
# Epoch 4/200
#  - 0s - loss: 39.5752 - mean_absolute_error: 39.5752
# Epoch 5/200
#  - 0s - loss: 21.5971 - mean_absolute_error: 21.5971
# Epoch 6/200
#  - 0s - loss: 14.9709 - mean_absolute_error: 14.9709
# Epoch 7/200
#  - 0s - loss: 14.2577 - mean_absolute_error: 14.2577
# Epoch 8/200
#  - 0s - loss: 14.1332 - mean_absolute_error: 14.1332
# Epoch 9/200
#  - 0s - loss: 13.8665 - mean_absolute_error: 13.8665
# Epoch 10/200
#  - 0s - loss: 13.8568 - mean_absolute_error: 13.8568
# Epoch 11/200
#  - 0s - loss: 13.5444 - mean_absolute_error: 13.5444
# Epoch 12/200
#  - 0s - loss: 13.4608 - mean_absolute_error: 13.4608
# Epoch 13/200
#  - 0s - loss: 13.5977 - mean_absolute_error: 13.5977
# Epoch 14/200
#  - 0s - loss: 13.2199 - mean_absolute_error: 13.2199
# Epoch 15/200
#  - 0s - loss: 13.2116 - mean_absolute_error: 13.2116
# Epoch 16/200
#  - 0s - loss: 13.0722 - mean_absolute_error: 13.0722
# Epoch 17/200
#  - 0s - loss: 12.8792 - mean_absolute_error: 12.8792
# Epoch 18/200
#  - 0s - loss: 12.8002 - mean_absolute_error: 12.8002
# Epoch 19/200
#  - 0s - loss: 12.7373 - mean_absolute_error: 12.7373
# Epoch 20/200
#  - 0s - loss: 12.7073 - mean_absolute_error: 12.7073
# Epoch 21/200
#  - 0s - loss: 12.6056 - mean_absolute_error: 12.6056
# Epoch 22/200
#  - 0s - loss: 12.5574 - mean_absolute_error: 12.5574
# Epoch 23/200
#  - 0s - loss: 12.5211 - mean_absolute_error: 12.5211
# Epoch 24/200
#  - 0s - loss: 12.4685 - mean_absolute_error: 12.4685
# Epoch 25/200
#  - 0s - loss: 12.4256 - mean_absolute_error: 12.4256
# Epoch 26/200
#  - 0s - loss: 12.4197 - mean_absolute_error: 12.4197
# Epoch 27/200
#  - 0s - loss: 12.3994 - mean_absolute_error: 12.3994
# Epoch 28/200
#  - 0s - loss: 12.3642 - mean_absolute_error: 12.3642
# Epoch 29/200
#  - 0s - loss: 12.3562 - mean_absolute_error: 12.3562
# Epoch 30/200
#  - 0s - loss: 12.3062 - mean_absolute_error: 12.3062
# Epoch 31/200
#  - 0s - loss: 12.3073 - mean_absolute_error: 12.3073
# Epoch 32/200
#  - 0s - loss: 12.3051 - mean_absolute_error: 12.3051
# Epoch 33/200
#  - 0s - loss: 12.2823 - mean_absolute_error: 12.2823
# Epoch 34/200
#  - 0s - loss: 12.2558 - mean_absolute_error: 12.2558
# Epoch 35/200
#  - 0s - loss: 12.2455 - mean_absolute_error: 12.2455
# Epoch 36/200
#  - 0s - loss: 12.2234 - mean_absolute_error: 12.2234
# Epoch 37/200
#  - 0s - loss: 12.2282 - mean_absolute_error: 12.2282
# Epoch 38/200
#  - 0s - loss: 12.2234 - mean_absolute_error: 12.2234
# Epoch 39/200
#  - 0s - loss: 12.2253 - mean_absolute_error: 12.2253
# Epoch 40/200
#  - 0s - loss: 12.1762 - mean_absolute_error: 12.1762
# Epoch 41/200
#  - 0s - loss: 12.1641 - mean_absolute_error: 12.1641
# Epoch 42/200
#  - 0s - loss: 12.1582 - mean_absolute_error: 12.1582
# Epoch 43/200
#  - 0s - loss: 12.1800 - mean_absolute_error: 12.1800
# Epoch 44/200
#  - 0s - loss: 12.1515 - mean_absolute_error: 12.1515
# Epoch 45/200
#  - 0s - loss: 12.1008 - mean_absolute_error: 12.1008
# Epoch 46/200
#  - 0s - loss: 12.1060 - mean_absolute_error: 12.1060
# Epoch 47/200
#  - 0s - loss: 12.1158 - mean_absolute_error: 12.1158
# Epoch 48/200
#  - 0s - loss: 12.0948 - mean_absolute_error: 12.0948
# Epoch 49/200
#  - 0s - loss: 12.0710 - mean_absolute_error: 12.0710
# Epoch 50/200
#  - 0s - loss: 12.0915 - mean_absolute_error: 12.0915
# Epoch 51/200
#  - 0s - loss: 12.0587 - mean_absolute_error: 12.0587
# Epoch 52/200
#  - 0s - loss: 12.0665 - mean_absolute_error: 12.0665
# Epoch 53/200
#  - 0s - loss: 12.0303 - mean_absolute_error: 12.0303
# Epoch 54/200
#  - 0s - loss: 12.0247 - mean_absolute_error: 12.0247
# Epoch 55/200
#  - 0s - loss: 11.9829 - mean_absolute_error: 11.9829
# Epoch 56/200
#  - 0s - loss: 12.0286 - mean_absolute_error: 12.0286
# Epoch 57/200
#  - 0s - loss: 11.9757 - mean_absolute_error: 11.9757
# Epoch 58/200
#  - 0s - loss: 11.9712 - mean_absolute_error: 11.9712
# Epoch 59/200
#  - 0s - loss: 11.9446 - mean_absolute_error: 11.9446
# Epoch 60/200
#  - 0s - loss: 11.9341 - mean_absolute_error: 11.9341
# Epoch 61/200
#  - 0s - loss: 11.9190 - mean_absolute_error: 11.9190
# Epoch 62/200
#  - 0s - loss: 11.9237 - mean_absolute_error: 11.9237
# Epoch 63/200
#  - 0s - loss: 11.9282 - mean_absolute_error: 11.9282
# Epoch 64/200
#  - 0s - loss: 11.9023 - mean_absolute_error: 11.9023
# Epoch 65/200
#  - 0s - loss: 11.8790 - mean_absolute_error: 11.8790
# Epoch 66/200
#  - 0s - loss: 11.8693 - mean_absolute_error: 11.8693
# Epoch 67/200
#  - 0s - loss: 11.8775 - mean_absolute_error: 11.8775
# Epoch 68/200
#  - 0s - loss: 11.8774 - mean_absolute_error: 11.8774
# Epoch 69/200
#  - 0s - loss: 11.8411 - mean_absolute_error: 11.8411
# Epoch 70/200
#  - 0s - loss: 11.8078 - mean_absolute_error: 11.8078
# Epoch 71/200
#  - 0s - loss: 11.7837 - mean_absolute_error: 11.7837
# Epoch 72/200
#  - 0s - loss: 11.8087 - mean_absolute_error: 11.8087
# Epoch 73/200
#  - 0s - loss: 11.8013 - mean_absolute_error: 11.8013
# Epoch 74/200
#  - 0s - loss: 11.7969 - mean_absolute_error: 11.7969
# Epoch 75/200
#  - 0s - loss: 11.7536 - mean_absolute_error: 11.7536
# Epoch 76/200
#  - 0s - loss: 11.7295 - mean_absolute_error: 11.7295
# Epoch 77/200
#  - 0s - loss: 11.7511 - mean_absolute_error: 11.7511
# Epoch 78/200
#  - 0s - loss: 11.7005 - mean_absolute_error: 11.7005
# Epoch 79/200
#  - 0s - loss: 11.6867 - mean_absolute_error: 11.6867
# Epoch 80/200
#  - 0s - loss: 11.6771 - mean_absolute_error: 11.6771
# Epoch 81/200
#  - 0s - loss: 11.6691 - mean_absolute_error: 11.6691
# Epoch 82/200
#  - 0s - loss: 11.6481 - mean_absolute_error: 11.6481
# Epoch 83/200
#  - 0s - loss: 11.6493 - mean_absolute_error: 11.6493
# Epoch 84/200
#  - 0s - loss: 11.6122 - mean_absolute_error: 11.6122
# Epoch 85/200
#  - 0s - loss: 11.6052 - mean_absolute_error: 11.6052
# Epoch 86/200
#  - 0s - loss: 11.6004 - mean_absolute_error: 11.6004
# Epoch 87/200
#  - 0s - loss: 11.5750 - mean_absolute_error: 11.5750
# Epoch 88/200
#  - 0s - loss: 11.5823 - mean_absolute_error: 11.5823
# Epoch 89/200
#  - 0s - loss: 11.5391 - mean_absolute_error: 11.5391
# Epoch 90/200
#  - 0s - loss: 11.5412 - mean_absolute_error: 11.5412
# Epoch 91/200
#  - 0s - loss: 11.5389 - mean_absolute_error: 11.5389
# Epoch 92/200
#  - 0s - loss: 11.5347 - mean_absolute_error: 11.5347
# Epoch 93/200
#  - 0s - loss: 11.4950 - mean_absolute_error: 11.4950
# Epoch 94/200
#  - 0s - loss: 11.4750 - mean_absolute_error: 11.4750
# Epoch 95/200
#  - 0s - loss: 11.4504 - mean_absolute_error: 11.4504
# Epoch 96/200
#  - 0s - loss: 11.4441 - mean_absolute_error: 11.4441
# Epoch 97/200
#  - 0s - loss: 11.4186 - mean_absolute_error: 11.4186
# Epoch 98/200
#  - 0s - loss: 11.4179 - mean_absolute_error: 11.4179
# Epoch 99/200
#  - 0s - loss: 11.3945 - mean_absolute_error: 11.3945
# Epoch 100/200
#  - 0s - loss: 11.3844 - mean_absolute_error: 11.3844
# Epoch 101/200
#  - 0s - loss: 11.3453 - mean_absolute_error: 11.3453
# Epoch 102/200
#  - 0s - loss: 11.3574 - mean_absolute_error: 11.3574
# Epoch 103/200
#  - 0s - loss: 11.3370 - mean_absolute_error: 11.3370
# Epoch 104/200
#  - 0s - loss: 11.3211 - mean_absolute_error: 11.3211
# Epoch 105/200
#  - 0s - loss: 11.3137 - mean_absolute_error: 11.3137
# Epoch 106/200
#  - 0s - loss: 11.2807 - mean_absolute_error: 11.2807
# Epoch 107/200
#  - 0s - loss: 11.2643 - mean_absolute_error: 11.2643
# Epoch 108/200
#  - 0s - loss: 11.2525 - mean_absolute_error: 11.2525
# Epoch 109/200
#  - 0s - loss: 11.2411 - mean_absolute_error: 11.2411
# Epoch 110/200
#  - 0s - loss: 11.1701 - mean_absolute_error: 11.1701
# Epoch 111/200
#  - 0s - loss: 11.2074 - mean_absolute_error: 11.2074
# Epoch 112/200
#  - 0s - loss: 11.1673 - mean_absolute_error: 11.1673
# Epoch 113/200
#  - 0s - loss: 11.1523 - mean_absolute_error: 11.1523
# Epoch 114/200
#  - 0s - loss: 11.1521 - mean_absolute_error: 11.1521
# Epoch 115/200
#  - 0s - loss: 11.1608 - mean_absolute_error: 11.1608
# Epoch 116/200
#  - 0s - loss: 11.1107 - mean_absolute_error: 11.1107
# Epoch 117/200
#  - 0s - loss: 11.1155 - mean_absolute_error: 11.1155
# Epoch 118/200
#  - 0s - loss: 11.0729 - mean_absolute_error: 11.0729
# Epoch 119/200
#  - 0s - loss: 11.0525 - mean_absolute_error: 11.0525
# Epoch 120/200
#  - 0s - loss: 11.0215 - mean_absolute_error: 11.0215
# Epoch 121/200
#  - 0s - loss: 10.9899 - mean_absolute_error: 10.9899
# Epoch 122/200
#  - 0s - loss: 10.9982 - mean_absolute_error: 10.9982
# Epoch 123/200
#  - 0s - loss: 11.0069 - mean_absolute_error: 11.0069
# Epoch 124/200
#  - 0s - loss: 10.9895 - mean_absolute_error: 10.9895
# Epoch 125/200
#  - 0s - loss: 10.9429 - mean_absolute_error: 10.9429
# Epoch 126/200
#  - 0s - loss: 10.9169 - mean_absolute_error: 10.9169
# Epoch 127/200
#  - 0s - loss: 10.9140 - mean_absolute_error: 10.9140
# Epoch 128/200
#  - 0s - loss: 10.9177 - mean_absolute_error: 10.9177
# Epoch 129/200
#  - 0s - loss: 10.8446 - mean_absolute_error: 10.8446
# Epoch 130/200
#  - 0s - loss: 10.8201 - mean_absolute_error: 10.8201
# Epoch 131/200
#  - 0s - loss: 10.8388 - mean_absolute_error: 10.8388
# Epoch 132/200
#  - 0s - loss: 10.8281 - mean_absolute_error: 10.8281
# Epoch 133/200
#  - 0s - loss: 10.7944 - mean_absolute_error: 10.7944
# Epoch 134/200
#  - 0s - loss: 10.8075 - mean_absolute_error: 10.8075
# Epoch 135/200
#  - 0s - loss: 10.7397 - mean_absolute_error: 10.7397
# Epoch 136/200
#  - 0s - loss: 10.7232 - mean_absolute_error: 10.7232
# Epoch 137/200
#  - 0s - loss: 10.7309 - mean_absolute_error: 10.7309
# Epoch 138/200
#  - 0s - loss: 10.7351 - mean_absolute_error: 10.7351
# Epoch 139/200
#  - 0s - loss: 10.6545 - mean_absolute_error: 10.6545
# Epoch 140/200
#  - 0s - loss: 10.6593 - mean_absolute_error: 10.6593
# Epoch 141/200
#  - 0s - loss: 10.6298 - mean_absolute_error: 10.6298
# Epoch 142/200
#  - 0s - loss: 10.6056 - mean_absolute_error: 10.6056
# Epoch 143/200
#  - 0s - loss: 10.6014 - mean_absolute_error: 10.6014
# Epoch 144/200
#  - 0s - loss: 10.5919 - mean_absolute_error: 10.5919
# Epoch 145/200
#  - 0s - loss: 10.5511 - mean_absolute_error: 10.5511
# Epoch 146/200
#  - 0s - loss: 10.5803 - mean_absolute_error: 10.5803
# Epoch 147/200
#  - 0s - loss: 10.5565 - mean_absolute_error: 10.5565
# Epoch 148/200
#  - 0s - loss: 10.4962 - mean_absolute_error: 10.4962
# Epoch 149/200
#  - 0s - loss: 10.5086 - mean_absolute_error: 10.5086
# Epoch 150/200
#  - 0s - loss: 10.4413 - mean_absolute_error: 10.4413
# Epoch 151/200
#  - 0s - loss: 10.4566 - mean_absolute_error: 10.4566
# Epoch 152/200
#  - 0s - loss: 10.4405 - mean_absolute_error: 10.4405
# Epoch 153/200
#  - 0s - loss: 10.4061 - mean_absolute_error: 10.4061
# Epoch 154/200
#  - 0s - loss: 10.3770 - mean_absolute_error: 10.3770
# Epoch 155/200
#  - 0s - loss: 10.3691 - mean_absolute_error: 10.3691
# Epoch 156/200
#  - 0s - loss: 10.3305 - mean_absolute_error: 10.3305
# Epoch 157/200
#  - 0s - loss: 10.3635 - mean_absolute_error: 10.3635
# Epoch 158/200
#  - 0s - loss: 10.3773 - mean_absolute_error: 10.3773
# Epoch 159/200
#  - 0s - loss: 10.3035 - mean_absolute_error: 10.3035
# Epoch 160/200
#  - 0s - loss: 10.2952 - mean_absolute_error: 10.2952
# Epoch 161/200
#  - 0s - loss: 10.2597 - mean_absolute_error: 10.2597
# Epoch 162/200
#  - 0s - loss: 10.2124 - mean_absolute_error: 10.2124
# Epoch 163/200
#  - 0s - loss: 10.1840 - mean_absolute_error: 10.1840
# Epoch 164/200
#  - 0s - loss: 10.1799 - mean_absolute_error: 10.1799
# Epoch 165/200
#  - 0s - loss: 10.2475 - mean_absolute_error: 10.2475
# Epoch 166/200
#  - 0s - loss: 10.1467 - mean_absolute_error: 10.1467
# Epoch 167/200
#  - 0s - loss: 10.1135 - mean_absolute_error: 10.1135
# Epoch 168/200
#  - 0s - loss: 10.0887 - mean_absolute_error: 10.0887
# Epoch 169/200
#  - 0s - loss: 10.0694 - mean_absolute_error: 10.0694
# Epoch 170/200
#  - 0s - loss: 10.0740 - mean_absolute_error: 10.0740
# Epoch 171/200
#  - 0s - loss: 10.1159 - mean_absolute_error: 10.1159
# Epoch 172/200
#  - 0s - loss: 10.0346 - mean_absolute_error: 10.0346
# Epoch 173/200
#  - 0s - loss: 10.0386 - mean_absolute_error: 10.0386
# Epoch 174/200
#  - 0s - loss: 10.0463 - mean_absolute_error: 10.0463
# Epoch 175/200
#  - 0s - loss: 9.9899 - mean_absolute_error: 9.9899
# Epoch 176/200
#  - 0s - loss: 9.9583 - mean_absolute_error: 9.9583
# Epoch 177/200
#  - 0s - loss: 9.9135 - mean_absolute_error: 9.9135
# Epoch 178/200
#  - 0s - loss: 9.9323 - mean_absolute_error: 9.9323
# Epoch 179/200
#  - 0s - loss: 9.9022 - mean_absolute_error: 9.9022
# Epoch 180/200
#  - 0s - loss: 9.8590 - mean_absolute_error: 9.8590
# Epoch 181/200
#  - 0s - loss: 9.8440 - mean_absolute_error: 9.8440
# Epoch 182/200
#  - 0s - loss: 9.8001 - mean_absolute_error: 9.8001
# Epoch 183/200
#  - 0s - loss: 9.7867 - mean_absolute_error: 9.7867
# Epoch 184/200
#  - 0s - loss: 9.7731 - mean_absolute_error: 9.7731
# Epoch 185/200
#  - 0s - loss: 9.7879 - mean_absolute_error: 9.7879
# Epoch 186/200
#  - 0s - loss: 9.7384 - mean_absolute_error: 9.7384
# Epoch 187/200
#  - 0s - loss: 9.7537 - mean_absolute_error: 9.7537
# Epoch 188/200
#  - 0s - loss: 9.7062 - mean_absolute_error: 9.7062
# Epoch 189/200
#  - 0s - loss: 9.7093 - mean_absolute_error: 9.7093
# Epoch 190/200
#  - 0s - loss: 9.6446 - mean_absolute_error: 9.6446
# Epoch 191/200
#  - 0s - loss: 9.6924 - mean_absolute_error: 9.6924
# Epoch 192/200
#  - 0s - loss: 9.6073 - mean_absolute_error: 9.6073
# Epoch 193/200
#  - 0s - loss: 9.6037 - mean_absolute_error: 9.6037
# Epoch 194/200
#  - 0s - loss: 9.5713 - mean_absolute_error: 9.5713
# Epoch 195/200
#  - 0s - loss: 9.5923 - mean_absolute_error: 9.5923
# Epoch 196/200
#  - 0s - loss: 9.5095 - mean_absolute_error: 9.5095
# Epoch 197/200
#  - 0s - loss: 9.5191 - mean_absolute_error: 9.5191
# Epoch 198/200
#  - 0s - loss: 9.5012 - mean_absolute_error: 9.5012
# Epoch 199/200
#  - 0s - loss: 9.4762 - mean_absolute_error: 9.4762
# Epoch 200/200
#  - 0s - loss: 9.4225 - mean_absolute_error: 9.4225
# The MAE for the Neural Networks with Grid Search tuning on the Testing Data is : 12.9338

# %%
#30 ITERTIONS RESULTS:

# %%
L_nn_gs=[]

# %%
for i in range(0,30):
    model_nn_gs.fit(X_train_new, Y_train)
    model_nn_test_pred_gs = model_nn_gs.predict(X_test_new)
    Q=abs(model_nn_test_pred_gs-Y_test)
    M= mean_absolute_error(Y_test, model_nn_test_pred_gs)
    L_nn_gs.append(mean_absolute_error(Y_test, model_nn_test_pred_gs))
# Out:
# Epoch 1/200
#  - 0s - loss: 124.0611 - mean_absolute_error: 124.0611
# Epoch 2/200
#  - 0s - loss: 90.6581 - mean_absolute_error: 90.6581
# Epoch 3/200
#  - 0s - loss: 62.0444 - mean_absolute_error: 62.0444
# Epoch 4/200
#  - 0s - loss: 40.0864 - mean_absolute_error: 40.0864
# Epoch 5/200
#  - 0s - loss: 21.9206 - mean_absolute_error: 21.9206
# Epoch 6/200
#  - 0s - loss: 15.0150 - mean_absolute_error: 15.0150
# Epoch 7/200
#  - 0s - loss: 14.1630 - mean_absolute_error: 14.1630
# Epoch 8/200
#  - 0s - loss: 14.0167 - mean_absolute_error: 14.0167
# Epoch 9/200
#  - 0s - loss: 14.1030 - mean_absolute_error: 14.1030
# Epoch 10/200
#  - 0s - loss: 13.9315 - mean_absolute_error: 13.9315
# Epoch 11/200
#  - 0s - loss: 13.7479 - mean_absolute_error: 13.7479
# Epoch 12/200
#  - 0s - loss: 13.4502 - mean_absolute_error: 13.4502
# Epoch 13/200
#  - 0s - loss: 13.3824 - mean_absolute_error: 13.3824
# Epoch 14/200
#  - 0s - loss: 13.2570 - mean_absolute_error: 13.2570
# Epoch 15/200
#  - 0s - loss: 13.2521 - mean_absolute_error: 13.2521
# Epoch 16/200
#  - 0s - loss: 12.9989 - mean_absolute_error: 12.9989
# Epoch 17/200
#  - 0s - loss: 12.9102 - mean_absolute_error: 12.9102
# Epoch 18/200
#  - 0s - loss: 12.8088 - mean_absolute_error: 12.8088
# Epoch 19/200
#  - 0s - loss: 12.7124 - mean_absolute_error: 12.7124
# Epoch 20/200
#  - 0s - loss: 12.6644 - mean_absolute_error: 12.6644
# Epoch 21/200
#  - 0s - loss: 12.5641 - mean_absolute_error: 12.5641
# Epoch 22/200
#  - 0s - loss: 12.5907 - mean_absolute_error: 12.5907
# Epoch 23/200
#  - 0s - loss: 12.5353 - mean_absolute_error: 12.5353
# Epoch 24/200
#  - 0s - loss: 12.4744 - mean_absolute_error: 12.4744
# Epoch 25/200
#  - 0s - loss: 12.4279 - mean_absolute_error: 12.4279
# Epoch 26/200
#  - 0s - loss: 12.4005 - mean_absolute_error: 12.4005
# Epoch 27/200
#  - 0s - loss: 12.3840 - mean_absolute_error: 12.3840
# Epoch 28/200
#  - 0s - loss: 12.3746 - mean_absolute_error: 12.3746
# Epoch 29/200
#  - 0s - loss: 12.3403 - mean_absolute_error: 12.3403
# Epoch 30/200
#  - 0s - loss: 12.3389 - mean_absolute_error: 12.3389
# Epoch 31/200
#  - 0s - loss: 12.3231 - mean_absolute_error: 12.3231
# Epoch 32/200
#  - 0s - loss: 12.2881 - mean_absolute_error: 12.2881
# Epoch 33/200
#  - 0s - loss: 12.2800 - mean_absolute_error: 12.2800
# Epoch 34/200
#  - 0s - loss: 12.2665 - mean_absolute_error: 12.2665
# Epoch 35/200
#  - 0s - loss: 12.2508 - mean_absolute_error: 12.2508
# Epoch 36/200
#  - 0s - loss: 12.2479 - mean_absolute_error: 12.2479
# Epoch 37/200
#  - 0s - loss: 12.2452 - mean_absolute_error: 12.2452
# Epoch 38/200
#  - 0s - loss: 12.2255 - mean_absolute_error: 12.2255
# Epoch 39/200
#  - 0s - loss: 12.2312 - mean_absolute_error: 12.2312
# Epoch 40/200
#  - 0s - loss: 12.2334 - mean_absolute_error: 12.2334
# Epoch 41/200
#  - 0s - loss: 12.2216 - mean_absolute_error: 12.2216
# Epoch 42/200
#  - 0s - loss: 12.2445 - mean_absolute_error: 12.2445
# Epoch 43/200
#  - 0s - loss: 12.1780 - mean_absolute_error: 12.1780
# Epoch 44/200
#  - 0s - loss: 12.1775 - mean_absolute_error: 12.1775
# Epoch 45/200
#  - 0s - loss: 12.1599 - mean_absolute_error: 12.1599
# Epoch 46/200
#  - 0s - loss: 12.1391 - mean_absolute_error: 12.1391
# Epoch 47/200
#  - 0s - loss: 12.1323 - mean_absolute_error: 12.1323
# Epoch 48/200
#  - 0s - loss: 12.1353 - mean_absolute_error: 12.1353
# Epoch 49/200
#  - 0s - loss: 12.1115 - mean_absolute_error: 12.1115
# Epoch 50/200
#  - 0s - loss: 12.0942 - mean_absolute_error: 12.0942
# Epoch 51/200
#  - 0s - loss: 12.0764 - mean_absolute_error: 12.0764
# Epoch 52/200
#  - 0s - loss: 12.0656 - mean_absolute_error: 12.0656
# Epoch 53/200
#  - 0s - loss: 12.0660 - mean_absolute_error: 12.0660
# Epoch 54/200
#  - 0s - loss: 12.0550 - mean_absolute_error: 12.0550
# Epoch 55/200
#  - 0s - loss: 12.0454 - mean_absolute_error: 12.0454
# Epoch 56/200
#  - 0s - loss: 12.0289 - mean_absolute_error: 12.0289
# Epoch 57/200
#  - 0s - loss: 12.0210 - mean_absolute_error: 12.0210
# Epoch 58/200
#  - 0s - loss: 12.0044 - mean_absolute_error: 12.0044
# Epoch 59/200
#  - 0s - loss: 11.9816 - mean_absolute_error: 11.9816
# Epoch 60/200
#  - 0s - loss: 11.9582 - mean_absolute_error: 11.9582
# Epoch 61/200
#  - 0s - loss: 11.9717 - mean_absolute_error: 11.9717
# Epoch 62/200
#  - 0s - loss: 11.9977 - mean_absolute_error: 11.9977
# Epoch 63/200
#  - 0s - loss: 11.9902 - mean_absolute_error: 11.9902
# Epoch 64/200
#  - 0s - loss: 11.9159 - mean_absolute_error: 11.9159
# Epoch 65/200
#  - 0s - loss: 11.9140 - mean_absolute_error: 11.9140
# Epoch 66/200
#  - 0s - loss: 11.8928 - mean_absolute_error: 11.8928
# Epoch 67/200
#  - 0s - loss: 11.8793 - mean_absolute_error: 11.8793
# Epoch 68/200
#  - 0s - loss: 11.9169 - mean_absolute_error: 11.9169
# Epoch 69/200
#  - 0s - loss: 11.8733 - mean_absolute_error: 11.8733
# Epoch 70/200
#  - 0s - loss: 11.8825 - mean_absolute_error: 11.8825
# Epoch 71/200
#  - 0s - loss: 11.8203 - mean_absolute_error: 11.8203
# Epoch 72/200
#  - 0s - loss: 11.8256 - mean_absolute_error: 11.8256
# Epoch 73/200
#  - 0s - loss: 11.7911 - mean_absolute_error: 11.7911
# Epoch 74/200
#  - 0s - loss: 11.8043 - mean_absolute_error: 11.8043
# Epoch 75/200
#  - 0s - loss: 11.8038 - mean_absolute_error: 11.8038
# Epoch 76/200
#  - 0s - loss: 11.7740 - mean_absolute_error: 11.7740
# Epoch 77/200
#  - 0s - loss: 11.7703 - mean_absolute_error: 11.7703
# Epoch 78/200
#  - 0s - loss: 11.7711 - mean_absolute_error: 11.7711
# Epoch 79/200
#  - 0s - loss: 11.7490 - mean_absolute_error: 11.7490
# Epoch 80/200
#  - 0s - loss: 11.7398 - mean_absolute_error: 11.7398
# Epoch 81/200
#  - 0s - loss: 11.7355 - mean_absolute_error: 11.7355
# Epoch 82/200
#  - 0s - loss: 11.7123 - mean_absolute_error: 11.7123
# Epoch 83/200
#  - 0s - loss: 11.6918 - mean_absolute_error: 11.6918
# Epoch 84/200
#  - 0s - loss: 11.6682 - mean_absolute_error: 11.6682
# Epoch 85/200
#  - 0s - loss: 11.6553 - mean_absolute_error: 11.6553
# Epoch 86/200
#  - 0s - loss: 11.6215 - mean_absolute_error: 11.6215
# Epoch 87/200
#  - 0s - loss: 11.6307 - mean_absolute_error: 11.6307
# Epoch 88/200
#  - 0s - loss: 11.6093 - mean_absolute_error: 11.6093
# Epoch 89/200
#  - 0s - loss: 11.6088 - mean_absolute_error: 11.6088
# Epoch 90/200
#  - 0s - loss: 11.5984 - mean_absolute_error: 11.5984
# Epoch 91/200
#  - 0s - loss: 11.5624 - mean_absolute_error: 11.5624
# Epoch 92/200
#  - 0s - loss: 11.5493 - mean_absolute_error: 11.5493
# Epoch 93/200
#  - 0s - loss: 11.5454 - mean_absolute_error: 11.5454
# Epoch 94/200
#  - 0s - loss: 11.4968 - mean_absolute_error: 11.4968
# Epoch 95/200
#  - 0s - loss: 11.5297 - mean_absolute_error: 11.5297
# Epoch 96/200
#  - 0s - loss: 11.4864 - mean_absolute_error: 11.4864
# Epoch 97/200
#  - 0s - loss: 11.5120 - mean_absolute_error: 11.5120
# Epoch 98/200
#  - 0s - loss: 11.4507 - mean_absolute_error: 11.4507
# Epoch 99/200
#  - 0s - loss: 11.4247 - mean_absolute_error: 11.4247
# Epoch 100/200
#  - 0s - loss: 11.4361 - mean_absolute_error: 11.4361
# Epoch 101/200
#  - 0s - loss: 11.4053 - mean_absolute_error: 11.4053
# Epoch 102/200
#  - 0s - loss: 11.3920 - mean_absolute_error: 11.3920
# Epoch 103/200
#  - 0s - loss: 11.3546 - mean_absolute_error: 11.3546
# Epoch 104/200
#  - 0s - loss: 11.3469 - mean_absolute_error: 11.3469
# Epoch 105/200
#  - 0s - loss: 11.3380 - mean_absolute_error: 11.3380
# Epoch 106/200
#  - 0s - loss: 11.3200 - mean_absolute_error: 11.3200
# Epoch 107/200
#  - 0s - loss: 11.3217 - mean_absolute_error: 11.3217
# Epoch 108/200
#  - 0s - loss: 11.2999 - mean_absolute_error: 11.2999
# Epoch 109/200
#  - 0s - loss: 11.2659 - mean_absolute_error: 11.2659
# Epoch 110/200
#  - 0s - loss: 11.2386 - mean_absolute_error: 11.2386
# Epoch 111/200
#  - 0s - loss: 11.2620 - mean_absolute_error: 11.2620
# Epoch 112/200
#  - 0s - loss: 11.2358 - mean_absolute_error: 11.2358
# Epoch 113/200
#  - 0s - loss: 11.2301 - mean_absolute_error: 11.2301
# Epoch 114/200
#  - 0s - loss: 11.1956 - mean_absolute_error: 11.1956
# Epoch 115/200
#  - 0s - loss: 11.1540 - mean_absolute_error: 11.1540
# Epoch 116/200
#  - 0s - loss: 11.1420 - mean_absolute_error: 11.1420
# Epoch 117/200
#  - 0s - loss: 11.1525 - mean_absolute_error: 11.1525
# Epoch 118/200
#  - 0s - loss: 11.1537 - mean_absolute_error: 11.1537
# Epoch 119/200
#  - 0s - loss: 11.1247 - mean_absolute_error: 11.1247
# Epoch 120/200
#  - 0s - loss: 11.0988 - mean_absolute_error: 11.0988
# Epoch 121/200
#  - 0s - loss: 11.0982 - mean_absolute_error: 11.0982
# Epoch 122/200
#  - 0s - loss: 11.0704 - mean_absolute_error: 11.0704
# Epoch 123/200
#  - 0s - loss: 11.0421 - mean_absolute_error: 11.0421
# Epoch 124/200
#  - 0s - loss: 11.0256 - mean_absolute_error: 11.0256
# Epoch 125/200
#  - 0s - loss: 11.0073 - mean_absolute_error: 11.0073
# Epoch 126/200
#  - 0s - loss: 10.9823 - mean_absolute_error: 10.9823
# Epoch 127/200
#  - 0s - loss: 10.9697 - mean_absolute_error: 10.9697
# Epoch 128/200
#  - 0s - loss: 10.9827 - mean_absolute_error: 10.9827
# Epoch 129/200
#  - 0s - loss: 10.9479 - mean_absolute_error: 10.9479
# Epoch 130/200
#  - 0s - loss: 10.9250 - mean_absolute_error: 10.9250
# Epoch 131/200
#  - 0s - loss: 10.8939 - mean_absolute_error: 10.8939
# Epoch 132/200
#  - 0s - loss: 10.8792 - mean_absolute_error: 10.8792
# Epoch 133/200
#  - 0s - loss: 10.8682 - mean_absolute_error: 10.8682
# Epoch 134/200
#  - 0s - loss: 10.8361 - mean_absolute_error: 10.8361
# Epoch 135/200
#  - 0s - loss: 10.8169 - mean_absolute_error: 10.8169
# Epoch 136/200
#  - 0s - loss: 10.8040 - mean_absolute_error: 10.8040
# Epoch 137/200
#  - 0s - loss: 10.8092 - mean_absolute_error: 10.8092
# Epoch 138/200
#  - 0s - loss: 10.8262 - mean_absolute_error: 10.8262
# Epoch 139/200
#  - 0s - loss: 10.7448 - mean_absolute_error: 10.7448
# Epoch 140/200
#  - 0s - loss: 10.7619 - mean_absolute_error: 10.7619
# Epoch 141/200
#  - 0s - loss: 10.7444 - mean_absolute_error: 10.7444
# Epoch 142/200
#  - 0s - loss: 10.7355 - mean_absolute_error: 10.7355
# Epoch 143/200
#  - 0s - loss: 10.7083 - mean_absolute_error: 10.7083
# Epoch 144/200
#  - 0s - loss: 10.6835 - mean_absolute_error: 10.6835
# Epoch 145/200
#  - 0s - loss: 10.6681 - mean_absolute_error: 10.6681
# Epoch 146/200
#  - 0s - loss: 10.6479 - mean_absolute_error: 10.6479
# Epoch 147/200
#  - 0s - loss: 10.6216 - mean_absolute_error: 10.6216
# Epoch 148/200
#  - 0s - loss: 10.6087 - mean_absolute_error: 10.6087
# Epoch 149/200
#  - 0s - loss: 10.5700 - mean_absolute_error: 10.5700
# Epoch 150/200
#  - 0s - loss: 10.5845 - mean_absolute_error: 10.5845
# Epoch 151/200
#  - 0s - loss: 10.5365 - mean_absolute_error: 10.5365
# Epoch 152/200
#  - 0s - loss: 10.5529 - mean_absolute_error: 10.5529
# Epoch 153/200
#  - 0s - loss: 10.5036 - mean_absolute_error: 10.5036
# Epoch 154/200
#  - 0s - loss: 10.5056 - mean_absolute_error: 10.5056
# Epoch 155/200
#  - 0s - loss: 10.4797 - mean_absolute_error: 10.4797
# Epoch 156/200
#  - 0s - loss: 10.4674 - mean_absolute_error: 10.4674
# Epoch 157/200
#  - 0s - loss: 10.4109 - mean_absolute_error: 10.4109
# Epoch 158/200
#  - 0s - loss: 10.3951 - mean_absolute_error: 10.3951
# Epoch 159/200
#  - 0s - loss: 10.4057 - mean_absolute_error: 10.4057
# Epoch 160/200
#  - 0s - loss: 10.4174 - mean_absolute_error: 10.4174
# Epoch 161/200
#  - 0s - loss: 10.3825 - mean_absolute_error: 10.3825
# Epoch 162/200
#  - 0s - loss: 10.3485 - mean_absolute_error: 10.3485
# Epoch 163/200
#  - 0s - loss: 10.3041 - mean_absolute_error: 10.3041
# Epoch 164/200
#  - 0s - loss: 10.3188 - mean_absolute_error: 10.3188
# Epoch 165/200
#  - 0s - loss: 10.2546 - mean_absolute_error: 10.2546
# Epoch 166/200
#  - 0s - loss: 10.2646 - mean_absolute_error: 10.2646
# Epoch 167/200
#  - 0s - loss: 10.2505 - mean_absolute_error: 10.2505
# Epoch 168/200
#  - 0s - loss: 10.2255 - mean_absolute_error: 10.2255
# Epoch 169/200
#  - 0s - loss: 10.1991 - mean_absolute_error: 10.1991
# Epoch 170/200
#  - 0s - loss: 10.1779 - mean_absolute_error: 10.1779
# Epoch 171/200
#  - 0s - loss: 10.1523 - mean_absolute_error: 10.1523
# Epoch 172/200
#  - 0s - loss: 10.1379 - mean_absolute_error: 10.1379
# Epoch 173/200
#  - 0s - loss: 10.1479 - mean_absolute_error: 10.1479
# Epoch 174/200
#  - 0s - loss: 10.1121 - mean_absolute_error: 10.1121
# Epoch 175/200
#  - 0s - loss: 10.0677 - mean_absolute_error: 10.0677
# Epoch 176/200
#  - 0s - loss: 10.0436 - mean_absolute_error: 10.0436
# Epoch 177/200
#  - 0s - loss: 10.0156 - mean_absolute_error: 10.0156
# Epoch 178/200
#  - 0s - loss: 10.0048 - mean_absolute_error: 10.0048
# Epoch 179/200
#  - 0s - loss: 9.9837 - mean_absolute_error: 9.9837
# Epoch 180/200
#  - 0s - loss: 9.9633 - mean_absolute_error: 9.9633
# Epoch 181/200
#  - 0s - loss: 9.9468 - mean_absolute_error: 9.9468
# Epoch 182/200
#  - 0s - loss: 9.9348 - mean_absolute_error: 9.9348
# Epoch 183/200
#  - 0s - loss: 9.9247 - mean_absolute_error: 9.9247
# Epoch 184/200
#  - 0s - loss: 9.8664 - mean_absolute_error: 9.8664
# Epoch 185/200
#  - 0s - loss: 9.8487 - mean_absolute_error: 9.8487
# Epoch 186/200
#  - 0s - loss: 9.8251 - mean_absolute_error: 9.8251
# Epoch 187/200
#  - 0s - loss: 9.8373 - mean_absolute_error: 9.8373
# Epoch 188/200
#  - 0s - loss: 9.7795 - mean_absolute_error: 9.7795
# Epoch 189/200
#  - 0s - loss: 9.7977 - mean_absolute_error: 9.7977
# Epoch 190/200
#  - 0s - loss: 9.7532 - mean_absolute_error: 9.7532
# Epoch 191/200
#  - 0s - loss: 9.8053 - mean_absolute_error: 9.8053
# Epoch 192/200
#  - 0s - loss: 9.7475 - mean_absolute_error: 9.7475
# Epoch 193/200
#  - 0s - loss: 9.7202 - mean_absolute_error: 9.7202
# Epoch 194/200
#  - 0s - loss: 9.6823 - mean_absolute_error: 9.6823
# Epoch 195/200
#  - 0s - loss: 9.6321 - mean_absolute_error: 9.6321
# Epoch 196/200
#  - 0s - loss: 9.6389 - mean_absolute_error: 9.6389
# Epoch 197/200
#  - 0s - loss: 9.6024 - mean_absolute_error: 9.6024
# Epoch 198/200
#  - 0s - loss: 9.5984 - mean_absolute_error: 9.5984
# Epoch 199/200
#  - 0s - loss: 9.5838 - mean_absolute_error: 9.5838
# Epoch 200/200
#  - 0s - loss: 9.5466 - mean_absolute_error: 9.5466
# Epoch 1/200
#  - 0s - loss: 124.2683 - mean_absolute_error: 124.2683
# Epoch 2/200
#  - 0s - loss: 91.3628 - mean_absolute_error: 91.3628
# Epoch 3/200
#  - 0s - loss: 62.4948 - mean_absolute_error: 62.4948
# Epoch 4/200
#  - 0s - loss: 40.4619 - mean_absolute_error: 40.4619
# Epoch 5/200
#  - 0s - loss: 22.1347 - mean_absolute_error: 22.1347
# Epoch 6/200
#  - 0s - loss: 15.0396 - mean_absolute_error: 15.0396
# Epoch 7/200
#  - 0s - loss: 14.3300 - mean_absolute_error: 14.3300
# Epoch 8/200
#  - 0s - loss: 14.2652 - mean_absolute_error: 14.2652
# Epoch 9/200
#  - 0s - loss: 14.0165 - mean_absolute_error: 14.0165
# Epoch 10/200
#  - 0s - loss: 13.8101 - mean_absolute_error: 13.8101
# Epoch 11/200
#  - 0s - loss: 13.4434 - mean_absolute_error: 13.4434
# Epoch 12/200
#  - 0s - loss: 13.6743 - mean_absolute_error: 13.6743
# Epoch 13/200
#  - 0s - loss: 13.5265 - mean_absolute_error: 13.5265
# Epoch 14/200
#  - 0s - loss: 13.4135 - mean_absolute_error: 13.4135
# Epoch 15/200
#  - 0s - loss: 13.2595 - mean_absolute_error: 13.2595
# Epoch 16/200
#  - 0s - loss: 13.0540 - mean_absolute_error: 13.0540
# Epoch 17/200
#  - 0s - loss: 12.9184 - mean_absolute_error: 12.9184
# Epoch 18/200
#  - 0s - loss: 12.8988 - mean_absolute_error: 12.8988
# Epoch 19/200
#  - 0s - loss: 12.7811 - mean_absolute_error: 12.7811
# Epoch 20/200
#  - 0s - loss: 12.6716 - mean_absolute_error: 12.6716
# Epoch 21/200
#  - 0s - loss: 12.6130 - mean_absolute_error: 12.6130
# Epoch 22/200
#  - 0s - loss: 12.5809 - mean_absolute_error: 12.5809
# Epoch 23/200
#  - 0s - loss: 12.5305 - mean_absolute_error: 12.5305
# Epoch 24/200
#  - 0s - loss: 12.4799 - mean_absolute_error: 12.4799
# Epoch 25/200
#  - 0s - loss: 12.4649 - mean_absolute_error: 12.4649
# Epoch 26/200
#  - 0s - loss: 12.4550 - mean_absolute_error: 12.4550
# Epoch 27/200
#  - 0s - loss: 12.4053 - mean_absolute_error: 12.4053
# Epoch 28/200
#  - 0s - loss: 12.3910 - mean_absolute_error: 12.3910
# Epoch 29/200
#  - 0s - loss: 12.3830 - mean_absolute_error: 12.3830
# Epoch 30/200
#  - 0s - loss: 12.3726 - mean_absolute_error: 12.3726
# Epoch 31/200
#  - 0s - loss: 12.3423 - mean_absolute_error: 12.3423
# Epoch 32/200
#  - 0s - loss: 12.3048 - mean_absolute_error: 12.3048
# Epoch 33/200
#  - 0s - loss: 12.2908 - mean_absolute_error: 12.2908
# Epoch 34/200
#  - 0s - loss: 12.2783 - mean_absolute_error: 12.2783
# Epoch 35/200
#  - 0s - loss: 12.2750 - mean_absolute_error: 12.2750
# Epoch 36/200
#  - 0s - loss: 12.2497 - mean_absolute_error: 12.2497
# Epoch 37/200
#  - 0s - loss: 12.2597 - mean_absolute_error: 12.2597
# Epoch 38/200
#  - 0s - loss: 12.2326 - mean_absolute_error: 12.2326
# Epoch 39/200
#  - 0s - loss: 12.2325 - mean_absolute_error: 12.2325
# Epoch 40/200
#  - 0s - loss: 12.2260 - mean_absolute_error: 12.2260
# Epoch 41/200
#  - 0s - loss: 12.1944 - mean_absolute_error: 12.1944
# Epoch 42/200
#  - 0s - loss: 12.1941 - mean_absolute_error: 12.1941
# Epoch 43/200
#  - 0s - loss: 12.1738 - mean_absolute_error: 12.1738
# Epoch 44/200
#  - 0s - loss: 12.1781 - mean_absolute_error: 12.1781
# Epoch 45/200
#  - 0s - loss: 12.1861 - mean_absolute_error: 12.1861
# Epoch 46/200
#  - 0s - loss: 12.1845 - mean_absolute_error: 12.1845
# Epoch 47/200
#  - 0s - loss: 12.1220 - mean_absolute_error: 12.1220
# Epoch 48/200
#  - 0s - loss: 12.1109 - mean_absolute_error: 12.1109
# Epoch 49/200
#  - 0s - loss: 12.1097 - mean_absolute_error: 12.1097
# Epoch 50/200
#  - 0s - loss: 12.1122 - mean_absolute_error: 12.1122
# Epoch 51/200
#  - 0s - loss: 12.0592 - mean_absolute_error: 12.0592
# Epoch 52/200
#  - 0s - loss: 12.0773 - mean_absolute_error: 12.0773
# Epoch 53/200
#  - 0s - loss: 12.0802 - mean_absolute_error: 12.0802
# Epoch 54/200
#  - 0s - loss: 12.0646 - mean_absolute_error: 12.0646
# Epoch 55/200
#  - 0s - loss: 12.0347 - mean_absolute_error: 12.0347
# Epoch 56/200
#  - 0s - loss: 12.0253 - mean_absolute_error: 12.0253
# Epoch 57/200
#  - 0s - loss: 11.9922 - mean_absolute_error: 11.9922
# Epoch 58/200
#  - 0s - loss: 11.9800 - mean_absolute_error: 11.9800
# Epoch 59/200
#  - 0s - loss: 11.9541 - mean_absolute_error: 11.9541
# Epoch 60/200
#  - 0s - loss: 11.9853 - mean_absolute_error: 11.9853
# Epoch 61/200
#  - 0s - loss: 11.9503 - mean_absolute_error: 11.9503
# Epoch 62/200
#  - 0s - loss: 11.9384 - mean_absolute_error: 11.9384
# Epoch 63/200
#  - 0s - loss: 11.9210 - mean_absolute_error: 11.9210
# Epoch 64/200
#  - 0s - loss: 11.9314 - mean_absolute_error: 11.9314
# Epoch 65/200
#  - 0s - loss: 11.8900 - mean_absolute_error: 11.8900
# Epoch 66/200
#  - 0s - loss: 11.8792 - mean_absolute_error: 11.8792
# Epoch 67/200
#  - 0s - loss: 11.8775 - mean_absolute_error: 11.8775
# Epoch 68/200
#  - 0s - loss: 11.8441 - mean_absolute_error: 11.8441
# Epoch 69/200
#  - 0s - loss: 11.8663 - mean_absolute_error: 11.8663
# Epoch 70/200
#  - 0s - loss: 11.8781 - mean_absolute_error: 11.8781
# Epoch 71/200
#  - 0s - loss: 11.8044 - mean_absolute_error: 11.8044
# Epoch 72/200
#  - 0s - loss: 11.8402 - mean_absolute_error: 11.8402
# Epoch 73/200
#  - 0s - loss: 11.7947 - mean_absolute_error: 11.7947
# Epoch 74/200
#  - 0s - loss: 11.7621 - mean_absolute_error: 11.7621
# Epoch 75/200
#  - 0s - loss: 11.7790 - mean_absolute_error: 11.7790
# Epoch 76/200
#  - 0s - loss: 11.7366 - mean_absolute_error: 11.7366
# Epoch 77/200
#  - 0s - loss: 11.7392 - mean_absolute_error: 11.7392
# Epoch 78/200
#  - 0s - loss: 11.7229 - mean_absolute_error: 11.7229
# Epoch 79/200
#  - 0s - loss: 11.7338 - mean_absolute_error: 11.7338
# Epoch 80/200
#  - 0s - loss: 11.7199 - mean_absolute_error: 11.7199
# Epoch 81/200
#  - 0s - loss: 11.6704 - mean_absolute_error: 11.6704
# Epoch 82/200
#  - 0s - loss: 11.6711 - mean_absolute_error: 11.6711
# Epoch 83/200
#  - 0s - loss: 11.6585 - mean_absolute_error: 11.6585
# Epoch 84/200
#  - 0s - loss: 11.6059 - mean_absolute_error: 11.6059
# Epoch 85/200
#  - 0s - loss: 11.6600 - mean_absolute_error: 11.6600
# Epoch 86/200
#  - 0s - loss: 11.5821 - mean_absolute_error: 11.5821
# Epoch 87/200
#  - 0s - loss: 11.5613 - mean_absolute_error: 11.5613
# Epoch 88/200
#  - 0s - loss: 11.5838 - mean_absolute_error: 11.5838
# Epoch 89/200
#  - 0s - loss: 11.5534 - mean_absolute_error: 11.5534
# Epoch 90/200
#  - 0s - loss: 11.5609 - mean_absolute_error: 11.5609
# Epoch 91/200
#  - 0s - loss: 11.5010 - mean_absolute_error: 11.5010
# Epoch 92/200
#  - 0s - loss: 11.4988 - mean_absolute_error: 11.4988
# Epoch 93/200
#  - 0s - loss: 11.4486 - mean_absolute_error: 11.4486
# Epoch 94/200
#  - 0s - loss: 11.4639 - mean_absolute_error: 11.4639
# Epoch 95/200
#  - 0s - loss: 11.4840 - mean_absolute_error: 11.4840
# Epoch 96/200
#  - 0s - loss: 11.4477 - mean_absolute_error: 11.4477
# Epoch 97/200
#  - 0s - loss: 11.4205 - mean_absolute_error: 11.4205
# Epoch 98/200
#  - 0s - loss: 11.4136 - mean_absolute_error: 11.4136
# Epoch 99/200
#  - 0s - loss: 11.3792 - mean_absolute_error: 11.3792
# Epoch 100/200
#  - 0s - loss: 11.3690 - mean_absolute_error: 11.3690
# Epoch 101/200
#  - 0s - loss: 11.3541 - mean_absolute_error: 11.3541
# Epoch 102/200
#  - 0s - loss: 11.3358 - mean_absolute_error: 11.3358
# Epoch 103/200
#  - 0s - loss: 11.3022 - mean_absolute_error: 11.3022
# Epoch 104/200
#  - 0s - loss: 11.3019 - mean_absolute_error: 11.3019
# Epoch 105/200
#  - 0s - loss: 11.3064 - mean_absolute_error: 11.3064
# Epoch 106/200
#  - 0s - loss: 11.3314 - mean_absolute_error: 11.3314
# Epoch 107/200
#  - 0s - loss: 11.2568 - mean_absolute_error: 11.2568
# Epoch 108/200
#  - 0s - loss: 11.2652 - mean_absolute_error: 11.2652
# Epoch 109/200
#  - 0s - loss: 11.2426 - mean_absolute_error: 11.2426
# Epoch 110/200
#  - 0s - loss: 11.1943 - mean_absolute_error: 11.1943
# Epoch 111/200
#  - 0s - loss: 11.1769 - mean_absolute_error: 11.1769
# Epoch 112/200
#  - 0s - loss: 11.1727 - mean_absolute_error: 11.1727
# Epoch 113/200
#  - 0s - loss: 11.1555 - mean_absolute_error: 11.1555
# Epoch 114/200
#  - 0s - loss: 11.1430 - mean_absolute_error: 11.1430
# Epoch 115/200
#  - 0s - loss: 11.1390 - mean_absolute_error: 11.1390
# Epoch 116/200
#  - 0s - loss: 11.0783 - mean_absolute_error: 11.0783
# Epoch 117/200
#  - 0s - loss: 11.0858 - mean_absolute_error: 11.0858
# Epoch 118/200
#  - 0s - loss: 11.0903 - mean_absolute_error: 11.0903
# Epoch 119/200
#  - 0s - loss: 11.0551 - mean_absolute_error: 11.0551
# Epoch 120/200
#  - 0s - loss: 11.0454 - mean_absolute_error: 11.0454
# Epoch 121/200
#  - 0s - loss: 11.0168 - mean_absolute_error: 11.0168
# Epoch 122/200
#  - 0s - loss: 11.0078 - mean_absolute_error: 11.0078
# Epoch 123/200
#  - 0s - loss: 11.0075 - mean_absolute_error: 11.0075
# Epoch 124/200
#  - 0s - loss: 10.9544 - mean_absolute_error: 10.9544
# Epoch 125/200
#  - 0s - loss: 10.9960 - mean_absolute_error: 10.9960
# Epoch 126/200
#  - 0s - loss: 10.9588 - mean_absolute_error: 10.9588
# Epoch 127/200
#  - 0s - loss: 10.9389 - mean_absolute_error: 10.9389
# Epoch 128/200
#  - 0s - loss: 10.8938 - mean_absolute_error: 10.8938
# Epoch 129/200
#  - 0s - loss: 10.8781 - mean_absolute_error: 10.8781
# Epoch 130/200
#  - 0s - loss: 10.8329 - mean_absolute_error: 10.8329
# Epoch 131/200
#  - 0s - loss: 10.8511 - mean_absolute_error: 10.8511
# Epoch 132/200
#  - 0s - loss: 10.8287 - mean_absolute_error: 10.8287
# Epoch 133/200
#  - 0s - loss: 10.8255 - mean_absolute_error: 10.8255
# Epoch 134/200
#  - 0s - loss: 10.7924 - mean_absolute_error: 10.7924
# Epoch 135/200
#  - 0s - loss: 10.7581 - mean_absolute_error: 10.7581
# Epoch 136/200
#  - 0s - loss: 10.7592 - mean_absolute_error: 10.7592
# Epoch 137/200
#  - 0s - loss: 10.7231 - mean_absolute_error: 10.7231
# Epoch 138/200
#  - 0s - loss: 10.7023 - mean_absolute_error: 10.7023
# Epoch 139/200
#  - 0s - loss: 10.6857 - mean_absolute_error: 10.6857
# Epoch 140/200
#  - 0s - loss: 10.6956 - mean_absolute_error: 10.6956
# Epoch 141/200
#  - 0s - loss: 10.6566 - mean_absolute_error: 10.6566
# Epoch 142/200
#  - 0s - loss: 10.6226 - mean_absolute_error: 10.6226
# Epoch 143/200
#  - 0s - loss: 10.6233 - mean_absolute_error: 10.6233
# Epoch 144/200
#  - 0s - loss: 10.5967 - mean_absolute_error: 10.5967
# Epoch 145/200
#  - 0s - loss: 10.5901 - mean_absolute_error: 10.5901
# Epoch 146/200
#  - 0s - loss: 10.5626 - mean_absolute_error: 10.5626
# Epoch 147/200
#  - 0s - loss: 10.5533 - mean_absolute_error: 10.5533
# Epoch 148/200
#  - 0s - loss: 10.5704 - mean_absolute_error: 10.5704
# Epoch 149/200
#  - 0s - loss: 10.5269 - mean_absolute_error: 10.5269
# Epoch 150/200
#  - 0s - loss: 10.4760 - mean_absolute_error: 10.4760
# Epoch 151/200
#  - 0s - loss: 10.5235 - mean_absolute_error: 10.5235
# Epoch 152/200
#  - 0s - loss: 10.5099 - mean_absolute_error: 10.5099
# Epoch 153/200
#  - 0s - loss: 10.4505 - mean_absolute_error: 10.4505
# Epoch 154/200
#  - 0s - loss: 10.4369 - mean_absolute_error: 10.4369
# Epoch 155/200
#  - 0s - loss: 10.4330 - mean_absolute_error: 10.4330
# Epoch 156/200
#  - 0s - loss: 10.3645 - mean_absolute_error: 10.3645
# Epoch 157/200
#  - 0s - loss: 10.3855 - mean_absolute_error: 10.3855
# Epoch 158/200
#  - 0s - loss: 10.3838 - mean_absolute_error: 10.3838
# Epoch 159/200
#  - 0s - loss: 10.3352 - mean_absolute_error: 10.3352
# Epoch 160/200
#  - 0s - loss: 10.3221 - mean_absolute_error: 10.3221
# Epoch 161/200
#  - 0s - loss: 10.3070 - mean_absolute_error: 10.3070
# Epoch 162/200
#  - 0s - loss: 10.3016 - mean_absolute_error: 10.3016
# Epoch 163/200
#  - 0s - loss: 10.2746 - mean_absolute_error: 10.2746
# Epoch 164/200
#  - 0s - loss: 10.2529 - mean_absolute_error: 10.2529
# Epoch 165/200
#  - 0s - loss: 10.2635 - mean_absolute_error: 10.2635
# Epoch 166/200
#  - 0s - loss: 10.2424 - mean_absolute_error: 10.2424
# Epoch 167/200
#  - 0s - loss: 10.2384 - mean_absolute_error: 10.2384
# Epoch 168/200
#  - 0s - loss: 10.1836 - mean_absolute_error: 10.1836
# Epoch 169/200
#  - 0s - loss: 10.1489 - mean_absolute_error: 10.1489
# Epoch 170/200
#  - 0s - loss: 10.1745 - mean_absolute_error: 10.1745
# Epoch 171/200
#  - 0s - loss: 10.1141 - mean_absolute_error: 10.1141
# Epoch 172/200
#  - 0s - loss: 10.0993 - mean_absolute_error: 10.0993
# Epoch 173/200
#  - 0s - loss: 10.1092 - mean_absolute_error: 10.1092
# Epoch 174/200
#  - 0s - loss: 10.0901 - mean_absolute_error: 10.0901
# Epoch 175/200
#  - 0s - loss: 10.0401 - mean_absolute_error: 10.0401
# Epoch 176/200
#  - 0s - loss: 10.0218 - mean_absolute_error: 10.0218
# Epoch 177/200
#  - 0s - loss: 9.9939 - mean_absolute_error: 9.9939
# Epoch 178/200
#  - 0s - loss: 9.9923 - mean_absolute_error: 9.9923
# Epoch 179/200
#  - 0s - loss: 9.9766 - mean_absolute_error: 9.9766
# Epoch 180/200
#  - 0s - loss: 9.9885 - mean_absolute_error: 9.9885
# Epoch 181/200
#  - 0s - loss: 9.9383 - mean_absolute_error: 9.9383
# Epoch 182/200
#  - 0s - loss: 9.9540 - mean_absolute_error: 9.9540
# Epoch 183/200
#  - 0s - loss: 9.9253 - mean_absolute_error: 9.9253
# Epoch 184/200
#  - 0s - loss: 9.8715 - mean_absolute_error: 9.8715
# Epoch 185/200
#  - 0s - loss: 9.8905 - mean_absolute_error: 9.8905
# Epoch 186/200
#  - 0s - loss: 9.8261 - mean_absolute_error: 9.8261
# Epoch 187/200
#  - 0s - loss: 9.8347 - mean_absolute_error: 9.8347
# Epoch 188/200
#  - 0s - loss: 9.8006 - mean_absolute_error: 9.8006
# Epoch 189/200
#  - 0s - loss: 9.7771 - mean_absolute_error: 9.7771
# Epoch 190/200
#  - 0s - loss: 9.7941 - mean_absolute_error: 9.7941
# Epoch 191/200
#  - 0s - loss: 9.7712 - mean_absolute_error: 9.7712
# Epoch 192/200
#  - 0s - loss: 9.7125 - mean_absolute_error: 9.7125
# Epoch 193/200
#  - 0s - loss: 9.7034 - mean_absolute_error: 9.7034
# Epoch 194/200
#  - 0s - loss: 9.6726 - mean_absolute_error: 9.6726
# Epoch 195/200
#  - 0s - loss: 9.6498 - mean_absolute_error: 9.6498
# Epoch 196/200
#  - 0s - loss: 9.6236 - mean_absolute_error: 9.6236
# Epoch 197/200
#  - 0s - loss: 9.7063 - mean_absolute_error: 9.7063
# Epoch 198/200
#  - 0s - loss: 9.6102 - mean_absolute_error: 9.6102
# Epoch 199/200
#  - 0s - loss: 9.5816 - mean_absolute_error: 9.5816
# Epoch 200/200
#  - 0s - loss: 9.5470 - mean_absolute_error: 9.5470
# Epoch 1/200
#  - 0s - loss: 124.1636 - mean_absolute_error: 124.1636
# Epoch 2/200
#  - 0s - loss: 91.0037 - mean_absolute_error: 91.0037
# Epoch 3/200
#  - 0s - loss: 62.3117 - mean_absolute_error: 62.3117
# Epoch 4/200
#  - 0s - loss: 40.3403 - mean_absolute_error: 40.3403
# Epoch 5/200
#  - 0s - loss: 22.0427 - mean_absolute_error: 22.0427
# Epoch 6/200
#  - 0s - loss: 15.0232 - mean_absolute_error: 15.0232
# Epoch 7/200
#  - 0s - loss: 14.3092 - mean_absolute_error: 14.3092
# Epoch 8/200
#  - 0s - loss: 14.2238 - mean_absolute_error: 14.2238
# Epoch 9/200
#  - 0s - loss: 14.1970 - mean_absolute_error: 14.1970
# Epoch 10/200
#  - 0s - loss: 14.0705 - mean_absolute_error: 14.0705
# Epoch 11/200
#  - 0s - loss: 13.6941 - mean_absolute_error: 13.6941
# Epoch 12/200
#  - 0s - loss: 13.5028 - mean_absolute_error: 13.5028
# Epoch 13/200
#  - 0s - loss: 13.3474 - mean_absolute_error: 13.3474
# Epoch 14/200
#  - 0s - loss: 13.4288 - mean_absolute_error: 13.4288
# Epoch 15/200
#  - 0s - loss: 13.4363 - mean_absolute_error: 13.4363
# Epoch 16/200
#  - 0s - loss: 13.1350 - mean_absolute_error: 13.1350
# Epoch 17/200
#  - 0s - loss: 12.9876 - mean_absolute_error: 12.9876
# Epoch 18/200
#  - 0s - loss: 12.8996 - mean_absolute_error: 12.8996
# Epoch 19/200
#  - 0s - loss: 12.7975 - mean_absolute_error: 12.7975
# Epoch 20/200
#  - 0s - loss: 12.7062 - mean_absolute_error: 12.7062
# Epoch 21/200
#  - 0s - loss: 12.6329 - mean_absolute_error: 12.6329
# Epoch 22/200
#  - 0s - loss: 12.5926 - mean_absolute_error: 12.5926
# Epoch 23/200
#  - 0s - loss: 12.5425 - mean_absolute_error: 12.5425
# Epoch 24/200
#  - 0s - loss: 12.5237 - mean_absolute_error: 12.5237
# Epoch 25/200
#  - 0s - loss: 12.5380 - mean_absolute_error: 12.5380
# Epoch 26/200
#  - 0s - loss: 12.4763 - mean_absolute_error: 12.4763
# Epoch 27/200
#  - 0s - loss: 12.4442 - mean_absolute_error: 12.4442
# Epoch 28/200
#  - 0s - loss: 12.4030 - mean_absolute_error: 12.4030
# Epoch 29/200
#  - 0s - loss: 12.3879 - mean_absolute_error: 12.3879
# Epoch 30/200
#  - 0s - loss: 12.3650 - mean_absolute_error: 12.3650
# Epoch 31/200
#  - 0s - loss: 12.3262 - mean_absolute_error: 12.3262
# Epoch 32/200
#  - 0s - loss: 12.3056 - mean_absolute_error: 12.3056
# Epoch 33/200
#  - 0s - loss: 12.3071 - mean_absolute_error: 12.3071
# Epoch 34/200
#  - 0s - loss: 12.2722 - mean_absolute_error: 12.2722
# Epoch 35/200
#  - 0s - loss: 12.2575 - mean_absolute_error: 12.2575
# Epoch 36/200
#  - 0s - loss: 12.2590 - mean_absolute_error: 12.2590
# Epoch 37/200
#  - 0s - loss: 12.2436 - mean_absolute_error: 12.2436
# Epoch 38/200
#  - 0s - loss: 12.2214 - mean_absolute_error: 12.2214
# Epoch 39/200
#  - 0s - loss: 12.2169 - mean_absolute_error: 12.2169
# Epoch 40/200
#  - 0s - loss: 12.2077 - mean_absolute_error: 12.2077
# Epoch 41/200
#  - 0s - loss: 12.1735 - mean_absolute_error: 12.1735
# Epoch 42/200
#  - 0s - loss: 12.1728 - mean_absolute_error: 12.1728
# Epoch 43/200
#  - 0s - loss: 12.1751 - mean_absolute_error: 12.1751
# Epoch 44/200
#  - 0s - loss: 12.1607 - mean_absolute_error: 12.1607
# Epoch 45/200
#  - 0s - loss: 12.1505 - mean_absolute_error: 12.1505
# Epoch 46/200
#  - 0s - loss: 12.1426 - mean_absolute_error: 12.1426
# Epoch 47/200
#  - 0s - loss: 12.1295 - mean_absolute_error: 12.1295
# Epoch 48/200
#  - 0s - loss: 12.1304 - mean_absolute_error: 12.1304
# Epoch 49/200
#  - 0s - loss: 12.1176 - mean_absolute_error: 12.1176
# Epoch 50/200
#  - 0s - loss: 12.1185 - mean_absolute_error: 12.1185
# Epoch 51/200
#  - 0s - loss: 12.0602 - mean_absolute_error: 12.0602
# Epoch 52/200
#  - 0s - loss: 12.0825 - mean_absolute_error: 12.0825
# Epoch 53/200
#  - 0s - loss: 12.0732 - mean_absolute_error: 12.0732
# Epoch 54/200
#  - 0s - loss: 12.0235 - mean_absolute_error: 12.0235
# Epoch 55/200
#  - 0s - loss: 12.0292 - mean_absolute_error: 12.0292
# Epoch 56/200
#  - 0s - loss: 12.0035 - mean_absolute_error: 12.0035
# Epoch 57/200
#  - 0s - loss: 11.9993 - mean_absolute_error: 11.9993
# Epoch 58/200
#  - 0s - loss: 12.0170 - mean_absolute_error: 12.0170
# Epoch 59/200
#  - 0s - loss: 12.0001 - mean_absolute_error: 12.0001
# Epoch 60/200
#  - 0s - loss: 11.9646 - mean_absolute_error: 11.9646
# Epoch 61/200
#  - 0s - loss: 11.9920 - mean_absolute_error: 11.9920
# Epoch 62/200
#  - 0s - loss: 11.9375 - mean_absolute_error: 11.9375
# Epoch 63/200
#  - 0s - loss: 11.9539 - mean_absolute_error: 11.9539
# Epoch 64/200
#  - 0s - loss: 11.9166 - mean_absolute_error: 11.9166
# Epoch 65/200
#  - 0s - loss: 11.9061 - mean_absolute_error: 11.9061
# Epoch 66/200
#  - 0s - loss: 11.9283 - mean_absolute_error: 11.9283
# Epoch 67/200
#  - 0s - loss: 11.8654 - mean_absolute_error: 11.8654
# Epoch 68/200
#  - 0s - loss: 11.9721 - mean_absolute_error: 11.9721
# Epoch 69/200
#  - 0s - loss: 11.8629 - mean_absolute_error: 11.8629
# Epoch 70/200
#  - 0s - loss: 11.8407 - mean_absolute_error: 11.8407
# Epoch 71/200
#  - 0s - loss: 11.8354 - mean_absolute_error: 11.8354
# Epoch 72/200
#  - 0s - loss: 11.8204 - mean_absolute_error: 11.8204
# Epoch 73/200
#  - 0s - loss: 11.8387 - mean_absolute_error: 11.8387
# Epoch 74/200
#  - 0s - loss: 11.8119 - mean_absolute_error: 11.8119
# Epoch 75/200
#  - 0s - loss: 11.7923 - mean_absolute_error: 11.7923
# Epoch 76/200
#  - 0s - loss: 11.7807 - mean_absolute_error: 11.7807
# Epoch 77/200
#  - 0s - loss: 11.7424 - mean_absolute_error: 11.7424
# Epoch 78/200
#  - 0s - loss: 11.7190 - mean_absolute_error: 11.7190
# Epoch 79/200
#  - 0s - loss: 11.7432 - mean_absolute_error: 11.7432
# Epoch 80/200
#  - 0s - loss: 11.7370 - mean_absolute_error: 11.7370
# Epoch 81/200
#  - 0s - loss: 11.7292 - mean_absolute_error: 11.7292
# Epoch 82/200
#  - 0s - loss: 11.6877 - mean_absolute_error: 11.6877
# Epoch 83/200
#  - 0s - loss: 11.7048 - mean_absolute_error: 11.7048
# Epoch 84/200
#  - 0s - loss: 11.6716 - mean_absolute_error: 11.6716
# Epoch 85/200
#  - 0s - loss: 11.6691 - mean_absolute_error: 11.6691
# Epoch 86/200
#  - 0s - loss: 11.6242 - mean_absolute_error: 11.6242
# Epoch 87/200
#  - 0s - loss: 11.6055 - mean_absolute_error: 11.6055
# Epoch 88/200
#  - 0s - loss: 11.5976 - mean_absolute_error: 11.5976
# Epoch 89/200
#  - 0s - loss: 11.6161 - mean_absolute_error: 11.6161
# Epoch 90/200
#  - 0s - loss: 11.5862 - mean_absolute_error: 11.5862
# Epoch 91/200
#  - 0s - loss: 11.5723 - mean_absolute_error: 11.5723
# Epoch 92/200
#  - 0s - loss: 11.5543 - mean_absolute_error: 11.5543
# Epoch 93/200
#  - 0s - loss: 11.5270 - mean_absolute_error: 11.5270
# Epoch 94/200
#  - 0s - loss: 11.5061 - mean_absolute_error: 11.5061
# Epoch 95/200
#  - 0s - loss: 11.4955 - mean_absolute_error: 11.4955
# Epoch 96/200
#  - 0s - loss: 11.4770 - mean_absolute_error: 11.4770
# Epoch 97/200
#  - 0s - loss: 11.5300 - mean_absolute_error: 11.5300
# Epoch 98/200
#  - 0s - loss: 11.4662 - mean_absolute_error: 11.4662
# Epoch 99/200
#  - 0s - loss: 11.4289 - mean_absolute_error: 11.4289
# Epoch 100/200
#  - 0s - loss: 11.4107 - mean_absolute_error: 11.4107
# Epoch 101/200
#  - 0s - loss: 11.3939 - mean_absolute_error: 11.3939
# Epoch 102/200
#  - 0s - loss: 11.3567 - mean_absolute_error: 11.3567
# Epoch 103/200
#  - 0s - loss: 11.3385 - mean_absolute_error: 11.3385
# Epoch 104/200
#  - 0s - loss: 11.3439 - mean_absolute_error: 11.3439
# Epoch 105/200
#  - 0s - loss: 11.3267 - mean_absolute_error: 11.3267
# Epoch 106/200
#  - 0s - loss: 11.3158 - mean_absolute_error: 11.3158
# Epoch 107/200
#  - 0s - loss: 11.3046 - mean_absolute_error: 11.3046
# Epoch 108/200
#  - 0s - loss: 11.2879 - mean_absolute_error: 11.2879
# Epoch 109/200
#  - 0s - loss: 11.2714 - mean_absolute_error: 11.2714
# Epoch 110/200
#  - 0s - loss: 11.3389 - mean_absolute_error: 11.3389
# Epoch 111/200
#  - 0s - loss: 11.2490 - mean_absolute_error: 11.2490
# Epoch 112/200
#  - 0s - loss: 11.2341 - mean_absolute_error: 11.2341
# Epoch 113/200
#  - 0s - loss: 11.2004 - mean_absolute_error: 11.2004
# Epoch 114/200
#  - 0s - loss: 11.1903 - mean_absolute_error: 11.1903
# Epoch 115/200
#  - 0s - loss: 11.2023 - mean_absolute_error: 11.2023
# Epoch 116/200
#  - 0s - loss: 11.1754 - mean_absolute_error: 11.1754
# Epoch 117/200
#  - 0s - loss: 11.1573 - mean_absolute_error: 11.1573
# Epoch 118/200
#  - 0s - loss: 11.1386 - mean_absolute_error: 11.1386
# Epoch 119/200
#  - 0s - loss: 11.1238 - mean_absolute_error: 11.1238
# Epoch 120/200
#  - 0s - loss: 11.0940 - mean_absolute_error: 11.0940
# Epoch 121/200
#  - 0s - loss: 11.0969 - mean_absolute_error: 11.0969
# Epoch 122/200
#  - 0s - loss: 11.0846 - mean_absolute_error: 11.0846
# Epoch 123/200
#  - 0s - loss: 11.0544 - mean_absolute_error: 11.0544
# Epoch 124/200
#  - 0s - loss: 11.0811 - mean_absolute_error: 11.0811
# Epoch 125/200
#  - 0s - loss: 11.0131 - mean_absolute_error: 11.0131
# Epoch 126/200
#  - 0s - loss: 10.9973 - mean_absolute_error: 10.9973
# Epoch 127/200
#  - 0s - loss: 10.9827 - mean_absolute_error: 10.9827
# Epoch 128/200
#  - 0s - loss: 10.9725 - mean_absolute_error: 10.9725
# Epoch 129/200
#  - 0s - loss: 10.9567 - mean_absolute_error: 10.9567
# Epoch 130/200
#  - 0s - loss: 10.9329 - mean_absolute_error: 10.9329
# Epoch 131/200
#  - 0s - loss: 10.9213 - mean_absolute_error: 10.9213
# Epoch 132/200
#  - 0s - loss: 10.9041 - mean_absolute_error: 10.9041
# Epoch 133/200
#  - 0s - loss: 10.9192 - mean_absolute_error: 10.9192
# Epoch 134/200
#  - 0s - loss: 10.9315 - mean_absolute_error: 10.9315
# Epoch 135/200
#  - 0s - loss: 10.8760 - mean_absolute_error: 10.8760
# Epoch 136/200
#  - 0s - loss: 10.8500 - mean_absolute_error: 10.8500
# Epoch 137/200
#  - 0s - loss: 10.8460 - mean_absolute_error: 10.8460
# Epoch 138/200
#  - 0s - loss: 10.8229 - mean_absolute_error: 10.8229
# Epoch 139/200
#  - 0s - loss: 10.8093 - mean_absolute_error: 10.8093
# Epoch 140/200
#  - 0s - loss: 10.7650 - mean_absolute_error: 10.7650
# Epoch 141/200
#  - 0s - loss: 10.7677 - mean_absolute_error: 10.7677
# Epoch 142/200
#  - 0s - loss: 10.7504 - mean_absolute_error: 10.7504
# Epoch 143/200
#  - 0s - loss: 10.7827 - mean_absolute_error: 10.7827
# Epoch 144/200
#  - 0s - loss: 10.7270 - mean_absolute_error: 10.7270
# Epoch 145/200
#  - 0s - loss: 10.6934 - mean_absolute_error: 10.6934
# Epoch 146/200
#  - 0s - loss: 10.7124 - mean_absolute_error: 10.7124
# Epoch 147/200
#  - 0s - loss: 10.6877 - mean_absolute_error: 10.6877
# Epoch 148/200
#  - 0s - loss: 10.6693 - mean_absolute_error: 10.6693
# Epoch 149/200
#  - 0s - loss: 10.6171 - mean_absolute_error: 10.6171
# Epoch 150/200
#  - 0s - loss: 10.6819 - mean_absolute_error: 10.6819
# Epoch 151/200
#  - 0s - loss: 10.6128 - mean_absolute_error: 10.6128
# Epoch 152/200
#  - 0s - loss: 10.6134 - mean_absolute_error: 10.6134
# Epoch 153/200
#  - 0s - loss: 10.5858 - mean_absolute_error: 10.5858
# Epoch 154/200
#  - 0s - loss: 10.5454 - mean_absolute_error: 10.5454
# Epoch 155/200
#  - 0s - loss: 10.5373 - mean_absolute_error: 10.5373
# Epoch 156/200
#  - 0s - loss: 10.5804 - mean_absolute_error: 10.5804
# Epoch 157/200
#  - 0s - loss: 10.5334 - mean_absolute_error: 10.5334
# Epoch 158/200
#  - 0s - loss: 10.5021 - mean_absolute_error: 10.5021
# Epoch 159/200
#  - 0s - loss: 10.5088 - mean_absolute_error: 10.5088
# Epoch 160/200
#  - 0s - loss: 10.4739 - mean_absolute_error: 10.4739
# Epoch 161/200
#  - 0s - loss: 10.4237 - mean_absolute_error: 10.4237
# Epoch 162/200
#  - 0s - loss: 10.4241 - mean_absolute_error: 10.4241
# Epoch 163/200
#  - 0s - loss: 10.4287 - mean_absolute_error: 10.4287
# Epoch 164/200
#  - 0s - loss: 10.4123 - mean_absolute_error: 10.4123
# Epoch 165/200
#  - 0s - loss: 10.3756 - mean_absolute_error: 10.3756
# Epoch 166/200
#  - 0s - loss: 10.3311 - mean_absolute_error: 10.3311
# Epoch 167/200
#  - 0s - loss: 10.3262 - mean_absolute_error: 10.3262
# Epoch 168/200
#  - 0s - loss: 10.2983 - mean_absolute_error: 10.2983
# Epoch 169/200
#  - 0s - loss: 10.3099 - mean_absolute_error: 10.3099
# Epoch 170/200
#  - 0s - loss: 10.2766 - mean_absolute_error: 10.2766
# Epoch 171/200
#  - 0s - loss: 10.2608 - mean_absolute_error: 10.2608
# Epoch 172/200
#  - 0s - loss: 10.2320 - mean_absolute_error: 10.2320
# Epoch 173/200
#  - 0s - loss: 10.2246 - mean_absolute_error: 10.2246
# Epoch 174/200
#  - 0s - loss: 10.2156 - mean_absolute_error: 10.2156
# Epoch 175/200
#  - 0s - loss: 10.1976 - mean_absolute_error: 10.1976
# Epoch 176/200
#  - 0s - loss: 10.1514 - mean_absolute_error: 10.1514
# Epoch 177/200
#  - 0s - loss: 10.1471 - mean_absolute_error: 10.1471
# Epoch 178/200
#  - 0s - loss: 10.1122 - mean_absolute_error: 10.1122
# Epoch 179/200
#  - 0s - loss: 10.1271 - mean_absolute_error: 10.1271
# Epoch 180/200
#  - 0s - loss: 10.1254 - mean_absolute_error: 10.1254
# Epoch 181/200
#  - 0s - loss: 10.1124 - mean_absolute_error: 10.1124
# Epoch 182/200
#  - 0s - loss: 10.0544 - mean_absolute_error: 10.0544
# Epoch 183/200
#  - 0s - loss: 10.0169 - mean_absolute_error: 10.0169
# Epoch 184/200
#  - 0s - loss: 10.0089 - mean_absolute_error: 10.0089
# Epoch 185/200
#  - 0s - loss: 9.9579 - mean_absolute_error: 9.9579
# Epoch 186/200
#  - 0s - loss: 9.9763 - mean_absolute_error: 9.9763
# Epoch 187/200
#  - 0s - loss: 9.9428 - mean_absolute_error: 9.9428
# Epoch 188/200
#  - 0s - loss: 9.9607 - mean_absolute_error: 9.9607
# Epoch 189/200
#  - 0s - loss: 9.9160 - mean_absolute_error: 9.9160
# Epoch 190/200
#  - 0s - loss: 9.8739 - mean_absolute_error: 9.8739
# Epoch 191/200
#  - 0s - loss: 9.8852 - mean_absolute_error: 9.8852
# Epoch 192/200
#  - 0s - loss: 9.8543 - mean_absolute_error: 9.8543
# Epoch 193/200
#  - 0s - loss: 9.8110 - mean_absolute_error: 9.8110
# Epoch 194/200
#  - 0s - loss: 9.8236 - mean_absolute_error: 9.8236
# Epoch 195/200
#  - 0s - loss: 9.8120 - mean_absolute_error: 9.8120
# Epoch 196/200
#  - 0s - loss: 9.7880 - mean_absolute_error: 9.7880
# Epoch 197/200
#  - 0s - loss: 9.7570 - mean_absolute_error: 9.7570
# Epoch 198/200
#  - 0s - loss: 9.7302 - mean_absolute_error: 9.7302
# Epoch 199/200
#  - 0s - loss: 9.7005 - mean_absolute_error: 9.7005
# Epoch 200/200
#  - 0s - loss: 9.7314 - mean_absolute_error: 9.7314
# Epoch 1/200
#  - 0s - loss: 124.2082 - mean_absolute_error: 124.2082
# Epoch 2/200
#  - 0s - loss: 91.3117 - mean_absolute_error: 91.3117
# Epoch 3/200
#  - 0s - loss: 62.4900 - mean_absolute_error: 62.4900
# Epoch 4/200
#  - 0s - loss: 40.4602 - mean_absolute_error: 40.4602
# Epoch 5/200
#  - 0s - loss: 22.1594 - mean_absolute_error: 22.1594
# Epoch 6/200
#  - 0s - loss: 15.0556 - mean_absolute_error: 15.0556
# Epoch 7/200
#  - 0s - loss: 14.1853 - mean_absolute_error: 14.1853
# Epoch 8/200
#  - 0s - loss: 14.1229 - mean_absolute_error: 14.1229
# Epoch 9/200
#  - 0s - loss: 13.8912 - mean_absolute_error: 13.8912
# Epoch 10/200
#  - 0s - loss: 13.5687 - mean_absolute_error: 13.5687
# Epoch 11/200
#  - 0s - loss: 13.5869 - mean_absolute_error: 13.5869
# Epoch 12/200
#  - 0s - loss: 13.4155 - mean_absolute_error: 13.4155
# Epoch 13/200
#  - 0s - loss: 13.3112 - mean_absolute_error: 13.3112
# Epoch 14/200
#  - 0s - loss: 13.2754 - mean_absolute_error: 13.2754
# Epoch 15/200
#  - 0s - loss: 13.2245 - mean_absolute_error: 13.2245
# Epoch 16/200
#  - 0s - loss: 13.1334 - mean_absolute_error: 13.1334
# Epoch 17/200
#  - 0s - loss: 12.8857 - mean_absolute_error: 12.8857
# Epoch 18/200
#  - 0s - loss: 12.8216 - mean_absolute_error: 12.8216
# Epoch 19/200
#  - 0s - loss: 12.8139 - mean_absolute_error: 12.8139
# Epoch 20/200
#  - 0s - loss: 12.6929 - mean_absolute_error: 12.6929
# Epoch 21/200
#  - 0s - loss: 12.6035 - mean_absolute_error: 12.6035
# Epoch 22/200
#  - 0s - loss: 12.5600 - mean_absolute_error: 12.5600
# Epoch 23/200
#  - 0s - loss: 12.5067 - mean_absolute_error: 12.5067
# Epoch 24/200
#  - 0s - loss: 12.4695 - mean_absolute_error: 12.4695
# Epoch 25/200
#  - 0s - loss: 12.4367 - mean_absolute_error: 12.4367
# Epoch 26/200
#  - 0s - loss: 12.3917 - mean_absolute_error: 12.3917
# Epoch 27/200
#  - 0s - loss: 12.3760 - mean_absolute_error: 12.3760
# Epoch 28/200
#  - 0s - loss: 12.3481 - mean_absolute_error: 12.3481
# Epoch 29/200
#  - 0s - loss: 12.3554 - mean_absolute_error: 12.3554
# Epoch 30/200
#  - 0s - loss: 12.3467 - mean_absolute_error: 12.3467
# Epoch 31/200
#  - 0s - loss: 12.2967 - mean_absolute_error: 12.2967
# Epoch 32/200
#  - 0s - loss: 12.2960 - mean_absolute_error: 12.2960
# Epoch 33/200
#  - 0s - loss: 12.2706 - mean_absolute_error: 12.2706
# Epoch 34/200
#  - 0s - loss: 12.2678 - mean_absolute_error: 12.2678
# Epoch 35/200
#  - 0s - loss: 12.2724 - mean_absolute_error: 12.2724
# Epoch 36/200
#  - 0s - loss: 12.2628 - mean_absolute_error: 12.2628
# Epoch 37/200
#  - 0s - loss: 12.2411 - mean_absolute_error: 12.2411
# Epoch 38/200
#  - 0s - loss: 12.2137 - mean_absolute_error: 12.2137
# Epoch 39/200
#  - 0s - loss: 12.2112 - mean_absolute_error: 12.2112
# Epoch 40/200
#  - 0s - loss: 12.1842 - mean_absolute_error: 12.1842
# Epoch 41/200
#  - 0s - loss: 12.2007 - mean_absolute_error: 12.2007
# Epoch 42/200
#  - 0s - loss: 12.1580 - mean_absolute_error: 12.1580
# Epoch 43/200
#  - 0s - loss: 12.1671 - mean_absolute_error: 12.1671
# Epoch 44/200
#  - 0s - loss: 12.1581 - mean_absolute_error: 12.1581
# Epoch 45/200
#  - 0s - loss: 12.1521 - mean_absolute_error: 12.1521
# Epoch 46/200
#  - 0s - loss: 12.1410 - mean_absolute_error: 12.1410
# Epoch 47/200
#  - 0s - loss: 12.1168 - mean_absolute_error: 12.1168
# Epoch 48/200
#  - 0s - loss: 12.1295 - mean_absolute_error: 12.1295
# Epoch 49/200
#  - 0s - loss: 12.0988 - mean_absolute_error: 12.0988
# Epoch 50/200
#  - 0s - loss: 12.0690 - mean_absolute_error: 12.0690
# Epoch 51/200
#  - 0s - loss: 12.0967 - mean_absolute_error: 12.0967
# Epoch 52/200
#  - 0s - loss: 12.0831 - mean_absolute_error: 12.0831
# Epoch 53/200
#  - 0s - loss: 12.0466 - mean_absolute_error: 12.0466
# Epoch 54/200
#  - 0s - loss: 12.0476 - mean_absolute_error: 12.0476
# Epoch 55/200
#  - 0s - loss: 12.0685 - mean_absolute_error: 12.0685
# Epoch 56/200
#  - 0s - loss: 12.0190 - mean_absolute_error: 12.0190
# Epoch 57/200
#  - 0s - loss: 12.0126 - mean_absolute_error: 12.0126
# Epoch 58/200
#  - 0s - loss: 12.0325 - mean_absolute_error: 12.0325
# Epoch 59/200
#  - 0s - loss: 12.0120 - mean_absolute_error: 12.0120
# Epoch 60/200
#  - 0s - loss: 11.9623 - mean_absolute_error: 11.9623
# Epoch 61/200
#  - 0s - loss: 11.9623 - mean_absolute_error: 11.9623
# Epoch 62/200
#  - 0s - loss: 11.9647 - mean_absolute_error: 11.9647
# Epoch 63/200
#  - 0s - loss: 11.9328 - mean_absolute_error: 11.9328
# Epoch 64/200
#  - 0s - loss: 11.9271 - mean_absolute_error: 11.9271
# Epoch 65/200
#  - 0s - loss: 11.9275 - mean_absolute_error: 11.9275
# Epoch 66/200
#  - 0s - loss: 11.9078 - mean_absolute_error: 11.9078
# Epoch 67/200
#  - 0s - loss: 11.9258 - mean_absolute_error: 11.9258
# Epoch 68/200
#  - 0s - loss: 11.8860 - mean_absolute_error: 11.8860
# Epoch 69/200
#  - 0s - loss: 11.8845 - mean_absolute_error: 11.8845
# Epoch 70/200
#  - 0s - loss: 11.8873 - mean_absolute_error: 11.8873
# Epoch 71/200
#  - 0s - loss: 11.8745 - mean_absolute_error: 11.8745
# Epoch 72/200
#  - 0s - loss: 11.8298 - mean_absolute_error: 11.8298
# Epoch 73/200
#  - 0s - loss: 11.8364 - mean_absolute_error: 11.8364
# Epoch 74/200
#  - 0s - loss: 11.8353 - mean_absolute_error: 11.8353
# Epoch 75/200
#  - 0s - loss: 11.8042 - mean_absolute_error: 11.8042
# Epoch 76/200
#  - 0s - loss: 11.7916 - mean_absolute_error: 11.7916
# Epoch 77/200
#  - 0s - loss: 11.7640 - mean_absolute_error: 11.7640
# Epoch 78/200
#  - 0s - loss: 11.7769 - mean_absolute_error: 11.7769
# Epoch 79/200
#  - 0s - loss: 11.7513 - mean_absolute_error: 11.7513
# Epoch 80/200
#  - 0s - loss: 11.7859 - mean_absolute_error: 11.7859
# Epoch 81/200
#  - 0s - loss: 11.7956 - mean_absolute_error: 11.7956
# Epoch 82/200
#  - 0s - loss: 11.7612 - mean_absolute_error: 11.7612
# Epoch 83/200
#  - 0s - loss: 11.7240 - mean_absolute_error: 11.7240
# Epoch 84/200
#  - 0s - loss: 11.7336 - mean_absolute_error: 11.7336
# Epoch 85/200
#  - 0s - loss: 11.6590 - mean_absolute_error: 11.6590
# Epoch 86/200
#  - 0s - loss: 11.6576 - mean_absolute_error: 11.6576
# Epoch 87/200
#  - 0s - loss: 11.6473 - mean_absolute_error: 11.6473
# Epoch 88/200
#  - 0s - loss: 11.6366 - mean_absolute_error: 11.6366
# Epoch 89/200
#  - 0s - loss: 11.6071 - mean_absolute_error: 11.6071
# Epoch 90/200
#  - 0s - loss: 11.6389 - mean_absolute_error: 11.6389
# Epoch 91/200
#  - 0s - loss: 11.6143 - mean_absolute_error: 11.6143
# Epoch 92/200
#  - 0s - loss: 11.5955 - mean_absolute_error: 11.5955
# Epoch 93/200
#  - 0s - loss: 11.5659 - mean_absolute_error: 11.5659
# Epoch 94/200
#  - 0s - loss: 11.5836 - mean_absolute_error: 11.5836
# Epoch 95/200
#  - 0s - loss: 11.5719 - mean_absolute_error: 11.5719
# Epoch 96/200
#  - 0s - loss: 11.5496 - mean_absolute_error: 11.5496
# Epoch 97/200
#  - 0s - loss: 11.5502 - mean_absolute_error: 11.5502
# Epoch 98/200
#  - 0s - loss: 11.4983 - mean_absolute_error: 11.4983
# Epoch 99/200
#  - 0s - loss: 11.4884 - mean_absolute_error: 11.4884
# Epoch 100/200
#  - 0s - loss: 11.4975 - mean_absolute_error: 11.4975
# Epoch 101/200
#  - 0s - loss: 11.4613 - mean_absolute_error: 11.4613
# Epoch 102/200
#  - 0s - loss: 11.4471 - mean_absolute_error: 11.4471
# Epoch 103/200
#  - 0s - loss: 11.4491 - mean_absolute_error: 11.4491
# Epoch 104/200
#  - 0s - loss: 11.4107 - mean_absolute_error: 11.4107
# Epoch 105/200
#  - 0s - loss: 11.3762 - mean_absolute_error: 11.3762
# Epoch 106/200
#  - 0s - loss: 11.3867 - mean_absolute_error: 11.3867
# Epoch 107/200
#  - 0s - loss: 11.3643 - mean_absolute_error: 11.3643
# Epoch 108/200
#  - 0s - loss: 11.3662 - mean_absolute_error: 11.3662
# Epoch 109/200
#  - 0s - loss: 11.3259 - mean_absolute_error: 11.3259
# Epoch 110/200
#  - 0s - loss: 11.2858 - mean_absolute_error: 11.2858
# Epoch 111/200
#  - 0s - loss: 11.3256 - mean_absolute_error: 11.3256
# Epoch 112/200
#  - 0s - loss: 11.2787 - mean_absolute_error: 11.2787
# Epoch 113/200
#  - 0s - loss: 11.2421 - mean_absolute_error: 11.2421
# Epoch 114/200
#  - 0s - loss: 11.2527 - mean_absolute_error: 11.2527
# Epoch 115/200
#  - 0s - loss: 11.2602 - mean_absolute_error: 11.2602
# Epoch 116/200
#  - 0s - loss: 11.2292 - mean_absolute_error: 11.2292
# Epoch 117/200
#  - 0s - loss: 11.1951 - mean_absolute_error: 11.1951
# Epoch 118/200
#  - 0s - loss: 11.2147 - mean_absolute_error: 11.2147
# Epoch 119/200
#  - 0s - loss: 11.2100 - mean_absolute_error: 11.2100
# Epoch 120/200
#  - 0s - loss: 11.1566 - mean_absolute_error: 11.1566
# Epoch 121/200
#  - 0s - loss: 11.1148 - mean_absolute_error: 11.1148
# Epoch 122/200
#  - 0s - loss: 11.1260 - mean_absolute_error: 11.1260
# Epoch 123/200
#  - 0s - loss: 11.1103 - mean_absolute_error: 11.1103
# Epoch 124/200
#  - 0s - loss: 11.0977 - mean_absolute_error: 11.0977
# Epoch 125/200
# ...
# Epoch 160/200
#  - 0s - loss: 10.3535 - mean_absolute_error: 10.3535
# Epoch 161/200
#  - 0s - loss: 10.3405 - mean_absolute_error: 10.3405
# Epoch 162/200
#  - 0s - loss: 10.2994 - mean_absolute_error: 10.2994
# Epoch 163/200
#  - 0s - loss: 10.2672 - mean_absolute_error: 10.2672
# Epoch 164/200
#  - 0s - loss: 10.2725 - mean_absolute_error: 10.2725
# Epoch 165/200
#  - 0s - loss: 10.2830 - mean_absolute_error: 10.2830
# Epoch 166/200
#  - 0s - loss: 10.2368 - mean_absolute_error: 10.2368
# Epoch 167/200
#  - 0s - loss: 10.1998 - mean_absolute_error: 10.1998
# Epoch 168/200
#  - 0s - loss: 10.1893 - mean_absolute_error: 10.1893
# Epoch 169/200
#  - 0s - loss: 10.1913 - mean_absolute_error: 10.1913
# Epoch 170/200
#  - 0s - loss: 10.1595 - mean_absolute_error: 10.1595
# Epoch 171/200
#  - 0s - loss: 10.1755 - mean_absolute_error: 10.1755
# Epoch 172/200
#  - 0s - loss: 10.1229 - mean_absolute_error: 10.1229
# Epoch 173/200
#  - 0s - loss: 10.0761 - mean_absolute_error: 10.0761
# Epoch 174/200
#  - 0s - loss: 10.0820 - mean_absolute_error: 10.0820
# Epoch 175/200
#  - 0s - loss: 10.0545 - mean_absolute_error: 10.0545
# Epoch 176/200
#  - 0s - loss: 10.0479 - mean_absolute_error: 10.0479
# Epoch 177/200
#  - 0s - loss: 10.0301 - mean_absolute_error: 10.0301
# Epoch 178/200
#  - 0s - loss: 10.0394 - mean_absolute_error: 10.0394
# Epoch 179/200
#  - 0s - loss: 9.9800 - mean_absolute_error: 9.9800
# Epoch 180/200
#  - 0s - loss: 9.9628 - mean_absolute_error: 9.9628
# Epoch 181/200
#  - 0s - loss: 9.9445 - mean_absolute_error: 9.9445
# Epoch 182/200
#  - 0s - loss: 9.9194 - mean_absolute_error: 9.9194
# Epoch 183/200
#  - 0s - loss: 9.9117 - mean_absolute_error: 9.9117
# Epoch 184/200
#  - 0s - loss: 9.8842 - mean_absolute_error: 9.8842
# Epoch 185/200
#  - 0s - loss: 9.8648 - mean_absolute_error: 9.8648
# Epoch 186/200
#  - 0s - loss: 9.8400 - mean_absolute_error: 9.8400
# Epoch 187/200
#  - 0s - loss: 9.8023 - mean_absolute_error: 9.8023
# Epoch 188/200
#  - 0s - loss: 9.8039 - mean_absolute_error: 9.8039
# Epoch 189/200
#  - 0s - loss: 9.7929 - mean_absolute_error: 9.7929
# Epoch 190/200
#  - 0s - loss: 9.7743 - mean_absolute_error: 9.7743
# Epoch 191/200
#  - 0s - loss: 9.7426 - mean_absolute_error: 9.7426
# Epoch 192/200
#  - 0s - loss: 9.7272 - mean_absolute_error: 9.7272
# Epoch 193/200
#  - 0s - loss: 9.7063 - mean_absolute_error: 9.7063
# Epoch 194/200
#  - 0s - loss: 9.6948 - mean_absolute_error: 9.6948
# Epoch 195/200
#  - 0s - loss: 9.6765 - mean_absolute_error: 9.6765
# Epoch 196/200
#  - 0s - loss: 9.6580 - mean_absolute_error: 9.6580
# Epoch 197/200
#  - 0s - loss: 9.6428 - mean_absolute_error: 9.6428
# Epoch 198/200
#  - 0s - loss: 9.5914 - mean_absolute_error: 9.5914
# Epoch 199/200
#  - 0s - loss: 9.6192 - mean_absolute_error: 9.6192
# Epoch 200/200
#  - 0s - loss: 9.5840 - mean_absolute_error: 9.5840
# Epoch 1/200
#  - 1s - loss: 124.1497 - mean_absolute_error: 124.1497
# Epoch 2/200
#  - 0s - loss: 90.7829 - mean_absolute_error: 90.7829
# Epoch 3/200
#  - 0s - loss: 61.8091 - mean_absolute_error: 61.8091
# Epoch 4/200
#  - 0s - loss: 39.7673 - mean_absolute_error: 39.7673
# Epoch 5/200
#  - 0s - loss: 21.5947 - mean_absolute_error: 21.5947
# Epoch 6/200
#  - 0s - loss: 14.9367 - mean_absolute_error: 14.9367
# Epoch 7/200
#  - 0s - loss: 14.2037 - mean_absolute_error: 14.2037
# Epoch 8/200
#  - 0s - loss: 14.2026 - mean_absolute_error: 14.2026
# Epoch 9/200
#  - 0s - loss: 14.1395 - mean_absolute_error: 14.1395
# Epoch 10/200
#  - 0s - loss: 14.0988 - mean_absolute_error: 14.0988
# Epoch 11/200
#  - 0s - loss: 13.7946 - mean_absolute_error: 13.7946
# Epoch 12/200
#  - 0s - loss: 13.4217 - mean_absolute_error: 13.4217
# Epoch 13/200
#  - 0s - loss: 13.4242 - mean_absolute_error: 13.4242
# Epoch 14/200
#  - 0s - loss: 13.2010 - mean_absolute_error: 13.2010
# Epoch 15/200
#  - 0s - loss: 13.3270 - mean_absolute_error: 13.3270
# Epoch 16/200
#  - 0s - loss: 13.1452 - mean_absolute_error: 13.1452
# Epoch 17/200
#  - 0s - loss: 12.9620 - mean_absolute_error: 12.9620
# Epoch 18/200
#  - 0s - loss: 12.8434 - mean_absolute_error: 12.8434
# Epoch 19/200
#  - 0s - loss: 12.8220 - mean_absolute_error: 12.8220
# Epoch 20/200
#  - 0s - loss: 12.7286 - mean_absolute_error: 12.7286
# Epoch 21/200
#  - 0s - loss: 12.6538 - mean_absolute_error: 12.6538
# Epoch 22/200
#  - 0s - loss: 12.5499 - mean_absolute_error: 12.5499
# Epoch 23/200
#  - 0s - loss: 12.5056 - mean_absolute_error: 12.5056
# Epoch 24/200
#  - 0s - loss: 12.4649 - mean_absolute_error: 12.4649
# Epoch 25/200
#  - 0s - loss: 12.4246 - mean_absolute_error: 12.4246
# Epoch 26/200
#  - 0s - loss: 12.4135 - mean_absolute_error: 12.4135
# Epoch 27/200
#  - 0s - loss: 12.4037 - mean_absolute_error: 12.4037
# Epoch 28/200
#  - 0s - loss: 12.3592 - mean_absolute_error: 12.3592
# Epoch 29/200
#  - 0s - loss: 12.3553 - mean_absolute_error: 12.3553
# Epoch 30/200
#  - 0s - loss: 12.3069 - mean_absolute_error: 12.3069
# Epoch 31/200
#  - 0s - loss: 12.2762 - mean_absolute_error: 12.2762
# Epoch 32/200
#  - 0s - loss: 12.2789 - mean_absolute_error: 12.2789
# Epoch 33/200
#  - 0s - loss: 12.2513 - mean_absolute_error: 12.2513
# Epoch 34/200
#  - 0s - loss: 12.2448 - mean_absolute_error: 12.2448
# Epoch 35/200
#  - 0s - loss: 12.2323 - mean_absolute_error: 12.2323
# Epoch 36/200
#  - 0s - loss: 12.2376 - mean_absolute_error: 12.2376
# Epoch 37/200
#  - 0s - loss: 12.2403 - mean_absolute_error: 12.2403
# Epoch 38/200
#  - 0s - loss: 12.2224 - mean_absolute_error: 12.2224
# Epoch 39/200
#  - 0s - loss: 12.2112 - mean_absolute_error: 12.2112
# Epoch 40/200
#  - 0s - loss: 12.2069 - mean_absolute_error: 12.2069
# Epoch 41/200
#  - 0s - loss: 12.2003 - mean_absolute_error: 12.2003
# Epoch 42/200
#  - 0s - loss: 12.1751 - mean_absolute_error: 12.1751
# Epoch 43/200
#  - 0s - loss: 12.1586 - mean_absolute_error: 12.1586
# Epoch 44/200
#  - 0s - loss: 12.1437 - mean_absolute_error: 12.1437
# Epoch 45/200
#  - 0s - loss: 12.1544 - mean_absolute_error: 12.1544
# Epoch 46/200
#  - 0s - loss: 12.1487 - mean_absolute_error: 12.1487
# Epoch 47/200
#  - 0s - loss: 12.1359 - mean_absolute_error: 12.1359
# Epoch 48/200
#  - 0s - loss: 12.1427 - mean_absolute_error: 12.1427
# Epoch 49/200
#  - 0s - loss: 12.1176 - mean_absolute_error: 12.1176
# Epoch 50/200
#  - 0s - loss: 12.1177 - mean_absolute_error: 12.1177
# Epoch 51/200
#  - 0s - loss: 12.0966 - mean_absolute_error: 12.0966
# Epoch 52/200
#  - 0s - loss: 12.0686 - mean_absolute_error: 12.0686
# Epoch 53/200
#  - 0s - loss: 12.0880 - mean_absolute_error: 12.0880
# Epoch 54/200
#  - 0s - loss: 12.0583 - mean_absolute_error: 12.0583
# Epoch 55/200
#  - 0s - loss: 12.0390 - mean_absolute_error: 12.0390
# Epoch 56/200
#  - 0s - loss: 12.0288 - mean_absolute_error: 12.0288
# Epoch 57/200
#  - 0s - loss: 12.0185 - mean_absolute_error: 12.0185
# Epoch 58/200
#  - 0s - loss: 11.9960 - mean_absolute_error: 11.9960
# Epoch 59/200
#  - 0s - loss: 11.9909 - mean_absolute_error: 11.9909
# Epoch 60/200
#  - 0s - loss: 11.9711 - mean_absolute_error: 11.9711
# Epoch 61/200
#  - 0s - loss: 11.9510 - mean_absolute_error: 11.9510
# Epoch 62/200
#  - 0s - loss: 11.9421 - mean_absolute_error: 11.9421
# Epoch 63/200
#  - 0s - loss: 11.9144 - mean_absolute_error: 11.9144
# Epoch 64/200
#  - 0s - loss: 11.9319 - mean_absolute_error: 11.9319
# Epoch 65/200
#  - 0s - loss: 11.8933 - mean_absolute_error: 11.8933
# Epoch 66/200
#  - 0s - loss: 11.8916 - mean_absolute_error: 11.8916
# Epoch 67/200
#  - 0s - loss: 11.8872 - mean_absolute_error: 11.8872
# Epoch 68/200
#  - 0s - loss: 11.8718 - mean_absolute_error: 11.8718
# Epoch 69/200
#  - 0s - loss: 11.8271 - mean_absolute_error: 11.8271
# Epoch 70/200
#  - 0s - loss: 11.8249 - mean_absolute_error: 11.8249
# Epoch 71/200
#  - 0s - loss: 11.8193 - mean_absolute_error: 11.8193
# Epoch 72/200
#  - 0s - loss: 11.8394 - mean_absolute_error: 11.8394
# Epoch 73/200
#  - 0s - loss: 11.7676 - mean_absolute_error: 11.7676
# Epoch 74/200
#  - 0s - loss: 11.8107 - mean_absolute_error: 11.8107
# Epoch 75/200
#  - 0s - loss: 11.7425 - mean_absolute_error: 11.7425
# Epoch 76/200
#  - 0s - loss: 11.7450 - mean_absolute_error: 11.7450
# Epoch 77/200
#  - 0s - loss: 11.7441 - mean_absolute_error: 11.7441
# Epoch 78/200
#  - 0s - loss: 11.7071 - mean_absolute_error: 11.7071
# Epoch 79/200
#  - 0s - loss: 11.7220 - mean_absolute_error: 11.7220
# Epoch 80/200
#  - 0s - loss: 11.6956 - mean_absolute_error: 11.6956
# Epoch 81/200
#  - 0s - loss: 11.7103 - mean_absolute_error: 11.7103
# Epoch 82/200
#  - 0s - loss: 11.6561 - mean_absolute_error: 11.6561
# Epoch 83/200
#  - 0s - loss: 11.6253 - mean_absolute_error: 11.6253
# Epoch 84/200
#  - 0s - loss: 11.6296 - mean_absolute_error: 11.6296
# Epoch 85/200
#  - 0s - loss: 11.5940 - mean_absolute_error: 11.5940
# Epoch 86/200
#  - 0s - loss: 11.5940 - mean_absolute_error: 11.5940
# Epoch 87/200
#  - 0s - loss: 11.5705 - mean_absolute_error: 11.5705
# Epoch 88/200
#  - 0s - loss: 11.5812 - mean_absolute_error: 11.5812
# Epoch 89/200
#  - 0s - loss: 11.5368 - mean_absolute_error: 11.5368
# Epoch 90/200
#  - 0s - loss: 11.5162 - mean_absolute_error: 11.5162
# Epoch 91/200
#  - 0s - loss: 11.5163 - mean_absolute_error: 11.5163
# Epoch 92/200
#  - 0s - loss: 11.4941 - mean_absolute_error: 11.4941
# Epoch 93/200
#  - 0s - loss: 11.4919 - mean_absolute_error: 11.4919
# Epoch 94/200
#  - 0s - loss: 11.4392 - mean_absolute_error: 11.4392
# Epoch 95/200
#  - 0s - loss: 11.4644 - mean_absolute_error: 11.4644
# Epoch 96/200
#  - 0s - loss: 11.4418 - mean_absolute_error: 11.4418
# Epoch 97/200
#  - 0s - loss: 11.3971 - mean_absolute_error: 11.3971
# Epoch 98/200
#  - 0s - loss: 11.4216 - mean_absolute_error: 11.4216
# Epoch 99/200
#  - 0s - loss: 11.3890 - mean_absolute_error: 11.3890
# Epoch 100/200
#  - 0s - loss: 11.4011 - mean_absolute_error: 11.4011
# Epoch 101/200
#  - 0s - loss: 11.3740 - mean_absolute_error: 11.3740
# Epoch 102/200
#  - 0s - loss: 11.3779 - mean_absolute_error: 11.3779
# Epoch 103/200
#  - 0s - loss: 11.3230 - mean_absolute_error: 11.3230
# Epoch 104/200
#  - 0s - loss: 11.3159 - mean_absolute_error: 11.3159
# Epoch 105/200
#  - 0s - loss: 11.3158 - mean_absolute_error: 11.3158
# Epoch 106/200
#  - 0s - loss: 11.2846 - mean_absolute_error: 11.2846
# Epoch 107/200
#  - 0s - loss: 11.2865 - mean_absolute_error: 11.2865
# Epoch 108/200
#  - 0s - loss: 11.2723 - mean_absolute_error: 11.2723
# Epoch 109/200
#  - 0s - loss: 11.2285 - mean_absolute_error: 11.2285
# Epoch 110/200
#  - 0s - loss: 11.2407 - mean_absolute_error: 11.2407
# Epoch 111/200
#  - 0s - loss: 11.2002 - mean_absolute_error: 11.2002
# Epoch 112/200
#  - 0s - loss: 11.2563 - mean_absolute_error: 11.2563
# Epoch 113/200
#  - 0s - loss: 11.1674 - mean_absolute_error: 11.1674
# Epoch 114/200
#  - 0s - loss: 11.1932 - mean_absolute_error: 11.1932
# Epoch 115/200
#  - 0s - loss: 11.1781 - mean_absolute_error: 11.1781
# Epoch 116/200
#  - 0s - loss: 11.1598 - mean_absolute_error: 11.1598
# Epoch 117/200
#  - 0s - loss: 11.1333 - mean_absolute_error: 11.1333
# Epoch 118/200
#  - 0s - loss: 11.1007 - mean_absolute_error: 11.1007
# Epoch 119/200
#  - 0s - loss: 11.0974 - mean_absolute_error: 11.0974
# Epoch 120/200
#  - 0s - loss: 11.0513 - mean_absolute_error: 11.0513
# Epoch 121/200
#  - 0s - loss: 11.0505 - mean_absolute_error: 11.0505
# Epoch 122/200
#  - 0s - loss: 11.0340 - mean_absolute_error: 11.0340
# Epoch 123/200
#  - 0s - loss: 10.9960 - mean_absolute_error: 10.9960
# Epoch 124/200
#  - 0s - loss: 11.0378 - mean_absolute_error: 11.0378
# Epoch 125/200
#  - 0s - loss: 11.0006 - mean_absolute_error: 11.0006
# Epoch 126/200
#  - 0s - loss: 10.9897 - mean_absolute_error: 10.9897
# Epoch 127/200
#  - 0s - loss: 10.9667 - mean_absolute_error: 10.9667
# Epoch 128/200
#  - 0s - loss: 10.9533 - mean_absolute_error: 10.9533
# Epoch 129/200
#  - 0s - loss: 10.9209 - mean_absolute_error: 10.9209
# Epoch 130/200
#  - 0s - loss: 10.9084 - mean_absolute_error: 10.9084
# Epoch 131/200
#  - 0s - loss: 10.8905 - mean_absolute_error: 10.8905
# Epoch 132/200
#  - 0s - loss: 10.9193 - mean_absolute_error: 10.9193
# Epoch 133/200
#  - 0s - loss: 10.8721 - mean_absolute_error: 10.8721
# Epoch 134/200
#  - 0s - loss: 10.8470 - mean_absolute_error: 10.8470
# Epoch 135/200
#  - 0s - loss: 10.8488 - mean_absolute_error: 10.8488
# Epoch 136/200
#  - 0s - loss: 10.8466 - mean_absolute_error: 10.8466
# Epoch 137/200
#  - 0s - loss: 10.8136 - mean_absolute_error: 10.8136
# Epoch 138/200
#  - 0s - loss: 10.7903 - mean_absolute_error: 10.7903
# Epoch 139/200
#  - 0s - loss: 10.7749 - mean_absolute_error: 10.7749
# Epoch 140/200
#  - 0s - loss: 10.7525 - mean_absolute_error: 10.7525
# Epoch 141/200
#  - 0s - loss: 10.7612 - mean_absolute_error: 10.7612
# Epoch 142/200
#  - 0s - loss: 10.7334 - mean_absolute_error: 10.7334
# Epoch 143/200
#  - 0s - loss: 10.7273 - mean_absolute_error: 10.7273
# Epoch 144/200
#  - 0s - loss: 10.7097 - mean_absolute_error: 10.7097
# Epoch 145/200
#  - 0s - loss: 10.6934 - mean_absolute_error: 10.6934
# Epoch 146/200
#  - 0s - loss: 10.7180 - mean_absolute_error: 10.7180
# Epoch 147/200
#  - 0s - loss: 10.6698 - mean_absolute_error: 10.6698
# Epoch 148/200
#  - 0s - loss: 10.6530 - mean_absolute_error: 10.6530
# Epoch 149/200
#  - 0s - loss: 10.6460 - mean_absolute_error: 10.6460
# Epoch 150/200
#  - 0s - loss: 10.5898 - mean_absolute_error: 10.5898
# Epoch 151/200
#  - 0s - loss: 10.5966 - mean_absolute_error: 10.5966
# Epoch 152/200
#  - 0s - loss: 10.5749 - mean_absolute_error: 10.5749
# Epoch 153/200
#  - 0s - loss: 10.5682 - mean_absolute_error: 10.5682
# Epoch 154/200
#  - 0s - loss: 10.5626 - mean_absolute_error: 10.5626
# Epoch 155/200
#  - 0s - loss: 10.5485 - mean_absolute_error: 10.5485
# Epoch 156/200
#  - 0s - loss: 10.5066 - mean_absolute_error: 10.5066
# Epoch 157/200
#  - 0s - loss: 10.5037 - mean_absolute_error: 10.5037
# Epoch 158/200
#  - 0s - loss: 10.4702 - mean_absolute_error: 10.4702
# Epoch 159/200
#  - 0s - loss: 10.4695 - mean_absolute_error: 10.4695
# Epoch 160/200
#  - 0s - loss: 10.4643 - mean_absolute_error: 10.4643
# Epoch 161/200
#  - 0s - loss: 10.4200 - mean_absolute_error: 10.4200
# Epoch 162/200
#  - 0s - loss: 10.4071 - mean_absolute_error: 10.4071
# Epoch 163/200
#  - 0s - loss: 10.4023 - mean_absolute_error: 10.4023
# Epoch 164/200
#  - 0s - loss: 10.3755 - mean_absolute_error: 10.3755
# Epoch 165/200
#  - 0s - loss: 10.3711 - mean_absolute_error: 10.3711
# Epoch 166/200
#  - 0s - loss: 10.3329 - mean_absolute_error: 10.3329
# Epoch 167/200
#  - 0s - loss: 10.3309 - mean_absolute_error: 10.3309
# Epoch 168/200
#  - 0s - loss: 10.3076 - mean_absolute_error: 10.3076
# Epoch 169/200
#  - 0s - loss: 10.2951 - mean_absolute_error: 10.2951
# Epoch 170/200
#  - 0s - loss: 10.2684 - mean_absolute_error: 10.2684
# Epoch 171/200
#  - 0s - loss: 10.2356 - mean_absolute_error: 10.2356
# Epoch 172/200
#  - 0s - loss: 10.2324 - mean_absolute_error: 10.2324
# Epoch 173/200
#  - 0s - loss: 10.1993 - mean_absolute_error: 10.1993
# Epoch 174/200
#  - 1s - loss: 10.2071 - mean_absolute_error: 10.2071
# Epoch 175/200
#  - 0s - loss: 10.2147 - mean_absolute_error: 10.2147
# Epoch 176/200
#  - 0s - loss: 10.1621 - mean_absolute_error: 10.1621
# Epoch 177/200
#  - 0s - loss: 10.1368 - mean_absolute_error: 10.1368
# Epoch 178/200
#  - 0s - loss: 10.1627 - mean_absolute_error: 10.1627
# Epoch 179/200
#  - 0s - loss: 10.1227 - mean_absolute_error: 10.1227
# Epoch 180/200
#  - 0s - loss: 10.0778 - mean_absolute_error: 10.0778
# Epoch 181/200
#  - 0s - loss: 10.0804 - mean_absolute_error: 10.0804
# Epoch 182/200
#  - 0s - loss: 10.0449 - mean_absolute_error: 10.0449
# Epoch 183/200
#  - 0s - loss: 10.0394 - mean_absolute_error: 10.0394
# Epoch 184/200
#  - 0s - loss: 10.0048 - mean_absolute_error: 10.0048
# Epoch 185/200
#  - 0s - loss: 9.9750 - mean_absolute_error: 9.9750
# Epoch 186/200
#  - 0s - loss: 9.9586 - mean_absolute_error: 9.9586
# Epoch 187/200
#  - 0s - loss: 9.9764 - mean_absolute_error: 9.9764
# Epoch 188/200
#  - 0s - loss: 9.9162 - mean_absolute_error: 9.9162
# Epoch 189/200
#  - 0s - loss: 9.9268 - mean_absolute_error: 9.9268
# Epoch 190/200
#  - 0s - loss: 9.8959 - mean_absolute_error: 9.8959
# Epoch 191/200
#  - 0s - loss: 9.8712 - mean_absolute_error: 9.8712
# Epoch 192/200
#  - 0s - loss: 9.8464 - mean_absolute_error: 9.8464
# Epoch 193/200
#  - 0s - loss: 9.8520 - mean_absolute_error: 9.8520
# Epoch 194/200
#  - 0s - loss: 9.8317 - mean_absolute_error: 9.8317
# Epoch 195/200
#  - 0s - loss: 9.8002 - mean_absolute_error: 9.8002
# Epoch 196/200
#  - 0s - loss: 9.7516 - mean_absolute_error: 9.7516
# Epoch 197/200
#  - 0s - loss: 9.7626 - mean_absolute_error: 9.7626
# Epoch 198/200
#  - 0s - loss: 9.7603 - mean_absolute_error: 9.7603
# Epoch 199/200
#  - 0s - loss: 9.7036 - mean_absolute_error: 9.7036
# Epoch 200/200
#  - 0s - loss: 9.7123 - mean_absolute_error: 9.7123

# %%
# finding the normality of the distribution of the grid search tuned Neural networks

# %%
# compare samples
stat, p = normaltest(L_nn_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Grid Serch tuned Neural Networks follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Grid Search  tuned Neural Networks does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=1.550, p=0.461
# The Samples from the  Grid Serch tuned Neural Networks follow a Gaussian distribution (fail to reject H0)

# %%
#RANDOM SEARCH CV:

# %%
time12=time.time()#start time for computation
def create_model(neurons=256,activation='relu'):
	# create model

    NN_model = Sequential()
    # The Input Layer :
    NN_model.add(Dense(neurons, input_dim=24,kernel_initializer='uniform', activation=activation))
    # The Hidden Layers :
    NN_model.add(Dense(neurons, kernel_initializer='uniform',activation=activation))
    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='uniform'))
    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    #NN_model.summary()     
    return NN_model
 
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# create model
model = KerasRegressor(build_fn=create_model, verbose=0)
activation=['relu','tanh','linear'] #creating search space for activation units
neurons=[5,10,15,20,50,100,200,300,400] #creating search space for neurons
epochs = [50, 100, 150,200,300] #creating search space for epochs
batches = [5, 10, 20,50,100]#creating search space for number of batches
param_grid = dict(neurons=neurons,activation=activation,batch_size=batches,epochs=epochs)
random_search_nn = RandomizedSearchCV(estimator=model, param_distributions=param_grid,scoring='neg_mean_absolute_error',verbose=2,n_jobs=-1,random_state=3)
random_nn = random_search_nn.fit(X_train_new, Y_train)
time13=time.time()- time12#end time for computation
# Out:
# C:\Users\Data Scientist-A1\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done  23 out of  30 | elapsed:  2.4min remaining:   42.9s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  2.8min finished

# %%
print("Best MAE score from the Hyper Parameter tuning on training data: %0.3f" % random_nn.best_score_)
print("Best hyepr parameters on Neural Network Regressor using Random Search:")
random_nn.best_params_
# Out:
# Best MAE score from the Hyper Parameter tuning on training data: -12.707
# Best hyepr parameters on Neural Network Regressor using Random Search:
# {'neurons': 15, 'epochs': 200, 'batch_size': 100, 'activation': 'relu'}

# %%
def create_model():
	# create model

    NN_model = Sequential()
    # The Input Layer :
    NN_model.add(Dense(15, input_dim=24,kernel_initializer='uniform', activation='relu'))
    # The Hidden Layers :
    NN_model.add(Dense(15, kernel_initializer='uniform',activation='relu'))
    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='uniform'))
    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    #NN_model.summary()
    return NN_model
 
# create model
model_nn_rs = KerasRegressor(build_fn=create_model, verbose=2,batch_size=100,epochs=200)
model_nn_rs.fit(X_train_new,Y_train)
nn_rs_test_pred= model_nn_rs.predict(X_test_new)
print('The MAE for the Neural Networks with Random Search tuning on the Testing Data is : {:.4f} \n'.format(mean_absolute_error(Y_test,nn_rs_test_pred)))
# Out:
# Epoch 1/200
#  - 1s - loss: 127.2127 - mean_absolute_error: 127.2127
# Epoch 2/200
#  - 0s - loss: 126.4831 - mean_absolute_error: 126.4831
# Epoch 3/200
#  - 0s - loss: 122.8421 - mean_absolute_error: 122.8421
# Epoch 4/200
#  - 0s - loss: 112.2894 - mean_absolute_error: 112.2894
# Epoch 5/200
#  - 0s - loss: 90.0897 - mean_absolute_error: 90.0897
# Epoch 6/200
#  - 0s - loss: 65.7943 - mean_absolute_error: 65.7943
# Epoch 7/200
#  - 0s - loss: 58.0858 - mean_absolute_error: 58.0858
# Epoch 8/200
#  - 0s - loss: 55.3549 - mean_absolute_error: 55.3549
# Epoch 9/200
#  - 0s - loss: 52.9892 - mean_absolute_error: 52.9892
# Epoch 10/200
#  - 0s - loss: 50.5072 - mean_absolute_error: 50.5072
# Epoch 11/200
#  - 0s - loss: 47.9662 - mean_absolute_error: 47.9662
# Epoch 12/200
#  - 0s - loss: 45.5410 - mean_absolute_error: 45.5410
# Epoch 13/200
#  - 0s - loss: 43.3952 - mean_absolute_error: 43.3952
# Epoch 14/200
#  - 0s - loss: 41.4864 - mean_absolute_error: 41.4864
# Epoch 15/200
#  - 0s - loss: 39.6599 - mean_absolute_error: 39.6599
# Epoch 16/200
#  - 0s - loss: 37.8674 - mean_absolute_error: 37.8674
# Epoch 17/200
#  - 0s - loss: 36.0254 - mean_absolute_error: 36.0254
# Epoch 18/200
#  - 0s - loss: 34.1220 - mean_absolute_error: 34.1220
# Epoch 19/200
#  - 0s - loss: 32.0973 - mean_absolute_error: 32.0973
# Epoch 20/200
#  - 0s - loss: 29.9759 - mean_absolute_error: 29.9759
# Epoch 21/200
#  - 0s - loss: 27.8280 - mean_absolute_error: 27.8280
# Epoch 22/200
#  - 0s - loss: 25.8494 - mean_absolute_error: 25.8494
# Epoch 23/200
#  - 0s - loss: 24.1118 - mean_absolute_error: 24.1118
# Epoch 24/200
#  - 0s - loss: 22.7252 - mean_absolute_error: 22.7252
# Epoch 25/200
#  - 0s - loss: 21.5708 - mean_absolute_error: 21.5708
# Epoch 26/200
#  - 0s - loss: 20.5974 - mean_absolute_error: 20.5974
# Epoch 27/200
#  - 0s - loss: 19.6970 - mean_absolute_error: 19.6970
# Epoch 28/200
#  - 0s - loss: 18.8968 - mean_absolute_error: 18.8968
# Epoch 29/200
#  - 0s - loss: 18.1346 - mean_absolute_error: 18.1346
# Epoch 30/200
#  - 0s - loss: 17.4273 - mean_absolute_error: 17.4273
# Epoch 31/200
#  - 0s - loss: 16.7624 - mean_absolute_error: 16.7624
# Epoch 32/200
#  - 0s - loss: 16.1177 - mean_absolute_error: 16.1177
# Epoch 33/200
#  - 0s - loss: 15.5542 - mean_absolute_error: 15.5542
# Epoch 34/200
#  - 0s - loss: 15.0397 - mean_absolute_error: 15.0397
# Epoch 35/200
#  - 0s - loss: 14.6231 - mean_absolute_error: 14.6231
# Epoch 36/200
#  - 0s - loss: 14.2578 - mean_absolute_error: 14.2578
# Epoch 37/200
#  - 0s - loss: 13.9588 - mean_absolute_error: 13.9588
# Epoch 38/200
#  - 0s - loss: 13.7231 - mean_absolute_error: 13.7231
# Epoch 39/200
#  - 0s - loss: 13.5042 - mean_absolute_error: 13.5042
# Epoch 40/200
#  - 0s - loss: 13.3306 - mean_absolute_error: 13.3306
# Epoch 41/200
#  - 0s - loss: 13.2080 - mean_absolute_error: 13.2080
# Epoch 42/200
#  - 0s - loss: 13.1175 - mean_absolute_error: 13.1175
# Epoch 43/200
#  - 0s - loss: 13.0301 - mean_absolute_error: 13.0301
# Epoch 44/200
#  - 0s - loss: 12.9247 - mean_absolute_error: 12.9247
# Epoch 45/200
#  - 0s - loss: 12.8845 - mean_absolute_error: 12.8845
# Epoch 46/200
#  - 0s - loss: 12.8434 - mean_absolute_error: 12.8434
# Epoch 47/200
#  - 0s - loss: 12.8034 - mean_absolute_error: 12.8034
# Epoch 48/200
#  - 0s - loss: 12.7376 - mean_absolute_error: 12.7376
# Epoch 49/200
#  - 0s - loss: 12.7342 - mean_absolute_error: 12.7342
# Epoch 50/200
#  - 0s - loss: 12.6759 - mean_absolute_error: 12.6759
# Epoch 51/200
#  - 0s - loss: 12.6985 - mean_absolute_error: 12.6985
# Epoch 52/200
#  - 0s - loss: 12.6586 - mean_absolute_error: 12.6586
# Epoch 53/200
#  - 0s - loss: 12.6455 - mean_absolute_error: 12.6455
# Epoch 54/200
#  - 0s - loss: 12.6054 - mean_absolute_error: 12.6054
# Epoch 55/200
#  - 0s - loss: 12.6653 - mean_absolute_error: 12.6653
# Epoch 56/200
#  - 0s - loss: 12.5816 - mean_absolute_error: 12.5816
# Epoch 57/200
#  - 0s - loss: 12.6023 - mean_absolute_error: 12.6023
# Epoch 58/200
#  - 0s - loss: 12.5791 - mean_absolute_error: 12.5791
# Epoch 59/200
#  - 0s - loss: 12.5826 - mean_absolute_error: 12.5826
# Epoch 60/200
#  - 0s - loss: 12.5541 - mean_absolute_error: 12.5541
# Epoch 61/200
#  - 0s - loss: 12.5416 - mean_absolute_error: 12.5416
# Epoch 62/200
#  - 0s - loss: 12.5241 - mean_absolute_error: 12.5241
# Epoch 63/200
#  - 0s - loss: 12.5267 - mean_absolute_error: 12.5267
# Epoch 64/200
#  - 0s - loss: 12.5498 - mean_absolute_error: 12.5498
# Epoch 65/200
#  - 0s - loss: 12.5722 - mean_absolute_error: 12.5722
# Epoch 66/200
#  - 0s - loss: 12.5168 - mean_absolute_error: 12.5168
# Epoch 67/200
#  - 0s - loss: 12.5165 - mean_absolute_error: 12.5165
# Epoch 68/200
#  - 0s - loss: 12.5677 - mean_absolute_error: 12.5677
# Epoch 69/200
#  - 0s - loss: 12.5550 - mean_absolute_error: 12.5550
# Epoch 70/200
#  - 0s - loss: 12.4993 - mean_absolute_error: 12.4993
# Epoch 71/200
#  - 0s - loss: 12.4912 - mean_absolute_error: 12.4912
# Epoch 72/200
#  - 0s - loss: 12.4895 - mean_absolute_error: 12.4895
# Epoch 73/200
#  - 0s - loss: 12.4983 - mean_absolute_error: 12.4983
# Epoch 74/200
#  - 0s - loss: 12.4845 - mean_absolute_error: 12.4845
# Epoch 75/200
#  - 0s - loss: 12.4963 - mean_absolute_error: 12.4963
# Epoch 76/200
#  - 0s - loss: 12.4937 - mean_absolute_error: 12.4937
# Epoch 77/200
#  - 0s - loss: 12.4864 - mean_absolute_error: 12.4864
# Epoch 78/200
#  - 0s - loss: 12.5065 - mean_absolute_error: 12.5065
# Epoch 79/200
#  - 0s - loss: 12.4686 - mean_absolute_error: 12.4686
# Epoch 80/200
#  - 0s - loss: 12.4777 - mean_absolute_error: 12.4777
# Epoch 81/200
#  - 0s - loss: 12.4772 - mean_absolute_error: 12.4772
# Epoch 82/200
#  - 0s - loss: 12.4612 - mean_absolute_error: 12.4612
# Epoch 83/200
#  - 0s - loss: 12.4739 - mean_absolute_error: 12.4739
# Epoch 84/200
#  - 0s - loss: 12.4604 - mean_absolute_error: 12.4604
# Epoch 85/200
#  - 0s - loss: 12.4502 - mean_absolute_error: 12.4502
# Epoch 86/200
#  - 0s - loss: 12.4587 - mean_absolute_error: 12.4587
# Epoch 87/200
#  - 0s - loss: 12.4609 - mean_absolute_error: 12.4609
# Epoch 88/200
#  - 0s - loss: 12.4575 - mean_absolute_error: 12.4575
# Epoch 89/200
#  - 0s - loss: 12.4363 - mean_absolute_error: 12.4363
# Epoch 90/200
#  - 0s - loss: 12.4587 - mean_absolute_error: 12.4587
# Epoch 91/200
#  - 0s - loss: 12.4486 - mean_absolute_error: 12.4486
# Epoch 92/200
#  - 0s - loss: 12.4397 - mean_absolute_error: 12.4397
# Epoch 93/200
#  - 0s - loss: 12.4249 - mean_absolute_error: 12.4249
# Epoch 94/200
#  - 0s - loss: 12.4447 - mean_absolute_error: 12.4447
# Epoch 95/200
#  - 0s - loss: 12.4364 - mean_absolute_error: 12.4364
# Epoch 96/200
#  - 0s - loss: 12.4195 - mean_absolute_error: 12.4195
# Epoch 97/200
#  - 0s - loss: 12.4503 - mean_absolute_error: 12.4503
# Epoch 98/200
#  - 0s - loss: 12.4271 - mean_absolute_error: 12.4271
# Epoch 99/200
#  - 0s - loss: 12.4695 - mean_absolute_error: 12.4695
# Epoch 100/200
#  - 0s - loss: 12.4525 - mean_absolute_error: 12.4525
# Epoch 101/200
#  - 0s - loss: 12.4507 - mean_absolute_error: 12.4507
# Epoch 102/200
#  - 0s - loss: 12.4238 - mean_absolute_error: 12.4238
# Epoch 103/200
#  - 0s - loss: 12.4202 - mean_absolute_error: 12.4202
# Epoch 104/200
#  - 0s - loss: 12.4379 - mean_absolute_error: 12.4379
# Epoch 105/200
#  - 0s - loss: 12.4423 - mean_absolute_error: 12.4423
# Epoch 106/200
#  - 0s - loss: 12.4177 - mean_absolute_error: 12.4177
# Epoch 107/200
#  - 0s - loss: 12.4120 - mean_absolute_error: 12.4120
# Epoch 108/200
#  - 0s - loss: 12.4271 - mean_absolute_error: 12.4271
# Epoch 109/200
#  - 0s - loss: 12.4117 - mean_absolute_error: 12.4117
# Epoch 110/200
#  - 0s - loss: 12.4130 - mean_absolute_error: 12.4130
# Epoch 111/200
#  - 0s - loss: 12.4384 - mean_absolute_error: 12.4384
# Epoch 112/200
#  - 0s - loss: 12.4202 - mean_absolute_error: 12.4202
# Epoch 113/200
#  - 0s - loss: 12.4104 - mean_absolute_error: 12.4104
# Epoch 114/200
#  - 0s - loss: 12.4383 - mean_absolute_error: 12.4383
# Epoch 115/200
#  - 0s - loss: 12.3997 - mean_absolute_error: 12.3997
# Epoch 116/200
#  - 0s - loss: 12.3959 - mean_absolute_error: 12.3959
# Epoch 117/200
#  - 0s - loss: 12.4060 - mean_absolute_error: 12.4060
# Epoch 118/200
#  - 0s - loss: 12.4004 - mean_absolute_error: 12.4004
# Epoch 119/200
#  - 0s - loss: 12.3993 - mean_absolute_error: 12.3993
# Epoch 120/200
#  - 0s - loss: 12.4126 - mean_absolute_error: 12.4126
# Epoch 121/200
#  - 0s - loss: 12.3877 - mean_absolute_error: 12.3877
# Epoch 122/200
#  - 0s - loss: 12.4029 - mean_absolute_error: 12.4029
# Epoch 123/200
#  - 0s - loss: 12.3909 - mean_absolute_error: 12.3909
# Epoch 124/200
#  - 0s - loss: 12.4009 - mean_absolute_error: 12.4009
# Epoch 125/200
#  - 0s - loss: 12.3938 - mean_absolute_error: 12.3938
# Epoch 126/200
#  - 0s - loss: 12.3979 - mean_absolute_error: 12.3979
# Epoch 127/200
#  - 0s - loss: 12.3878 - mean_absolute_error: 12.3878
# Epoch 128/200
#  - 0s - loss: 12.3838 - mean_absolute_error: 12.3838
# Epoch 129/200
#  - 0s - loss: 12.3889 - mean_absolute_error: 12.3889
# Epoch 130/200
#  - 0s - loss: 12.3733 - mean_absolute_error: 12.3733
# Epoch 131/200
#  - 0s - loss: 12.4115 - mean_absolute_error: 12.4115
# Epoch 132/200
#  - 0s - loss: 12.3928 - mean_absolute_error: 12.3928
# Epoch 133/200
#  - 0s - loss: 12.3980 - mean_absolute_error: 12.3980
# Epoch 134/200
#  - 0s - loss: 12.3897 - mean_absolute_error: 12.3897
# Epoch 135/200
#  - 0s - loss: 12.3679 - mean_absolute_error: 12.3679
# Epoch 136/200
#  - 0s - loss: 12.3862 - mean_absolute_error: 12.3862
# Epoch 137/200
#  - 0s - loss: 12.3668 - mean_absolute_error: 12.3668
# Epoch 138/200
#  - 0s - loss: 12.3840 - mean_absolute_error: 12.3840
# Epoch 139/200
#  - 0s - loss: 12.3579 - mean_absolute_error: 12.3579
# Epoch 140/200
#  - 0s - loss: 12.3888 - mean_absolute_error: 12.3888
# Epoch 141/200
#  - 0s - loss: 12.3713 - mean_absolute_error: 12.3713
# Epoch 142/200
#  - 0s - loss: 12.3665 - mean_absolute_error: 12.3665
# Epoch 143/200
#  - 0s - loss: 12.3634 - mean_absolute_error: 12.3634
# Epoch 144/200
#  - 0s - loss: 12.3706 - mean_absolute_error: 12.3706
# Epoch 145/200
#  - 0s - loss: 12.3762 - mean_absolute_error: 12.3762
# Epoch 146/200
#  - 0s - loss: 12.3634 - mean_absolute_error: 12.3634
# Epoch 147/200
#  - 0s - loss: 12.3777 - mean_absolute_error: 12.3777
# Epoch 148/200
#  - 0s - loss: 12.3643 - mean_absolute_error: 12.3643
# Epoch 149/200
#  - 0s - loss: 12.3721 - mean_absolute_error: 12.3721
# Epoch 150/200
#  - 0s - loss: 12.3566 - mean_absolute_error: 12.3566
# Epoch 151/200
#  - 0s - loss: 12.3720 - mean_absolute_error: 12.3720
# Epoch 152/200
#  - 0s - loss: 12.3725 - mean_absolute_error: 12.3725
# Epoch 153/200
#  - 0s - loss: 12.3470 - mean_absolute_error: 12.3470
# Epoch 154/200
#  - 0s - loss: 12.3428 - mean_absolute_error: 12.3428
# Epoch 155/200
#  - 0s - loss: 12.3598 - mean_absolute_error: 12.3598
# Epoch 156/200
#  - 0s - loss: 12.3528 - mean_absolute_error: 12.3528
# Epoch 157/200
#  - 0s - loss: 12.3491 - mean_absolute_error: 12.3491
# Epoch 158/200
#  - 0s - loss: 12.3642 - mean_absolute_error: 12.3642
# Epoch 159/200
#  - 0s - loss: 12.3629 - mean_absolute_error: 12.3629
# Epoch 160/200
#  - 0s - loss: 12.3472 - mean_absolute_error: 12.3472
# Epoch 161/200
#  - 0s - loss: 12.3636 - mean_absolute_error: 12.3636
# Epoch 162/200
#  - 0s - loss: 12.3495 - mean_absolute_error: 12.3495
# Epoch 163/200
#  - 0s - loss: 12.3279 - mean_absolute_error: 12.3279
# Epoch 164/200
#  - 0s - loss: 12.3366 - mean_absolute_error: 12.3366
# Epoch 165/200
#  - 0s - loss: 12.3508 - mean_absolute_error: 12.3508
# Epoch 166/200
#  - 0s - loss: 12.3665 - mean_absolute_error: 12.3665
# Epoch 167/200
#  - 0s - loss: 12.3582 - mean_absolute_error: 12.3582
# Epoch 168/200
#  - 0s - loss: 12.3439 - mean_absolute_error: 12.3439
# Epoch 169/200
#  - 0s - loss: 12.3344 - mean_absolute_error: 12.3344
# Epoch 170/200
#  - 0s - loss: 12.3502 - mean_absolute_error: 12.3502
# Epoch 171/200
#  - 0s - loss: 12.3462 - mean_absolute_error: 12.3462
# Epoch 172/200
#  - 0s - loss: 12.3296 - mean_absolute_error: 12.3296
# Epoch 173/200
#  - 0s - loss: 12.3325 - mean_absolute_error: 12.3325
# Epoch 174/200
#  - 0s - loss: 12.3290 - mean_absolute_error: 12.3290
# Epoch 175/200
#  - 0s - loss: 12.3472 - mean_absolute_error: 12.3472
# Epoch 176/200
#  - 0s - loss: 12.3232 - mean_absolute_error: 12.3232
# Epoch 177/200
#  - 0s - loss: 12.3298 - mean_absolute_error: 12.3298
# Epoch 178/200
#  - 0s - loss: 12.3329 - mean_absolute_error: 12.3329
# Epoch 179/200
#  - 0s - loss: 12.3207 - mean_absolute_error: 12.3207
# Epoch 180/200
#  - 0s - loss: 12.3382 - mean_absolute_error: 12.3382
# Epoch 181/200
#  - 0s - loss: 12.3252 - mean_absolute_error: 12.3252
# Epoch 182/200
#  - 0s - loss: 12.3510 - mean_absolute_error: 12.3510
# Epoch 183/200
#  - 0s - loss: 12.3715 - mean_absolute_error: 12.3715
# Epoch 184/200
#  - 0s - loss: 12.3220 - mean_absolute_error: 12.3220
# Epoch 185/200
#  - 0s - loss: 12.3552 - mean_absolute_error: 12.3552
# Epoch 186/200
#  - 0s - loss: 12.3308 - mean_absolute_error: 12.3308
# Epoch 187/200
#  - 0s - loss: 12.3242 - mean_absolute_error: 12.3242
# Epoch 188/200
#  - 0s - loss: 12.3303 - mean_absolute_error: 12.3303
# Epoch 189/200
#  - 0s - loss: 12.3304 - mean_absolute_error: 12.3304
# Epoch 190/200
#  - 0s - loss: 12.3333 - mean_absolute_error: 12.3333
# Epoch 191/200
#  - 0s - loss: 12.3238 - mean_absolute_error: 12.3238
# Epoch 192/200
#  - 0s - loss: 12.3366 - mean_absolute_error: 12.3366
# Epoch 193/200
#  - 0s - loss: 12.3361 - mean_absolute_error: 12.3361
# Epoch 194/200
#  - 0s - loss: 12.3253 - mean_absolute_error: 12.3253
# Epoch 195/200
#  - 0s - loss: 12.3424 - mean_absolute_error: 12.3424
# Epoch 196/200
#  - 0s - loss: 12.3193 - mean_absolute_error: 12.3193
# Epoch 197/200
#  - 0s - loss: 12.3311 - mean_absolute_error: 12.3311
# Epoch 198/200
#  - 0s - loss: 12.3437 - mean_absolute_error: 12.3437
# Epoch 199/200
#  - 0s - loss: 12.3175 - mean_absolute_error: 12.3175
# Epoch 200/200
#  - 0s - loss: 12.3171 - mean_absolute_error: 12.3171
# The MAE for the Neural Networks with Random Search tuning on the Testing Data is : 12.6927

# %%
#FINDING THE DISTIBUTION OF THE 30 ITERATION RESULTS FOR THE RANDOM SEARCH TUNED NEURAL NETWORKS:

# %%
L_nn_rs=[]

# %%
for i in range(0,30):
    model_nn_rs.fit(X_train_new, Y_train)
    model_nn_test_pred_rs = model_nn_rs.predict(X_test_new)
    Q=abs(model_nn_test_pred_rs-Y_test)
    M= mean_absolute_error(Y_test, model_nn_test_pred_rs)
    L_nn_rs.append(mean_absolute_error(Y_test, model_nn_test_pred_rs))
# Out:
# Epoch 1/200
#  - 1s - loss: 127.1946 - mean_absolute_error: 127.1946
# Epoch 2/200
#  - 0s - loss: 126.2738 - mean_absolute_error: 126.2738
# Epoch 3/200
#  - 0s - loss: 122.0313 - mean_absolute_error: 122.0313
# Epoch 4/200
#  - 0s - loss: 110.6682 - mean_absolute_error: 110.6682
# Epoch 5/200
#  - 0s - loss: 88.3852 - mean_absolute_error: 88.3852
# Epoch 6/200
#  - 0s - loss: 65.5905 - mean_absolute_error: 65.5905
# Epoch 7/200
#  - 0s - loss: 58.1230 - mean_absolute_error: 58.1230
# Epoch 8/200
#  - 0s - loss: 55.3490 - mean_absolute_error: 55.3490
# Epoch 9/200
#  - 0s - loss: 53.0026 - mean_absolute_error: 53.0026
# Epoch 10/200
#  - 0s - loss: 50.5570 - mean_absolute_error: 50.5570
# Epoch 11/200
#  - 0s - loss: 47.9921 - mean_absolute_error: 47.9921
# Epoch 12/200
#  - 0s - loss: 45.5233 - mean_absolute_error: 45.5233
# Epoch 13/200
#  - 0s - loss: 43.3531 - mean_absolute_error: 43.3531
# Epoch 14/200
#  - 0s - loss: 41.4510 - mean_absolute_error: 41.4510
# Epoch 15/200
#  - 0s - loss: 39.6045 - mean_absolute_error: 39.6045
# Epoch 16/200
#  - 0s - loss: 37.7890 - mean_absolute_error: 37.7890
# Epoch 17/200
#  - 0s - loss: 35.9438 - mean_absolute_error: 35.9438
# Epoch 18/200
#  - 0s - loss: 34.0464 - mean_absolute_error: 34.0464
# Epoch 19/200
#  - 0s - loss: 32.0380 - mean_absolute_error: 32.0380
# Epoch 20/200
#  - 0s - loss: 29.9369 - mean_absolute_error: 29.9369
# Epoch 21/200
#  - 0s - loss: 27.8674 - mean_absolute_error: 27.8674
# Epoch 22/200
#  - 0s - loss: 25.8914 - mean_absolute_error: 25.8914
# Epoch 23/200
#  - 0s - loss: 24.2337 - mean_absolute_error: 24.2337
# Epoch 24/200
#  - 0s - loss: 22.9282 - mean_absolute_error: 22.9282
# Epoch 25/200
#  - 0s - loss: 21.8944 - mean_absolute_error: 21.8944
# Epoch 26/200
#  - 0s - loss: 20.9929 - mean_absolute_error: 20.9929
# Epoch 27/200
#  - 0s - loss: 20.1946 - mean_absolute_error: 20.1946
# Epoch 28/200
#  - 0s - loss: 19.4176 - mean_absolute_error: 19.4176
# Epoch 29/200
#  - 0s - loss: 18.6701 - mean_absolute_error: 18.6701
# Epoch 30/200
#  - 0s - loss: 17.9314 - mean_absolute_error: 17.9314
# Epoch 31/200
#  - 0s - loss: 17.1993 - mean_absolute_error: 17.1993
# Epoch 32/200
#  - 0s - loss: 16.5363 - mean_absolute_error: 16.5363
# Epoch 33/200
#  - 0s - loss: 15.9420 - mean_absolute_error: 15.9420
# Epoch 34/200
#  - 0s - loss: 15.4038 - mean_absolute_error: 15.4038
# Epoch 35/200
#  - 0s - loss: 14.8973 - mean_absolute_error: 14.8973
# Epoch 36/200
#  - 0s - loss: 14.4537 - mean_absolute_error: 14.4537
# Epoch 37/200
#  - 0s - loss: 14.1079 - mean_absolute_error: 14.1079
# Epoch 38/200
#  - 0s - loss: 13.7948 - mean_absolute_error: 13.7948
# Epoch 39/200
#  - 0s - loss: 13.5424 - mean_absolute_error: 13.5424
# Epoch 40/200
#  - 0s - loss: 13.3375 - mean_absolute_error: 13.3375
# Epoch 41/200
#  - 0s - loss: 13.1903 - mean_absolute_error: 13.1903
# Epoch 42/200
#  - 0s - loss: 13.0623 - mean_absolute_error: 13.0623
# Epoch 43/200
#  - 0s - loss: 12.9554 - mean_absolute_error: 12.9554
# Epoch 44/200
#  - 0s - loss: 12.8878 - mean_absolute_error: 12.8878
# Epoch 45/200
#  - 0s - loss: 12.8158 - mean_absolute_error: 12.8158
# Epoch 46/200
#  - 0s - loss: 12.7635 - mean_absolute_error: 12.7635
# Epoch 47/200
#  - 0s - loss: 12.7510 - mean_absolute_error: 12.7510
# Epoch 48/200
#  - 0s - loss: 12.7130 - mean_absolute_error: 12.7130
# Epoch 49/200
#  - 0s - loss: 12.6540 - mean_absolute_error: 12.6540
# Epoch 50/200
#  - 0s - loss: 12.6325 - mean_absolute_error: 12.6325
# Epoch 51/200
#  - 0s - loss: 12.6297 - mean_absolute_error: 12.6297
# Epoch 52/200
#  - 0s - loss: 12.6551 - mean_absolute_error: 12.6551
# Epoch 53/200
#  - 0s - loss: 12.6193 - mean_absolute_error: 12.6193
# Epoch 54/200
#  - 0s - loss: 12.5752 - mean_absolute_error: 12.5752
# Epoch 55/200
#  - 0s - loss: 12.6539 - mean_absolute_error: 12.6539
# Epoch 56/200
#  - 0s - loss: 12.5782 - mean_absolute_error: 12.5782
# Epoch 57/200
#  - 0s - loss: 12.5579 - mean_absolute_error: 12.5579
# Epoch 58/200
#  - 0s - loss: 12.5486 - mean_absolute_error: 12.5486
# Epoch 59/200
#  - 0s - loss: 12.5674 - mean_absolute_error: 12.5674
# Epoch 60/200
#  - 0s - loss: 12.5182 - mean_absolute_error: 12.5182
# Epoch 61/200
#  - 0s - loss: 12.5153 - mean_absolute_error: 12.5153
# Epoch 62/200
#  - 0s - loss: 12.5170 - mean_absolute_error: 12.5170
# Epoch 63/200
#  - 0s - loss: 12.5128 - mean_absolute_error: 12.5128
# Epoch 64/200
#  - 0s - loss: 12.5211 - mean_absolute_error: 12.5211
# Epoch 65/200
#  - 0s - loss: 12.5096 - mean_absolute_error: 12.5096
# Epoch 66/200
#  - 0s - loss: 12.4980 - mean_absolute_error: 12.4980
# Epoch 67/200
#  - 0s - loss: 12.4877 - mean_absolute_error: 12.4877
# Epoch 68/200
#  - 0s - loss: 12.4939 - mean_absolute_error: 12.4939
# Epoch 69/200
#  - 0s - loss: 12.4840 - mean_absolute_error: 12.4840
# Epoch 70/200
#  - 0s - loss: 12.4859 - mean_absolute_error: 12.4859
# Epoch 71/200
#  - 0s - loss: 12.4650 - mean_absolute_error: 12.4650
# Epoch 72/200
#  - 0s - loss: 12.5146 - mean_absolute_error: 12.5146
# Epoch 73/200
#  - 0s - loss: 12.4758 - mean_absolute_error: 12.4758
# Epoch 74/200
#  - 0s - loss: 12.4548 - mean_absolute_error: 12.4548
# Epoch 75/200
#  - 0s - loss: 12.4913 - mean_absolute_error: 12.4913
# Epoch 76/200
#  - 0s - loss: 12.4853 - mean_absolute_error: 12.4853
# Epoch 77/200
#  - 0s - loss: 12.4408 - mean_absolute_error: 12.4408
# Epoch 78/200
#  - 0s - loss: 12.4653 - mean_absolute_error: 12.4653
# Epoch 79/200
#  - 0s - loss: 12.5041 - mean_absolute_error: 12.5041
# Epoch 80/200
#  - 0s - loss: 12.4479 - mean_absolute_error: 12.4479
# Epoch 81/200
#  - 0s - loss: 12.4533 - mean_absolute_error: 12.4533
# Epoch 82/200
#  - 0s - loss: 12.4519 - mean_absolute_error: 12.4519
# Epoch 83/200
#  - 0s - loss: 12.4537 - mean_absolute_error: 12.4537
# Epoch 84/200
#  - 0s - loss: 12.4477 - mean_absolute_error: 12.4477
# Epoch 85/200
#  - 0s - loss: 12.4511 - mean_absolute_error: 12.4511
# Epoch 86/200
#  - 0s - loss: 12.4191 - mean_absolute_error: 12.4191
# Epoch 87/200
#  - 0s - loss: 12.4478 - mean_absolute_error: 12.4478
# Epoch 88/200
#  - 0s - loss: 12.4583 - mean_absolute_error: 12.4583
# Epoch 89/200
#  - 0s - loss: 12.4231 - mean_absolute_error: 12.4231
# Epoch 90/200
#  - 0s - loss: 12.4418 - mean_absolute_error: 12.4418
# Epoch 91/200
#  - 0s - loss: 12.4132 - mean_absolute_error: 12.4132
# Epoch 92/200
#  - 0s - loss: 12.4404 - mean_absolute_error: 12.4404
# Epoch 93/200
#  - 0s - loss: 12.4438 - mean_absolute_error: 12.4438
# Epoch 94/200
#  - 0s - loss: 12.4447 - mean_absolute_error: 12.4447
# Epoch 95/200
#  - 0s - loss: 12.4307 - mean_absolute_error: 12.4307
# Epoch 96/200
#  - 0s - loss: 12.4158 - mean_absolute_error: 12.4158
# Epoch 97/200
#  - 0s - loss: 12.4210 - mean_absolute_error: 12.4210
# Epoch 98/200
#  - 0s - loss: 12.4109 - mean_absolute_error: 12.4109
# Epoch 99/200
#  - 0s - loss: 12.4217 - mean_absolute_error: 12.4217
# Epoch 100/200
#  - 0s - loss: 12.4213 - mean_absolute_error: 12.4213
# Epoch 101/200
#  - 0s - loss: 12.4110 - mean_absolute_error: 12.4110
# Epoch 102/200
#  - 0s - loss: 12.4245 - mean_absolute_error: 12.4245
# Epoch 103/200
#  - 0s - loss: 12.4198 - mean_absolute_error: 12.4198
# Epoch 104/200
#  - 0s - loss: 12.4100 - mean_absolute_error: 12.4100
# Epoch 105/200
#  - 0s - loss: 12.4178 - mean_absolute_error: 12.4178
# Epoch 106/200
#  - 0s - loss: 12.4448 - mean_absolute_error: 12.4448
# Epoch 107/200
#  - 0s - loss: 12.4007 - mean_absolute_error: 12.4007
# Epoch 108/200
#  - 0s - loss: 12.4205 - mean_absolute_error: 12.4205
# Epoch 109/200
#  - 0s - loss: 12.4103 - mean_absolute_error: 12.4103
# Epoch 110/200
#  - 0s - loss: 12.4149 - mean_absolute_error: 12.4149
# Epoch 111/200
#  - 0s - loss: 12.4062 - mean_absolute_error: 12.4062
# Epoch 112/200
#  - 0s - loss: 12.4127 - mean_absolute_error: 12.4127
# Epoch 113/200
#  - 0s - loss: 12.4099 - mean_absolute_error: 12.4099
# Epoch 114/200
#  - 0s - loss: 12.4116 - mean_absolute_error: 12.4116
# Epoch 115/200
#  - 0s - loss: 12.4099 - mean_absolute_error: 12.4099
# Epoch 116/200
#  - 0s - loss: 12.4149 - mean_absolute_error: 12.4149
# Epoch 117/200
#  - 0s - loss: 12.4388 - mean_absolute_error: 12.4388
# Epoch 118/200
#  - 0s - loss: 12.4040 - mean_absolute_error: 12.4040
# Epoch 119/200
#  - 0s - loss: 12.4261 - mean_absolute_error: 12.4261
# Epoch 120/200
#  - 0s - loss: 12.3973 - mean_absolute_error: 12.3973
# Epoch 121/200
#  - 0s - loss: 12.3931 - mean_absolute_error: 12.3931
# Epoch 122/200
#  - 0s - loss: 12.4258 - mean_absolute_error: 12.4258
# Epoch 123/200
#  - 0s - loss: 12.4189 - mean_absolute_error: 12.4189
# Epoch 124/200
#  - 0s - loss: 12.3789 - mean_absolute_error: 12.3789
# Epoch 125/200
#  - 0s - loss: 12.3990 - mean_absolute_error: 12.3990
# Epoch 126/200
#  - 0s - loss: 12.3806 - mean_absolute_error: 12.3806
# Epoch 127/200
#  - 0s - loss: 12.3884 - mean_absolute_error: 12.3884
# Epoch 128/200
#  - 0s - loss: 12.3802 - mean_absolute_error: 12.3802
# Epoch 129/200
#  - 0s - loss: 12.3697 - mean_absolute_error: 12.3697
# Epoch 130/200
#  - 0s - loss: 12.3935 - mean_absolute_error: 12.3935
# Epoch 131/200
#  - 0s - loss: 12.4189 - mean_absolute_error: 12.4189
# Epoch 132/200
#  - 0s - loss: 12.3965 - mean_absolute_error: 12.3965
# Epoch 133/200
#  - 0s - loss: 12.4170 - mean_absolute_error: 12.4170
# Epoch 134/200
#  - 0s - loss: 12.3875 - mean_absolute_error: 12.3875
# Epoch 135/200
#  - 0s - loss: 12.3880 - mean_absolute_error: 12.3880
# Epoch 136/200
#  - 0s - loss: 12.3818 - mean_absolute_error: 12.3818
# Epoch 137/200
#  - 0s - loss: 12.4123 - mean_absolute_error: 12.4123
# Epoch 138/200
#  - 0s - loss: 12.3918 - mean_absolute_error: 12.3918
# Epoch 139/200
#  - 0s - loss: 12.3873 - mean_absolute_error: 12.3873
# Epoch 140/200
#  - 0s - loss: 12.3691 - mean_absolute_error: 12.3691
# Epoch 141/200
#  - 0s - loss: 12.3651 - mean_absolute_error: 12.3651
# Epoch 142/200
#  - 0s - loss: 12.3768 - mean_absolute_error: 12.3768
# Epoch 143/200
#  - 0s - loss: 12.4010 - mean_absolute_error: 12.4010
# Epoch 144/200
#  - 0s - loss: 12.3758 - mean_absolute_error: 12.3758
# Epoch 145/200
#  - 0s - loss: 12.4157 - mean_absolute_error: 12.4157
# Epoch 146/200
#  - 0s - loss: 12.3979 - mean_absolute_error: 12.3979
# Epoch 147/200
#  - 0s - loss: 12.3799 - mean_absolute_error: 12.3799
# Epoch 148/200
#  - 0s - loss: 12.3937 - mean_absolute_error: 12.3937
# Epoch 149/200
#  - 0s - loss: 12.3603 - mean_absolute_error: 12.3603
# Epoch 150/200
#  - 0s - loss: 12.3633 - mean_absolute_error: 12.3633
# Epoch 151/200
#  - 0s - loss: 12.3810 - mean_absolute_error: 12.3810
# Epoch 152/200
#  - 0s - loss: 12.3766 - mean_absolute_error: 12.3766
# Epoch 153/200
#  - 0s - loss: 12.3713 - mean_absolute_error: 12.3713
# Epoch 154/200
#  - 0s - loss: 12.3362 - mean_absolute_error: 12.3362
# Epoch 155/200
#  - 0s - loss: 12.3442 - mean_absolute_error: 12.3442
# Epoch 156/200
#  - 0s - loss: 12.3609 - mean_absolute_error: 12.3609
# Epoch 157/200
#  - 0s - loss: 12.3482 - mean_absolute_error: 12.3482
# Epoch 158/200
#  - 0s - loss: 12.3629 - mean_absolute_error: 12.3629
# Epoch 159/200
#  - 0s - loss: 12.3925 - mean_absolute_error: 12.3925
# Epoch 160/200
#  - 0s - loss: 12.3509 - mean_absolute_error: 12.3509
# Epoch 161/200
#  - 0s - loss: 12.3550 - mean_absolute_error: 12.3550
# Epoch 162/200
#  - 0s - loss: 12.3441 - mean_absolute_error: 12.3441
# Epoch 163/200
#  - 0s - loss: 12.3553 - mean_absolute_error: 12.3553
# Epoch 164/200
#  - 0s - loss: 12.3880 - mean_absolute_error: 12.3880
# Epoch 165/200
#  - 0s - loss: 12.3800 - mean_absolute_error: 12.3800
# Epoch 166/200
#  - 0s - loss: 12.3577 - mean_absolute_error: 12.3577
# Epoch 167/200
#  - 0s - loss: 12.3746 - mean_absolute_error: 12.3746
# Epoch 168/200
#  - 0s - loss: 12.3834 - mean_absolute_error: 12.3834
# Epoch 169/200
#  - 0s - loss: 12.3716 - mean_absolute_error: 12.3716
# Epoch 170/200
#  - 0s - loss: 12.3512 - mean_absolute_error: 12.3512
# Epoch 171/200
#  - 0s - loss: 12.3660 - mean_absolute_error: 12.3660
# Epoch 172/200
#  - 0s - loss: 12.3668 - mean_absolute_error: 12.3668
# Epoch 173/200
#  - 0s - loss: 12.3335 - mean_absolute_error: 12.3335
# Epoch 174/200
#  - 0s - loss: 12.3445 - mean_absolute_error: 12.3445
# Epoch 175/200
#  - 0s - loss: 12.3546 - mean_absolute_error: 12.3546
# Epoch 176/200
#  - 0s - loss: 12.3523 - mean_absolute_error: 12.3523
# Epoch 177/200
#  - 0s - loss: 12.3378 - mean_absolute_error: 12.3378
# Epoch 178/200
#  - 0s - loss: 12.3412 - mean_absolute_error: 12.3412
# Epoch 179/200
#  - 0s - loss: 12.3670 - mean_absolute_error: 12.3670
# Epoch 180/200
#  - 0s - loss: 12.3398 - mean_absolute_error: 12.3398
# Epoch 181/200
#  - 0s - loss: 12.3289 - mean_absolute_error: 12.3289
# Epoch 182/200
#  - 0s - loss: 12.3568 - mean_absolute_error: 12.3568
# Epoch 183/200
#  - 0s - loss: 12.3844 - mean_absolute_error: 12.3844
# Epoch 184/200
#  - 0s - loss: 12.3438 - mean_absolute_error: 12.3438
# Epoch 185/200
#  - 0s - loss: 12.3503 - mean_absolute_error: 12.3503
# Epoch 186/200
#  - 0s - loss: 12.3485 - mean_absolute_error: 12.3485
# Epoch 187/200
#  - 0s - loss: 12.3379 - mean_absolute_error: 12.3379
# Epoch 188/200
#  - 0s - loss: 12.3375 - mean_absolute_error: 12.3375
# Epoch 189/200
#  - 0s - loss: 12.3444 - mean_absolute_error: 12.3444
# Epoch 190/200
#  - 0s - loss: 12.3677 - mean_absolute_error: 12.3677
# Epoch 191/200
#  - 0s - loss: 12.3541 - mean_absolute_error: 12.3541
# Epoch 192/200
#  - 0s - loss: 12.3614 - mean_absolute_error: 12.3614
# Epoch 193/200
#  - 0s - loss: 12.3419 - mean_absolute_error: 12.3419
# Epoch 194/200
#  - 0s - loss: 12.3311 - mean_absolute_error: 12.3311
# Epoch 195/200
#  - 0s - loss: 12.3369 - mean_absolute_error: 12.3369
# Epoch 196/200
#  - 0s - loss: 12.3328 - mean_absolute_error: 12.3328
# Epoch 197/200
#  - 0s - loss: 12.3398 - mean_absolute_error: 12.3398
# Epoch 198/200
#  - 0s - loss: 12.3354 - mean_absolute_error: 12.3354
# Epoch 199/200
#  - 0s - loss: 12.3558 - mean_absolute_error: 12.3558
# Epoch 200/200
#  - 0s - loss: 12.3389 - mean_absolute_error: 12.3389
# Epoch 1/200
#  - 1s - loss: 127.2165 - mean_absolute_error: 127.2165
# Epoch 2/200
#  - 0s - loss: 126.5462 - mean_absolute_error: 126.5462
# Epoch 3/200
#  - 0s - loss: 122.9963 - mean_absolute_error: 122.9963
# Epoch 4/200
#  - 0s - loss: 112.5265 - mean_absolute_error: 112.5265
# Epoch 5/200
#  - 0s - loss: 94.4126 - mean_absolute_error: 94.4126
# Epoch 6/200
#  - 0s - loss: 83.7351 - mean_absolute_error: 83.7351
# Epoch 7/200
#  - 0s - loss: 76.8780 - mean_absolute_error: 76.8780
# Epoch 8/200
#  - 0s - loss: 68.3429 - mean_absolute_error: 68.3429
# Epoch 9/200
#  - 0s - loss: 58.4294 - mean_absolute_error: 58.4294
# Epoch 10/200
#  - 0s - loss: 51.1763 - mean_absolute_error: 51.1763
# Epoch 11/200
#  - 0s - loss: 46.8804 - mean_absolute_error: 46.8804
# Epoch 12/200
#  - 0s - loss: 43.9478 - mean_absolute_error: 43.9478
# Epoch 13/200
#  - 0s - loss: 41.8376 - mean_absolute_error: 41.8376
# Epoch 14/200
#  - 0s - loss: 39.8626 - mean_absolute_error: 39.8626
# Epoch 15/200
#  - 0s - loss: 37.7105 - mean_absolute_error: 37.7105
# Epoch 16/200
#  - 0s - loss: 35.3900 - mean_absolute_error: 35.3900
# Epoch 17/200
#  - 0s - loss: 32.8887 - mean_absolute_error: 32.8887
# Epoch 18/200
#  - 0s - loss: 30.3262 - mean_absolute_error: 30.3262
# Epoch 19/200
#  - 0s - loss: 27.7864 - mean_absolute_error: 27.7864
# Epoch 20/200
#  - 0s - loss: 25.4738 - mean_absolute_error: 25.4738
# Epoch 21/200
#  - 0s - loss: 23.5033 - mean_absolute_error: 23.5033
# Epoch 22/200
#  - 0s - loss: 21.7998 - mean_absolute_error: 21.7998
# Epoch 23/200
#  - 0s - loss: 20.4154 - mean_absolute_error: 20.4154
# Epoch 24/200
#  - 0s - loss: 19.2806 - mean_absolute_error: 19.2806
# Epoch 25/200
#  - 0s - loss: 18.3424 - mean_absolute_error: 18.3424
# Epoch 26/200
#  - 0s - loss: 17.5017 - mean_absolute_error: 17.5017
# Epoch 27/200
#  - 0s - loss: 16.8075 - mean_absolute_error: 16.8075
# Epoch 28/200
#  - 0s - loss: 16.2628 - mean_absolute_error: 16.2628
# Epoch 29/200
#  - 0s - loss: 15.7822 - mean_absolute_error: 15.7822
# Epoch 30/200
#  - 0s - loss: 15.3686 - mean_absolute_error: 15.3686
# Epoch 31/200
#  - 0s - loss: 15.0193 - mean_absolute_error: 15.0193
# Epoch 32/200
#  - 0s - loss: 14.7264 - mean_absolute_error: 14.7264
# Epoch 33/200
#  - 0s - loss: 14.4977 - mean_absolute_error: 14.4977
# Epoch 34/200
#  - 0s - loss: 14.2834 - mean_absolute_error: 14.2834
# Epoch 35/200
#  - 0s - loss: 14.1080 - mean_absolute_error: 14.1080
# Epoch 36/200
#  - 0s - loss: 13.9194 - mean_absolute_error: 13.9194
# Epoch 37/200
#  - 0s - loss: 13.7788 - mean_absolute_error: 13.7788
# Epoch 38/200
#  - 0s - loss: 13.6587 - mean_absolute_error: 13.6587
# Epoch 39/200
#  - 0s - loss: 13.5223 - mean_absolute_error: 13.5223
# Epoch 40/200
#  - 0s - loss: 13.4201 - mean_absolute_error: 13.4201
# Epoch 41/200
#  - 0s - loss: 13.3527 - mean_absolute_error: 13.3527
# Epoch 42/200
#  - 0s - loss: 13.3405 - mean_absolute_error: 13.3405
# Epoch 43/200
#  - 0s - loss: 13.2020 - mean_absolute_error: 13.2020
# Epoch 44/200
#  - 0s - loss: 13.1477 - mean_absolute_error: 13.1477
# Epoch 45/200
#  - 0s - loss: 13.0886 - mean_absolute_error: 13.0886
# Epoch 46/200
#  - 0s - loss: 13.0197 - mean_absolute_error: 13.0197
# Epoch 47/200
#  - 0s - loss: 13.0116 - mean_absolute_error: 13.0116
# Epoch 48/200
#  - 0s - loss: 12.9915 - mean_absolute_error: 12.9915
# Epoch 49/200
#  - 0s - loss: 12.9123 - mean_absolute_error: 12.9123
# Epoch 50/200
#  - 0s - loss: 12.8781 - mean_absolute_error: 12.8781
# Epoch 51/200
#  - 0s - loss: 12.8499 - mean_absolute_error: 12.8499
# Epoch 52/200
#  - 0s - loss: 12.8051 - mean_absolute_error: 12.8051
# Epoch 53/200
#  - 0s - loss: 12.8372 - mean_absolute_error: 12.8372
# Epoch 54/200
#  - 0s - loss: 12.7871 - mean_absolute_error: 12.7871
# Epoch 55/200
#  - 0s - loss: 12.7658 - mean_absolute_error: 12.7658
# Epoch 56/200
#  - 0s - loss: 12.7523 - mean_absolute_error: 12.7523
# Epoch 57/200
#  - 0s - loss: 12.7073 - mean_absolute_error: 12.7073
# Epoch 58/200
#  - 0s - loss: 12.7357 - mean_absolute_error: 12.7357
# Epoch 59/200
#  - 0s - loss: 12.6958 - mean_absolute_error: 12.6958
# Epoch 60/200
#  - 0s - loss: 12.7084 - mean_absolute_error: 12.7084
# Epoch 61/200
#  - 0s - loss: 12.7045 - mean_absolute_error: 12.7045
# Epoch 62/200
#  - 0s - loss: 12.6565 - mean_absolute_error: 12.6565
# Epoch 63/200
#  - 0s - loss: 12.6793 - mean_absolute_error: 12.6793
# Epoch 64/200
#  - 0s - loss: 12.6646 - mean_absolute_error: 12.6646
# Epoch 65/200
#  - 0s - loss: 12.6663 - mean_absolute_error: 12.6663
# Epoch 66/200
#  - 0s - loss: 12.6665 - mean_absolute_error: 12.6665
# Epoch 67/200
#  - 0s - loss: 12.6590 - mean_absolute_error: 12.6590
# Epoch 68/200
#  - 0s - loss: 12.6356 - mean_absolute_error: 12.6356
# Epoch 69/200
#  - 0s - loss: 12.6059 - mean_absolute_error: 12.6059
# Epoch 70/200
#  - 0s - loss: 12.6077 - mean_absolute_error: 12.6077
# Epoch 71/200
#  - 0s - loss: 12.6249 - mean_absolute_error: 12.6249
# Epoch 72/200
#  - 0s - loss: 12.6160 - mean_absolute_error: 12.6160
# Epoch 73/200
#  - 0s - loss: 12.6073 - mean_absolute_error: 12.6073
# Epoch 74/200
#  - 0s - loss: 12.5816 - mean_absolute_error: 12.5816
# Epoch 75/200
#  - 0s - loss: 12.5865 - mean_absolute_error: 12.5865
# Epoch 76/200
#  - 0s - loss: 12.5888 - mean_absolute_error: 12.5888
# Epoch 77/200
#  - 0s - loss: 12.5776 - mean_absolute_error: 12.5776
# Epoch 78/200
#  - 0s - loss: 12.5592 - mean_absolute_error: 12.5592
# Epoch 79/200
#  - 0s - loss: 12.5570 - mean_absolute_error: 12.5570
# Epoch 80/200
#  - 0s - loss: 12.5575 - mean_absolute_error: 12.5575
# Epoch 81/200
#  - 0s - loss: 12.5531 - mean_absolute_error: 12.5531
# Epoch 82/200
#  - 0s - loss: 12.5772 - mean_absolute_error: 12.5772
# Epoch 83/200
#  - 0s - loss: 12.5565 - mean_absolute_error: 12.5565
# Epoch 84/200
#  - 0s - loss: 12.5298 - mean_absolute_error: 12.5298
# Epoch 85/200
#  - 0s - loss: 12.5612 - mean_absolute_error: 12.5612
# Epoch 86/200
#  - 0s - loss: 12.5368 - mean_absolute_error: 12.5368
# Epoch 87/200
#  - 0s - loss: 12.5465 - mean_absolute_error: 12.5465
# Epoch 88/200
#  - 0s - loss: 12.5274 - mean_absolute_error: 12.5274
# Epoch 89/200
#  - 0s - loss: 12.5429 - mean_absolute_error: 12.5429
# Epoch 90/200
#  - 0s - loss: 12.5353 - mean_absolute_error: 12.5353
# Epoch 91/200
#  - 0s - loss: 12.5156 - mean_absolute_error: 12.5156
# Epoch 92/200
#  - 0s - loss: 12.5067 - mean_absolute_error: 12.5067
# Epoch 93/200
#  - 0s - loss: 12.5082 - mean_absolute_error: 12.5082
# Epoch 94/200
#  - 0s - loss: 12.5189 - mean_absolute_error: 12.5189
# Epoch 95/200
#  - 0s - loss: 12.4990 - mean_absolute_error: 12.4990
# Epoch 96/200
#  - 0s - loss: 12.5030 - mean_absolute_error: 12.5030
# Epoch 97/200
#  - 0s - loss: 12.4940 - mean_absolute_error: 12.4940
# Epoch 98/200
#  - 0s - loss: 12.5080 - mean_absolute_error: 12.5080
# Epoch 99/200
#  - 0s - loss: 12.5188 - mean_absolute_error: 12.5188
# Epoch 100/200
#  - 0s - loss: 12.4832 - mean_absolute_error: 12.4832
# Epoch 101/200
#  - 0s - loss: 12.5096 - mean_absolute_error: 12.5096
# Epoch 102/200
#  - 0s - loss: 12.4844 - mean_absolute_error: 12.4844
# Epoch 103/200
#  - 0s - loss: 12.5077 - mean_absolute_error: 12.5077
# Epoch 104/200
#  - 0s - loss: 12.4880 - mean_absolute_error: 12.4880
# Epoch 105/200
#  - 0s - loss: 12.4666 - mean_absolute_error: 12.4666
# Epoch 106/200
#  - 0s - loss: 12.4705 - mean_absolute_error: 12.4705
# Epoch 107/200
#  - 0s - loss: 12.4767 - mean_absolute_error: 12.4767
# Epoch 108/200
#  - 0s - loss: 12.4760 - mean_absolute_error: 12.4760
# Epoch 109/200
#  - 0s - loss: 12.4647 - mean_absolute_error: 12.4647
# Epoch 110/200
#  - 0s - loss: 12.4614 - mean_absolute_error: 12.4614
# Epoch 111/200
#  - 0s - loss: 12.4603 - mean_absolute_error: 12.4603
# Epoch 112/200
#  - 0s - loss: 12.4762 - mean_absolute_error: 12.4762
# Epoch 113/200
#  - 0s - loss: 12.4897 - mean_absolute_error: 12.4897
# Epoch 114/200
#  - 0s - loss: 12.4482 - mean_absolute_error: 12.4482
# Epoch 115/200
#  - 0s - loss: 12.4900 - mean_absolute_error: 12.4900
# Epoch 116/200
#  - 0s - loss: 12.4566 - mean_absolute_error: 12.4566
# Epoch 117/200
#  - 0s - loss: 12.4633 - mean_absolute_error: 12.4633
# Epoch 118/200
#  - 0s - loss: 12.4698 - mean_absolute_error: 12.4698
# Epoch 119/200
#  - 0s - loss: 12.4835 - mean_absolute_error: 12.4835
# Epoch 120/200
#  - 0s - loss: 12.4462 - mean_absolute_error: 12.4462
# Epoch 121/200
#  - 0s - loss: 12.4493 - mean_absolute_error: 12.4493
# Epoch 122/200
#  - 0s - loss: 12.4751 - mean_absolute_error: 12.4751
# Epoch 123/200
#  - 0s - loss: 12.4917 - mean_absolute_error: 12.4917
# Epoch 124/200
#  - 0s - loss: 12.4576 - mean_absolute_error: 12.4576
# Epoch 125/200
#  - 0s - loss: 12.4490 - mean_absolute_error: 12.4490
# Epoch 126/200
#  - 0s - loss: 12.4340 - mean_absolute_error: 12.4340
# Epoch 127/200
#  - 0s - loss: 12.4404 - mean_absolute_error: 12.4404
# Epoch 128/200
#  - 0s - loss: 12.4408 - mean_absolute_error: 12.4408
# Epoch 129/200
#  - 0s - loss: 12.4616 - mean_absolute_error: 12.4616
# Epoch 130/200
#  - 0s - loss: 12.4632 - mean_absolute_error: 12.4632
# Epoch 131/200
#  - 0s - loss: 12.4328 - mean_absolute_error: 12.4328
# Epoch 132/200
#  - 0s - loss: 12.4555 - mean_absolute_error: 12.4555
# Epoch 133/200
#  - 0s - loss: 12.4449 - mean_absolute_error: 12.4449
# Epoch 134/200
#  - 0s - loss: 12.4460 - mean_absolute_error: 12.4460
# Epoch 135/200
#  - 0s - loss: 12.4765 - mean_absolute_error: 12.4765
# Epoch 136/200
#  - 0s - loss: 12.4510 - mean_absolute_error: 12.4510
# Epoch 137/200
#  - 0s - loss: 12.4356 - mean_absolute_error: 12.4356
# Epoch 138/200
#  - 0s - loss: 12.4491 - mean_absolute_error: 12.4491
# Epoch 139/200
#  - 0s - loss: 12.4270 - mean_absolute_error: 12.4270
# Epoch 140/200
#  - 0s - loss: 12.4567 - mean_absolute_error: 12.4567
# Epoch 141/200
#  - 0s - loss: 12.4305 - mean_absolute_error: 12.4305
# Epoch 142/200
#  - 0s - loss: 12.4345 - mean_absolute_error: 12.4345
# Epoch 143/200
#  - 0s - loss: 12.4261 - mean_absolute_error: 12.4261
# Epoch 144/200
#  - 0s - loss: 12.4173 - mean_absolute_error: 12.4173
# Epoch 145/200
#  - 0s - loss: 12.4613 - mean_absolute_error: 12.4613
# Epoch 146/200
#  - 0s - loss: 12.4382 - mean_absolute_error: 12.4382
# Epoch 147/200
#  - 0s - loss: 12.4114 - mean_absolute_error: 12.4114
# Epoch 148/200
#  - 0s - loss: 12.4201 - mean_absolute_error: 12.4201
# Epoch 149/200
#  - 0s - loss: 12.4231 - mean_absolute_error: 12.4231
# Epoch 150/200
#  - 0s - loss: 12.4245 - mean_absolute_error: 12.4245
# Epoch 151/200
#  - 0s - loss: 12.4158 - mean_absolute_error: 12.4158
# Epoch 152/200
#  - 0s - loss: 12.4525 - mean_absolute_error: 12.4525
# Epoch 153/200
#  - 0s - loss: 12.4036 - mean_absolute_error: 12.4036
# Epoch 154/200
#  - 0s - loss: 12.4071 - mean_absolute_error: 12.4071
# Epoch 155/200
#  - 0s - loss: 12.4554 - mean_absolute_error: 12.4554
# Epoch 156/200
#  - 0s - loss: 12.4267 - mean_absolute_error: 12.4267
# Epoch 157/200
#  - 0s - loss: 12.4275 - mean_absolute_error: 12.4275
# Epoch 158/200
#  - 0s - loss: 12.4171 - mean_absolute_error: 12.4171
# Epoch 159/200
#  - 0s - loss: 12.4118 - mean_absolute_error: 12.4118
# Epoch 160/200
#  - 0s - loss: 12.4056 - mean_absolute_error: 12.4056
# Epoch 161/200
#  - 0s - loss: 12.4183 - mean_absolute_error: 12.4183
# Epoch 162/200
#  - 0s - loss: 12.4143 - mean_absolute_error: 12.4143
# Epoch 163/200
#  - 0s - loss: 12.4274 - mean_absolute_error: 12.4274
# Epoch 164/200
#  - 0s - loss: 12.4099 - mean_absolute_error: 12.4099
# Epoch 165/200
#  - 0s - loss: 12.4283 - mean_absolute_error: 12.4283
# Epoch 166/200
#  - 0s - loss: 12.4223 - mean_absolute_error: 12.4223
# Epoch 167/200
#  - 0s - loss: 12.4042 - mean_absolute_error: 12.4042
# Epoch 168/200
#  - 0s - loss: 12.4065 - mean_absolute_error: 12.4065
# Epoch 169/200
#  - 0s - loss: 12.4065 - mean_absolute_error: 12.4065
# Epoch 170/200
#  - 0s - loss: 12.4166 - mean_absolute_error: 12.4166
# Epoch 171/200
#  - 0s - loss: 12.4171 - mean_absolute_error: 12.4171
# Epoch 172/200
#  - 0s - loss: 12.4084 - mean_absolute_error: 12.4084
# Epoch 173/200
#  - 0s - loss: 12.4269 - mean_absolute_error: 12.4269
# Epoch 174/200
#  - 0s - loss: 12.3948 - mean_absolute_error: 12.3948
# Epoch 175/200
#  - 0s - loss: 12.4022 - mean_absolute_error: 12.4022
# Epoch 176/200
#  - 0s - loss: 12.3755 - mean_absolute_error: 12.3755
# Epoch 177/200
#  - 0s - loss: 12.3954 - mean_absolute_error: 12.3954
# Epoch 178/200
#  - 0s - loss: 12.4132 - mean_absolute_error: 12.4132
# Epoch 179/200
#  - 0s - loss: 12.4071 - mean_absolute_error: 12.4071
# Epoch 180/200
#  - 0s - loss: 12.4034 - mean_absolute_error: 12.4034
# Epoch 181/200
#  - 0s - loss: 12.3928 - mean_absolute_error: 12.3928
# Epoch 182/200
#  - 0s - loss: 12.4058 - mean_absolute_error: 12.4058
# Epoch 183/200
#  - 0s - loss: 12.4214 - mean_absolute_error: 12.4214
# Epoch 184/200
#  - 0s - loss: 12.4028 - mean_absolute_error: 12.4028
# Epoch 185/200
#  - 0s - loss: 12.3879 - mean_absolute_error: 12.3879
# Epoch 186/200
#  - 0s - loss: 12.3912 - mean_absolute_error: 12.3912
# Epoch 187/200
#  - 0s - loss: 12.4009 - mean_absolute_error: 12.4009
# Epoch 188/200
#  - 0s - loss: 12.3912 - mean_absolute_error: 12.3912
# Epoch 189/200
#  - 0s - loss: 12.3875 - mean_absolute_error: 12.3875
# Epoch 190/200
#  - 0s - loss: 12.3985 - mean_absolute_error: 12.3985
# Epoch 191/200
#  - 0s - loss: 12.4074 - mean_absolute_error: 12.4074
# Epoch 192/200
#  - 0s - loss: 12.3628 - mean_absolute_error: 12.3628
# Epoch 193/200
#  - 0s - loss: 12.3855 - mean_absolute_error: 12.3855
# Epoch 194/200
#  - 0s - loss: 12.3747 - mean_absolute_error: 12.3747
# Epoch 195/200
#  - 0s - loss: 12.3648 - mean_absolute_error: 12.3648
# Epoch 196/200
#  - 0s - loss: 12.3752 - mean_absolute_error: 12.3752
# Epoch 197/200
#  - 0s - loss: 12.3908 - mean_absolute_error: 12.3908
# Epoch 198/200
#  - 0s - loss: 12.3953 - mean_absolute_error: 12.3953
# Epoch 199/200
#  - 0s - loss: 12.3739 - mean_absolute_error: 12.3739
# Epoch 200/200
#  - 0s - loss: 12.3512 - mean_absolute_error: 12.3512
# Epoch 1/200
#  - 1s - loss: 127.2098 - mean_absolute_error: 127.2098
# Epoch 2/200
#  - 0s - loss: 126.4005 - mean_absolute_error: 126.4005
# Epoch 3/200
#  - 0s - loss: 122.4179 - mean_absolute_error: 122.4179
# Epoch 4/200
#  - 0s - loss: 111.3675 - mean_absolute_error: 111.3675
# Epoch 5/200
#  - 0s - loss: 89.2828 - mean_absolute_error: 89.2828
# Epoch 6/200
#  - 0s - loss: 66.2208 - mean_absolute_error: 66.2208
# Epoch 7/200
#  - 0s - loss: 58.2306 - mean_absolute_error: 58.2306
# Epoch 8/200
#  - 0s - loss: 55.3096 - mean_absolute_error: 55.3096
# Epoch 9/200
#  - 0s - loss: 52.8442 - mean_absolute_error: 52.8442
# Epoch 10/200
#  - 0s - loss: 50.3022 - mean_absolute_error: 50.3022
# Epoch 11/200
#  - 0s - loss: 47.6402 - mean_absolute_error: 47.6402
# Epoch 12/200
#  - 0s - loss: 45.0623 - mean_absolute_error: 45.0623
# Epoch 13/200
#  - 0s - loss: 42.6280 - mean_absolute_error: 42.6280
# Epoch 14/200
#  - 0s - loss: 40.4015 - mean_absolute_error: 40.4015
# Epoch 15/200
#  - 0s - loss: 38.2123 - mean_absolute_error: 38.2123
# Epoch 16/200
#  - 0s - loss: 36.0164 - mean_absolute_error: 36.0164
# Epoch 17/200
#  - 0s - loss: 33.8020 - mean_absolute_error: 33.8020
# Epoch 18/200
#  - 0s - loss: 31.6804 - mean_absolute_error: 31.6804
# Epoch 19/200
#  - 0s - loss: 29.7055 - mean_absolute_error: 29.7055
# Epoch 20/200
#  - 0s - loss: 28.0477 - mean_absolute_error: 28.0477
# Epoch 21/200
#  - 0s - loss: 26.5629 - mean_absolute_error: 26.5629
# Epoch 22/200
#  - 0s - loss: 25.2958 - mean_absolute_error: 25.2958
# Epoch 23/200
#  - 0s - loss: 24.1995 - mean_absolute_error: 24.1995
# Epoch 24/200
#  - 0s - loss: 23.2648 - mean_absolute_error: 23.2648
# Epoch 25/200
#  - 0s - loss: 22.4406 - mean_absolute_error: 22.4406
# Epoch 26/200
#  - 0s - loss: 21.6537 - mean_absolute_error: 21.6537
# Epoch 27/200
#  - 0s - loss: 20.9231 - mean_absolute_error: 20.9231
# Epoch 28/200
#  - 0s - loss: 20.1719 - mean_absolute_error: 20.1719
# Epoch 29/200
#  - 0s - loss: 19.4389 - mean_absolute_error: 19.4389
# Epoch 30/200
#  - 0s - loss: 18.6788 - mean_absolute_error: 18.6788
# Epoch 31/200
#  - 0s - loss: 18.0014 - mean_absolute_error: 18.0014
# Epoch 32/200
#  - 0s - loss: 17.3116 - mean_absolute_error: 17.3116
# Epoch 33/200
#  - 0s - loss: 16.6580 - mean_absolute_error: 16.6580
# Epoch 34/200
#  - 0s - loss: 16.0397 - mean_absolute_error: 16.0397
# Epoch 35/200
#  - 0s - loss: 15.4903 - mean_absolute_error: 15.4903
# Epoch 36/200
#  - 0s - loss: 15.0210 - mean_absolute_error: 15.0210
# Epoch 37/200
#  - 0s - loss: 14.5425 - mean_absolute_error: 14.5425
# Epoch 38/200
#  - 0s - loss: 14.2013 - mean_absolute_error: 14.2013
# Epoch 39/200
#  - 0s - loss: 13.8585 - mean_absolute_error: 13.8585
# Epoch 40/200
#  - 0s - loss: 13.5750 - mean_absolute_error: 13.5750
# Epoch 41/200
#  - 0s - loss: 13.3596 - mean_absolute_error: 13.3596
# Epoch 42/200
#  - 0s - loss: 13.2205 - mean_absolute_error: 13.2205
# Epoch 43/200
#  - 0s - loss: 13.0854 - mean_absolute_error: 13.0854
# Epoch 44/200
#  - 0s - loss: 12.9842 - mean_absolute_error: 12.9842
# Epoch 45/200
#  - 0s - loss: 12.8960 - mean_absolute_error: 12.8960
# Epoch 46/200
#  - 0s - loss: 12.8543 - mean_absolute_error: 12.8543
# Epoch 47/200
#  - 0s - loss: 12.7913 - mean_absolute_error: 12.7913
# Epoch 48/200
#  - 0s - loss: 12.7730 - mean_absolute_error: 12.7730
# Epoch 49/200
#  - 0s - loss: 12.7166 - mean_absolute_error: 12.7166
# Epoch 50/200
#  - 0s - loss: 12.7105 - mean_absolute_error: 12.7105
# Epoch 51/200
#  - 0s - loss: 12.6893 - mean_absolute_error: 12.6893
# Epoch 52/200
#  - 0s - loss: 12.6595 - mean_absolute_error: 12.6595
# Epoch 53/200
#  - 0s - loss: 12.6329 - mean_absolute_error: 12.6329
# Epoch 54/200
#  - 0s - loss: 12.6221 - mean_absolute_error: 12.6221
# Epoch 55/200
#  - 0s - loss: 12.5933 - mean_absolute_error: 12.5933
# Epoch 56/200
#  - 0s - loss: 12.6006 - mean_absolute_error: 12.6006
# Epoch 57/200
#  - 0s - loss: 12.5845 - mean_absolute_error: 12.5845
# Epoch 58/200
#  - 0s - loss: 12.5695 - mean_absolute_error: 12.5695
# Epoch 59/200
#  - 0s - loss: 12.5483 - mean_absolute_error: 12.5483
# Epoch 60/200
#  - 0s - loss: 12.5373 - mean_absolute_error: 12.5373
# Epoch 61/200
#  - 0s - loss: 12.5596 - mean_absolute_error: 12.5596
# Epoch 62/200
#  - 0s - loss: 12.5446 - mean_absolute_error: 12.5446
# Epoch 63/200
#  - 0s - loss: 12.5667 - mean_absolute_error: 12.5667
# Epoch 64/200
#  - 0s - loss: 12.5807 - mean_absolute_error: 12.5807
# Epoch 65/200
#  - 0s - loss: 12.5721 - mean_absolute_error: 12.5721
# Epoch 66/200
#  - 0s - loss: 12.5224 - mean_absolute_error: 12.5224
# Epoch 67/200
#  - 0s - loss: 12.5115 - mean_absolute_error: 12.5115
# Epoch 68/200
#  - 0s - loss: 12.5022 - mean_absolute_error: 12.5022
# Epoch 69/200
#  - 0s - loss: 12.4973 - mean_absolute_error: 12.4973
# Epoch 70/200
#  - 0s - loss: 12.5259 - mean_absolute_error: 12.5259
# Epoch 71/200
#  - 0s - loss: 12.4995 - mean_absolute_error: 12.4995
# Epoch 72/200
#  - 0s - loss: 12.5177 - mean_absolute_error: 12.5177
# Epoch 73/200
#  - 0s - loss: 12.5100 - mean_absolute_error: 12.5100
# Epoch 74/200
#  - 0s - loss: 12.5198 - mean_absolute_error: 12.5198
# Epoch 75/200
#  - 0s - loss: 12.4985 - mean_absolute_error: 12.4985
# Epoch 76/200
#  - 0s - loss: 12.4948 - mean_absolute_error: 12.4948
# Epoch 77/200
#  - 0s - loss: 12.4748 - mean_absolute_error: 12.4748
# Epoch 78/200
#  - 0s - loss: 12.5081 - mean_absolute_error: 12.5081
# Epoch 79/200
#  - 0s - loss: 12.5034 - mean_absolute_error: 12.5034
# Epoch 80/200
#  - 0s - loss: 12.4891 - mean_absolute_error: 12.4891
# Epoch 81/200
#  - 0s - loss: 12.4725 - mean_absolute_error: 12.4725
# Epoch 82/200
#  - 0s - loss: 12.4755 - mean_absolute_error: 12.4755
# Epoch 83/200
#  - 0s - loss: 12.4722 - mean_absolute_error: 12.4722
# Epoch 84/200
#  - 0s - loss: 12.4471 - mean_absolute_error: 12.4471
# Epoch 85/200
#  - 0s - loss: 12.4715 - mean_absolute_error: 12.4715
# Epoch 86/200
#  - 0s - loss: 12.4652 - mean_absolute_error: 12.4652
# Epoch 87/200
#  - 0s - loss: 12.4517 - mean_absolute_error: 12.4517
# Epoch 88/200
#  - 0s - loss: 12.4700 - mean_absolute_error: 12.4700
# Epoch 89/200
#  - 0s - loss: 12.4700 - mean_absolute_error: 12.4700
# Epoch 90/200
#  - 0s - loss: 12.4672 - mean_absolute_error: 12.4672
# Epoch 91/200
#  - 0s - loss: 12.4650 - mean_absolute_error: 12.4650
# Epoch 92/200
#  - 0s - loss: 12.4653 - mean_absolute_error: 12.4653
# Epoch 93/200
#  - 0s - loss: 12.4510 - mean_absolute_error: 12.4510
# Epoch 94/200
#  - 0s - loss: 12.4457 - mean_absolute_error: 12.4457
# Epoch 95/200
#  - 0s - loss: 12.4599 - mean_absolute_error: 12.4599
# Epoch 96/200
#  - 0s - loss: 12.4657 - mean_absolute_error: 12.4657
# Epoch 97/200
#  - 0s - loss: 12.4310 - mean_absolute_error: 12.4310
# Epoch 98/200
#  - 0s - loss: 12.4537 - mean_absolute_error: 12.4537
# Epoch 99/200
#  - 0s - loss: 12.4553 - mean_absolute_error: 12.4553
# Epoch 100/200
#  - 0s - loss: 12.4426 - mean_absolute_error: 12.4426
# Epoch 101/200
#  - 0s - loss: 12.4439 - mean_absolute_error: 12.4439
# Epoch 102/200
#  - 0s - loss: 12.4448 - mean_absolute_error: 12.4448
# Epoch 103/200
#  - 0s - loss: 12.4274 - mean_absolute_error: 12.4274
# Epoch 104/200
#  - 0s - loss: 12.4826 - mean_absolute_error: 12.4826
# Epoch 105/200
#  - 0s - loss: 12.4573 - mean_absolute_error: 12.4573
# Epoch 106/200
#  - 0s - loss: 12.4261 - mean_absolute_error: 12.4261
# Epoch 107/200
#  - 0s - loss: 12.4533 - mean_absolute_error: 12.4533
# Epoch 108/200
#  - 0s - loss: 12.4705 - mean_absolute_error: 12.4705
# Epoch 109/200
#  - 0s - loss: 12.4469 - mean_absolute_error: 12.4469
# Epoch 110/200
#  - 0s - loss: 12.4563 - mean_absolute_error: 12.4563
# Epoch 111/200
#  - 0s - loss: 12.4611 - mean_absolute_error: 12.4611
# Epoch 112/200
#  - 0s - loss: 12.4408 - mean_absolute_error: 12.4408
# Epoch 113/200
#  - 0s - loss: 12.4190 - mean_absolute_error: 12.4190
# Epoch 114/200
#  - 0s - loss: 12.4243 - mean_absolute_error: 12.4243
# Epoch 115/200
#  - 0s - loss: 12.4174 - mean_absolute_error: 12.4174
# Epoch 116/200
#  - 0s - loss: 12.4257 - mean_absolute_error: 12.4257
# Epoch 117/200
#  - 0s - loss: 12.4122 - mean_absolute_error: 12.4122
# Epoch 118/200
#  - 0s - loss: 12.4386 - mean_absolute_error: 12.4386
# Epoch 119/200
#  - 0s - loss: 12.4227 - mean_absolute_error: 12.4227
# Epoch 120/200
#  - 0s - loss: 12.4428 - mean_absolute_error: 12.4428
# Epoch 121/200
#  - 0s - loss: 12.4335 - mean_absolute_error: 12.4335
# Epoch 122/200
#  - 0s - loss: 12.4195 - mean_absolute_error: 12.4195
# Epoch 123/200
#  - 0s - loss: 12.3985 - mean_absolute_error: 12.3985
# Epoch 124/200
#  - 0s - loss: 12.4043 - mean_absolute_error: 12.4043
# Epoch 125/200
#  - 0s - loss: 12.4289 - mean_absolute_error: 12.4289
# Epoch 126/200
#  - 0s - loss: 12.4086 - mean_absolute_error: 12.4086
# Epoch 127/200
#  - 0s - loss: 12.4027 - mean_absolute_error: 12.4027
# Epoch 128/200
#  - 0s - loss: 12.4229 - mean_absolute_error: 12.4229
# Epoch 129/200
#  - 0s - loss: 12.4099 - mean_absolute_error: 12.4099
# Epoch 130/200
#  - 0s - loss: 12.4247 - mean_absolute_error: 12.4247
# Epoch 131/200
#  - 0s - loss: 12.4106 - mean_absolute_error: 12.4106
# Epoch 132/200
#  - 0s - loss: 12.4169 - mean_absolute_error: 12.4169
# Epoch 133/200
#  - 0s - loss: 12.3996 - mean_absolute_error: 12.3996
# Epoch 134/200
#  - 0s - loss: 12.4069 - mean_absolute_error: 12.4069
# Epoch 135/200
#  - 0s - loss: 12.4086 - mean_absolute_error: 12.4086
# Epoch 136/200
#  - 0s - loss: 12.4259 - mean_absolute_error: 12.4259
# Epoch 137/200
#  - 0s - loss: 12.4172 - mean_absolute_error: 12.4172
# Epoch 138/200
#  - 0s - loss: 12.3840 - mean_absolute_error: 12.3840
# Epoch 139/200
#  - 0s - loss: 12.4227 - mean_absolute_error: 12.4227
# Epoch 140/200
#  - 0s - loss: 12.3892 - mean_absolute_error: 12.3892
# Epoch 141/200
#  - 0s - loss: 12.3975 - mean_absolute_error: 12.3975
# Epoch 142/200
#  - 0s - loss: 12.3838 - mean_absolute_error: 12.3838
# Epoch 143/200
#  - 0s - loss: 12.3813 - mean_absolute_error: 12.3813
# Epoch 144/200
#  - 0s - loss: 12.3934 - mean_absolute_error: 12.3934
# Epoch 145/200
#  - 0s - loss: 12.4036 - mean_absolute_error: 12.4036
# Epoch 146/200
#  - 0s - loss: 12.3747 - mean_absolute_error: 12.3747
# Epoch 147/200
#  - 0s - loss: 12.3845 - mean_absolute_error: 12.3845
# Epoch 148/200
#  - 0s - loss: 12.3825 - mean_absolute_error: 12.3825
# Epoch 149/200
#  - 0s - loss: 12.3884 - mean_absolute_error: 12.3884
# Epoch 150/200
#  - 0s - loss: 12.3867 - mean_absolute_error: 12.3867
# Epoch 151/200
#  - 0s - loss: 12.4202 - mean_absolute_error: 12.4202
# Epoch 152/200
#  - 0s - loss: 12.3691 - mean_absolute_error: 12.3691
# Epoch 153/200
#  - 0s - loss: 12.3780 - mean_absolute_error: 12.3780
# Epoch 154/200
#  - 0s - loss: 12.3946 - mean_absolute_error: 12.3946
# Epoch 155/200
#  - 0s - loss: 12.4303 - mean_absolute_error: 12.4303
# Epoch 156/200
#  - 0s - loss: 12.3990 - mean_absolute_error: 12.3990
# Epoch 157/200
#  - 0s - loss: 12.4144 - mean_absolute_error: 12.4144
# Epoch 158/200
#  - 0s - loss: 12.4043 - mean_absolute_error: 12.4043
# Epoch 159/200
#  - 0s - loss: 12.4138 - mean_absolute_error: 12.4138
# Epoch 160/200
#  - 0s - loss: 12.3716 - mean_absolute_error: 12.3716
# Epoch 161/200
#  - 0s - loss: 12.3637 - mean_absolute_error: 12.3637
# Epoch 162/200
#  - 0s - loss: 12.3773 - mean_absolute_error: 12.3773
# Epoch 163/200
#  - 0s - loss: 12.3929 - mean_absolute_error: 12.3929
# Epoch 164/200
#  - 0s - loss: 12.3731 - mean_absolute_error: 12.3731
# Epoch 165/200
#  - 0s - loss: 12.3849 - mean_absolute_error: 12.3849
# Epoch 166/200
#  - 0s - loss: 12.3879 - mean_absolute_error: 12.3879
# Epoch 167/200
#  - 0s - loss: 12.3704 - mean_absolute_error: 12.3704
# Epoch 168/200
#  - 0s - loss: 12.3694 - mean_absolute_error: 12.3694
# Epoch 169/200
#  - 0s - loss: 12.3684 - mean_absolute_error: 12.3684
# Epoch 170/200
#  - 0s - loss: 12.4029 - mean_absolute_error: 12.4029
# Epoch 171/200
#  - 0s - loss: 12.3857 - mean_absolute_error: 12.3857
# Epoch 172/200
#  - 0s - loss: 12.3595 - mean_absolute_error: 12.3595
# Epoch 173/200
#  - 0s - loss: 12.3726 - mean_absolute_error: 12.3726
# Epoch 174/200
#  - 0s - loss: 12.3803 - mean_absolute_error: 12.3803
# Epoch 175/200
#  - 0s - loss: 12.3725 - mean_absolute_error: 12.3725
# Epoch 176/200
#  - 0s - loss: 12.4056 - mean_absolute_error: 12.4056
# Epoch 177/200
#  - 0s - loss: 12.3954 - mean_absolute_error: 12.3954
# Epoch 178/200
#  - 0s - loss: 12.3641 - mean_absolute_error: 12.3641
# Epoch 179/200
#  - 0s - loss: 12.3460 - mean_absolute_error: 12.3460
# Epoch 180/200
#  - 0s - loss: 12.3761 - mean_absolute_error: 12.3761
# Epoch 181/200
#  - 0s - loss: 12.3754 - mean_absolute_error: 12.3754
# Epoch 182/200
#  - 0s - loss: 12.3895 - mean_absolute_error: 12.3895
# Epoch 183/200
#  - 0s - loss: 12.3551 - mean_absolute_error: 12.3551
# Epoch 184/200
#  - 0s - loss: 12.3599 - mean_absolute_error: 12.3599
# Epoch 185/200
#  - 0s - loss: 12.3619 - mean_absolute_error: 12.3619
# Epoch 186/200
#  - 0s - loss: 12.3671 - mean_absolute_error: 12.3671
# Epoch 187/200
#  - 0s - loss: 12.3671 - mean_absolute_error: 12.3671
# Epoch 188/200
#  - 0s - loss: 12.3590 - mean_absolute_error: 12.3590
# Epoch 189/200
#  - 0s - loss: 12.3544 - mean_absolute_error: 12.3544
# Epoch 190/200
#  - 0s - loss: 12.3469 - mean_absolute_error: 12.3469
# Epoch 191/200
#  - 0s - loss: 12.3572 - mean_absolute_error: 12.3572
# Epoch 192/200
#  - 0s - loss: 12.3743 - mean_absolute_error: 12.3743
# Epoch 193/200
#  - 0s - loss: 12.3746 - mean_absolute_error: 12.3746
# Epoch 194/200
#  - 0s - loss: 12.3691 - mean_absolute_error: 12.3691
# Epoch 195/200
#  - 0s - loss: 12.3495 - mean_absolute_error: 12.3495
# Epoch 196/200
#  - 0s - loss: 12.3397 - mean_absolute_error: 12.3397
# Epoch 197/200
#  - 0s - loss: 12.3477 - mean_absolute_error: 12.3477
# Epoch 198/200
#  - 0s - loss: 12.3784 - mean_absolute_error: 12.3784
# Epoch 199/200
#  - 0s - loss: 12.3532 - mean_absolute_error: 12.3532
# Epoch 200/200
#  - 0s - loss: 12.3415 - mean_absolute_error: 12.3415
# Epoch 1/200
#  - 1s - loss: 127.2291 - mean_absolute_error: 127.2291
# Epoch 2/200
#  - 0s - loss: 126.7534 - mean_absolute_error: 126.7534
# Epoch 3/200
#  - 0s - loss: 124.1801 - mean_absolute_error: 124.1801
# Epoch 4/200
#  - 0s - loss: 116.3448 - mean_absolute_error: 116.3448
# Epoch 5/200
#  - 0s - loss: 99.7335 - mean_absolute_error: 99.7335
# Epoch 6/200
#  - 0s - loss: 77.0653 - mean_absolute_error: 77.0653
# Epoch 7/200
#  - 0s - loss: 62.6612 - mean_absolute_error: 62.6612
# Epoch 8/200
#  - 0s - loss: 57.0390 - mean_absolute_error: 57.0390
# Epoch 9/200
#  - 0s - loss: 54.2583 - mean_absolute_error: 54.2583
# Epoch 10/200
#  - 0s - loss: 51.9218 - mean_absolute_error: 51.9218
# Epoch 11/200
#  - 0s - loss: 49.5404 - mean_absolute_error: 49.5404
# Epoch 12/200
#  - 0s - loss: 47.1199 - mean_absolute_error: 47.1199
# Epoch 13/200
#  - 0s - loss: 44.8806 - mean_absolute_error: 44.8806
# Epoch 14/200
#  - 0s - loss: 43.0651 - mean_absolute_error: 43.0651
# Epoch 15/200
#  - 0s - loss: 41.5292 - mean_absolute_error: 41.5292
# Epoch 16/200
#  - 0s - loss: 40.1088 - mean_absolute_error: 40.1088
# Epoch 17/200
#  - 0s - loss: 38.6134 - mean_absolute_error: 38.6134
# Epoch 18/200
#  - 0s - loss: 37.0474 - mean_absolute_error: 37.0474
# Epoch 19/200
#  - 0s - loss: 35.4084 - mean_absolute_error: 35.4084
# Epoch 20/200
#  - 0s - loss: 33.6138 - mean_absolute_error: 33.6138
# Epoch 21/200
#  - 0s - loss: 31.6885 - mean_absolute_error: 31.6885
# Epoch 22/200
#  - 0s - loss: 29.6668 - mean_absolute_error: 29.6668
# Epoch 23/200
#  - 0s - loss: 27.6374 - mean_absolute_error: 27.6374
# Epoch 24/200
#  - 0s - loss: 25.7547 - mean_absolute_error: 25.7547
# Epoch 25/200
#  - 0s - loss: 24.1668 - mean_absolute_error: 24.1668
# Epoch 26/200
#  - 0s - loss: 22.7968 - mean_absolute_error: 22.7968
# Epoch 27/200
#  - 0s - loss: 21.7231 - mean_absolute_error: 21.7231
# Epoch 28/200
#  - 0s - loss: 20.7012 - mean_absolute_error: 20.7012
# Epoch 29/200
#  - 0s - loss: 19.7501 - mean_absolute_error: 19.7501
# Epoch 30/200
#  - 0s - loss: 18.9731 - mean_absolute_error: 18.9731
# Epoch 31/200
#  - 0s - loss: 18.2415 - mean_absolute_error: 18.2415
# Epoch 32/200
#  - 0s - loss: 17.5360 - mean_absolute_error: 17.5360
# Epoch 33/200
#  - 0s - loss: 16.8715 - mean_absolute_error: 16.8715
# Epoch 34/200
#  - 0s - loss: 16.3213 - mean_absolute_error: 16.3213
# Epoch 35/200
#  - 0s - loss: 15.8398 - mean_absolute_error: 15.8398
# Epoch 36/200
#  - 0s - loss: 15.3952 - mean_absolute_error: 15.3952
# Epoch 37/200
#  - 0s - loss: 14.9983 - mean_absolute_error: 14.9983
# Epoch 38/200
#  - 0s - loss: 14.6676 - mean_absolute_error: 14.6676
# Epoch 39/200
#  - 0s - loss: 14.3732 - mean_absolute_error: 14.3732
# Epoch 40/200
#  - 0s - loss: 14.1042 - mean_absolute_error: 14.1042
# Epoch 41/200
#  - 0s - loss: 13.8793 - mean_absolute_error: 13.8793
# Epoch 42/200
#  - 0s - loss: 13.6584 - mean_absolute_error: 13.6584
# Epoch 43/200
#  - 0s - loss: 13.4798 - mean_absolute_error: 13.4798
# Epoch 44/200
#  - 0s - loss: 13.3415 - mean_absolute_error: 13.3415
# Epoch 45/200
#  - 0s - loss: 13.2181 - mean_absolute_error: 13.2181
# Epoch 46/200
#  - 0s - loss: 13.0832 - mean_absolute_error: 13.0832
# Epoch 47/200
#  - 0s - loss: 13.0397 - mean_absolute_error: 13.0397
# Epoch 48/200
#  - 0s - loss: 12.9559 - mean_absolute_error: 12.9559
# Epoch 49/200
#  - 0s - loss: 12.8891 - mean_absolute_error: 12.8891
# Epoch 50/200
#  - 0s - loss: 12.8231 - mean_absolute_error: 12.8231
# Epoch 51/200
#  - 0s - loss: 12.7883 - mean_absolute_error: 12.7883
# Epoch 52/200
#  - 0s - loss: 12.7391 - mean_absolute_error: 12.7391
# Epoch 53/200
#  - 0s - loss: 12.7359 - mean_absolute_error: 12.7359
# Epoch 54/200
#  - 0s - loss: 12.6951 - mean_absolute_error: 12.6951
# Epoch 55/200
#  - 0s - loss: 12.6658 - mean_absolute_error: 12.6658
# Epoch 56/200
#  - 0s - loss: 12.6620 - mean_absolute_error: 12.6620
# Epoch 57/200
#  - 0s - loss: 12.6419 - mean_absolute_error: 12.6419
# Epoch 58/200
#  - 0s - loss: 12.6080 - mean_absolute_error: 12.6080
# Epoch 59/200
#  - 0s - loss: 12.6063 - mean_absolute_error: 12.6063
# Epoch 60/200
#  - 0s - loss: 12.5914 - mean_absolute_error: 12.5914
# Epoch 61/200
#  - 0s - loss: 12.5682 - mean_absolute_error: 12.5682
# Epoch 62/200
#  - 0s - loss: 12.5736 - mean_absolute_error: 12.5736
# Epoch 63/200
#  - 0s - loss: 12.5787 - mean_absolute_error: 12.5787
# Epoch 64/200
#  - 0s - loss: 12.5413 - mean_absolute_error: 12.5413
# Epoch 65/200
#  - 0s - loss: 12.5400 - mean_absolute_error: 12.5400
# Epoch 66/200
#  - 0s - loss: 12.5278 - mean_absolute_error: 12.5278
# Epoch 67/200
#  - 0s - loss: 12.4978 - mean_absolute_error: 12.4978
# Epoch 68/200
#  - 0s - loss: 12.5125 - mean_absolute_error: 12.5125
# Epoch 69/200
#  - 0s - loss: 12.5332 - mean_absolute_error: 12.5332
# Epoch 70/200
#  - 0s - loss: 12.5163 - mean_absolute_error: 12.5163
# Epoch 71/200
#  - 0s - loss: 12.4807 - mean_absolute_error: 12.4807
# Epoch 72/200
#  - 0s - loss: 12.4939 - mean_absolute_error: 12.4939
# Epoch 73/200
#  - 0s - loss: 12.5033 - mean_absolute_error: 12.5033
# Epoch 74/200
#  - 0s - loss: 12.4892 - mean_absolute_error: 12.4892
# Epoch 75/200
#  - 0s - loss: 12.4814 - mean_absolute_error: 12.4814
# Epoch 76/200
#  - 0s - loss: 12.5025 - mean_absolute_error: 12.5025
# Epoch 77/200
#  - 0s - loss: 12.4989 - mean_absolute_error: 12.4989
# Epoch 78/200
#  - 0s - loss: 12.5019 - mean_absolute_error: 12.5019
# Epoch 79/200
#  - 0s - loss: 12.4788 - mean_absolute_error: 12.4788
# Epoch 80/200
#  - 0s - loss: 12.4760 - mean_absolute_error: 12.4760
# Epoch 81/200
#  - 0s - loss: 12.4993 - mean_absolute_error: 12.4993
# Epoch 82/200
#  - 0s - loss: 12.4726 - mean_absolute_error: 12.4726
# Epoch 83/200
#  - 0s - loss: 12.4978 - mean_absolute_error: 12.4978
# Epoch 84/200
#  - 0s - loss: 12.4703 - mean_absolute_error: 12.4703
# Epoch 85/200
#  - 0s - loss: 12.4536 - mean_absolute_error: 12.4536
# Epoch 86/200
#  - 0s - loss: 12.4632 - mean_absolute_error: 12.4632
# Epoch 87/200
#  - 0s - loss: 12.4695 - mean_absolute_error: 12.4695
# Epoch 88/200
#  - 0s - loss: 12.4715 - mean_absolute_error: 12.4715
# Epoch 89/200
#  - 0s - loss: 12.4799 - mean_absolute_error: 12.4799
# Epoch 90/200
#  - 0s - loss: 12.4523 - mean_absolute_error: 12.4523
# Epoch 91/200
#  - 0s - loss: 12.4797 - mean_absolute_error: 12.4797
# Epoch 92/200
#  - 0s - loss: 12.4667 - mean_absolute_error: 12.4667
# Epoch 93/200
#  - 0s - loss: 12.4524 - mean_absolute_error: 12.4524
# Epoch 94/200
#  - 0s - loss: 12.4529 - mean_absolute_error: 12.4529
# Epoch 95/200
#  - 0s - loss: 12.4403 - mean_absolute_error: 12.4403
# Epoch 96/200
#  - 0s - loss: 12.4497 - mean_absolute_error: 12.4497
# Epoch 97/200
#  - 0s - loss: 12.4378 - mean_absolute_error: 12.4378
# Epoch 98/200
#  - 0s - loss: 12.4336 - mean_absolute_error: 12.4336
# Epoch 99/200
#  - 0s - loss: 12.4842 - mean_absolute_error: 12.4842
# Epoch 100/200
#  - 0s - loss: 12.4640 - mean_absolute_error: 12.4640
# Epoch 101/200
#  - 0s - loss: 12.4279 - mean_absolute_error: 12.4279
# Epoch 102/200
#  - 0s - loss: 12.4471 - mean_absolute_error: 12.4471
# Epoch 103/200
#  - 0s - loss: 12.4618 - mean_absolute_error: 12.4618
# Epoch 104/200
#  - 0s - loss: 12.4451 - mean_absolute_error: 12.4451
# Epoch 105/200
#  - 0s - loss: 12.4391 - mean_absolute_error: 12.4391
# Epoch 106/200
#  - 0s - loss: 12.4386 - mean_absolute_error: 12.4386
# Epoch 107/200
#  - 0s - loss: 12.4356 - mean_absolute_error: 12.4356
# Epoch 108/200
#  - 0s - loss: 12.4414 - mean_absolute_error: 12.4414
# Epoch 109/200
#  - 0s - loss: 12.4620 - mean_absolute_error: 12.4620
# Epoch 110/200
#  - 0s - loss: 12.4264 - mean_absolute_error: 12.4264
# Epoch 111/200
#  - 0s - loss: 12.4165 - mean_absolute_error: 12.4165
# Epoch 112/200
#  - 0s - loss: 12.4300 - mean_absolute_error: 12.4300
# Epoch 113/200
#  - 0s - loss: 12.4820 - mean_absolute_error: 12.4820
# Epoch 114/200
#  - 0s - loss: 12.4514 - mean_absolute_error: 12.4514
# Epoch 115/200
#  - 0s - loss: 12.4336 - mean_absolute_error: 12.4336
# Epoch 116/200
#  - 0s - loss: 12.4295 - mean_absolute_error: 12.4295
# Epoch 117/200
#  - 0s - loss: 12.4469 - mean_absolute_error: 12.4469
# Epoch 118/200
#  - 0s - loss: 12.4272 - mean_absolute_error: 12.4272
# Epoch 119/200
#  - 0s - loss: 12.4236 - mean_absolute_error: 12.4236
# Epoch 120/200
#  - 0s - loss: 12.4222 - mean_absolute_error: 12.4222
# Epoch 121/200
#  - 0s - loss: 12.4235 - mean_absolute_error: 12.4235
# Epoch 122/200
#  - 0s - loss: 12.4370 - mean_absolute_error: 12.4370
# Epoch 123/200
# ...
# Epoch 161/200
#  - 0s - loss: 12.3947 - mean_absolute_error: 12.3947
# Epoch 162/200
#  - 0s - loss: 12.3719 - mean_absolute_error: 12.3719
# Epoch 163/200
#  - 0s - loss: 12.3575 - mean_absolute_error: 12.3575
# Epoch 164/200
#  - 0s - loss: 12.3668 - mean_absolute_error: 12.3668
# Epoch 165/200
#  - 0s - loss: 12.3860 - mean_absolute_error: 12.3860
# Epoch 166/200
#  - 0s - loss: 12.3849 - mean_absolute_error: 12.3849
# Epoch 167/200
#  - 0s - loss: 12.3800 - mean_absolute_error: 12.3800
# Epoch 168/200
#  - 0s - loss: 12.3920 - mean_absolute_error: 12.3920
# Epoch 169/200
#  - 0s - loss: 12.3709 - mean_absolute_error: 12.3709
# Epoch 170/200
#  - 0s - loss: 12.3769 - mean_absolute_error: 12.3769
# Epoch 171/200
#  - 0s - loss: 12.3527 - mean_absolute_error: 12.3527
# Epoch 172/200
#  - 0s - loss: 12.3630 - mean_absolute_error: 12.3630
# Epoch 173/200
#  - 0s - loss: 12.3738 - mean_absolute_error: 12.3738
# Epoch 174/200
#  - 0s - loss: 12.3651 - mean_absolute_error: 12.3651
# Epoch 175/200
#  - 0s - loss: 12.3660 - mean_absolute_error: 12.3660
# Epoch 176/200
#  - 0s - loss: 12.3564 - mean_absolute_error: 12.3564
# Epoch 177/200
#  - 0s - loss: 12.3580 - mean_absolute_error: 12.3580
# Epoch 178/200
#  - 0s - loss: 12.3616 - mean_absolute_error: 12.3616
# Epoch 179/200
#  - 0s - loss: 12.3620 - mean_absolute_error: 12.3620
# Epoch 180/200
#  - 0s - loss: 12.3683 - mean_absolute_error: 12.3683
# Epoch 181/200
#  - 0s - loss: 12.3509 - mean_absolute_error: 12.3509
# Epoch 182/200
#  - 0s - loss: 12.3717 - mean_absolute_error: 12.3717
# Epoch 183/200
#  - 0s - loss: 12.3479 - mean_absolute_error: 12.3479
# Epoch 184/200
#  - 0s - loss: 12.3581 - mean_absolute_error: 12.3581
# Epoch 185/200
#  - 0s - loss: 12.3624 - mean_absolute_error: 12.3624
# Epoch 186/200
#  - 0s - loss: 12.3445 - mean_absolute_error: 12.3445
# Epoch 187/200
#  - 0s - loss: 12.3713 - mean_absolute_error: 12.3713
# Epoch 188/200
#  - 0s - loss: 12.3689 - mean_absolute_error: 12.3689
# Epoch 189/200
#  - 0s - loss: 12.3564 - mean_absolute_error: 12.3564
# Epoch 190/200
#  - 0s - loss: 12.3424 - mean_absolute_error: 12.3424
# Epoch 191/200
#  - 0s - loss: 12.3402 - mean_absolute_error: 12.3402
# Epoch 192/200
#  - 0s - loss: 12.3518 - mean_absolute_error: 12.3518
# Epoch 193/200
#  - 0s - loss: 12.3366 - mean_absolute_error: 12.3366
# Epoch 194/200
#  - 0s - loss: 12.3548 - mean_absolute_error: 12.3548
# Epoch 195/200
#  - 0s - loss: 12.3557 - mean_absolute_error: 12.3557
# Epoch 196/200
#  - 0s - loss: 12.3583 - mean_absolute_error: 12.3583
# Epoch 197/200
#  - 0s - loss: 12.3379 - mean_absolute_error: 12.3379
# Epoch 198/200
#  - 0s - loss: 12.3606 - mean_absolute_error: 12.3606
# Epoch 199/200
#  - 0s - loss: 12.3301 - mean_absolute_error: 12.3301
# Epoch 200/200
#  - 0s - loss: 12.3526 - mean_absolute_error: 12.3526
# Epoch 1/200
#  - 1s - loss: 127.2022 - mean_absolute_error: 127.2022
# Epoch 2/200
#  - 0s - loss: 126.3133 - mean_absolute_error: 126.3133
# Epoch 3/200
#  - 0s - loss: 122.1200 - mean_absolute_error: 122.1200
# Epoch 4/200
#  - 0s - loss: 110.4279 - mean_absolute_error: 110.4279
# Epoch 5/200
#  - 0s - loss: 87.2677 - mean_absolute_error: 87.2677
# Epoch 6/200
#  - 0s - loss: 64.5587 - mean_absolute_error: 64.5587
# Epoch 7/200
#  - 0s - loss: 57.5362 - mean_absolute_error: 57.5362
# Epoch 8/200
#  - 0s - loss: 54.7765 - mean_absolute_error: 54.7765
# Epoch 9/200
#  - 0s - loss: 52.3299 - mean_absolute_error: 52.3299
# Epoch 10/200
#  - 0s - loss: 49.7650 - mean_absolute_error: 49.7650
# Epoch 11/200
#  - 0s - loss: 47.1741 - mean_absolute_error: 47.1741
# Epoch 12/200
#  - 0s - loss: 44.7182 - mean_absolute_error: 44.7182
# Epoch 13/200
#  - 0s - loss: 42.7138 - mean_absolute_error: 42.7138
# Epoch 14/200
#  - 0s - loss: 41.0695 - mean_absolute_error: 41.0695
# Epoch 15/200
#  - 0s - loss: 39.5425 - mean_absolute_error: 39.5425
# Epoch 16/200
#  - 0s - loss: 38.0010 - mean_absolute_error: 38.0010
# Epoch 17/200
#  - 0s - loss: 36.3860 - mean_absolute_error: 36.3860
# Epoch 18/200
#  - 0s - loss: 34.7136 - mean_absolute_error: 34.7136
# Epoch 19/200
#  - 0s - loss: 32.9345 - mean_absolute_error: 32.9345
# Epoch 20/200
#  - 0s - loss: 31.0362 - mean_absolute_error: 31.0362
# Epoch 21/200
#  - 0s - loss: 29.0120 - mean_absolute_error: 29.0120
# Epoch 22/200
#  - 0s - loss: 26.9852 - mean_absolute_error: 26.9852
# Epoch 23/200
#  - 0s - loss: 25.0617 - mean_absolute_error: 25.0617
# Epoch 24/200
#  - 0s - loss: 23.3807 - mean_absolute_error: 23.3807
# Epoch 25/200
#  - 0s - loss: 21.9346 - mean_absolute_error: 21.9346
# Epoch 26/200
#  - 0s - loss: 20.7249 - mean_absolute_error: 20.7249
# Epoch 27/200
#  - 0s - loss: 19.6703 - mean_absolute_error: 19.6703
# Epoch 28/200
#  - 0s - loss: 18.7744 - mean_absolute_error: 18.7744
# Epoch 29/200
#  - 0s - loss: 17.9258 - mean_absolute_error: 17.9258
# Epoch 30/200
#  - 0s - loss: 17.1683 - mean_absolute_error: 17.1683
# Epoch 31/200
#  - 0s - loss: 16.4801 - mean_absolute_error: 16.4801
# Epoch 32/200
#  - 0s - loss: 15.8699 - mean_absolute_error: 15.8699
# Epoch 33/200
#  - 0s - loss: 15.3525 - mean_absolute_error: 15.3525
# Epoch 34/200
#  - 0s - loss: 14.9396 - mean_absolute_error: 14.9396
# Epoch 35/200
#  - 0s - loss: 14.5236 - mean_absolute_error: 14.5236
# Epoch 36/200
#  - 0s - loss: 14.2091 - mean_absolute_error: 14.2091
# Epoch 37/200
#  - 0s - loss: 13.9557 - mean_absolute_error: 13.9557
# Epoch 38/200
#  - 0s - loss: 13.7004 - mean_absolute_error: 13.7004
# Epoch 39/200
#  - 0s - loss: 13.5143 - mean_absolute_error: 13.5143
# Epoch 40/200
#  - 0s - loss: 13.3182 - mean_absolute_error: 13.3182
# Epoch 41/200
#  - 0s - loss: 13.1824 - mean_absolute_error: 13.1824
# Epoch 42/200
#  - 0s - loss: 13.0863 - mean_absolute_error: 13.0863
# Epoch 43/200
#  - 0s - loss: 12.9741 - mean_absolute_error: 12.9741
# Epoch 44/200
#  - 0s - loss: 12.9261 - mean_absolute_error: 12.9261
# Epoch 45/200
#  - 0s - loss: 12.8547 - mean_absolute_error: 12.8547
# Epoch 46/200
#  - 0s - loss: 12.8082 - mean_absolute_error: 12.8082
# Epoch 47/200
#  - 0s - loss: 12.7518 - mean_absolute_error: 12.7518
# Epoch 48/200
#  - 0s - loss: 12.7073 - mean_absolute_error: 12.7073
# Epoch 49/200
#  - 0s - loss: 12.6572 - mean_absolute_error: 12.6572
# Epoch 50/200
#  - 0s - loss: 12.6718 - mean_absolute_error: 12.6718
# Epoch 51/200
#  - 0s - loss: 12.6517 - mean_absolute_error: 12.6517
# Epoch 52/200
#  - 0s - loss: 12.6446 - mean_absolute_error: 12.6446
# Epoch 53/200
#  - 0s - loss: 12.5865 - mean_absolute_error: 12.5865
# Epoch 54/200
#  - 0s - loss: 12.5875 - mean_absolute_error: 12.5875
# Epoch 55/200
#  - 0s - loss: 12.5760 - mean_absolute_error: 12.5760
# Epoch 56/200
#  - 0s - loss: 12.5583 - mean_absolute_error: 12.5583
# Epoch 57/200
#  - 0s - loss: 12.5640 - mean_absolute_error: 12.5640
# Epoch 58/200
#  - 0s - loss: 12.5721 - mean_absolute_error: 12.5721
# Epoch 59/200
#  - 0s - loss: 12.5468 - mean_absolute_error: 12.5468
# Epoch 60/200
#  - 0s - loss: 12.5368 - mean_absolute_error: 12.5368
# Epoch 61/200
#  - 0s - loss: 12.5367 - mean_absolute_error: 12.5367
# Epoch 62/200
#  - 0s - loss: 12.5360 - mean_absolute_error: 12.5360
# Epoch 63/200
#  - 0s - loss: 12.5442 - mean_absolute_error: 12.5442
# Epoch 64/200
#  - 0s - loss: 12.5197 - mean_absolute_error: 12.5197
# Epoch 65/200
#  - 0s - loss: 12.5234 - mean_absolute_error: 12.5234
# Epoch 66/200
#  - 0s - loss: 12.5121 - mean_absolute_error: 12.5121
# Epoch 67/200
#  - 0s - loss: 12.5330 - mean_absolute_error: 12.5330
# Epoch 68/200
#  - 0s - loss: 12.5176 - mean_absolute_error: 12.5176
# Epoch 69/200
#  - 0s - loss: 12.5044 - mean_absolute_error: 12.5044
# Epoch 70/200
#  - 0s - loss: 12.4958 - mean_absolute_error: 12.4958
# Epoch 71/200
#  - 0s - loss: 12.5128 - mean_absolute_error: 12.5128
# Epoch 72/200
#  - 0s - loss: 12.5060 - mean_absolute_error: 12.5060
# Epoch 73/200
#  - 0s - loss: 12.5019 - mean_absolute_error: 12.5019
# Epoch 74/200
#  - 0s - loss: 12.5395 - mean_absolute_error: 12.5395
# Epoch 75/200
#  - 0s - loss: 12.4913 - mean_absolute_error: 12.4913
# Epoch 76/200
#  - 0s - loss: 12.4911 - mean_absolute_error: 12.4911
# Epoch 77/200
#  - 0s - loss: 12.4880 - mean_absolute_error: 12.4880
# Epoch 78/200
#  - 0s - loss: 12.4852 - mean_absolute_error: 12.4852
# Epoch 79/200
#  - 0s - loss: 12.4785 - mean_absolute_error: 12.4785
# Epoch 80/200
#  - 0s - loss: 12.4843 - mean_absolute_error: 12.4843
# Epoch 81/200
#  - 0s - loss: 12.4698 - mean_absolute_error: 12.4698
# Epoch 82/200
#  - 0s - loss: 12.4539 - mean_absolute_error: 12.4539
# Epoch 83/200
#  - 0s - loss: 12.4805 - mean_absolute_error: 12.4805
# Epoch 84/200
#  - 0s - loss: 12.4721 - mean_absolute_error: 12.4721
# Epoch 85/200
#  - 0s - loss: 12.4981 - mean_absolute_error: 12.4981
# Epoch 86/200
#  - 0s - loss: 12.4793 - mean_absolute_error: 12.4793
# Epoch 87/200
#  - 0s - loss: 12.5230 - mean_absolute_error: 12.5230
# Epoch 88/200
#  - 0s - loss: 12.4804 - mean_absolute_error: 12.4804
# Epoch 89/200
#  - 0s - loss: 12.4906 - mean_absolute_error: 12.4906
# Epoch 90/200
#  - 0s - loss: 12.4689 - mean_absolute_error: 12.4689
# Epoch 91/200
#  - 0s - loss: 12.4608 - mean_absolute_error: 12.4608
# Epoch 92/200
#  - 0s - loss: 12.4402 - mean_absolute_error: 12.4402
# Epoch 93/200
#  - 0s - loss: 12.4509 - mean_absolute_error: 12.4509
# Epoch 94/200
#  - 0s - loss: 12.4507 - mean_absolute_error: 12.4507
# Epoch 95/200
#  - 0s - loss: 12.4605 - mean_absolute_error: 12.4605
# Epoch 96/200
#  - 0s - loss: 12.4642 - mean_absolute_error: 12.4642
# Epoch 97/200
#  - 0s - loss: 12.4661 - mean_absolute_error: 12.4661
# Epoch 98/200
#  - 0s - loss: 12.4820 - mean_absolute_error: 12.4820
# Epoch 99/200
#  - 0s - loss: 12.4863 - mean_absolute_error: 12.4863
# Epoch 100/200
#  - 0s - loss: 12.4490 - mean_absolute_error: 12.4490
# Epoch 101/200
#  - 0s - loss: 12.4466 - mean_absolute_error: 12.4466
# Epoch 102/200
#  - 0s - loss: 12.4616 - mean_absolute_error: 12.4616
# Epoch 103/200
#  - 0s - loss: 12.4530 - mean_absolute_error: 12.4530
# Epoch 104/200
#  - 0s - loss: 12.4394 - mean_absolute_error: 12.4394
# Epoch 105/200
#  - 0s - loss: 12.4578 - mean_absolute_error: 12.4578
# Epoch 106/200
#  - 0s - loss: 12.4643 - mean_absolute_error: 12.4643
# Epoch 107/200
#  - 0s - loss: 12.4497 - mean_absolute_error: 12.4497
# Epoch 108/200
#  - 0s - loss: 12.4769 - mean_absolute_error: 12.4769
# Epoch 109/200
#  - 0s - loss: 12.4297 - mean_absolute_error: 12.4297
# Epoch 110/200
#  - 0s - loss: 12.4316 - mean_absolute_error: 12.4316
# Epoch 111/200
#  - 0s - loss: 12.4129 - mean_absolute_error: 12.4129
# Epoch 112/200
#  - 0s - loss: 12.4344 - mean_absolute_error: 12.4344
# Epoch 113/200
#  - 0s - loss: 12.4272 - mean_absolute_error: 12.4272
# Epoch 114/200
#  - 0s - loss: 12.4448 - mean_absolute_error: 12.4448
# Epoch 115/200
#  - 0s - loss: 12.4183 - mean_absolute_error: 12.4183
# Epoch 116/200
#  - 0s - loss: 12.4298 - mean_absolute_error: 12.4298
# Epoch 117/200
#  - 0s - loss: 12.4272 - mean_absolute_error: 12.4272
# Epoch 118/200
#  - 0s - loss: 12.4375 - mean_absolute_error: 12.4375
# Epoch 119/200
#  - 0s - loss: 12.4510 - mean_absolute_error: 12.4510
# Epoch 120/200
#  - 0s - loss: 12.4183 - mean_absolute_error: 12.4183
# Epoch 121/200
#  - 0s - loss: 12.4440 - mean_absolute_error: 12.4440
# Epoch 122/200
#  - 0s - loss: 12.4361 - mean_absolute_error: 12.4361
# Epoch 123/200
#  - 0s - loss: 12.4144 - mean_absolute_error: 12.4144
# Epoch 124/200
#  - 0s - loss: 12.4133 - mean_absolute_error: 12.4133
# Epoch 125/200
#  - 0s - loss: 12.4051 - mean_absolute_error: 12.4051
# Epoch 126/200
#  - 0s - loss: 12.4111 - mean_absolute_error: 12.4111
# Epoch 127/200
#  - 0s - loss: 12.4057 - mean_absolute_error: 12.4057
# Epoch 128/200
#  - 0s - loss: 12.4136 - mean_absolute_error: 12.4136
# Epoch 129/200
#  - 0s - loss: 12.4180 - mean_absolute_error: 12.4180
# Epoch 130/200
#  - 0s - loss: 12.4219 - mean_absolute_error: 12.4219
# Epoch 131/200
#  - 0s - loss: 12.4246 - mean_absolute_error: 12.4246
# Epoch 132/200
#  - 0s - loss: 12.4171 - mean_absolute_error: 12.4171
# Epoch 133/200
#  - 0s - loss: 12.3920 - mean_absolute_error: 12.3920
# Epoch 134/200
#  - 0s - loss: 12.4178 - mean_absolute_error: 12.4178
# Epoch 135/200
#  - 0s - loss: 12.3887 - mean_absolute_error: 12.3887
# Epoch 136/200
#  - 0s - loss: 12.3986 - mean_absolute_error: 12.3986
# Epoch 137/200
#  - 0s - loss: 12.3887 - mean_absolute_error: 12.3887
# Epoch 138/200
#  - 0s - loss: 12.4374 - mean_absolute_error: 12.4374
# Epoch 139/200
#  - 0s - loss: 12.3963 - mean_absolute_error: 12.3963
# Epoch 140/200
#  - 0s - loss: 12.4021 - mean_absolute_error: 12.4021
# Epoch 141/200
#  - 0s - loss: 12.4128 - mean_absolute_error: 12.4128
# Epoch 142/200
#  - 0s - loss: 12.3919 - mean_absolute_error: 12.3919
# Epoch 143/200
#  - 0s - loss: 12.3827 - mean_absolute_error: 12.3827
# Epoch 144/200
#  - 0s - loss: 12.4153 - mean_absolute_error: 12.4153
# Epoch 145/200
#  - 0s - loss: 12.3800 - mean_absolute_error: 12.3800
# Epoch 146/200
#  - 0s - loss: 12.3943 - mean_absolute_error: 12.3943
# Epoch 147/200
#  - 0s - loss: 12.3864 - mean_absolute_error: 12.3864
# Epoch 148/200
#  - 0s - loss: 12.3963 - mean_absolute_error: 12.3963
# Epoch 149/200
#  - 0s - loss: 12.3941 - mean_absolute_error: 12.3941
# Epoch 150/200
#  - 0s - loss: 12.3750 - mean_absolute_error: 12.3750
# Epoch 151/200
#  - 0s - loss: 12.3907 - mean_absolute_error: 12.3907
# Epoch 152/200
#  - 0s - loss: 12.3981 - mean_absolute_error: 12.3981
# Epoch 153/200
#  - 0s - loss: 12.3688 - mean_absolute_error: 12.3688
# Epoch 154/200
#  - 0s - loss: 12.3814 - mean_absolute_error: 12.3814
# Epoch 155/200
#  - 0s - loss: 12.4143 - mean_absolute_error: 12.4143
# Epoch 156/200
#  - 0s - loss: 12.3775 - mean_absolute_error: 12.3775
# Epoch 157/200
#  - 0s - loss: 12.3868 - mean_absolute_error: 12.3868
# Epoch 158/200
#  - 0s - loss: 12.3833 - mean_absolute_error: 12.3833
# Epoch 159/200
#  - 0s - loss: 12.3738 - mean_absolute_error: 12.3738
# Epoch 160/200
#  - 0s - loss: 12.3810 - mean_absolute_error: 12.3810
# Epoch 161/200
#  - 0s - loss: 12.3624 - mean_absolute_error: 12.3624
# Epoch 162/200
#  - 0s - loss: 12.3757 - mean_absolute_error: 12.3757
# Epoch 163/200
#  - 0s - loss: 12.3855 - mean_absolute_error: 12.3855
# Epoch 164/200
#  - 0s - loss: 12.3424 - mean_absolute_error: 12.3424
# Epoch 165/200
#  - 0s - loss: 12.3902 - mean_absolute_error: 12.3902
# Epoch 166/200
#  - 0s - loss: 12.3654 - mean_absolute_error: 12.3654
# Epoch 167/200
#  - 0s - loss: 12.3559 - mean_absolute_error: 12.3559
# Epoch 168/200
#  - 0s - loss: 12.3819 - mean_absolute_error: 12.3819
# Epoch 169/200
#  - 0s - loss: 12.3779 - mean_absolute_error: 12.3779
# Epoch 170/200
#  - 0s - loss: 12.3712 - mean_absolute_error: 12.3712
# Epoch 171/200
#  - 0s - loss: 12.3529 - mean_absolute_error: 12.3529
# Epoch 172/200
#  - 0s - loss: 12.3643 - mean_absolute_error: 12.3643
# Epoch 173/200
#  - 0s - loss: 12.3426 - mean_absolute_error: 12.3426
# Epoch 174/200
#  - 0s - loss: 12.3486 - mean_absolute_error: 12.3486
# Epoch 175/200
#  - 0s - loss: 12.3523 - mean_absolute_error: 12.3523
# Epoch 176/200
#  - 0s - loss: 12.3641 - mean_absolute_error: 12.3641
# Epoch 177/200
#  - 0s - loss: 12.3378 - mean_absolute_error: 12.3378
# Epoch 178/200
#  - 0s - loss: 12.3537 - mean_absolute_error: 12.3537
# Epoch 179/200
#  - 0s - loss: 12.3443 - mean_absolute_error: 12.3443
# Epoch 180/200
#  - 0s - loss: 12.3630 - mean_absolute_error: 12.3630
# Epoch 181/200
#  - 0s - loss: 12.3447 - mean_absolute_error: 12.3447
# Epoch 182/200
#  - 0s - loss: 12.3704 - mean_absolute_error: 12.3704
# Epoch 183/200
#  - 0s - loss: 12.3556 - mean_absolute_error: 12.3556
# Epoch 184/200
#  - 0s - loss: 12.3360 - mean_absolute_error: 12.3360
# Epoch 185/200
#  - 0s - loss: 12.3511 - mean_absolute_error: 12.3511
# Epoch 186/200
#  - 0s - loss: 12.3447 - mean_absolute_error: 12.3447
# Epoch 187/200
#  - 0s - loss: 12.3536 - mean_absolute_error: 12.3536
# Epoch 188/200
#  - 0s - loss: 12.3360 - mean_absolute_error: 12.3360
# Epoch 189/200
#  - 0s - loss: 12.3265 - mean_absolute_error: 12.3265
# Epoch 190/200
#  - 0s - loss: 12.3327 - mean_absolute_error: 12.3327
# Epoch 191/200
#  - 0s - loss: 12.3315 - mean_absolute_error: 12.3315
# Epoch 192/200
#  - 0s - loss: 12.3389 - mean_absolute_error: 12.3389
# Epoch 193/200
#  - 0s - loss: 12.3530 - mean_absolute_error: 12.3530
# Epoch 194/200
#  - 0s - loss: 12.3689 - mean_absolute_error: 12.3689
# Epoch 195/200
#  - 0s - loss: 12.3271 - mean_absolute_error: 12.3271
# Epoch 196/200
#  - 0s - loss: 12.3595 - mean_absolute_error: 12.3595
# Epoch 197/200
#  - 0s - loss: 12.3009 - mean_absolute_error: 12.3009
# Epoch 198/200
#  - 0s - loss: 12.4263 - mean_absolute_error: 12.4263
# Epoch 199/200
#  - 0s - loss: 12.3477 - mean_absolute_error: 12.3477
# Epoch 200/200
#  - 0s - loss: 12.3390 - mean_absolute_error: 12.3390

# %%
# TRYING TO FIND THE DISTRIBUTION OF THE RANDOM SEARCH RESULTS OF NEURAL NETWROKS

# %%
# compare samples
stat, p = normaltest(L_nn_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The Samples from the  Random Search tuned Neural Networks follow a Gaussian distribution (fail to reject H0)')
else:
	print('The Samples from the  Random Search tuned Neural Networks does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=0.525, p=0.769
# The Samples from the  Random Search tuned Neural Networks follow a Gaussian distribution (fail to reject H0)

# %%
#BAYESIAN SEARCH:

# %%
time14=time.time() #COMPUTATIONAL TIME START
def create_model(neurons=256,activation='relu'):
	# create model

    NN_model = Sequential()
    # The Input Layer :
    NN_model.add(Dense(neurons, input_dim=24,kernel_initializer='uniform', activation=activation))
    # The Hidden Layers :
    NN_model.add(Dense(neurons, kernel_initializer='uniform',activation=activation))
    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='uniform'))
    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    #NN_model.summary()
    return NN_model
 
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# create model
model = KerasRegressor(build_fn=create_model, verbose=2)
searchcv = BayesSearchCV(
    model,
    search_spaces={'activation': ('relu','tanh','linear'),'neurons': (5,400),
                'epochs':(50,300),'batch_size':(5,100)},
    n_iter=10,
    cv=10,scoring='neg_mean_absolute_error',random_state=3,
    n_jobs=-1,verbose=2
)
searchcv.fit(X_train_new,Y_train)
time15=time.time()-time14#ENDING OF COMPUTATIONAL TIME
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.6min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.6min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  2.1min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  2.3min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   43.7s remaining:   43.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   50.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   27.9s remaining:   27.9s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   31.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   53.0s remaining:   53.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   55.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   40.7s remaining:   40.7s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   42.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   16.8s remaining:   16.8s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   18.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.1min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.2min finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:   16.6s remaining:   16.6s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   18.1s finished
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:  1.7min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:  1.8min finished
# Epoch 1/122
#  - 2s - loss: 126.7860 - mean_absolute_error: 126.7860
# Epoch 2/122
#  - 0s - loss: 118.9512 - mean_absolute_error: 118.9512
# Epoch 3/122
#  - 0s - loss: 106.4285 - mean_absolute_error: 106.4285
# Epoch 4/122
#  - 0s - loss: 98.1178 - mean_absolute_error: 98.1178
# Epoch 5/122
#  - 0s - loss: 91.0750 - mean_absolute_error: 91.0750
# Epoch 6/122
#  - 0s - loss: 84.5251 - mean_absolute_error: 84.5251
# Epoch 7/122
#  - 0s - loss: 78.2454 - mean_absolute_error: 78.2454
# Epoch 8/122
#  - 0s - loss: 72.1376 - mean_absolute_error: 72.1376
# Epoch 9/122
#  - 0s - loss: 66.1488 - mean_absolute_error: 66.1488
# Epoch 10/122
#  - 0s - loss: 60.2473 - mean_absolute_error: 60.2473
# Epoch 11/122
#  - 0s - loss: 54.4138 - mean_absolute_error: 54.4138
# Epoch 12/122
#  - 0s - loss: 48.6365 - mean_absolute_error: 48.6365
# Epoch 13/122
#  - 0s - loss: 42.9060 - mean_absolute_error: 42.9060
# Epoch 14/122
#  - 0s - loss: 37.2247 - mean_absolute_error: 37.2247
# Epoch 15/122
#  - 0s - loss: 31.6254 - mean_absolute_error: 31.6254
# Epoch 16/122
#  - 0s - loss: 26.3511 - mean_absolute_error: 26.3511
# Epoch 17/122
#  - 0s - loss: 21.8743 - mean_absolute_error: 21.8743
# Epoch 18/122
#  - 0s - loss: 18.6695 - mean_absolute_error: 18.6695
# Epoch 19/122
#  - 0s - loss: 16.7007 - mean_absolute_error: 16.7007
# Epoch 20/122
#  - 0s - loss: 15.5934 - mean_absolute_error: 15.5934
# Epoch 21/122
#  - 0s - loss: 14.9846 - mean_absolute_error: 14.9846
# Epoch 22/122
#  - 0s - loss: 14.6810 - mean_absolute_error: 14.6810
# Epoch 23/122
#  - 0s - loss: 14.5138 - mean_absolute_error: 14.5138
# Epoch 24/122
#  - 0s - loss: 14.4250 - mean_absolute_error: 14.4250
# Epoch 25/122
#  - 0s - loss: 14.4257 - mean_absolute_error: 14.4257
# Epoch 26/122
#  - 0s - loss: 14.3700 - mean_absolute_error: 14.3700
# Epoch 27/122
#  - 0s - loss: 14.3703 - mean_absolute_error: 14.3703
# Epoch 28/122
#  - 0s - loss: 14.3161 - mean_absolute_error: 14.3161
# Epoch 29/122
#  - 0s - loss: 14.3493 - mean_absolute_error: 14.3493
# Epoch 30/122
#  - 0s - loss: 14.2913 - mean_absolute_error: 14.2913
# Epoch 31/122
#  - 0s - loss: 14.2739 - mean_absolute_error: 14.2739
# Epoch 32/122
#  - 0s - loss: 14.2493 - mean_absolute_error: 14.2493
# Epoch 33/122
#  - 0s - loss: 14.1218 - mean_absolute_error: 14.1218
# Epoch 34/122
#  - 0s - loss: 13.9055 - mean_absolute_error: 13.9055
# Epoch 35/122
#  - 0s - loss: 13.6135 - mean_absolute_error: 13.6135
# Epoch 36/122
#  - 0s - loss: 13.4635 - mean_absolute_error: 13.4635
# Epoch 37/122
#  - 0s - loss: 13.3285 - mean_absolute_error: 13.3285
# Epoch 38/122
#  - 0s - loss: 13.3434 - mean_absolute_error: 13.3434
# Epoch 39/122
#  - 0s - loss: 13.1656 - mean_absolute_error: 13.1656
# Epoch 40/122
#  - 0s - loss: 13.0276 - mean_absolute_error: 13.0276
# Epoch 41/122
#  - 0s - loss: 12.9595 - mean_absolute_error: 12.9595
# Epoch 42/122
#  - 0s - loss: 12.9160 - mean_absolute_error: 12.9160
# Epoch 43/122
#  - 0s - loss: 12.8584 - mean_absolute_error: 12.8584
# Epoch 44/122
#  - 0s - loss: 12.8047 - mean_absolute_error: 12.8047
# Epoch 45/122
#  - 0s - loss: 12.7696 - mean_absolute_error: 12.7696
# Epoch 46/122
#  - 0s - loss: 12.7020 - mean_absolute_error: 12.7020
# Epoch 47/122
#  - 0s - loss: 12.6554 - mean_absolute_error: 12.6554
# Epoch 48/122
#  - 0s - loss: 12.6415 - mean_absolute_error: 12.6415
# Epoch 49/122
#  - 0s - loss: 12.6223 - mean_absolute_error: 12.6223
# Epoch 50/122
#  - 0s - loss: 12.6088 - mean_absolute_error: 12.6088
# Epoch 51/122
#  - 0s - loss: 12.5994 - mean_absolute_error: 12.5994
# Epoch 52/122
#  - 0s - loss: 12.5855 - mean_absolute_error: 12.5855
# Epoch 53/122
#  - 0s - loss: 12.5879 - mean_absolute_error: 12.5879
# Epoch 54/122
#  - 0s - loss: 12.5544 - mean_absolute_error: 12.5544
# Epoch 55/122
#  - 0s - loss: 12.5649 - mean_absolute_error: 12.5649
# Epoch 56/122
#  - 0s - loss: 12.5368 - mean_absolute_error: 12.5368
# Epoch 57/122
#  - 0s - loss: 12.5495 - mean_absolute_error: 12.5495
# Epoch 58/122
#  - 0s - loss: 12.5314 - mean_absolute_error: 12.5314
# Epoch 59/122
#  - 0s - loss: 12.5210 - mean_absolute_error: 12.5210
# Epoch 60/122
#  - 0s - loss: 12.4720 - mean_absolute_error: 12.4720
# Epoch 61/122
#  - 0s - loss: 12.4777 - mean_absolute_error: 12.4777
# Epoch 62/122
#  - 0s - loss: 12.4555 - mean_absolute_error: 12.4555
# Epoch 63/122
#  - 0s - loss: 12.4486 - mean_absolute_error: 12.4486
# Epoch 64/122
#  - 0s - loss: 12.4363 - mean_absolute_error: 12.4363
# Epoch 65/122
#  - 0s - loss: 12.4261 - mean_absolute_error: 12.4261
# Epoch 66/122
#  - 0s - loss: 12.4216 - mean_absolute_error: 12.4216
# Epoch 67/122
#  - 0s - loss: 12.4155 - mean_absolute_error: 12.4155
# Epoch 68/122
#  - 0s - loss: 12.3984 - mean_absolute_error: 12.3984
# Epoch 69/122
#  - 0s - loss: 12.3727 - mean_absolute_error: 12.3727
# Epoch 70/122
#  - 0s - loss: 12.3727 - mean_absolute_error: 12.3727
# Epoch 71/122
#  - 0s - loss: 12.3659 - mean_absolute_error: 12.3659
# Epoch 72/122
#  - 0s - loss: 12.3522 - mean_absolute_error: 12.3522
# Epoch 73/122
#  - 0s - loss: 12.3510 - mean_absolute_error: 12.3510
# Epoch 74/122
#  - 0s - loss: 12.3482 - mean_absolute_error: 12.3482
# Epoch 75/122
#  - 0s - loss: 12.3256 - mean_absolute_error: 12.3256
# Epoch 76/122
#  - 0s - loss: 12.3211 - mean_absolute_error: 12.3211
# Epoch 77/122
#  - 0s - loss: 12.3116 - mean_absolute_error: 12.3116
# Epoch 78/122
#  - 0s - loss: 12.2973 - mean_absolute_error: 12.2973
# Epoch 79/122
#  - 0s - loss: 12.3003 - mean_absolute_error: 12.3003
# Epoch 80/122
#  - 0s - loss: 12.2808 - mean_absolute_error: 12.2808
# Epoch 81/122
#  - 0s - loss: 12.2791 - mean_absolute_error: 12.2791
# Epoch 82/122
#  - 0s - loss: 12.2377 - mean_absolute_error: 12.2377
# Epoch 83/122
#  - 0s - loss: 12.2719 - mean_absolute_error: 12.2719
# Epoch 84/122
#  - 0s - loss: 12.2429 - mean_absolute_error: 12.2429
# Epoch 85/122
#  - 0s - loss: 12.2563 - mean_absolute_error: 12.2563
# Epoch 86/122
#  - 0s - loss: 12.2354 - mean_absolute_error: 12.2354
# Epoch 87/122
#  - 0s - loss: 12.2354 - mean_absolute_error: 12.2354
# Epoch 88/122
#  - 0s - loss: 12.2373 - mean_absolute_error: 12.2373
# Epoch 89/122
#  - 0s - loss: 12.2171 - mean_absolute_error: 12.2171
# Epoch 90/122
#  - 0s - loss: 12.2205 - mean_absolute_error: 12.2205
# Epoch 91/122
#  - 0s - loss: 12.2066 - mean_absolute_error: 12.2066
# Epoch 92/122
#  - 0s - loss: 12.1939 - mean_absolute_error: 12.1939
# Epoch 93/122
#  - 0s - loss: 12.1840 - mean_absolute_error: 12.1840
# Epoch 94/122
#  - 0s - loss: 12.1768 - mean_absolute_error: 12.1768
# Epoch 95/122
#  - 0s - loss: 12.1827 - mean_absolute_error: 12.1827
# Epoch 96/122
#  - 0s - loss: 12.1840 - mean_absolute_error: 12.1840
# Epoch 97/122
#  - 0s - loss: 12.1776 - mean_absolute_error: 12.1776
# Epoch 98/122
#  - 0s - loss: 12.1587 - mean_absolute_error: 12.1587
# Epoch 99/122
#  - 0s - loss: 12.1622 - mean_absolute_error: 12.1622
# Epoch 100/122
#  - 0s - loss: 12.1504 - mean_absolute_error: 12.1504
# Epoch 101/122
#  - 0s - loss: 12.1439 - mean_absolute_error: 12.1439
# Epoch 102/122
#  - 0s - loss: 12.1315 - mean_absolute_error: 12.1315
# Epoch 103/122
#  - 0s - loss: 12.1283 - mean_absolute_error: 12.1283
# Epoch 104/122
#  - 0s - loss: 12.1260 - mean_absolute_error: 12.1260
# Epoch 105/122
#  - 0s - loss: 12.1194 - mean_absolute_error: 12.1194
# Epoch 106/122
#  - 0s - loss: 12.1139 - mean_absolute_error: 12.1139
# Epoch 107/122
#  - 0s - loss: 12.1205 - mean_absolute_error: 12.1205
# Epoch 108/122
#  - 0s - loss: 12.0927 - mean_absolute_error: 12.0927
# Epoch 109/122
#  - 0s - loss: 12.0958 - mean_absolute_error: 12.0958
# Epoch 110/122
#  - 0s - loss: 12.0828 - mean_absolute_error: 12.0828
# Epoch 111/122
#  - 0s - loss: 12.1043 - mean_absolute_error: 12.1043
# Epoch 112/122
#  - 0s - loss: 12.0904 - mean_absolute_error: 12.0904
# Epoch 113/122
#  - 0s - loss: 12.0718 - mean_absolute_error: 12.0718
# Epoch 114/122
#  - 0s - loss: 12.0606 - mean_absolute_error: 12.0606
# Epoch 115/122
#  - 0s - loss: 12.0675 - mean_absolute_error: 12.0675
# Epoch 116/122
#  - 0s - loss: 12.0484 - mean_absolute_error: 12.0484
# Epoch 117/122
#  - 0s - loss: 12.0676 - mean_absolute_error: 12.0676
# Epoch 118/122
#  - 0s - loss: 12.0591 - mean_absolute_error: 12.0591
# Epoch 119/122
#  - 0s - loss: 12.0363 - mean_absolute_error: 12.0363
# Epoch 120/122
#  - 0s - loss: 12.0525 - mean_absolute_error: 12.0525
# Epoch 121/122
#  - 0s - loss: 12.0340 - mean_absolute_error: 12.0340
# Epoch 122/122
#  - 0s - loss: 12.0279 - mean_absolute_error: 12.0279

# %%
print("The total time for computation of Bayesian Search on Neural networks is: %0.3f" % time15)
print("Best MAE score from the Bayesian Search tuning on training data: %0.3f" % searchcv.best_score_)
print("Best hyper parameters on Neural Networks using Bayesian Search is :")
searchcv.best_params_
# Out:
# The total time for computation of Bayesian Search on Neural networks is: 648.342
# Best MAE score from the Bayesian Search tuning on training data: -12.460
# Best hyper parameters on Neural Networks using Bayesian Search is :
# {'activation': 'tanh', 'batch_size': 97, 'epochs': 122, 'neurons': 122}

# %%
def create_model():
	# create model

    NN_model = Sequential()
    # The Input Layer :
    NN_model.add(Dense(122, input_dim=24,kernel_initializer='uniform', activation='tanh'))
    # The Hidden Layers :
    NN_model.add(Dense(122, kernel_initializer='uniform',activation='tanh'))
    # The Output Layer :
    NN_model.add(Dense(1, kernel_initializer='uniform'))
    # Compile the network :
    NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mae'])
    #NN_model.summary()
    return NN_model
 
# create model
model_nn_bs = KerasRegressor(build_fn=create_model, verbose=2,batch_size=97,epochs=122)
model_nn_bs.fit(X_train_new,Y_train)
nn_bs_test_pred= model_nn_bs.predict(X_test_new)
print('The MAE for the Neural Networks with Bayesian Search tuning on the Testing Data is : {:.4f} \n'.format(mean_absolute_error(Y_test,nn_bs_test_pred)))
# Out:
# Epoch 1/122
#  - 2s - loss: 126.7841 - mean_absolute_error: 126.7841
# Epoch 2/122
#  - 0s - loss: 118.8203 - mean_absolute_error: 118.8203
# Epoch 3/122
#  - 0s - loss: 105.9354 - mean_absolute_error: 105.9354
# Epoch 4/122
#  - 0s - loss: 97.5178 - mean_absolute_error: 97.5178
# Epoch 5/122
#  - 0s - loss: 90.4341 - mean_absolute_error: 90.4341
# Epoch 6/122
#  - 0s - loss: 83.8599 - mean_absolute_error: 83.8599
# Epoch 7/122
#  - 0s - loss: 77.5631 - mean_absolute_error: 77.5631
# Epoch 8/122
#  - 0s - loss: 71.4422 - mean_absolute_error: 71.4422
# Epoch 9/122
#  - 0s - loss: 65.4431 - mean_absolute_error: 65.4431
# Epoch 10/122
#  - 0s - loss: 59.5326 - mean_absolute_error: 59.5326
# Epoch 11/122
#  - 0s - loss: 53.6922 - mean_absolute_error: 53.6922
# Epoch 12/122
#  - 0s - loss: 47.9090 - mean_absolute_error: 47.9090
# Epoch 13/122
#  - 0s - loss: 42.1752 - mean_absolute_error: 42.1752
# Epoch 14/122
#  - 0s - loss: 36.4899 - mean_absolute_error: 36.4899
# Epoch 15/122
#  - 0s - loss: 30.9118 - mean_absolute_error: 30.9118
# Epoch 16/122
#  - 0s - loss: 25.7050 - mean_absolute_error: 25.7050
# Epoch 17/122
#  - 0s - loss: 21.3962 - mean_absolute_error: 21.3962
# Epoch 18/122
#  - 0s - loss: 18.3686 - mean_absolute_error: 18.3686
# Epoch 19/122
#  - 0s - loss: 16.5266 - mean_absolute_error: 16.5266
# Epoch 20/122
#  - 0s - loss: 15.4914 - mean_absolute_error: 15.4914
# Epoch 21/122
#  - 0s - loss: 14.9811 - mean_absolute_error: 14.9811
# Epoch 22/122
#  - 0s - loss: 14.6702 - mean_absolute_error: 14.6702
# Epoch 23/122
#  - 0s - loss: 14.4932 - mean_absolute_error: 14.4932
# Epoch 24/122
#  - 0s - loss: 14.3921 - mean_absolute_error: 14.3921
# Epoch 25/122
#  - 0s - loss: 14.3392 - mean_absolute_error: 14.3392
# Epoch 26/122
#  - 0s - loss: 14.2853 - mean_absolute_error: 14.2853
# Epoch 27/122
#  - 0s - loss: 14.1472 - mean_absolute_error: 14.1472
# Epoch 28/122
#  - 0s - loss: 14.0523 - mean_absolute_error: 14.0523
# Epoch 29/122
#  - 0s - loss: 14.1436 - mean_absolute_error: 14.1436
# Epoch 30/122
#  - 0s - loss: 13.7387 - mean_absolute_error: 13.7387
# Epoch 31/122
#  - 0s - loss: 13.5036 - mean_absolute_error: 13.5036
# Epoch 32/122
#  - 0s - loss: 13.3682 - mean_absolute_error: 13.3682
# Epoch 33/122
#  - 0s - loss: 13.4526 - mean_absolute_error: 13.4526
# Epoch 34/122
#  - 0s - loss: 13.3089 - mean_absolute_error: 13.3089
# Epoch 35/122
#  - 0s - loss: 13.2008 - mean_absolute_error: 13.2008
# Epoch 36/122
#  - 0s - loss: 13.1387 - mean_absolute_error: 13.1387
# Epoch 37/122
#  - 0s - loss: 13.0797 - mean_absolute_error: 13.0797
# Epoch 38/122
#  - 0s - loss: 13.0066 - mean_absolute_error: 13.0066
# Epoch 39/122
#  - 0s - loss: 12.9871 - mean_absolute_error: 12.9871
# Epoch 40/122
#  - 0s - loss: 12.8716 - mean_absolute_error: 12.8716
# Epoch 41/122
#  - 0s - loss: 12.8645 - mean_absolute_error: 12.8645
# Epoch 42/122
#  - 0s - loss: 12.8256 - mean_absolute_error: 12.8256
# Epoch 43/122
#  - 0s - loss: 12.8378 - mean_absolute_error: 12.8378
# Epoch 44/122
#  - 0s - loss: 12.7585 - mean_absolute_error: 12.7585
# Epoch 45/122
#  - 0s - loss: 12.7418 - mean_absolute_error: 12.7418
# Epoch 46/122
#  - 0s - loss: 12.7194 - mean_absolute_error: 12.7194
# Epoch 47/122
#  - 0s - loss: 12.7270 - mean_absolute_error: 12.7270
# Epoch 48/122
#  - 0s - loss: 12.6826 - mean_absolute_error: 12.6826
# Epoch 49/122
#  - 0s - loss: 12.6339 - mean_absolute_error: 12.6339
# Epoch 50/122
#  - 0s - loss: 12.6598 - mean_absolute_error: 12.6598
# Epoch 51/122
#  - 0s - loss: 12.6086 - mean_absolute_error: 12.6086
# Epoch 52/122
#  - 0s - loss: 12.5754 - mean_absolute_error: 12.5754
# Epoch 53/122
#  - 0s - loss: 12.5531 - mean_absolute_error: 12.5531
# Epoch 54/122
#  - 0s - loss: 12.5430 - mean_absolute_error: 12.5430
# Epoch 55/122
#  - 0s - loss: 12.5333 - mean_absolute_error: 12.5333
# Epoch 56/122
#  - 0s - loss: 12.5204 - mean_absolute_error: 12.5204
# Epoch 57/122
#  - 0s - loss: 12.5032 - mean_absolute_error: 12.5032
# Epoch 58/122
#  - 0s - loss: 12.4796 - mean_absolute_error: 12.4796
# Epoch 59/122
#  - 0s - loss: 12.4751 - mean_absolute_error: 12.4751
# Epoch 60/122
#  - 0s - loss: 12.4614 - mean_absolute_error: 12.4614
# Epoch 61/122
#  - 0s - loss: 12.4524 - mean_absolute_error: 12.4524
# Epoch 62/122
#  - 0s - loss: 12.4488 - mean_absolute_error: 12.4488
# Epoch 63/122
#  - 0s - loss: 12.4326 - mean_absolute_error: 12.4326
# Epoch 64/122
#  - 0s - loss: 12.4115 - mean_absolute_error: 12.4115
# Epoch 65/122
#  - 0s - loss: 12.4088 - mean_absolute_error: 12.4088
# Epoch 66/122
#  - 0s - loss: 12.3913 - mean_absolute_error: 12.3913
# Epoch 67/122
#  - 0s - loss: 12.3782 - mean_absolute_error: 12.3782
# Epoch 68/122
#  - 0s - loss: 12.3782 - mean_absolute_error: 12.3782
# Epoch 69/122
#  - 0s - loss: 12.3732 - mean_absolute_error: 12.3732
# Epoch 70/122
#  - 0s - loss: 12.3627 - mean_absolute_error: 12.3627
# Epoch 71/122
#  - 0s - loss: 12.3490 - mean_absolute_error: 12.3490
# Epoch 72/122
#  - 0s - loss: 12.3390 - mean_absolute_error: 12.3390
# Epoch 73/122
#  - 0s - loss: 12.3415 - mean_absolute_error: 12.3415
# Epoch 74/122
#  - 0s - loss: 12.3371 - mean_absolute_error: 12.3371
# Epoch 75/122
#  - 0s - loss: 12.3133 - mean_absolute_error: 12.3133
# Epoch 76/122
#  - 0s - loss: 12.2970 - mean_absolute_error: 12.2970
# Epoch 77/122
#  - 0s - loss: 12.3084 - mean_absolute_error: 12.3084
# Epoch 78/122
#  - 0s - loss: 12.2838 - mean_absolute_error: 12.2838
# Epoch 79/122
#  - 0s - loss: 12.2868 - mean_absolute_error: 12.2868
# Epoch 80/122
#  - 0s - loss: 12.2760 - mean_absolute_error: 12.2760
# Epoch 81/122
#  - 0s - loss: 12.2673 - mean_absolute_error: 12.2673
# Epoch 82/122
#  - 0s - loss: 12.2846 - mean_absolute_error: 12.2846
# Epoch 83/122
#  - 0s - loss: 12.2689 - mean_absolute_error: 12.2689
# Epoch 84/122
#  - 0s - loss: 12.2567 - mean_absolute_error: 12.2567
# Epoch 85/122
#  - 0s - loss: 12.2504 - mean_absolute_error: 12.2504
# Epoch 86/122
#  - 0s - loss: 12.2504 - mean_absolute_error: 12.2504
# Epoch 87/122
#  - 0s - loss: 12.2477 - mean_absolute_error: 12.2477
# Epoch 88/122
#  - 0s - loss: 12.2232 - mean_absolute_error: 12.2232
# Epoch 89/122
#  - 0s - loss: 12.2213 - mean_absolute_error: 12.2213
# Epoch 90/122
#  - 0s - loss: 12.2020 - mean_absolute_error: 12.2020
# Epoch 91/122
#  - 0s - loss: 12.1977 - mean_absolute_error: 12.1977
# Epoch 92/122
#  - 0s - loss: 12.1910 - mean_absolute_error: 12.1910
# Epoch 93/122
#  - 0s - loss: 12.1812 - mean_absolute_error: 12.1812
# Epoch 94/122
#  - 0s - loss: 12.1881 - mean_absolute_error: 12.1881
# Epoch 95/122
#  - 0s - loss: 12.1714 - mean_absolute_error: 12.1714
# Epoch 96/122
#  - 0s - loss: 12.2025 - mean_absolute_error: 12.2025
# Epoch 97/122
#  - 0s - loss: 12.1558 - mean_absolute_error: 12.1558
# Epoch 98/122
#  - 0s - loss: 12.1586 - mean_absolute_error: 12.1586
# Epoch 99/122
#  - 0s - loss: 12.1379 - mean_absolute_error: 12.1379
# Epoch 100/122
#  - 0s - loss: 12.1265 - mean_absolute_error: 12.1265
# Epoch 101/122
#  - 0s - loss: 12.1353 - mean_absolute_error: 12.1353
# Epoch 102/122
#  - 0s - loss: 12.1476 - mean_absolute_error: 12.1476
# Epoch 103/122
#  - 0s - loss: 12.1116 - mean_absolute_error: 12.1116
# Epoch 104/122
#  - 0s - loss: 12.1057 - mean_absolute_error: 12.1057
# Epoch 105/122
#  - 0s - loss: 12.1136 - mean_absolute_error: 12.1136
# Epoch 106/122
#  - 0s - loss: 12.1122 - mean_absolute_error: 12.1122
# Epoch 107/122
#  - 0s - loss: 12.0982 - mean_absolute_error: 12.0982
# Epoch 108/122
#  - 0s - loss: 12.0800 - mean_absolute_error: 12.0800
# Epoch 109/122
#  - 0s - loss: 12.0742 - mean_absolute_error: 12.0742
# Epoch 110/122
#  - 0s - loss: 12.0657 - mean_absolute_error: 12.0657
# Epoch 111/122
#  - 0s - loss: 12.0817 - mean_absolute_error: 12.0817
# Epoch 112/122
#  - 0s - loss: 12.0474 - mean_absolute_error: 12.0474
# Epoch 113/122
#  - 0s - loss: 12.0495 - mean_absolute_error: 12.0495
# Epoch 114/122
#  - 0s - loss: 12.0544 - mean_absolute_error: 12.0544
# Epoch 115/122
#  - 0s - loss: 12.0432 - mean_absolute_error: 12.0432
# Epoch 116/122
#  - 0s - loss: 12.0123 - mean_absolute_error: 12.0123
# Epoch 117/122
#  - 0s - loss: 12.0139 - mean_absolute_error: 12.0139
# Epoch 118/122
#  - 0s - loss: 12.0108 - mean_absolute_error: 12.0108
# Epoch 119/122
#  - 0s - loss: 11.9884 - mean_absolute_error: 11.9884
# Epoch 120/122
#  - 0s - loss: 11.9833 - mean_absolute_error: 11.9833
# Epoch 121/122
#  - 0s - loss: 11.9644 - mean_absolute_error: 11.9644
# Epoch 122/122
#  - 0s - loss: 11.9625 - mean_absolute_error: 11.9625
# The MAE for the Neural Networks with Bayesian Search tuning on the Testing Data is : 12.6039

# %%
#BAYESIAN SEARCH 30 ITERATIONS:

# %%
L_nn_bs=[]

# %%
for i in range(0,30):
    model_nn_bs.fit(X_train_new, Y_train)
    model_nn_test_pred_bs = model_nn_bs.predict(X_test_new)
    Q=abs(model_nn_test_pred_bs-Y_test)
    M= mean_absolute_error(Y_test, model_nn_test_pred_bs)
    L_nn_bs.append(mean_absolute_error(Y_test, model_nn_test_pred_bs))
# Out:
# Epoch 1/122
#  - 2s - loss: 126.7581 - mean_absolute_error: 126.7581
# Epoch 2/122
#  - 0s - loss: 118.6322 - mean_absolute_error: 118.6322
# Epoch 3/122
#  - 0s - loss: 105.9110 - mean_absolute_error: 105.9110
# Epoch 4/122
#  - 0s - loss: 97.5518 - mean_absolute_error: 97.5518
# Epoch 5/122
#  - 0s - loss: 90.4940 - mean_absolute_error: 90.4940
# Epoch 6/122
#  - 0s - loss: 83.9347 - mean_absolute_error: 83.9347
# Epoch 7/122
#  - 0s - loss: 77.6487 - mean_absolute_error: 77.6487
# Epoch 8/122
#  - 0s - loss: 71.5361 - mean_absolute_error: 71.5361
# Epoch 9/122
#  - 0s - loss: 65.5434 - mean_absolute_error: 65.5434
# Epoch 10/122
#  - 0s - loss: 59.6387 - mean_absolute_error: 59.6387
# Epoch 11/122
#  - 0s - loss: 53.8026 - mean_absolute_error: 53.8026
# Epoch 12/122
#  - 0s - loss: 48.0240 - mean_absolute_error: 48.0240
# Epoch 13/122
#  - 0s - loss: 42.2916 - mean_absolute_error: 42.2916
# Epoch 14/122
#  - 0s - loss: 36.6060 - mean_absolute_error: 36.6060
# Epoch 15/122
#  - 0s - loss: 31.0255 - mean_absolute_error: 31.0255
# Epoch 16/122
#  - 0s - loss: 25.8017 - mean_absolute_error: 25.8017
# Epoch 17/122
#  - 0s - loss: 21.4280 - mean_absolute_error: 21.4280
# Epoch 18/122
#  - 0s - loss: 18.3665 - mean_absolute_error: 18.3665
# Epoch 19/122
#  - 0s - loss: 16.5169 - mean_absolute_error: 16.5169
# Epoch 20/122
#  - 0s - loss: 15.4903 - mean_absolute_error: 15.4903
# Epoch 21/122
#  - 0s - loss: 15.0335 - mean_absolute_error: 15.0335
# Epoch 22/122
#  - 0s - loss: 14.6451 - mean_absolute_error: 14.6451
# Epoch 23/122
#  - 0s - loss: 14.4930 - mean_absolute_error: 14.4930
# Epoch 24/122
#  - 0s - loss: 14.3853 - mean_absolute_error: 14.3853
# Epoch 25/122
#  - 0s - loss: 14.2594 - mean_absolute_error: 14.2594
# Epoch 26/122
#  - 0s - loss: 14.2827 - mean_absolute_error: 14.2827
# Epoch 27/122
#  - 0s - loss: 14.1191 - mean_absolute_error: 14.1191
# Epoch 28/122
#  - 0s - loss: 13.8435 - mean_absolute_error: 13.8435
# Epoch 29/122
#  - 0s - loss: 13.6664 - mean_absolute_error: 13.6664
# Epoch 30/122
#  - 0s - loss: 13.7585 - mean_absolute_error: 13.7585
# Epoch 31/122
#  - 0s - loss: 13.4454 - mean_absolute_error: 13.4454
# Epoch 32/122
#  - 0s - loss: 13.3663 - mean_absolute_error: 13.3663
# Epoch 33/122
#  - 0s - loss: 13.3097 - mean_absolute_error: 13.3097
# Epoch 34/122
#  - 0s - loss: 13.3016 - mean_absolute_error: 13.3016
# Epoch 35/122
#  - 0s - loss: 13.2458 - mean_absolute_error: 13.2458
# Epoch 36/122
#  - 0s - loss: 13.2017 - mean_absolute_error: 13.2017
# Epoch 37/122
#  - 0s - loss: 12.9979 - mean_absolute_error: 12.9979
# Epoch 38/122
#  - 0s - loss: 12.9170 - mean_absolute_error: 12.9170
# Epoch 39/122
#  - 0s - loss: 12.8665 - mean_absolute_error: 12.8665
# Epoch 40/122
#  - 0s - loss: 12.8393 - mean_absolute_error: 12.8393
# Epoch 41/122
#  - 0s - loss: 12.7880 - mean_absolute_error: 12.7880
# Epoch 42/122
#  - 0s - loss: 12.7806 - mean_absolute_error: 12.7806
# Epoch 43/122
#  - 0s - loss: 12.7230 - mean_absolute_error: 12.7230
# Epoch 44/122
#  - 0s - loss: 12.7009 - mean_absolute_error: 12.7009
# Epoch 45/122
#  - 0s - loss: 12.6381 - mean_absolute_error: 12.6381
# Epoch 46/122
#  - 0s - loss: 12.6413 - mean_absolute_error: 12.6413
# Epoch 47/122
#  - 0s - loss: 12.6108 - mean_absolute_error: 12.6108
# Epoch 48/122
#  - 0s - loss: 12.5898 - mean_absolute_error: 12.5898
# Epoch 49/122
#  - 0s - loss: 12.5683 - mean_absolute_error: 12.5683
# Epoch 50/122
#  - 0s - loss: 12.5541 - mean_absolute_error: 12.5541
# Epoch 51/122
#  - 0s - loss: 12.5611 - mean_absolute_error: 12.5611
# Epoch 52/122
#  - 0s - loss: 12.5405 - mean_absolute_error: 12.5405
# Epoch 53/122
#  - 0s - loss: 12.5318 - mean_absolute_error: 12.5318
# Epoch 54/122
#  - 0s - loss: 12.5057 - mean_absolute_error: 12.5057
# Epoch 55/122
#  - 0s - loss: 12.5028 - mean_absolute_error: 12.5028
# Epoch 56/122
#  - 0s - loss: 12.4868 - mean_absolute_error: 12.4868
# Epoch 57/122
#  - 0s - loss: 12.4699 - mean_absolute_error: 12.4699
# Epoch 58/122
#  - 0s - loss: 12.4528 - mean_absolute_error: 12.4528
# Epoch 59/122
#  - 0s - loss: 12.4380 - mean_absolute_error: 12.4380
# Epoch 60/122
#  - 0s - loss: 12.4208 - mean_absolute_error: 12.4208
# Epoch 61/122
#  - 0s - loss: 12.4079 - mean_absolute_error: 12.4079
# Epoch 62/122
#  - 0s - loss: 12.4054 - mean_absolute_error: 12.4054
# Epoch 63/122
#  - 0s - loss: 12.3983 - mean_absolute_error: 12.3983
# Epoch 64/122
#  - 0s - loss: 12.3829 - mean_absolute_error: 12.3829
# Epoch 65/122
#  - 0s - loss: 12.4030 - mean_absolute_error: 12.4030
# Epoch 66/122
#  - 0s - loss: 12.3696 - mean_absolute_error: 12.3696
# Epoch 67/122
#  - 0s - loss: 12.3587 - mean_absolute_error: 12.3587
# Epoch 68/122
#  - 0s - loss: 12.3378 - mean_absolute_error: 12.3378
# Epoch 69/122
#  - 0s - loss: 12.3407 - mean_absolute_error: 12.3407
# Epoch 70/122
#  - 0s - loss: 12.3320 - mean_absolute_error: 12.3320
# Epoch 71/122
#  - 0s - loss: 12.3114 - mean_absolute_error: 12.3114
# Epoch 72/122
#  - 0s - loss: 12.2926 - mean_absolute_error: 12.2926
# Epoch 73/122
#  - 0s - loss: 12.2954 - mean_absolute_error: 12.2954
# Epoch 74/122
#  - 0s - loss: 12.2923 - mean_absolute_error: 12.2923
# Epoch 75/122
#  - 0s - loss: 12.2793 - mean_absolute_error: 12.2793
# Epoch 76/122
#  - 0s - loss: 12.2723 - mean_absolute_error: 12.2723
# Epoch 77/122
#  - 0s - loss: 12.2516 - mean_absolute_error: 12.2516
# Epoch 78/122
#  - 0s - loss: 12.2516 - mean_absolute_error: 12.2516
# Epoch 79/122
#  - 0s - loss: 12.2438 - mean_absolute_error: 12.2438
# Epoch 80/122
#  - 0s - loss: 12.2421 - mean_absolute_error: 12.2421
# Epoch 81/122
#  - 0s - loss: 12.2433 - mean_absolute_error: 12.2433
# Epoch 82/122
#  - 0s - loss: 12.2198 - mean_absolute_error: 12.2198
# Epoch 83/122
#  - 0s - loss: 12.2233 - mean_absolute_error: 12.2233
# Epoch 84/122
#  - 0s - loss: 12.2275 - mean_absolute_error: 12.2275
# Epoch 85/122
#  - 0s - loss: 12.1960 - mean_absolute_error: 12.1960
# Epoch 86/122
#  - 0s - loss: 12.2006 - mean_absolute_error: 12.2006
# Epoch 87/122
#  - 0s - loss: 12.2017 - mean_absolute_error: 12.2017
# Epoch 88/122
#  - 0s - loss: 12.1966 - mean_absolute_error: 12.1966
# Epoch 89/122
#  - 0s - loss: 12.1827 - mean_absolute_error: 12.1827
# Epoch 90/122
#  - 0s - loss: 12.1759 - mean_absolute_error: 12.1759
# Epoch 91/122
#  - 0s - loss: 12.1543 - mean_absolute_error: 12.1543
# Epoch 92/122
#  - 0s - loss: 12.1745 - mean_absolute_error: 12.1745
# Epoch 93/122
#  - 0s - loss: 12.1623 - mean_absolute_error: 12.1623
# Epoch 94/122
#  - 0s - loss: 12.1518 - mean_absolute_error: 12.1518
# Epoch 95/122
#  - 0s - loss: 12.1564 - mean_absolute_error: 12.1564
# Epoch 96/122
#  - 0s - loss: 12.1414 - mean_absolute_error: 12.1414
# Epoch 97/122
#  - 0s - loss: 12.1341 - mean_absolute_error: 12.1341
# Epoch 98/122
#  - 0s - loss: 12.1217 - mean_absolute_error: 12.1217
# Epoch 99/122
#  - 0s - loss: 12.1399 - mean_absolute_error: 12.1399
# Epoch 100/122
#  - 0s - loss: 12.1158 - mean_absolute_error: 12.1158
# Epoch 101/122
#  - 0s - loss: 12.1260 - mean_absolute_error: 12.1260
# Epoch 102/122
#  - 0s - loss: 12.1169 - mean_absolute_error: 12.1169
# Epoch 103/122
#  - 0s - loss: 12.1141 - mean_absolute_error: 12.1141
# Epoch 104/122
#  - 0s - loss: 12.1106 - mean_absolute_error: 12.1106
# Epoch 105/122
#  - 0s - loss: 12.0938 - mean_absolute_error: 12.0938
# Epoch 106/122
#  - 0s - loss: 12.0894 - mean_absolute_error: 12.0894
# Epoch 107/122
#  - 0s - loss: 12.0829 - mean_absolute_error: 12.0829
# Epoch 108/122
#  - 0s - loss: 12.0982 - mean_absolute_error: 12.0982
# Epoch 109/122
#  - 0s - loss: 12.0695 - mean_absolute_error: 12.0695
# Epoch 110/122
#  - 0s - loss: 12.0787 - mean_absolute_error: 12.0787
# Epoch 111/122
#  - 0s - loss: 12.0467 - mean_absolute_error: 12.0467
# Epoch 112/122
#  - 0s - loss: 12.0910 - mean_absolute_error: 12.0910
# Epoch 113/122
#  - 0s - loss: 12.0493 - mean_absolute_error: 12.0493
# Epoch 114/122
#  - 0s - loss: 12.0615 - mean_absolute_error: 12.0615
# Epoch 115/122
#  - 0s - loss: 12.0481 - mean_absolute_error: 12.0481
# Epoch 116/122
#  - 0s - loss: 12.0346 - mean_absolute_error: 12.0346
# Epoch 117/122
#  - 0s - loss: 12.0425 - mean_absolute_error: 12.0425
# Epoch 118/122
#  - 0s - loss: 12.0178 - mean_absolute_error: 12.0178
# Epoch 119/122
#  - 0s - loss: 12.0278 - mean_absolute_error: 12.0278
# Epoch 120/122
#  - 0s - loss: 12.0155 - mean_absolute_error: 12.0155
# Epoch 121/122
#  - 0s - loss: 11.9987 - mean_absolute_error: 11.9987
# Epoch 122/122
#  - 0s - loss: 12.0158 - mean_absolute_error: 12.0158
# 0
# 12.653016814217759
# Epoch 1/122
#  - 2s - loss: 126.7570 - mean_absolute_error: 126.7570
# Epoch 2/122
#  - 0s - loss: 118.6958 - mean_absolute_error: 118.6958
# Epoch 3/122
#  - 0s - loss: 105.8833 - mean_absolute_error: 105.8833
# Epoch 4/122
#  - 0s - loss: 97.4844 - mean_absolute_error: 97.4844
# Epoch 5/122
#  - 0s - loss: 90.4105 - mean_absolute_error: 90.4105
# Epoch 6/122
#  - 0s - loss: 83.8416 - mean_absolute_error: 83.8416
# Epoch 7/122
#  - 0s - loss: 77.5489 - mean_absolute_error: 77.5489
# Epoch 8/122
#  - 0s - loss: 71.4308 - mean_absolute_error: 71.4308
# Epoch 9/122
#  - 0s - loss: 65.4338 - mean_absolute_error: 65.4338
# Epoch 10/122
#  - 0s - loss: 59.5256 - mean_absolute_error: 59.5256
# Epoch 11/122
#  - 0s - loss: 53.6851 - mean_absolute_error: 53.6851
# Epoch 12/122
#  - 0s - loss: 47.9025 - mean_absolute_error: 47.9025
# Epoch 13/122
#  - 0s - loss: 42.1676 - mean_absolute_error: 42.1676
# Epoch 14/122
#  - 0s - loss: 36.4856 - mean_absolute_error: 36.4856
# Epoch 15/122
#  - 0s - loss: 30.9054 - mean_absolute_error: 30.9054
# Epoch 16/122
#  - 0s - loss: 25.6895 - mean_absolute_error: 25.6895
# Epoch 17/122
#  - 0s - loss: 21.3594 - mean_absolute_error: 21.3594
# Epoch 18/122
#  - 0s - loss: 18.3407 - mean_absolute_error: 18.3407
# Epoch 19/122
#  - 0s - loss: 16.5038 - mean_absolute_error: 16.5038
# Epoch 20/122
#  - 0s - loss: 15.4964 - mean_absolute_error: 15.4964
# Epoch 21/122
#  - 0s - loss: 14.9278 - mean_absolute_error: 14.9278
# Epoch 22/122
#  - 0s - loss: 14.6747 - mean_absolute_error: 14.6747
# Epoch 23/122
#  - 0s - loss: 14.4976 - mean_absolute_error: 14.4976
# Epoch 24/122
#  - 0s - loss: 14.4055 - mean_absolute_error: 14.4055
# Epoch 25/122
#  - 0s - loss: 14.3192 - mean_absolute_error: 14.3192
# Epoch 26/122
#  - 0s - loss: 14.3132 - mean_absolute_error: 14.3132
# Epoch 27/122
#  - 0s - loss: 14.2844 - mean_absolute_error: 14.2844
# Epoch 28/122
#  - 0s - loss: 14.1934 - mean_absolute_error: 14.1934
# Epoch 29/122
#  - 0s - loss: 14.0128 - mean_absolute_error: 14.0128
# Epoch 30/122
#  - 0s - loss: 13.8762 - mean_absolute_error: 13.8762
# Epoch 31/122
#  - 0s - loss: 13.6929 - mean_absolute_error: 13.6929
# Epoch 32/122
#  - 0s - loss: 13.4547 - mean_absolute_error: 13.4547
# Epoch 33/122
#  - 0s - loss: 13.4556 - mean_absolute_error: 13.4556
# Epoch 34/122
#  - 0s - loss: 13.2991 - mean_absolute_error: 13.2991
# Epoch 35/122
#  - 0s - loss: 13.1655 - mean_absolute_error: 13.1655
# Epoch 36/122
#  - 0s - loss: 13.1587 - mean_absolute_error: 13.1587
# Epoch 37/122
#  - 0s - loss: 13.1605 - mean_absolute_error: 13.1605
# Epoch 38/122
#  - 0s - loss: 12.9962 - mean_absolute_error: 12.9962
# Epoch 39/122
#  - 0s - loss: 12.9121 - mean_absolute_error: 12.9121
# Epoch 40/122
#  - 0s - loss: 12.8312 - mean_absolute_error: 12.8312
# Epoch 41/122
#  - 0s - loss: 12.8006 - mean_absolute_error: 12.8006
# Epoch 42/122
#  - 0s - loss: 12.8022 - mean_absolute_error: 12.8022
# Epoch 43/122
#  - 0s - loss: 12.7467 - mean_absolute_error: 12.7467
# Epoch 44/122
#  - 0s - loss: 12.6936 - mean_absolute_error: 12.6936
# Epoch 45/122
#  - 0s - loss: 12.6681 - mean_absolute_error: 12.6681
# Epoch 46/122
#  - 0s - loss: 12.6310 - mean_absolute_error: 12.6310
# Epoch 47/122
#  - 0s - loss: 12.6231 - mean_absolute_error: 12.6231
# Epoch 48/122
#  - 0s - loss: 12.5905 - mean_absolute_error: 12.5905
# Epoch 49/122
#  - 0s - loss: 12.5818 - mean_absolute_error: 12.5818
# Epoch 50/122
#  - 0s - loss: 12.5599 - mean_absolute_error: 12.5599
# Epoch 51/122
#  - 0s - loss: 12.5531 - mean_absolute_error: 12.5531
# Epoch 52/122
#  - 0s - loss: 12.5362 - mean_absolute_error: 12.5362
# Epoch 53/122
#  - 0s - loss: 12.5210 - mean_absolute_error: 12.5210
# Epoch 54/122
#  - 0s - loss: 12.5060 - mean_absolute_error: 12.5060
# Epoch 55/122
#  - 0s - loss: 12.5017 - mean_absolute_error: 12.5017
# Epoch 56/122
#  - 0s - loss: 12.4868 - mean_absolute_error: 12.4868
# Epoch 57/122
#  - 0s - loss: 12.4613 - mean_absolute_error: 12.4613
# Epoch 58/122
#  - 0s - loss: 12.4639 - mean_absolute_error: 12.4639
# Epoch 59/122
#  - 0s - loss: 12.4628 - mean_absolute_error: 12.4628
# Epoch 60/122
#  - 0s - loss: 12.4433 - mean_absolute_error: 12.4433
# Epoch 61/122
#  - 0s - loss: 12.4278 - mean_absolute_error: 12.4278
# Epoch 62/122
#  - 0s - loss: 12.4292 - mean_absolute_error: 12.4292
# Epoch 63/122
#  - 0s - loss: 12.3901 - mean_absolute_error: 12.3901
# Epoch 64/122
#  - 0s - loss: 12.4151 - mean_absolute_error: 12.4151
# Epoch 65/122
#  - 0s - loss: 12.3965 - mean_absolute_error: 12.3965
# Epoch 66/122
#  - 0s - loss: 12.3813 - mean_absolute_error: 12.3813
# Epoch 67/122
#  - 0s - loss: 12.3896 - mean_absolute_error: 12.3896
# Epoch 68/122
#  - 0s - loss: 12.3593 - mean_absolute_error: 12.3593
# Epoch 69/122
#  - 0s - loss: 12.3566 - mean_absolute_error: 12.3566
# Epoch 70/122
#  - 0s - loss: 12.3528 - mean_absolute_error: 12.3528
# Epoch 71/122
#  - 0s - loss: 12.3492 - mean_absolute_error: 12.3492
# Epoch 72/122
#  - 0s - loss: 12.3295 - mean_absolute_error: 12.3295
# Epoch 73/122
#  - 0s - loss: 12.3152 - mean_absolute_error: 12.3152
# Epoch 74/122
#  - 0s - loss: 12.2990 - mean_absolute_error: 12.2990
# Epoch 75/122
#  - 0s - loss: 12.3006 - mean_absolute_error: 12.3006
# Epoch 76/122
#  - 0s - loss: 12.2958 - mean_absolute_error: 12.2958
# Epoch 77/122
#  - 0s - loss: 12.2964 - mean_absolute_error: 12.2964
# Epoch 78/122
#  - 0s - loss: 12.2859 - mean_absolute_error: 12.2859
# Epoch 79/122
#  - 0s - loss: 12.2688 - mean_absolute_error: 12.2688
# Epoch 80/122
#  - 0s - loss: 12.2653 - mean_absolute_error: 12.2653
# Epoch 81/122
#  - 0s - loss: 12.2523 - mean_absolute_error: 12.2523
# Epoch 82/122
#  - 0s - loss: 12.2756 - mean_absolute_error: 12.2756
# Epoch 83/122
#  - 0s - loss: 12.2293 - mean_absolute_error: 12.2293
# Epoch 84/122
#  - 0s - loss: 12.2445 - mean_absolute_error: 12.2445
# Epoch 85/122
#  - 0s - loss: 12.2194 - mean_absolute_error: 12.2194
# Epoch 86/122
#  - 0s - loss: 12.2422 - mean_absolute_error: 12.2422
# Epoch 87/122
#  - 0s - loss: 12.2200 - mean_absolute_error: 12.2200
# Epoch 88/122
#  - 0s - loss: 12.2057 - mean_absolute_error: 12.2057
# Epoch 89/122
#  - 0s - loss: 12.1991 - mean_absolute_error: 12.1991
# Epoch 90/122
#  - 0s - loss: 12.1921 - mean_absolute_error: 12.1921
# Epoch 91/122
#  - 0s - loss: 12.1861 - mean_absolute_error: 12.1861
# Epoch 92/122
#  - 0s - loss: 12.1725 - mean_absolute_error: 12.1725
# Epoch 93/122
#  - 0s - loss: 12.2138 - mean_absolute_error: 12.2138
# Epoch 94/122
#  - 0s - loss: 12.1811 - mean_absolute_error: 12.1811
# Epoch 95/122
#  - 0s - loss: 12.1789 - mean_absolute_error: 12.1789
# Epoch 96/122
#  - 0s - loss: 12.1767 - mean_absolute_error: 12.1767
# Epoch 97/122
#  - 0s - loss: 12.1606 - mean_absolute_error: 12.1606
# Epoch 98/122
#  - 0s - loss: 12.1635 - mean_absolute_error: 12.1635
# Epoch 99/122
#  - 0s - loss: 12.1490 - mean_absolute_error: 12.1490
# Epoch 100/122
#  - 0s - loss: 12.1341 - mean_absolute_error: 12.1341
# Epoch 101/122
#  - 0s - loss: 12.1494 - mean_absolute_error: 12.1494
# Epoch 102/122
#  - 0s - loss: 12.1407 - mean_absolute_error: 12.1407
# Epoch 103/122
#  - 0s - loss: 12.1444 - mean_absolute_error: 12.1444
# Epoch 104/122
#  - 0s - loss: 12.1108 - mean_absolute_error: 12.1108
# Epoch 105/122
#  - 0s - loss: 12.1232 - mean_absolute_error: 12.1232
# Epoch 106/122
#  - 0s - loss: 12.1156 - mean_absolute_error: 12.1156
# Epoch 107/122
#  - 0s - loss: 12.1226 - mean_absolute_error: 12.1226
# Epoch 108/122
#  - 0s - loss: 12.1107 - mean_absolute_error: 12.1107
# Epoch 109/122
#  - 0s - loss: 12.1074 - mean_absolute_error: 12.1074
# Epoch 110/122
#  - 0s - loss: 12.0947 - mean_absolute_error: 12.0947
# Epoch 111/122
#  - 0s - loss: 12.0807 - mean_absolute_error: 12.0807
# Epoch 112/122
#  - 0s - loss: 12.1098 - mean_absolute_error: 12.1098
# Epoch 113/122
#  - 0s - loss: 12.0926 - mean_absolute_error: 12.0926
# Epoch 114/122
#  - 0s - loss: 12.0850 - mean_absolute_error: 12.0850
# Epoch 115/122
#  - 0s - loss: 12.0702 - mean_absolute_error: 12.0702
# Epoch 116/122
#  - 0s - loss: 12.0566 - mean_absolute_error: 12.0566
# Epoch 117/122
#  - 0s - loss: 12.0735 - mean_absolute_error: 12.0735
# Epoch 118/122
#  - 0s - loss: 12.0794 - mean_absolute_error: 12.0794
# Epoch 119/122
#  - 0s - loss: 12.0374 - mean_absolute_error: 12.0374
# Epoch 120/122
#  - 0s - loss: 12.0569 - mean_absolute_error: 12.0569
# Epoch 121/122
#  - 0s - loss: 12.0435 - mean_absolute_error: 12.0435
# Epoch 122/122
#  - 0s - loss: 12.0470 - mean_absolute_error: 12.0470
# 1
# 12.635330883023435
# Epoch 1/122
#  - 2s - loss: 126.7968 - mean_absolute_error: 126.7968
# Epoch 2/122
#  - 0s - loss: 118.9492 - mean_absolute_error: 118.9492
# Epoch 3/122
#  - 0s - loss: 106.2393 - mean_absolute_error: 106.2393
# Epoch 4/122
#  - 0s - loss: 97.8577 - mean_absolute_error: 97.8577
# Epoch 5/122
#  - 0s - loss: 90.7881 - mean_absolute_error: 90.7881
# Epoch 6/122
#  - 0s - loss: 84.2227 - mean_absolute_error: 84.2227
# Epoch 7/122
#  - 0s - loss: 77.9320 - mean_absolute_error: 77.9320
# Epoch 8/122
#  - 0s - loss: 71.8157 - mean_absolute_error: 71.8157
# Epoch 9/122
#  - 0s - loss: 65.8201 - mean_absolute_error: 65.8201
# Epoch 10/122
#  - 0s - loss: 59.9128 - mean_absolute_error: 59.9128
# Epoch 11/122
#  - 0s - loss: 54.0732 - mean_absolute_error: 54.0732
# Epoch 12/122
#  - 0s - loss: 48.2912 - mean_absolute_error: 48.2912
# Epoch 13/122
#  - 0s - loss: 42.5571 - mean_absolute_error: 42.5571
# Epoch 14/122
#  - 0s - loss: 36.8719 - mean_absolute_error: 36.8719
# Epoch 15/122
#  - 0s - loss: 31.2784 - mean_absolute_error: 31.2784
# Epoch 16/122
#  - 0s - loss: 26.0304 - mean_absolute_error: 26.0304
# Epoch 17/122
#  - 0s - loss: 21.6208 - mean_absolute_error: 21.6208
# Epoch 18/122
#  - 0s - loss: 18.5191 - mean_absolute_error: 18.5191
# Epoch 19/122
#  - 0s - loss: 16.6260 - mean_absolute_error: 16.6260
# Epoch 20/122
#  - 0s - loss: 15.5588 - mean_absolute_error: 15.5588
# Epoch 21/122
#  - 0s - loss: 14.9724 - mean_absolute_error: 14.9724
# Epoch 22/122
#  - 0s - loss: 14.6681 - mean_absolute_error: 14.6681
# Epoch 23/122
#  - 0s - loss: 14.5648 - mean_absolute_error: 14.5648
# Epoch 24/122
#  - 0s - loss: 14.3961 - mean_absolute_error: 14.3961
# Epoch 25/122
#  - 0s - loss: 14.3414 - mean_absolute_error: 14.3414
# Epoch 26/122
#  - 0s - loss: 14.2942 - mean_absolute_error: 14.2942
# Epoch 27/122
#  - 0s - loss: 14.1719 - mean_absolute_error: 14.1719
# Epoch 28/122
#  - 0s - loss: 14.0794 - mean_absolute_error: 14.0794
# Epoch 29/122
#  - 0s - loss: 13.8718 - mean_absolute_error: 13.8718
# Epoch 30/122
#  - 0s - loss: 13.7026 - mean_absolute_error: 13.7026
# Epoch 31/122
#  - 0s - loss: 13.5193 - mean_absolute_error: 13.5193
# Epoch 32/122
#  - 0s - loss: 13.5773 - mean_absolute_error: 13.5773
# Epoch 33/122
#  - 0s - loss: 13.3986 - mean_absolute_error: 13.3986
# Epoch 34/122
#  - 0s - loss: 13.2673 - mean_absolute_error: 13.2673
# Epoch 35/122
#  - 0s - loss: 13.2782 - mean_absolute_error: 13.2782
# Epoch 36/122
#  - 0s - loss: 13.1064 - mean_absolute_error: 13.1064
# Epoch 37/122
#  - 0s - loss: 13.0944 - mean_absolute_error: 13.0944
# Epoch 38/122
#  - 0s - loss: 12.9248 - mean_absolute_error: 12.9248
# Epoch 39/122
#  - 0s - loss: 12.8655 - mean_absolute_error: 12.8655
# Epoch 40/122
#  - 0s - loss: 12.8595 - mean_absolute_error: 12.8595
# Epoch 41/122
#  - 0s - loss: 12.8204 - mean_absolute_error: 12.8204
# Epoch 42/122
#  - 0s - loss: 12.7779 - mean_absolute_error: 12.7779
# Epoch 43/122
#  - 0s - loss: 12.7668 - mean_absolute_error: 12.7668
# Epoch 44/122
#  - 0s - loss: 12.7149 - mean_absolute_error: 12.7149
# Epoch 45/122
#  - 0s - loss: 12.7004 - mean_absolute_error: 12.7004
# Epoch 46/122
#  - 0s - loss: 12.6546 - mean_absolute_error: 12.6546
# Epoch 47/122
#  - 0s - loss: 12.6250 - mean_absolute_error: 12.6250
# Epoch 48/122
#  - 0s - loss: 12.6244 - mean_absolute_error: 12.6244
# Epoch 49/122
#  - 0s - loss: 12.5983 - mean_absolute_error: 12.5983
# Epoch 50/122
#  - 0s - loss: 12.5947 - mean_absolute_error: 12.5947
# Epoch 51/122
#  - 0s - loss: 12.5844 - mean_absolute_error: 12.5844
# Epoch 52/122
#  - 0s - loss: 12.5676 - mean_absolute_error: 12.5676
# Epoch 53/122
#  - 0s - loss: 12.5412 - mean_absolute_error: 12.5412
# Epoch 54/122
#  - 0s - loss: 12.5412 - mean_absolute_error: 12.5412
# Epoch 55/122
#  - 0s - loss: 12.5183 - mean_absolute_error: 12.5183
# Epoch 56/122
#  - 0s - loss: 12.5226 - mean_absolute_error: 12.5226
# Epoch 57/122
#  - 0s - loss: 12.4968 - mean_absolute_error: 12.4968
# Epoch 58/122
#  - 0s - loss: 12.4784 - mean_absolute_error: 12.4784
# Epoch 59/122
#  - 0s - loss: 12.4740 - mean_absolute_error: 12.4740
# Epoch 60/122
#  - 0s - loss: 12.4477 - mean_absolute_error: 12.4477
# Epoch 61/122
#  - 0s - loss: 12.4308 - mean_absolute_error: 12.4308
# Epoch 62/122
#  - 0s - loss: 12.4087 - mean_absolute_error: 12.4087
# Epoch 63/122
#  - 0s - loss: 12.4040 - mean_absolute_error: 12.4040
# Epoch 64/122
#  - 0s - loss: 12.4218 - mean_absolute_error: 12.4218
# Epoch 65/122
#  - 0s - loss: 12.3771 - mean_absolute_error: 12.3771
# Epoch 66/122
#  - 0s - loss: 12.3687 - mean_absolute_error: 12.3687
# Epoch 67/122
#  - 0s - loss: 12.3458 - mean_absolute_error: 12.3458
# Epoch 68/122
#  - 0s - loss: 12.3335 - mean_absolute_error: 12.3335
# Epoch 69/122
#  - 0s - loss: 12.3269 - mean_absolute_error: 12.3269
# Epoch 70/122
#  - 0s - loss: 12.3202 - mean_absolute_error: 12.3202
# Epoch 71/122
#  - 0s - loss: 12.3161 - mean_absolute_error: 12.3161
# Epoch 72/122
#  - 0s - loss: 12.3135 - mean_absolute_error: 12.3135
# Epoch 73/122
#  - 0s - loss: 12.3143 - mean_absolute_error: 12.3143
# Epoch 74/122
#  - 0s - loss: 12.3015 - mean_absolute_error: 12.3015
# Epoch 75/122
#  - 0s - loss: 12.3014 - mean_absolute_error: 12.3014
# Epoch 76/122
#  - 0s - loss: 12.2976 - mean_absolute_error: 12.2976
# Epoch 77/122
#  - 0s - loss: 12.2694 - mean_absolute_error: 12.2694
# Epoch 78/122
#  - 0s - loss: 12.2593 - mean_absolute_error: 12.2593
# Epoch 79/122
#  - 0s - loss: 12.2615 - mean_absolute_error: 12.2615
# Epoch 80/122
#  - 0s - loss: 12.2599 - mean_absolute_error: 12.2599
# Epoch 81/122
#  - 0s - loss: 12.2488 - mean_absolute_error: 12.2488
# Epoch 82/122
#  - 0s - loss: 12.2424 - mean_absolute_error: 12.2424
# Epoch 83/122
#  - 0s - loss: 12.2263 - mean_absolute_error: 12.2263
# Epoch 84/122
#  - 0s - loss: 12.2323 - mean_absolute_error: 12.2323
# Epoch 85/122
#  - 0s - loss: 12.2151 - mean_absolute_error: 12.2151
# Epoch 86/122
#  - 0s - loss: 12.1971 - mean_absolute_error: 12.1971
# Epoch 87/122
#  - 0s - loss: 12.1990 - mean_absolute_error: 12.1990
# Epoch 88/122
#  - 0s - loss: 12.2148 - mean_absolute_error: 12.2148
# Epoch 89/122
#  - 0s - loss: 12.1916 - mean_absolute_error: 12.1916
# Epoch 90/122
#  - 0s - loss: 12.1797 - mean_absolute_error: 12.1797
# Epoch 91/122
#  - 0s - loss: 12.1702 - mean_absolute_error: 12.1702
# Epoch 92/122
#  - 0s - loss: 12.1708 - mean_absolute_error: 12.1708
# Epoch 93/122
#  - 0s - loss: 12.1601 - mean_absolute_error: 12.1601
# Epoch 94/122
#  - 0s - loss: 12.1637 - mean_absolute_error: 12.1637
# Epoch 95/122
#  - 0s - loss: 12.1495 - mean_absolute_error: 12.1495
# Epoch 96/122
#  - 0s - loss: 12.1531 - mean_absolute_error: 12.1531
# Epoch 97/122
#  - 0s - loss: 12.1296 - mean_absolute_error: 12.1296
# Epoch 98/122
#  - 0s - loss: 12.1292 - mean_absolute_error: 12.1292
# Epoch 99/122
#  - 0s - loss: 12.1231 - mean_absolute_error: 12.1231
# Epoch 100/122
#  - 0s - loss: 12.1176 - mean_absolute_error: 12.1176
# Epoch 101/122
#  - 0s - loss: 12.1093 - mean_absolute_error: 12.1093
# Epoch 102/122
#  - 0s - loss: 12.1052 - mean_absolute_error: 12.1052
# Epoch 103/122
#  - 0s - loss: 12.1180 - mean_absolute_error: 12.1180
# Epoch 104/122
#  - 0s - loss: 12.0973 - mean_absolute_error: 12.0973
# Epoch 105/122
#  - 0s - loss: 12.0941 - mean_absolute_error: 12.0941
# Epoch 106/122
#  - 0s - loss: 12.0816 - mean_absolute_error: 12.0816
# Epoch 107/122
#  - 0s - loss: 12.0761 - mean_absolute_error: 12.0761
# Epoch 108/122
#  - 0s - loss: 12.0664 - mean_absolute_error: 12.0664
# Epoch 109/122
#  - 0s - loss: 12.0679 - mean_absolute_error: 12.0679
# Epoch 110/122
#  - 0s - loss: 12.0755 - mean_absolute_error: 12.0755
# Epoch 111/122
#  - 0s - loss: 12.0602 - mean_absolute_error: 12.0602
# Epoch 112/122
#  - 0s - loss: 12.0461 - mean_absolute_error: 12.0461
# Epoch 113/122
#  - 0s - loss: 12.0641 - mean_absolute_error: 12.0641
# Epoch 114/122
#  - 0s - loss: 12.0483 - mean_absolute_error: 12.0483
# Epoch 115/122
#  - 0s - loss: 12.0232 - mean_absolute_error: 12.0232
# Epoch 116/122
#  - 0s - loss: 12.0319 - mean_absolute_error: 12.0319
# Epoch 117/122
#  - 0s - loss: 12.0281 - mean_absolute_error: 12.0281
# Epoch 118/122
#  - 0s - loss: 12.0102 - mean_absolute_error: 12.0102
# Epoch 119/122
#  - 0s - loss: 12.0339 - mean_absolute_error: 12.0339
# Epoch 120/122
#  - 0s - loss: 12.0041 - mean_absolute_error: 12.0041
# Epoch 121/122
#  - 0s - loss: 12.0146 - mean_absolute_error: 12.0146
# Epoch 122/122
#  - 0s - loss: 12.0015 - mean_absolute_error: 12.0015
# 2
# 12.61602466521421
# Epoch 1/122
#  - 2s - loss: 126.7429 - mean_absolute_error: 126.7429
# Epoch 2/122
#  - 0s - loss: 118.5601 - mean_absolute_error: 118.5601
# Epoch 3/122
#  - 0s - loss: 105.8885 - mean_absolute_error: 105.8885
# Epoch 4/122
#  - 0s - loss: 97.5406 - mean_absolute_error: 97.5406
# Epoch 5/122
#  - 0s - loss: 90.4916 - mean_absolute_error: 90.4916
# Epoch 6/122
#  - 0s - loss: 83.9372 - mean_absolute_error: 83.9372
# Epoch 7/122
#  - 0s - loss: 77.6549 - mean_absolute_error: 77.6549
# Epoch 8/122
#  - 0s - loss: 71.5450 - mean_absolute_error: 71.5450
# Epoch 9/122
#  - 0s - loss: 65.5544 - mean_absolute_error: 65.5544
# Epoch 10/122
#  - 0s - loss: 59.6515 - mean_absolute_error: 59.6515
# Epoch 11/122
#  - 0s - loss: 53.8169 - mean_absolute_error: 53.8169
# Epoch 12/122
#  - 0s - loss: 48.0392 - mean_absolute_error: 48.0392
# Epoch 13/122
#  - 0s - loss: 42.3077 - mean_absolute_error: 42.3077
# Epoch 14/122
#  - 0s - loss: 36.6275 - mean_absolute_error: 36.6275
# Epoch 15/122
#  - 0s - loss: 31.0387 - mean_absolute_error: 31.0387
# Epoch 16/122
#  - 0s - loss: 25.8107 - mean_absolute_error: 25.8107
# Epoch 17/122
#  - 0s - loss: 21.4487 - mean_absolute_error: 21.4487
# Epoch 18/122
#  - 0s - loss: 18.3982 - mean_absolute_error: 18.3982
# Epoch 19/122
#  - 0s - loss: 16.5539 - mean_absolute_error: 16.5539
# Epoch 20/122
#  - 0s - loss: 15.5159 - mean_absolute_error: 15.5159
# Epoch 21/122
#  - 0s - loss: 14.9435 - mean_absolute_error: 14.9435
# Epoch 22/122
#  - 0s - loss: 14.6561 - mean_absolute_error: 14.6561
# Epoch 23/122
#  - 0s - loss: 14.5115 - mean_absolute_error: 14.5115
# Epoch 24/122
#  - 0s - loss: 14.4171 - mean_absolute_error: 14.4171
# Epoch 25/122
#  - 0s - loss: 14.3285 - mean_absolute_error: 14.3285
# Epoch 26/122
#  - 0s - loss: 14.3480 - mean_absolute_error: 14.3480
# Epoch 27/122
#  - 0s - loss: 14.3218 - mean_absolute_error: 14.3218
# Epoch 28/122
#  - 0s - loss: 14.3083 - mean_absolute_error: 14.3083
# Epoch 29/122
#  - 0s - loss: 14.2189 - mean_absolute_error: 14.2189
# Epoch 30/122
#  - 0s - loss: 14.0966 - mean_absolute_error: 14.0966
# Epoch 31/122
#  - 0s - loss: 13.8565 - mean_absolute_error: 13.8565
# Epoch 32/122
#  - 0s - loss: 13.6320 - mean_absolute_error: 13.6320
# Epoch 33/122
#  - 0s - loss: 13.4941 - mean_absolute_error: 13.4941
# Epoch 34/122
#  - 0s - loss: 13.4341 - mean_absolute_error: 13.4341
# Epoch 35/122
#  - 0s - loss: 13.2807 - mean_absolute_error: 13.2807
# Epoch 36/122
#  - 0s - loss: 13.1712 - mean_absolute_error: 13.1712
# Epoch 37/122
#  - 0s - loss: 13.1353 - mean_absolute_error: 13.1353
# Epoch 38/122
#  - 0s - loss: 13.0214 - mean_absolute_error: 13.0214
# Epoch 39/122
#  - 0s - loss: 12.9340 - mean_absolute_error: 12.9340
# Epoch 40/122
#  - 0s - loss: 12.9005 - mean_absolute_error: 12.9005
# Epoch 41/122
#  - 0s - loss: 12.8745 - mean_absolute_error: 12.8745
# Epoch 42/122
#  - 0s - loss: 12.8384 - mean_absolute_error: 12.8384
# Epoch 43/122
#  - 0s - loss: 12.7512 - mean_absolute_error: 12.7512
# Epoch 44/122
#  - 0s - loss: 12.7152 - mean_absolute_error: 12.7152
# Epoch 45/122
#  - 0s - loss: 12.6773 - mean_absolute_error: 12.6773
# Epoch 46/122
#  - 0s - loss: 12.6470 - mean_absolute_error: 12.6470
# Epoch 47/122
#  - 0s - loss: 12.6241 - mean_absolute_error: 12.6241
# Epoch 48/122
#  - 0s - loss: 12.6038 - mean_absolute_error: 12.6038
# Epoch 49/122
#  - 0s - loss: 12.5830 - mean_absolute_error: 12.5830
# Epoch 50/122
#  - 0s - loss: 12.6082 - mean_absolute_error: 12.6082
# Epoch 51/122
#  - 0s - loss: 12.5610 - mean_absolute_error: 12.5610
# Epoch 52/122
#  - 0s - loss: 12.5409 - mean_absolute_error: 12.5409
# Epoch 53/122
#  - 0s - loss: 12.5396 - mean_absolute_error: 12.5396
# Epoch 54/122
#  - 0s - loss: 12.5264 - mean_absolute_error: 12.5264
# Epoch 55/122
#  - 0s - loss: 12.5143 - mean_absolute_error: 12.5143
# Epoch 56/122
#  - 0s - loss: 12.4886 - mean_absolute_error: 12.4886
# Epoch 57/122
#  - 0s - loss: 12.4738 - mean_absolute_error: 12.4738
# Epoch 58/122
#  - 0s - loss: 12.4737 - mean_absolute_error: 12.4737
# Epoch 59/122
#  - 0s - loss: 12.4540 - mean_absolute_error: 12.4540
# Epoch 60/122
#  - 0s - loss: 12.4324 - mean_absolute_error: 12.4324
# Epoch 61/122
#  - 0s - loss: 12.4227 - mean_absolute_error: 12.4227
# Epoch 62/122
#  - 0s - loss: 12.4064 - mean_absolute_error: 12.4064
# Epoch 63/122
#  - 0s - loss: 12.4031 - mean_absolute_error: 12.4031
# Epoch 64/122
#  - 0s - loss: 12.3961 - mean_absolute_error: 12.3961
# Epoch 65/122
#  - 0s - loss: 12.3706 - mean_absolute_error: 12.3706
# Epoch 66/122
#  - 0s - loss: 12.3666 - mean_absolute_error: 12.3666
# Epoch 67/122
#  - 0s - loss: 12.3445 - mean_absolute_error: 12.3445
# Epoch 68/122
#  - 0s - loss: 12.3435 - mean_absolute_error: 12.3435
# Epoch 69/122
#  - 0s - loss: 12.3582 - mean_absolute_error: 12.3582
# Epoch 70/122
#  - 0s - loss: 12.3234 - mean_absolute_error: 12.3234
# Epoch 71/122
#  - 0s - loss: 12.3234 - mean_absolute_error: 12.3234
# Epoch 72/122
#  - 0s - loss: 12.3008 - mean_absolute_error: 12.3008
# Epoch 73/122
#  - 0s - loss: 12.2978 - mean_absolute_error: 12.2978
# Epoch 74/122
#  - 0s - loss: 12.2872 - mean_absolute_error: 12.2872
# Epoch 75/122
#  - 0s - loss: 12.2750 - mean_absolute_error: 12.2750
# Epoch 76/122
#  - 0s - loss: 12.2901 - mean_absolute_error: 12.2901
# Epoch 77/122
#  - 0s - loss: 12.2825 - mean_absolute_error: 12.2825
# Epoch 78/122
#  - 0s - loss: 12.2565 - mean_absolute_error: 12.2565
# Epoch 79/122
#  - 0s - loss: 12.2490 - mean_absolute_error: 12.2490
# Epoch 80/122
#  - 0s - loss: 12.2576 - mean_absolute_error: 12.2576
# Epoch 81/122
#  - 0s - loss: 12.2419 - mean_absolute_error: 12.2419
# Epoch 82/122
#  - 0s - loss: 12.2633 - mean_absolute_error: 12.2633
# Epoch 83/122
#  - 0s - loss: 12.2289 - mean_absolute_error: 12.2289
# Epoch 84/122
#  - 0s - loss: 12.2206 - mean_absolute_error: 12.2206
# Epoch 85/122
#  - 0s - loss: 12.2199 - mean_absolute_error: 12.2199
# Epoch 86/122
#  - 0s - loss: 12.1992 - mean_absolute_error: 12.1992
# Epoch 87/122
#  - 0s - loss: 12.1980 - mean_absolute_error: 12.1980
# Epoch 88/122
#  - 0s - loss: 12.1925 - mean_absolute_error: 12.1925
# Epoch 89/122
#  - 0s - loss: 12.1776 - mean_absolute_error: 12.1776
# Epoch 90/122
#  - 0s - loss: 12.1934 - mean_absolute_error: 12.1934
# Epoch 91/122
#  - 0s - loss: 12.1746 - mean_absolute_error: 12.1746
# Epoch 92/122
#  - 0s - loss: 12.1737 - mean_absolute_error: 12.1737
# Epoch 93/122
#  - 0s - loss: 12.1669 - mean_absolute_error: 12.1669
# Epoch 94/122
#  - 0s - loss: 12.1624 - mean_absolute_error: 12.1624
# Epoch 95/122
#  - 0s - loss: 12.1680 - mean_absolute_error: 12.1680
# Epoch 96/122
#  - 0s - loss: 12.1397 - mean_absolute_error: 12.1397
# Epoch 97/122
#  - 0s - loss: 12.1454 - mean_absolute_error: 12.1454
# Epoch 98/122
#  - 0s - loss: 12.1332 - mean_absolute_error: 12.1332
# Epoch 99/122
#  - 0s - loss: 12.1217 - mean_absolute_error: 12.1217
# Epoch 100/122
#  - 0s - loss: 12.1247 - mean_absolute_error: 12.1247
# Epoch 101/122
#  - 0s - loss: 12.1215 - mean_absolute_error: 12.1215
# Epoch 102/122
#  - 0s - loss: 12.1052 - mean_absolute_error: 12.1052
# Epoch 103/122
#  - 0s - loss: 12.0953 - mean_absolute_error: 12.0953
# Epoch 104/122
#  - 0s - loss: 12.1151 - mean_absolute_error: 12.1151
# Epoch 105/122
#  - 0s - loss: 12.0982 - mean_absolute_error: 12.0982
# Epoch 106/122
#  - 0s - loss: 12.0708 - mean_absolute_error: 12.0708
# Epoch 107/122
#  - 0s - loss: 12.1054 - mean_absolute_error: 12.1054
# Epoch 108/122
#  - 0s - loss: 12.0795 - mean_absolute_error: 12.0795
# Epoch 109/122
#  - 0s - loss: 12.0750 - mean_absolute_error: 12.0750
# Epoch 110/122
#  - 0s - loss: 12.0628 - mean_absolute_error: 12.0628
# Epoch 111/122
#  - 0s - loss: 12.0644 - mean_absolute_error: 12.0644
# Epoch 112/122
#  - 0s - loss: 12.0610 - mean_absolute_error: 12.0610
# Epoch 113/122
#  - 0s - loss: 12.0457 - mean_absolute_error: 12.0457
# Epoch 114/122
#  - 0s - loss: 12.0327 - mean_absolute_error: 12.0327
# Epoch 115/122
#  - 0s - loss: 12.0421 - mean_absolute_error: 12.0421
# Epoch 116/122
#  - 0s - loss: 12.0209 - mean_absolute_error: 12.0209
# Epoch 117/122
#  - 0s - loss: 12.0213 - mean_absolute_error: 12.0213
# Epoch 118/122
#  - 0s - loss: 12.0266 - mean_absolute_error: 12.0266
# Epoch 119/122
#  - 0s - loss: 12.0108 - mean_absolute_error: 12.0108
# Epoch 120/122
#  - 0s - loss: 11.9955 - mean_absolute_error: 11.9955
# Epoch 121/122
#  - 0s - loss: 11.9979 - mean_absolute_error: 11.9979
# Epoch 122/122
#  - 0s - loss: 12.0007 - mean_absolute_error: 12.0007
# 3
# 12.66050884738785
# Epoch 1/122
#  - 2s - loss: 126.7620 - mean_absolute_error: 126.7620
# Epoch 2/122
#  - 0s - loss: 118.7112 - mean_absolute_error: 118.7112
# Epoch 3/122
#  - 0s - loss: 105.9380 - mean_absolute_error: 105.9380
# Epoch 4/122
#  - 0s - loss: 97.5669 - mean_absolute_error: 97.5669
# Epoch 5/122
#  - 0s - loss: 90.5012 - mean_absolute_error: 90.5012
# Epoch 6/122
#  - 0s - loss: 83.9386 - mean_absolute_error: 83.9386
# Epoch 7/122
#  - 0s - loss: 77.6502 - mean_absolute_error: 77.6502
# Epoch 8/122
#  - 0s - loss: 71.5356 - mean_absolute_error: 71.5356
# Epoch 9/122
#  - 0s - loss: 65.5414 - mean_absolute_error: 65.5414
# Epoch 10/122
#  - 0s - loss: 59.6355 - mean_absolute_error: 59.6355
# Epoch 11/122
#  - 0s - loss: 53.7985 - mean_absolute_error: 53.7985
# Epoch 12/122
#  - 0s - loss: 48.0182 - mean_absolute_error: 48.0182
# Epoch 13/122
#  - 0s - loss: 42.2849 - mean_absolute_error: 42.2849
# Epoch 14/122
#  - 0s - loss: 36.6021 - mean_absolute_error: 36.6021
# Epoch 15/122
#  - 0s - loss: 31.0199 - mean_absolute_error: 31.0199
# Epoch 16/122
#  - 0s - loss: 25.8175 - mean_absolute_error: 25.8175
# Epoch 17/122
#  - 0s - loss: 21.4637 - mean_absolute_error: 21.4637
# Epoch 18/122
#  - 0s - loss: 18.4121 - mean_absolute_error: 18.4121
# Epoch 19/122
#  - 0s - loss: 16.5583 - mean_absolute_error: 16.5583
# Epoch 20/122
#  - 0s - loss: 15.5257 - mean_absolute_error: 15.5257
# Epoch 21/122
#  - 0s - loss: 14.9432 - mean_absolute_error: 14.9432
# Epoch 22/122
#  - 0s - loss: 14.6415 - mean_absolute_error: 14.6415
# Epoch 23/122
#  - 0s - loss: 14.4939 - mean_absolute_error: 14.4939
# Epoch 24/122
#  - 0s - loss: 14.4293 - mean_absolute_error: 14.4293
# Epoch 25/122
#  - 0s - loss: 14.3780 - mean_absolute_error: 14.3780
# Epoch 26/122
#  - 0s - loss: 14.3329 - mean_absolute_error: 14.3329
# Epoch 27/122
#  - 0s - loss: 14.3418 - mean_absolute_error: 14.3418
# Epoch 28/122
#  - 0s - loss: 14.2380 - mean_absolute_error: 14.2380
# Epoch 29/122
#  - 0s - loss: 14.1974 - mean_absolute_error: 14.1974
# Epoch 30/122
#  - 0s - loss: 14.1160 - mean_absolute_error: 14.1160
# Epoch 31/122
#  - 0s - loss: 13.8287 - mean_absolute_error: 13.8287
# Epoch 32/122
#  - 0s - loss: 13.6436 - mean_absolute_error: 13.6436
# Epoch 33/122
#  - 0s - loss: 13.4221 - mean_absolute_error: 13.4221
# Epoch 34/122
#  - 0s - loss: 13.4588 - mean_absolute_error: 13.4588
# Epoch 35/122
#  - 0s - loss: 13.3223 - mean_absolute_error: 13.3223
# Epoch 36/122
#  - 0s - loss: 13.2487 - mean_absolute_error: 13.2487
# Epoch 37/122
#  - 0s - loss: 13.1347 - mean_absolute_error: 13.1347
# Epoch 38/122
#  - 0s - loss: 13.0057 - mean_absolute_error: 13.0057
# Epoch 39/122
#  - 0s - loss: 12.9293 - mean_absolute_error: 12.9293
# Epoch 40/122
#  - 0s - loss: 12.8900 - mean_absolute_error: 12.8900
# Epoch 41/122
#  - 0s - loss: 12.8564 - mean_absolute_error: 12.8564
# Epoch 42/122
#  - 0s - loss: 12.8351 - mean_absolute_error: 12.8351
# Epoch 43/122
#  - 0s - loss: 12.7848 - mean_absolute_error: 12.7848
# Epoch 44/122
#  - 0s - loss: 12.7622 - mean_absolute_error: 12.7622
# Epoch 45/122
#  - 0s - loss: 12.7180 - mean_absolute_error: 12.7180
# Epoch 46/122
#  - 0s - loss: 12.7010 - mean_absolute_error: 12.7010
# Epoch 47/122
#  - 0s - loss: 12.6592 - mean_absolute_error: 12.6592
# Epoch 48/122
#  - 0s - loss: 12.6223 - mean_absolute_error: 12.6223
# Epoch 49/122
#  - 0s - loss: 12.6127 - mean_absolute_error: 12.6127
# Epoch 50/122
#  - 0s - loss: 12.6022 - mean_absolute_error: 12.6022
# Epoch 51/122
#  - 0s - loss: 12.5933 - mean_absolute_error: 12.5933
# Epoch 52/122
#  - 0s - loss: 12.5671 - mean_absolute_error: 12.5671
# Epoch 53/122
#  - 0s - loss: 12.5502 - mean_absolute_error: 12.5502
# Epoch 54/122
#  - 0s - loss: 12.5359 - mean_absolute_error: 12.5359
# Epoch 55/122
#  - 0s - loss: 12.5286 - mean_absolute_error: 12.5286
# Epoch 56/122
#  - 0s - loss: 12.5046 - mean_absolute_error: 12.5046
# Epoch 57/122
#  - 0s - loss: 12.5114 - mean_absolute_error: 12.5114
# Epoch 58/122
#  - 0s - loss: 12.4711 - mean_absolute_error: 12.4711
# Epoch 59/122
#  - 0s - loss: 12.4624 - mean_absolute_error: 12.4624
# Epoch 60/122
#  - 0s - loss: 12.4528 - mean_absolute_error: 12.4528
# Epoch 61/122
#  - 0s - loss: 12.4257 - mean_absolute_error: 12.4257
# Epoch 62/122
#  - 0s - loss: 12.4382 - mean_absolute_error: 12.4382
# Epoch 63/122
#  - 0s - loss: 12.4252 - mean_absolute_error: 12.4252
# Epoch 64/122
#  - 0s - loss: 12.3984 - mean_absolute_error: 12.3984
# Epoch 65/122
#  - 0s - loss: 12.4225 - mean_absolute_error: 12.4225
# Epoch 66/122
#  - 0s - loss: 12.3729 - mean_absolute_error: 12.3729
# Epoch 67/122
#  - 0s - loss: 12.3578 - mean_absolute_error: 12.3578
# Epoch 68/122
#  - 0s - loss: 12.3500 - mean_absolute_error: 12.3500
# Epoch 69/122
#  - 0s - loss: 12.3448 - mean_absolute_error: 12.3448
# Epoch 70/122
#  - 0s - loss: 12.3324 - mean_absolute_error: 12.3324
# Epoch 71/122
#  - 0s - loss: 12.3372 - mean_absolute_error: 12.3372
# Epoch 72/122
#  - 0s - loss: 12.3140 - mean_absolute_error: 12.3140
# Epoch 73/122
#  - 0s - loss: 12.3066 - mean_absolute_error: 12.3066
# Epoch 74/122
#  - 0s - loss: 12.3182 - mean_absolute_error: 12.3182
# Epoch 75/122
#  - 0s - loss: 12.3040 - mean_absolute_error: 12.3040
# Epoch 76/122
#  - 0s - loss: 12.2968 - mean_absolute_error: 12.2968
# Epoch 77/122
#  - 0s - loss: 12.2875 - mean_absolute_error: 12.2875
# Epoch 78/122
#  - 0s - loss: 12.2873 - mean_absolute_error: 12.2873
# Epoch 79/122
#  - 0s - loss: 12.2628 - mean_absolute_error: 12.2628
# Epoch 80/122
#  - 0s - loss: 12.2546 - mean_absolute_error: 12.2546
# Epoch 81/122
#  - 0s - loss: 12.2758 - mean_absolute_error: 12.2758
# Epoch 82/122
#  - 0s - loss: 12.2606 - mean_absolute_error: 12.2606
# Epoch 83/122
#  - 0s - loss: 12.2472 - mean_absolute_error: 12.2472
# Epoch 84/122
#  - 0s - loss: 12.2259 - mean_absolute_error: 12.2259
# Epoch 85/122
#  - 0s - loss: 12.2406 - mean_absolute_error: 12.2406
# Epoch 86/122
#  - 0s - loss: 12.2282 - mean_absolute_error: 12.2282
# Epoch 87/122
#  - 0s - loss: 12.2219 - mean_absolute_error: 12.2219
# Epoch 88/122
#  - 0s - loss: 12.2018 - mean_absolute_error: 12.2018
# Epoch 89/122
#  - 0s - loss: 12.2052 - mean_absolute_error: 12.2052
# Epoch 90/122
#  - 0s - loss: 12.2175 - mean_absolute_error: 12.2175
# Epoch 91/122
#  - 0s - loss: 12.1970 - mean_absolute_error: 12.1970
# Epoch 92/122
#  - 0s - loss: 12.1821 - mean_absolute_error: 12.1821
# Epoch 93/122
#  - 0s - loss: 12.1995 - mean_absolute_error: 12.1995
# Epoch 94/122
#  - 0s - loss: 12.1852 - mean_absolute_error: 12.1852
# Epoch 95/122
#  - 0s - loss: 12.1654 - mean_absolute_error: 12.1654
# Epoch 96/122
#  - 0s - loss: 12.1525 - mean_absolute_error: 12.1525
# Epoch 97/122
#  - 0s - loss: 12.1549 - mean_absolute_error: 12.1549
# Epoch 98/122
#  - 0s - loss: 12.1417 - mean_absolute_error: 12.1417
# Epoch 99/122
#  - 0s - loss: 12.1505 - mean_absolute_error: 12.1505
# Epoch 100/122
#  - 0s - loss: 12.1321 - mean_absolute_error: 12.1321
# Epoch 101/122
#  - 0s - loss: 12.1432 - mean_absolute_error: 12.1432
# Epoch 102/122
#  - 0s - loss: 12.1247 - mean_absolute_error: 12.1247
# Epoch 103/122
#  - 0s - loss: 12.1419 - mean_absolute_error: 12.1419
# Epoch 104/122
#  - 0s - loss: 12.1330 - mean_absolute_error: 12.1330
# Epoch 105/122
#  - 0s - loss: 12.1012 - mean_absolute_error: 12.1012
# Epoch 106/122
#  - 0s - loss: 12.1062 - mean_absolute_error: 12.1062
# Epoch 107/122
#  - 0s - loss: 12.0929 - mean_absolute_error: 12.0929
# Epoch 108/122
#  - 0s - loss: 12.0942 - mean_absolute_error: 12.0942
# Epoch 109/122
#  - 0s - loss: 12.0836 - mean_absolute_error: 12.0836
# Epoch 110/122
#  - 0s - loss: 12.0965 - mean_absolute_error: 12.0965
# Epoch 111/122
#  - 0s - loss: 12.0717 - mean_absolute_error: 12.0717
# Epoch 112/122
#  - 0s - loss: 12.0751 - mean_absolute_error: 12.0751
# Epoch 113/122
#  - 0s - loss: 12.0861 - mean_absolute_error: 12.0861
# Epoch 114/122
#  - 0s - loss: 12.0586 - mean_absolute_error: 12.0586
# Epoch 115/122
#  - 0s - loss: 12.0664 - mean_absolute_error: 12.0664
# Epoch 116/122
#  - 0s - loss: 12.0484 - mean_absolute_error: 12.0484
# Epoch 117/122
#  - 0s - loss: 12.0529 - mean_absolute_error: 12.0529
# Epoch 118/122
#  - 0s - loss: 12.0561 - mean_absolute_error: 12.0561
# Epoch 119/122
#  - 0s - loss: 12.0242 - mean_absolute_error: 12.0242
# Epoch 120/122
#  - 0s - loss: 12.0207 - mean_absolute_error: 12.0207
# Epoch 121/122
#  - 0s - loss: 12.0168 - mean_absolute_error: 12.0168
# Epoch 122/122
#  - 0s - loss: 11.9983 - mean_absolute_error: 11.9983
# 4
# 12.616630317628847
# Epoch 1/122
#  - 2s - loss: 126.8305 - mean_absolute_error: 126.8305
# Epoch 2/122
#  - 0s - loss: 119.2282 - mean_absolute_error: 119.2282
# Epoch 3/122
#  - 0s - loss: 106.4717 - mean_absolute_error: 106.4717
# Epoch 4/122
#  - 0s - loss: 98.0479 - mean_absolute_error: 98.0479
# Epoch 5/122
#  - 0s - loss: 90.9591 - mean_absolute_error: 90.9591
# Epoch 6/122
#  - 0s - loss: 84.3804 - mean_absolute_error: 84.3804
# Epoch 7/122
#  - 0s - loss: 78.0804 - mean_absolute_error: 78.0804
# Epoch 8/122
#  - 0s - loss: 71.9571 - mean_absolute_error: 71.9571
# Epoch 9/122
#  - 0s - loss: 65.9557 - mean_absolute_error: 65.9557
# Epoch 10/122
#  - 0s - loss: 60.0438 - mean_absolute_error: 60.0438
# Epoch 11/122
#  - 0s - loss: 54.2017 - mean_absolute_error: 54.2017
# Epoch 12/122
#  - 0s - loss: 48.4170 - mean_absolute_error: 48.4170
# Epoch 13/122
#  - 0s - loss: 42.6799 - mean_absolute_error: 42.6799
# Epoch 14/122
#  - 0s - loss: 36.9895 - mean_absolute_error: 36.9895
# Epoch 15/122
#  - 0s - loss: 31.3889 - mean_absolute_error: 31.3889
# Epoch 16/122
#  - 0s - loss: 26.1370 - mean_absolute_error: 26.1370
# Epoch 17/122
#  - 0s - loss: 21.7199 - mean_absolute_error: 21.7199
# Epoch 18/122
#  - 0s - loss: 18.5721 - mean_absolute_error: 18.5721
# Epoch 19/122
#  - 0s - loss: 16.6501 - mean_absolute_error: 16.6501
# Epoch 20/122
#  - 0s - loss: 15.5714 - mean_absolute_error: 15.5714
# Epoch 21/122
#  - 0s - loss: 14.9735 - mean_absolute_error: 14.9735
# Epoch 22/122
#  - 0s - loss: 14.6916 - mean_absolute_error: 14.6916
# Epoch 23/122
#  - 0s - loss: 14.5001 - mean_absolute_error: 14.5001
# Epoch 24/122
#  - 0s - loss: 14.4267 - mean_absolute_error: 14.4267
# Epoch 25/122
#  - 0s - loss: 14.3801 - mean_absolute_error: 14.3801
# Epoch 26/122
#  - 0s - loss: 14.3249 - mean_absolute_error: 14.3249
# Epoch 27/122
#  - 0s - loss: 14.3240 - mean_absolute_error: 14.3240
# Epoch 28/122
#  - 0s - loss: 14.3285 - mean_absolute_error: 14.3285
# Epoch 29/122
#  - 0s - loss: 14.3092 - mean_absolute_error: 14.3092
# Epoch 30/122
#  - 0s - loss: 14.3264 - mean_absolute_error: 14.3264
# Epoch 31/122
#  - 0s - loss: 14.2417 - mean_absolute_error: 14.2417
# Epoch 32/122
#  - 0s - loss: 14.1133 - mean_absolute_error: 14.1133
# Epoch 33/122
#  - 0s - loss: 14.1088 - mean_absolute_error: 14.1088
# Epoch 34/122
#  - 0s - loss: 13.7943 - mean_absolute_error: 13.7943
# Epoch 35/122
#  - 0s - loss: 13.5933 - mean_absolute_error: 13.5933
# Epoch 36/122
#  - 0s - loss: 13.3611 - mean_absolute_error: 13.3611
# Epoch 37/122
#  - 0s - loss: 13.2814 - mean_absolute_error: 13.2814
# Epoch 38/122
#  - 0s - loss: 13.1561 - mean_absolute_error: 13.1561
# Epoch 39/122
#  - 0s - loss: 13.0509 - mean_absolute_error: 13.0509
# Epoch 40/122
#  - 0s - loss: 12.9808 - mean_absolute_error: 12.9808
# Epoch 41/122
#  - 0s - loss: 12.9065 - mean_absolute_error: 12.9065
# Epoch 42/122
#  - 0s - loss: 12.8161 - mean_absolute_error: 12.8161
# Epoch 43/122
#  - 0s - loss: 12.8058 - mean_absolute_error: 12.8058
# Epoch 44/122
#  - 0s - loss: 12.7974 - mean_absolute_error: 12.7974
# Epoch 45/122
#  - 0s - loss: 12.7495 - mean_absolute_error: 12.7495
# Epoch 46/122
#  - 0s - loss: 12.6863 - mean_absolute_error: 12.6863
# Epoch 47/122
#  - 0s - loss: 12.6533 - mean_absolute_error: 12.6533
# Epoch 48/122
#  - 0s - loss: 12.6381 - mean_absolute_error: 12.6381
# Epoch 49/122
#  - 0s - loss: 12.6149 - mean_absolute_error: 12.6149
# Epoch 50/122
#  - 0s - loss: 12.6009 - mean_absolute_error: 12.6009
# Epoch 51/122
#  - 0s - loss: 12.5768 - mean_absolute_error: 12.5768
# Epoch 52/122
#  - 0s - loss: 12.5684 - mean_absolute_error: 12.5684
# Epoch 53/122
#  - 0s - loss: 12.5660 - mean_absolute_error: 12.5660
# Epoch 54/122
#  - 0s - loss: 12.5369 - mean_absolute_error: 12.5369
# Epoch 55/122
#  - 0s - loss: 12.5381 - mean_absolute_error: 12.5381
# Epoch 56/122
#  - 0s - loss: 12.5120 - mean_absolute_error: 12.5120
# Epoch 57/122
#  - 0s - loss: 12.5118 - mean_absolute_error: 12.5118
# Epoch 58/122
#  - 0s - loss: 12.4973 - mean_absolute_error: 12.4973
# Epoch 59/122
#  - 0s - loss: 12.4740 - mean_absolute_error: 12.4740
# Epoch 60/122
#  - 0s - loss: 12.4709 - mean_absolute_error: 12.4709
# Epoch 61/122
#  - 0s - loss: 12.4595 - mean_absolute_error: 12.4595
# Epoch 62/122
#  - 0s - loss: 12.4414 - mean_absolute_error: 12.4414
# Epoch 63/122
#  - 0s - loss: 12.4525 - mean_absolute_error: 12.4525
# Epoch 64/122
#  - 0s - loss: 12.4458 - mean_absolute_error: 12.4458
# Epoch 65/122
#  - 0s - loss: 12.4311 - mean_absolute_error: 12.4311
# Epoch 66/122
#  - 0s - loss: 12.4047 - mean_absolute_error: 12.4047
# Epoch 67/122
#  - 0s - loss: 12.3962 - mean_absolute_error: 12.3962
# Epoch 68/122
#  - 0s - loss: 12.3914 - mean_absolute_error: 12.3914
# Epoch 69/122
#  - 0s - loss: 12.3850 - mean_absolute_error: 12.3850
# Epoch 70/122
#  - 0s - loss: 12.3748 - mean_absolute_error: 12.3748
# Epoch 71/122
#  - 0s - loss: 12.3504 - mean_absolute_error: 12.3504
# Epoch 72/122
#  - 0s - loss: 12.3529 - mean_absolute_error: 12.3529
# Epoch 73/122
#  - 0s - loss: 12.3625 - mean_absolute_error: 12.3625
# Epoch 74/122
#  - 0s - loss: 12.3653 - mean_absolute_error: 12.3653
# Epoch 75/122
#  - 0s - loss: 12.3433 - mean_absolute_error: 12.3433
# Epoch 76/122
#  - 0s - loss: 12.3305 - mean_absolute_error: 12.3305
# Epoch 77/122
#  - 0s - loss: 12.3382 - mean_absolute_error: 12.3382
# Epoch 78/122
#  - 0s - loss: 12.3290 - mean_absolute_error: 12.3290
# Epoch 79/122
#  - 0s - loss: 12.3250 - mean_absolute_error: 12.3250
# Epoch 80/122
#  - 0s - loss: 12.3079 - mean_absolute_error: 12.3079
# Epoch 81/122
#  - 0s - loss: 12.3061 - mean_absolute_error: 12.3061
# Epoch 82/122
#  - 0s - loss: 12.2840 - mean_absolute_error: 12.2840
# Epoch 83/122
#  - 0s - loss: 12.2844 - mean_absolute_error: 12.2844
# Epoch 84/122
#  - 0s - loss: 12.2731 - mean_absolute_error: 12.2731
# Epoch 85/122
#  - 0s - loss: 12.2603 - mean_absolute_error: 12.2603
# Epoch 86/122
#  - 0s - loss: 12.2520 - mean_absolute_error: 12.2520
# Epoch 87/122
#  - 0s - loss: 12.2300 - mean_absolute_error: 12.2300
# Epoch 88/122
#  - 0s - loss: 12.2434 - mean_absolute_error: 12.2434
# Epoch 89/122
#  - 0s - loss: 12.2195 - mean_absolute_error: 12.2195
# Epoch 90/122
#  - 0s - loss: 12.2193 - mean_absolute_error: 12.2193
# Epoch 91/122
#  - 0s - loss: 12.2076 - mean_absolute_error: 12.2076
# Epoch 92/122
#  - 0s - loss: 12.1910 - mean_absolute_error: 12.1910
# Epoch 93/122
#  - 0s - loss: 12.1934 - mean_absolute_error: 12.1934
# Epoch 94/122
#  - 0s - loss: 12.1810 - mean_absolute_error: 12.1810
# Epoch 95/122
#  - 0s - loss: 12.1728 - mean_absolute_error: 12.1728
# Epoch 96/122
#  - 0s - loss: 12.1620 - mean_absolute_error: 12.1620
# Epoch 97/122
#  - 0s - loss: 12.1687 - mean_absolute_error: 12.1687
# Epoch 98/122
#  - 0s - loss: 12.1482 - mean_absolute_error: 12.1482
# Epoch 99/122
#  - 0s - loss: 12.1478 - mean_absolute_error: 12.1478
# Epoch 100/122
#  - 0s - loss: 12.1319 - mean_absolute_error: 12.1319
# Epoch 101/122
#  - 0s - loss: 12.1488 - mean_absolute_error: 12.1488
# Epoch 102/122
#  - 0s - loss: 12.1426 - mean_absolute_error: 12.1426
# Epoch 103/122
#  - 0s - loss: 12.1111 - mean_absolute_error: 12.1111
# Epoch 104/122
#  - 0s - loss: 12.1057 - mean_absolute_error: 12.1057
# Epoch 105/122
#  - 0s - loss: 12.1109 - mean_absolute_error: 12.1109
# Epoch 106/122
#  - 0s - loss: 12.0867 - mean_absolute_error: 12.0867
# Epoch 107/122
#  - 0s - loss: 12.0852 - mean_absolute_error: 12.0852
# Epoch 108/122
#  - 0s - loss: 12.0716 - mean_absolute_error: 12.0716
# Epoch 109/122
#  - 0s - loss: 12.0791 - mean_absolute_error: 12.0791
# Epoch 110/122
#  - 0s - loss: 12.1039 - mean_absolute_error: 12.1039
# Epoch 111/122
#  - 0s - loss: 12.0552 - mean_absolute_error: 12.0552
# Epoch 112/122
#  - 0s - loss: 12.0660 - mean_absolute_error: 12.0660
# Epoch 113/122
#  - 0s - loss: 12.0401 - mean_absolute_error: 12.0401
# Epoch 114/122
#  - 0s - loss: 12.0419 - mean_absolute_error: 12.0419
# ...
# Epoch 4/122
#  - 0s - loss: 97.4012 - mean_absolute_error: 97.4012
# Epoch 5/122
#  - 0s - loss: 90.3154 - mean_absolute_error: 90.3154
# Epoch 6/122
#  - 0s - loss: 83.7399 - mean_absolute_error: 83.7399
# Epoch 7/122
#  - 0s - loss: 77.4421 - mean_absolute_error: 77.4421
# Epoch 8/122
#  - 0s - loss: 71.3206 - mean_absolute_error: 71.3206
# Epoch 9/122
#  - 0s - loss: 65.3208 - mean_absolute_error: 65.3208
# Epoch 10/122
#  - 0s - loss: 59.4101 - mean_absolute_error: 59.4101
# Epoch 11/122
#  - 0s - loss: 53.5696 - mean_absolute_error: 53.5696
# Epoch 12/122
#  - 0s - loss: 47.7855 - mean_absolute_error: 47.7855
# Epoch 13/122
#  - 0s - loss: 42.0491 - mean_absolute_error: 42.0491
# Epoch 14/122
#  - 0s - loss: 36.3608 - mean_absolute_error: 36.3608
# Epoch 15/122
#  - 0s - loss: 30.7841 - mean_absolute_error: 30.7841
# Epoch 16/122
#  - 0s - loss: 25.5921 - mean_absolute_error: 25.5921
# Epoch 17/122
#  - 0s - loss: 21.2878 - mean_absolute_error: 21.2878
# Epoch 18/122
#  - 0s - loss: 18.3021 - mean_absolute_error: 18.3021
# Epoch 19/122
#  - 0s - loss: 16.4946 - mean_absolute_error: 16.4946
# Epoch 20/122
#  - 0s - loss: 15.4772 - mean_absolute_error: 15.4772
# Epoch 21/122
#  - 0s - loss: 14.9269 - mean_absolute_error: 14.9269
# Epoch 22/122
#  - 0s - loss: 14.6359 - mean_absolute_error: 14.6359
# Epoch 23/122
#  - 0s - loss: 14.5749 - mean_absolute_error: 14.5749
# Epoch 24/122
#  - 0s - loss: 14.4185 - mean_absolute_error: 14.4185
# Epoch 25/122
#  - 0s - loss: 14.3618 - mean_absolute_error: 14.3618
# Epoch 26/122
#  - 0s - loss: 14.3658 - mean_absolute_error: 14.3658
# Epoch 27/122
#  - 0s - loss: 14.3621 - mean_absolute_error: 14.3621
# Epoch 28/122
#  - 0s - loss: 14.3088 - mean_absolute_error: 14.3088
# Epoch 29/122
#  - 0s - loss: 14.2293 - mean_absolute_error: 14.2293
# Epoch 30/122
#  - 0s - loss: 14.1436 - mean_absolute_error: 14.1436
# Epoch 31/122
#  - 0s - loss: 14.0435 - mean_absolute_error: 14.0435
# Epoch 32/122
#  - 0s - loss: 13.7751 - mean_absolute_error: 13.7751
# Epoch 33/122
#  - 0s - loss: 13.5931 - mean_absolute_error: 13.5931
# Epoch 34/122
#  - 0s - loss: 13.4311 - mean_absolute_error: 13.4311
# Epoch 35/122
#  - 0s - loss: 13.3028 - mean_absolute_error: 13.3028
# Epoch 36/122
#  - 0s - loss: 13.2674 - mean_absolute_error: 13.2674
# Epoch 37/122
#  - 0s - loss: 13.2162 - mean_absolute_error: 13.2162
# Epoch 38/122
#  - 0s - loss: 13.0989 - mean_absolute_error: 13.0989
# Epoch 39/122
#  - 0s - loss: 13.0004 - mean_absolute_error: 13.0004
# Epoch 40/122
#  - 0s - loss: 12.9740 - mean_absolute_error: 12.9740
# Epoch 41/122
#  - 0s - loss: 12.9271 - mean_absolute_error: 12.9271
# Epoch 42/122
#  - 0s - loss: 12.8542 - mean_absolute_error: 12.8542
# Epoch 43/122
#  - 0s - loss: 12.7756 - mean_absolute_error: 12.7756
# Epoch 44/122
#  - 0s - loss: 12.7908 - mean_absolute_error: 12.7908
# Epoch 45/122
#  - 0s - loss: 12.7309 - mean_absolute_error: 12.7309
# Epoch 46/122
#  - 0s - loss: 12.6751 - mean_absolute_error: 12.6751
# Epoch 47/122
#  - 0s - loss: 12.6531 - mean_absolute_error: 12.6531
# Epoch 48/122
#  - 0s - loss: 12.6221 - mean_absolute_error: 12.6221
# Epoch 49/122
#  - 0s - loss: 12.6193 - mean_absolute_error: 12.6193
# Epoch 50/122
#  - 0s - loss: 12.5977 - mean_absolute_error: 12.5977
# Epoch 51/122
#  - 0s - loss: 12.5772 - mean_absolute_error: 12.5772
# Epoch 52/122
#  - 0s - loss: 12.5783 - mean_absolute_error: 12.5783
# Epoch 53/122
#  - 0s - loss: 12.5652 - mean_absolute_error: 12.5652
# Epoch 54/122
#  - 0s - loss: 12.5503 - mean_absolute_error: 12.5503
# Epoch 55/122
#  - 0s - loss: 12.5318 - mean_absolute_error: 12.5318
# Epoch 56/122
#  - 0s - loss: 12.5234 - mean_absolute_error: 12.5234
# Epoch 57/122
#  - 0s - loss: 12.5025 - mean_absolute_error: 12.5025
# Epoch 58/122
#  - 0s - loss: 12.4937 - mean_absolute_error: 12.4937
# Epoch 59/122
#  - 0s - loss: 12.4821 - mean_absolute_error: 12.4821
# Epoch 60/122
#  - 0s - loss: 12.4718 - mean_absolute_error: 12.4718
# Epoch 61/122
#  - 0s - loss: 12.4452 - mean_absolute_error: 12.4452
# Epoch 62/122
#  - 0s - loss: 12.4610 - mean_absolute_error: 12.4610
# Epoch 63/122
#  - 0s - loss: 12.4237 - mean_absolute_error: 12.4237
# Epoch 64/122
#  - 0s - loss: 12.4264 - mean_absolute_error: 12.4264
# Epoch 65/122
#  - 0s - loss: 12.4022 - mean_absolute_error: 12.4022
# Epoch 66/122
#  - 0s - loss: 12.4048 - mean_absolute_error: 12.4048
# Epoch 67/122
#  - 0s - loss: 12.3746 - mean_absolute_error: 12.3746
# Epoch 68/122
#  - 0s - loss: 12.3665 - mean_absolute_error: 12.3665
# Epoch 69/122
#  - 0s - loss: 12.3626 - mean_absolute_error: 12.3626
# Epoch 70/122
#  - 0s - loss: 12.3719 - mean_absolute_error: 12.3719
# Epoch 71/122
#  - 0s - loss: 12.3365 - mean_absolute_error: 12.3365
# Epoch 72/122
#  - 0s - loss: 12.3399 - mean_absolute_error: 12.3399
# Epoch 73/122
#  - 0s - loss: 12.3173 - mean_absolute_error: 12.3173
# Epoch 74/122
#  - 0s - loss: 12.3233 - mean_absolute_error: 12.3233
# Epoch 75/122
#  - 0s - loss: 12.3028 - mean_absolute_error: 12.3028
# Epoch 76/122
#  - 0s - loss: 12.3175 - mean_absolute_error: 12.3175
# Epoch 77/122
#  - 0s - loss: 12.2973 - mean_absolute_error: 12.2973
# Epoch 78/122
#  - 0s - loss: 12.2880 - mean_absolute_error: 12.2880
# Epoch 79/122
#  - 0s - loss: 12.2720 - mean_absolute_error: 12.2720
# Epoch 80/122
#  - 0s - loss: 12.2708 - mean_absolute_error: 12.2708
# Epoch 81/122
#  - 0s - loss: 12.2688 - mean_absolute_error: 12.2688
# Epoch 82/122
#  - 0s - loss: 12.2769 - mean_absolute_error: 12.2769
# Epoch 83/122
#  - 0s - loss: 12.2352 - mean_absolute_error: 12.2352
# Epoch 84/122
#  - 0s - loss: 12.2367 - mean_absolute_error: 12.2367
# Epoch 85/122
#  - 0s - loss: 12.2341 - mean_absolute_error: 12.2341
# Epoch 86/122
#  - 0s - loss: 12.2205 - mean_absolute_error: 12.2205
# Epoch 87/122
#  - 0s - loss: 12.2089 - mean_absolute_error: 12.2089
# Epoch 88/122
#  - 0s - loss: 12.2046 - mean_absolute_error: 12.2046
# Epoch 89/122
#  - 0s - loss: 12.2151 - mean_absolute_error: 12.2151
# Epoch 90/122
#  - 0s - loss: 12.1860 - mean_absolute_error: 12.1860
# Epoch 91/122
#  - 0s - loss: 12.1900 - mean_absolute_error: 12.1900
# Epoch 92/122
#  - 0s - loss: 12.1850 - mean_absolute_error: 12.1850
# Epoch 93/122
#  - 0s - loss: 12.1761 - mean_absolute_error: 12.1761
# Epoch 94/122
#  - 0s - loss: 12.1745 - mean_absolute_error: 12.1745
# Epoch 95/122
#  - 0s - loss: 12.1855 - mean_absolute_error: 12.1855
# Epoch 96/122
#  - 0s - loss: 12.1770 - mean_absolute_error: 12.1770
# Epoch 97/122
#  - 0s - loss: 12.1475 - mean_absolute_error: 12.1475
# Epoch 98/122
#  - 0s - loss: 12.1516 - mean_absolute_error: 12.1516
# Epoch 99/122
#  - 0s - loss: 12.1621 - mean_absolute_error: 12.1621
# Epoch 100/122
#  - 0s - loss: 12.1407 - mean_absolute_error: 12.1407
# Epoch 101/122
#  - 0s - loss: 12.1379 - mean_absolute_error: 12.1379
# Epoch 102/122
#  - 0s - loss: 12.1290 - mean_absolute_error: 12.1290
# Epoch 103/122
#  - 0s - loss: 12.1353 - mean_absolute_error: 12.1353
# Epoch 104/122
#  - 0s - loss: 12.1247 - mean_absolute_error: 12.1247
# Epoch 105/122
#  - 0s - loss: 12.1090 - mean_absolute_error: 12.1090
# Epoch 106/122
#  - 0s - loss: 12.1097 - mean_absolute_error: 12.1097
# Epoch 107/122
#  - 0s - loss: 12.0867 - mean_absolute_error: 12.0867
# Epoch 108/122
#  - 0s - loss: 12.1337 - mean_absolute_error: 12.1337
# Epoch 109/122
#  - 0s - loss: 12.0811 - mean_absolute_error: 12.0811
# Epoch 110/122
#  - 0s - loss: 12.0758 - mean_absolute_error: 12.0758
# Epoch 111/122
#  - 0s - loss: 12.0820 - mean_absolute_error: 12.0820
# Epoch 112/122
#  - 0s - loss: 12.0898 - mean_absolute_error: 12.0898
# Epoch 113/122
#  - 0s - loss: 12.0636 - mean_absolute_error: 12.0636
# Epoch 114/122
#  - 0s - loss: 12.0749 - mean_absolute_error: 12.0749
# Epoch 115/122
#  - 0s - loss: 12.0621 - mean_absolute_error: 12.0621
# Epoch 116/122
#  - 0s - loss: 12.0471 - mean_absolute_error: 12.0471
# Epoch 117/122
#  - 0s - loss: 12.0352 - mean_absolute_error: 12.0352
# Epoch 118/122
#  - 0s - loss: 12.0568 - mean_absolute_error: 12.0568
# Epoch 119/122
#  - 0s - loss: 12.0466 - mean_absolute_error: 12.0466
# Epoch 120/122
#  - 0s - loss: 12.0388 - mean_absolute_error: 12.0388
# Epoch 121/122
#  - 0s - loss: 12.0401 - mean_absolute_error: 12.0401
# Epoch 122/122
#  - 0s - loss: 12.0295 - mean_absolute_error: 12.0295
# 28
# 12.623041600556
# Epoch 1/122
#  - 3s - loss: 126.7556 - mean_absolute_error: 126.7556
# Epoch 2/122
#  - 0s - loss: 118.6465 - mean_absolute_error: 118.6465
# Epoch 3/122
#  - 0s - loss: 106.1030 - mean_absolute_error: 106.1030
# Epoch 4/122
#  - 0s - loss: 97.8139 - mean_absolute_error: 97.8139
# Epoch 5/122
#  - 0s - loss: 90.7800 - mean_absolute_error: 90.7800
# Epoch 6/122
#  - 0s - loss: 84.2359 - mean_absolute_error: 84.2359
# Epoch 7/122
#  - 0s - loss: 77.9605 - mean_absolute_error: 77.9605
# Epoch 8/122
#  - 0s - loss: 71.8560 - mean_absolute_error: 71.8560
# Epoch 9/122
#  - 0s - loss: 65.8697 - mean_absolute_error: 65.8697
# Epoch 10/122
#  - 0s - loss: 59.9704 - mean_absolute_error: 59.9704
# Epoch 11/122
#  - 0s - loss: 54.1387 - mean_absolute_error: 54.1387
# Epoch 12/122
#  - 0s - loss: 48.3635 - mean_absolute_error: 48.3635
# Epoch 13/122
#  - 0s - loss: 42.6331 - mean_absolute_error: 42.6331
# Epoch 14/122
#  - 0s - loss: 36.9496 - mean_absolute_error: 36.9496
# Epoch 15/122
#  - 0s - loss: 31.3597 - mean_absolute_error: 31.3597
# Epoch 16/122
#  - 0s - loss: 26.1004 - mean_absolute_error: 26.1004
# Epoch 17/122
#  - 0s - loss: 21.6772 - mean_absolute_error: 21.6772
# Epoch 18/122
#  - 0s - loss: 18.5668 - mean_absolute_error: 18.5668
# Epoch 19/122
#  - 0s - loss: 16.6524 - mean_absolute_error: 16.6524
# Epoch 20/122
#  - 0s - loss: 15.5728 - mean_absolute_error: 15.5728
# Epoch 21/122
#  - 0s - loss: 14.9744 - mean_absolute_error: 14.9744
# Epoch 22/122
#  - 0s - loss: 14.6702 - mean_absolute_error: 14.6702
# Epoch 23/122
#  - 0s - loss: 14.4952 - mean_absolute_error: 14.4952
# Epoch 24/122
#  - 0s - loss: 14.3656 - mean_absolute_error: 14.3656
# Epoch 25/122
#  - 0s - loss: 14.3781 - mean_absolute_error: 14.3781
# Epoch 26/122
#  - 0s - loss: 14.3009 - mean_absolute_error: 14.3009
# Epoch 27/122
#  - 0s - loss: 14.2988 - mean_absolute_error: 14.2988
# Epoch 28/122
#  - 0s - loss: 14.1576 - mean_absolute_error: 14.1576
# Epoch 29/122
#  - 0s - loss: 13.9582 - mean_absolute_error: 13.9582
# Epoch 30/122
#  - 0s - loss: 13.7544 - mean_absolute_error: 13.7544
# Epoch 31/122
#  - 0s - loss: 13.5497 - mean_absolute_error: 13.5497
# Epoch 32/122
#  - 0s - loss: 13.5883 - mean_absolute_error: 13.5883
# Epoch 33/122
#  - 0s - loss: 13.4826 - mean_absolute_error: 13.4826
# Epoch 34/122
#  - 0s - loss: 13.2674 - mean_absolute_error: 13.2674
# Epoch 35/122
#  - 0s - loss: 13.2655 - mean_absolute_error: 13.2655
# Epoch 36/122
#  - 0s - loss: 13.1610 - mean_absolute_error: 13.1610
# Epoch 37/122
#  - 0s - loss: 13.0989 - mean_absolute_error: 13.0989
# Epoch 38/122
#  - 0s - loss: 12.9851 - mean_absolute_error: 12.9851
# Epoch 39/122
#  - 0s - loss: 12.9406 - mean_absolute_error: 12.9406
# Epoch 40/122
#  - 0s - loss: 12.9095 - mean_absolute_error: 12.9095
# Epoch 41/122
#  - 0s - loss: 12.8732 - mean_absolute_error: 12.8732
# Epoch 42/122
#  - 0s - loss: 12.8662 - mean_absolute_error: 12.8662
# Epoch 43/122
#  - 0s - loss: 12.7811 - mean_absolute_error: 12.7811
# Epoch 44/122
#  - 0s - loss: 12.7776 - mean_absolute_error: 12.7776
# Epoch 45/122
#  - 0s - loss: 12.7485 - mean_absolute_error: 12.7485
# Epoch 46/122
#  - 0s - loss: 12.7370 - mean_absolute_error: 12.7370
# Epoch 47/122
#  - 0s - loss: 12.6886 - mean_absolute_error: 12.6886
# Epoch 48/122
#  - 0s - loss: 12.6765 - mean_absolute_error: 12.6765
# Epoch 49/122
#  - 0s - loss: 12.6478 - mean_absolute_error: 12.6478
# Epoch 50/122
#  - 0s - loss: 12.6181 - mean_absolute_error: 12.6181
# Epoch 51/122
#  - 0s - loss: 12.6040 - mean_absolute_error: 12.6040
# Epoch 52/122
#  - 0s - loss: 12.5694 - mean_absolute_error: 12.5694
# Epoch 53/122
#  - 0s - loss: 12.5624 - mean_absolute_error: 12.5624
# Epoch 54/122
#  - 0s - loss: 12.5426 - mean_absolute_error: 12.5426
# Epoch 55/122
#  - 0s - loss: 12.5314 - mean_absolute_error: 12.5314
# Epoch 56/122
#  - 0s - loss: 12.5359 - mean_absolute_error: 12.5359
# Epoch 57/122
#  - 0s - loss: 12.4903 - mean_absolute_error: 12.4903
# Epoch 58/122
#  - 0s - loss: 12.4907 - mean_absolute_error: 12.4907
# Epoch 59/122
#  - 0s - loss: 12.4553 - mean_absolute_error: 12.4553
# Epoch 60/122
#  - 0s - loss: 12.4490 - mean_absolute_error: 12.4490
# Epoch 61/122
#  - 0s - loss: 12.4449 - mean_absolute_error: 12.4449
# Epoch 62/122
#  - 0s - loss: 12.4074 - mean_absolute_error: 12.4074
# Epoch 63/122
#  - 0s - loss: 12.3971 - mean_absolute_error: 12.3971
# Epoch 64/122
#  - 0s - loss: 12.3787 - mean_absolute_error: 12.3787
# Epoch 65/122
#  - 0s - loss: 12.3849 - mean_absolute_error: 12.3849
# Epoch 66/122
#  - 0s - loss: 12.3610 - mean_absolute_error: 12.3610
# Epoch 67/122
#  - 0s - loss: 12.3442 - mean_absolute_error: 12.3442
# Epoch 68/122
#  - 0s - loss: 12.3434 - mean_absolute_error: 12.3434
# Epoch 69/122
#  - 0s - loss: 12.3216 - mean_absolute_error: 12.3216
# Epoch 70/122
#  - 0s - loss: 12.3241 - mean_absolute_error: 12.3241
# Epoch 71/122
#  - 0s - loss: 12.2987 - mean_absolute_error: 12.2987
# Epoch 72/122
#  - 0s - loss: 12.2840 - mean_absolute_error: 12.2840
# Epoch 73/122
#  - 0s - loss: 12.2912 - mean_absolute_error: 12.2912
# Epoch 74/122
#  - 0s - loss: 12.2810 - mean_absolute_error: 12.2810
# Epoch 75/122
#  - 0s - loss: 12.2556 - mean_absolute_error: 12.2556
# Epoch 76/122
#  - 0s - loss: 12.2518 - mean_absolute_error: 12.2518
# Epoch 77/122
#  - 0s - loss: 12.2515 - mean_absolute_error: 12.2515
# Epoch 78/122
#  - 0s - loss: 12.2540 - mean_absolute_error: 12.2540
# Epoch 79/122
#  - 0s - loss: 12.2362 - mean_absolute_error: 12.2362
# Epoch 80/122
#  - 0s - loss: 12.2323 - mean_absolute_error: 12.2323
# Epoch 81/122
#  - 0s - loss: 12.2177 - mean_absolute_error: 12.2177
# Epoch 82/122
#  - 0s - loss: 12.2202 - mean_absolute_error: 12.2202
# Epoch 83/122
#  - 0s - loss: 12.2072 - mean_absolute_error: 12.2072
# Epoch 84/122
#  - 0s - loss: 12.2075 - mean_absolute_error: 12.2075
# Epoch 85/122
#  - 0s - loss: 12.2044 - mean_absolute_error: 12.2044
# Epoch 86/122
#  - 0s - loss: 12.2082 - mean_absolute_error: 12.2082
# Epoch 87/122
#  - 0s - loss: 12.1876 - mean_absolute_error: 12.1876
# Epoch 88/122
#  - 0s - loss: 12.1817 - mean_absolute_error: 12.1817
# Epoch 89/122
#  - 0s - loss: 12.1611 - mean_absolute_error: 12.1611
# Epoch 90/122
#  - 0s - loss: 12.1605 - mean_absolute_error: 12.1605
# Epoch 91/122
#  - 0s - loss: 12.1489 - mean_absolute_error: 12.1489
# Epoch 92/122
#  - 0s - loss: 12.1585 - mean_absolute_error: 12.1585
# Epoch 93/122
#  - 0s - loss: 12.1382 - mean_absolute_error: 12.1382
# Epoch 94/122
#  - 0s - loss: 12.1513 - mean_absolute_error: 12.1513
# Epoch 95/122
#  - 0s - loss: 12.1333 - mean_absolute_error: 12.1333
# Epoch 96/122
#  - 0s - loss: 12.1243 - mean_absolute_error: 12.1243
# Epoch 97/122
#  - 0s - loss: 12.1209 - mean_absolute_error: 12.1209
# Epoch 98/122
#  - 0s - loss: 12.1013 - mean_absolute_error: 12.1013
# Epoch 99/122
#  - 0s - loss: 12.1082 - mean_absolute_error: 12.1082
# Epoch 100/122
#  - 0s - loss: 12.0934 - mean_absolute_error: 12.0934
# Epoch 101/122
#  - 0s - loss: 12.0885 - mean_absolute_error: 12.0885
# Epoch 102/122
#  - 0s - loss: 12.0924 - mean_absolute_error: 12.0924
# Epoch 103/122
#  - 0s - loss: 12.1018 - mean_absolute_error: 12.1018
# Epoch 104/122
#  - 0s - loss: 12.0826 - mean_absolute_error: 12.0826
# Epoch 105/122
#  - 0s - loss: 12.0773 - mean_absolute_error: 12.0773
# Epoch 106/122
#  - 0s - loss: 12.0619 - mean_absolute_error: 12.0619
# Epoch 107/122
#  - 0s - loss: 12.0675 - mean_absolute_error: 12.0675
# Epoch 108/122
#  - 0s - loss: 12.0519 - mean_absolute_error: 12.0519
# Epoch 109/122
#  - 0s - loss: 12.0700 - mean_absolute_error: 12.0700
# Epoch 110/122
#  - 0s - loss: 12.0425 - mean_absolute_error: 12.0425
# Epoch 111/122
#  - 0s - loss: 12.0503 - mean_absolute_error: 12.0503
# Epoch 112/122
#  - 0s - loss: 12.0297 - mean_absolute_error: 12.0297
# Epoch 113/122
#  - 0s - loss: 12.0294 - mean_absolute_error: 12.0294
# Epoch 114/122
#  - 0s - loss: 12.0255 - mean_absolute_error: 12.0255
# Epoch 115/122
#  - 0s - loss: 12.0237 - mean_absolute_error: 12.0237
# Epoch 116/122
#  - 0s - loss: 12.0232 - mean_absolute_error: 12.0232
# Epoch 117/122
#  - 0s - loss: 11.9923 - mean_absolute_error: 11.9923
# Epoch 118/122
#  - 0s - loss: 12.0048 - mean_absolute_error: 12.0048
# Epoch 119/122
#  - 0s - loss: 11.9891 - mean_absolute_error: 11.9891
# Epoch 120/122
#  - 0s - loss: 11.9717 - mean_absolute_error: 11.9717
# Epoch 121/122
#  - 0s - loss: 11.9951 - mean_absolute_error: 11.9951
# Epoch 122/122
#  - 0s - loss: 11.9626 - mean_absolute_error: 11.9626
# 29
# 12.690922178627321

# %%
# compare samples
stat, p = normaltest(L_nn_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05 #Significance level set at 5%
if p > alpha:
	print('The samples from the  Bayesian search tuned Neural Networks follow a Gaussian distribution (fail to reject H0)')
else:
	print('The samples from the  Bayeasian search tuned Neural Networks does not follow a Gaussian distribution (reject H0)')
# Out:
# Statistics=0.191, p=0.909
# The samples from the  Bayesian search tuned Neural Networks follow a Gaussian distribution (fail to reject H0)

# %%
# TESTING THE SIGNIFICNANCE OF THE NON HYPER PARAMETER TUNED RESULTS WITH THAT OF THE TUNED RESULTS:

# %%
# compare samples
stat, p = wilcoxon(L_nn, L_nn_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Non Hyper parameter tuned and Grid Search tuned Neural networks are same (fail to reject H0)')
else:
	print('The means results of Non Hyper parameter tuned and Grid Search tuned Neural networks are different (reject H0)')
# Out:
# Statistics=146.000, p=0.075
# The means results of Non Hyper parameter tuned and Grid Search tuned Neural networks are same (fail to reject H0)

# %%
# compare samples
stat, p = wilcoxon(L_nn, L_nn_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Non Hyper parameter tuned and Random Search tuned Neural networks are same (fail to reject H0)')
else:
	print('The means results of Non Hyper parameter tuned and Random Search tuned Neural networks are different (reject H0)')
# Out:
# Statistics=0.000, p=0.000
# The means results of Non Hyper parameter tuned and Random Search tuned Neural networks are different (reject H0)

# %%
# compare samples
stat, p = wilcoxon(L_nn, L_nn_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Non Hyper parameter tuned and Bayesian Search tuned Neural networks are same (fail to reject H0)')
else:
	print('The means results of Non Hyper parameter tuned and Bayesian Search tuned Neural networks are different (reject H0)')
# Out:
# Statistics=0.000, p=0.000
# The means results of Non Hyper parameter tuned and Bayesian Search tuned Neural networks are different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_nn_gs, L_nn_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Grid Search tuned and Random Search tuned Neural networks are same (fail to reject H0)')
else:
	print('The means results of Grid Search tuned and Random Search tuned Neural networks are different (reject H0)')
# Out:
# Statistics=18.195, p=0.000
# The means results of Grid Search tuned and Random Search tuned Neural networks are different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_nn_bs, L_nn_rs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Bayesian Search tuned and Random Search tuned Neural networks are same (fail to reject H0)')
else:
	print('The means results of Bayesian Search tuned and Random Search tuned Neural networks are different (reject H0)')
# Out:
# Statistics=-7.357, p=0.000
# The means results of Bayesian Search tuned and Random Search tuned Neural networks are different (reject H0)

# %%
# compare samples
stat, p = ttest_rel(L_nn_gs, L_nn_bs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Bayesian Search tuned and Random Search tuned Neural networks are same (fail to reject H0)')
else:
	print('The means results of Bayesian Search tuned and Random Search tuned Neural networks are different (reject H0)')
# Out:
# Statistics=22.362, p=0.000
# The means results of Bayesian Search tuned and Random Search tuned Neural networks are different (reject H0)

# %%
#COMAPRING THE TWO BEST HYPER PARAMETER TUNED ALGORITHMS TO SEE IF THE RESULTS ARE SIGNIFICANTLY DIFFERENT

# %%
# compare samples
stat, p = ttest_rel(L_nn_bs, L_randomforest_gs)
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
	print('The means results of Bayesian Search tuned Neural Network and Grid Search tuned  Random Forests are same (fail to reject H0)')
else:
	print('The means results of Bayesian Search tuned Neural Network and Grid Search tuned Random Forests are different (reject H0)')
# Out:
# Statistics=4.628, p=0.000
# The means results of Bayesian Search tuned Neural Network and Grid Search tuned Random Forests are different (reject H0)
